# %%
import os
import json

# %%
def get_files(path: str):
    """
    Get all file names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of file names.
    """
    try:
        return [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def clean_json_file(input_file_path, output_dir):
    """
    Cleans a JSON text file by removing the first and last lines (```json and ```) 
    and saves the cleaned content to the same filename in a different directory.

    :param input_file_path: Path to the original file.
    :param output_dir: Directory where the cleaned file will be saved.
    """
    try:
        # Read the file content
        with open(input_file_path, "r", encoding="utf-8") as file:
            lines = file.readlines()

        # Ensure file has at least 3 lines to remove first & last safely
        if len(lines) < 3:
            print(f"Skipping {os.path.basename(input_file_path)}: Content does not have enough lines.")
            return

        # Check if the first line contains ```json and last line contains ```
        if not lines[0].strip().startswith("```json") or not lines[-1].strip() == "```":
            print(f"Skipping {os.path.basename(input_file_path)}: Content does not start/end with JSON format.")
            return

        # Remove first and last lines
        cleaned_lines = lines[1:-1]

        # Ensure output directory exists
        os.makedirs(output_dir, exist_ok=True)

        # Extract filename from input path
        filename = os.path.basename(input_file_path)
        output_file_path = os.path.join(output_dir, filename)

        # Validate if cleaned content is still JSON
        cleaned_text = "".join(cleaned_lines).strip()
        try:
            json.loads(cleaned_text)  # Check if valid JSON
        except json.JSONDecodeError:
            print(f"Skipping {os.path.basename(input_file_path)}: Extracted content is not valid JSON.")
            return

        # Write cleaned content to new file
        with open(output_file_path, "w", encoding="utf-8") as file:
            file.writelines(cleaned_lines)

        print(f"✅ Successfully cleaned and saved: {output_file_path}")

    except Exception as e:
        print(f"❌ Error processing {input_file_path}: {e}")

# %%
file_path = r"C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_standalone"

# %%
file_name_arr = get_files(file_path)
print(len(file_name_arr))
print(file_name_arr)
# Out:
# 71
# ['app.groupcal.www.txt', 'apps.r.compass.txt', 'ch.publisheria.bring.txt', 'com.albuquerquedesign.adanalog013.txt', 'com.anghami.txt', 'com.audible.application.txt', 'com.c25k.txt', 'com.cardiogram.v1.txt', 'com.centr.app.txt', 'com.codverter.wearflashlight.txt', 'com.contorra.golfpad.txt', 'com.customsolutions.android.alexa.txt', 'com.dungelin.heartrate.txt', 'com.exovoid.weather.app.txt', 'com.fish4fun.mycards.txt', 'com.fitbod.fitbod.txt', 'com.fitiv.fitivapplication.txt', 'com.fiton.android.txt', 'com.flightradar24free.txt', 'com.fourtechnologies.mynetdiary.ad.txt', 'com.fsoydan.howistheweather.txt', 'com.funnmedia.waterminder.txt', 'com.furyapps.scoreswidget.txt', 'com.GD.Minimal.txt', 'com.golfbuddy.smartcaddie.txt', 'com.google.android.apps.maps.txt', 'com.google.android.contacts.txt', 'com.google.android.deskclock.txt', 'com.google.android.keep.txt', 'com.grint.thegrint.pro.txt', 'com.hrd.iam.txt', 'com.hrd.motivation.txt', 'com.imperon.android.gymapp.txt', 'com.ingravity.woo.txt', 'com.jee.calc.txt', 'com.JiaRen.LCDsimple.txt', 'com.juventus.app.android.txt', 'com.krisdb.wearcasts.txt', 'com.lemonsystems.cipadidas.txt', 'com.luxsank.analogclassic.txt', 'com.mobilefootie.wc2010.txt', 'com.mysticmobileapps.gps.area.calculator.txt', 'com.mysticmobileapps.gps.location.txt', 'com.newreading.goodfm.txt', 'com.northcube.sleepcycle.txt', 'com.northpark.drinkwater.txt', 'com.padelem.padelem.txt', 'com.recreative.recreative01.txt', 'com.rideonewheel.onewheel.txt', 'com.shazam.android.txt', 'com.shotzoom.golfshot2.txt', 'com.soundcloud.android.txt', 'com.spotify.music.txt', 'com.todoist.txt', 'com.vpar.android.txt', 'com.watchfacedesigns.Vanish.txt', 'com.watchfacestudio.minimalblack1.txt', 'com.wikiloc.wikilocandroid.txt', 'com.windyty.android.txt', 'de.komoot.android.txt', 'de.michelinside.glucodatahandler.txt', 'grit.storytel.app.txt', 'me.twentyfour.www.txt', 'nl.slisky.stopwatch.txt', 'qubin.de.wearmedia.txt', 'se.perigee.android.seven.txt', 'secureauth.android.token.txt', 'time.flies.nebula.txt', 'todolist.scheduleplanner.dailyplanner.todo.reminders.txt', 'walking.tracker.app.pedometer.txt', 'xyz.klinker.messenger.txt']

# %%
input_dir = r"C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app"
output_dir = r"C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json"

# %%
for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):
        input_file_path = os.path.join(input_dir, filename)
        clean_json_file(input_file_path, output_dir)
# Out:
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\adarshurs.android.vlcmobileremote.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.EnForma.fitcoapp.net.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.entrenamientogenetico.android.fitcoapp.net.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.f4square.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.fit.meet.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.growwithjo.diet.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.krowdfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.LomasGym.fitcoapp.net.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.mfit.personal.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.midfit.train.own.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.mlfitness.diet.workout.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.MOVE.fitcoapp.net.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\app.weightfit.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\appnativo.navysportcenter.fitcoapp.net.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\at.radioplayer.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\biz.mobidev.mdplayer.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\blacknote.amazfitmaster.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.fitastic.appaluno.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.mufitness.station.aluno.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.personalfitapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.tecnofit.mobileapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.w12.bluefit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.w12.heyfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.w12.redfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\br.com.w12.skyfitapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\calorie.pedo.fitbit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\club.nfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\club.skllzz.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\clubwise.com.fitsense.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\cn.fitdays.fitdays.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\co.macrofit.macroFit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\coach.zing.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.abhijitvalluri.android.fitnotifications.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.abyx.fit.connect.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.acmeaom.android.myradar.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.acquasys.contrack.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.actofitSmartScale.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.adi.remote.phone.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.aheqab.salahwear.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.aircanada.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.airofit_app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.alex.crockfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.alphapod.fitsifu.jordanyeoh.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.amdroidalarmclock.amdroid.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.anytimefitness.anytimeworkouts.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.anytimefitness.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.anytimefitness.userapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.apep.fitapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.app.cy.GsFiten.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.app.ufit365.forza.gym.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.app.ufit365.gimnasio.zeus.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.app.ufit365.world.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.appfour.wearvideos.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.appyfurious.getfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.arisdot.gymfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.arketa.jamiegfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.artkitch.alexfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.atlaswearables.ionic.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.attspaceventures.fitfit_client.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.aukey.fit.pro.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.avena.avenafit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.bandlab.bandlab.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.basemsalloum.goodfitness.goodfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.basicfit.trainingApp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.bbfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.beatxp.dafit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.bejaofit.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.benda.fitpro.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.bendingspoons.thirtydayfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.best.fit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com.bhphoto.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\com
txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.cult.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.cure.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.hplus.hplusfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.ketoindia.ketoindia.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.mude.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.remotecoach.fitin.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.remotecoach.kaylag.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.trainiac.android.client.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fit.withu.flutter.withu.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitapp.fittofit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitflex.workout.fitness.weight.gym.fat.training.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitness.app.women.female.workout.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitness.com.senior.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitness.ddx.ddx_fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitness.fitprosport.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitness.home.workout.weight.loss.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\fitnesscoach.workoutplanner.weightloss.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\foodtracker.loseweight.caloriecounter.diet.myfitnesspal.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\home.fitness.challenge.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\homeworkout.fitness.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\homeworkoutapp.homeworkout.fitness.workout.loseweight.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ie.zappy.fennec.barbellqueenfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\il.co.freefit.freefit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\il.co.offline.profit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\in.codeseed.audify.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\in.fitnesspal.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\interactiveshift.com.trailswear.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\io.befitter.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\io.fitness.club.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\it.evolutionfit.evolutionfit.club.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\it.softwarepalestre.newfitnessclub.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\it.tripix.buddyfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\je.fit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\jp.co.yahoo.android.vassist.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\jp.joyfit.joyfitappandroid.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\kr.co.everyfit.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\kr.co.openit.openrider.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\kr.fitt.fmes.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\kz.maestrosultan.fitjournal.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\loseweight.weightloss.workout.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\maxcom.toolbox.altimeter.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\me.cofit.ironman.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\musclemonster.fitness.workout.home.gym.planner.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.ddns.axiiim.wearphonelock.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.familo.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.homeip.thkerkmann.einkaufsliste.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.kosev.dicing.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.kurdsofts.fitnesskar.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.peater.fitlovers.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.sarmady.akhbarak.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.workout.lose.weight.fitness.fit.coach.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\net.workoutinc.seven_7minutesfitness_forwomen.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nl.birdssoftware.mondaymorning.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nl.dominos.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nl.fitforfree.serviceapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nl.nefit.easy.main.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nz.co.madfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\nz.co.telecom.smartphone.android.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\oms.mmc.fortunetelling.gmpay.almanac2.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.eson.getfit3.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.fitrunner.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.moffitt.brandedpatientportal.play.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.obduro.kentekeninfo.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.sombrenuit.dk.redfeed.free.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\org.uguess.android.sysinfo.wear.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ott.beatboxingfitnessworkouts.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ott.transformyoufitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\pedometer.stepcounter.fitnessapp.stepstracker.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\pl.efitness.mobile.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\pl.fit.world.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\pl.tweeba.mobile.learning.english.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\rebel.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\revox.voxnet.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ro.fitgym.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\rs.abstract.fitpass.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\rs.fastfit.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\rs.nonstopfitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ru.disav.befit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\ru.starline.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\scope.fitnessfirstmena.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\se.matlistan.free.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\se.perigee.android.seven.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\senior.fitness.exercises.elderly.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\softin.my.fast.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\starshipproduct.perifitmainapp.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\steptracker.healthandfitness.walkingtracker.pedometer.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\sweatybetty.com.fitness.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\tarlin.fitness.loseweight.belly.fem.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\tk.deuchnord.phonejuicechecker.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\today.upfit.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\tr.com.fitwell.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\uk.co.fitness4less.app.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\uk.me.andre.dicionarioportugues.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\verv.health.fitness.workout.weight.loss.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\walking.tracker.app.pedometer.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\women.workout.female.fitness.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\workoutforwomen.femalefitness.womenworkout.loseweight.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\xyz.micrusa.fitnesscalc.txt
# ✅ Successfully cleaned and saved: C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app_json\yogaworkouts.dailyyoga.yogafitness.txt
