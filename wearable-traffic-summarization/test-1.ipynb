# %%
from langchain.prompts import PromptTemplate
from langchain.document_loaders import DirectoryLoader, TextLoader
import json
import re

def detect_sensitive_data(traffic_data: str):
    """
    Analyze Android app network traffic to detect sensitive data leaks.
    
    :param traffic_data: Raw traffic data (JSON or text).
    :return: A formatted prompt for an LLM to analyze the data.
    """
    # Escape curly braces to prevent formatting errors
    escaped_traffic_data = traffic_data.replace("{", "{{").replace("}", "}}").replace("\"", "\\\"")

    sensitive_data_prompt = PromptTemplate(
        input_variables=["traffic_data"],
        template="""
        You are a cybersecurity expert specializing in **privacy and data security**. 
        Your task is to analyze the outgoing network traffic of an Android application 
        and identify any **sensitive information** that could pose privacy risks.

        ### **Given Traffic Data:**
        ```
        {traffic_data}
        ```

        ### **Your Task:**
        1. Identify any **sensitive data** being transmitted, including but not limited to:
           - **Personal Identifiable Information (PII)**: Email, phone number, IP address, user credentials.
           - **Device Information**: Model, OS version, manufacturer, fingerprint, MCC/MNC.
           - **Authentication Data**: Firebase authentication tokens, API keys, session IDs.
           - **Tracking & Advertising Data**: Firebase installation ID, advertising ID, package name.
           - **Location & Network Data**: Country, locale, timezone, network connection type.
           - **Any other potentially sensitive data** that could lead to privacy risks.

        2. Evaluate the potential **privacy risks** associated with each piece of sensitive data.

        3. Provide **recommendations** on how to mitigate privacy concerns, such as encryption, anonymization, or restricting unnecessary data transmission.

        ---

        ### **Expected JSON Output Format:**
        ```json
        {{
            "sensitive_data_detected": [
                {{
                    "type": "Device ID",
                    "value": "...",
                    "risk": "This can be used to track users across applications."
                }},
                {{
                    "type": "Firebase Authentication Token",
                    "value": "...",
                    "risk": "May allow unauthorized access if leaked."
                }}
            ],
            "recommendations": "The app should encrypt this data before transmission or avoid sending it if unnecessary."
        }}
        ```
        
        Please analyze the given traffic data and return a **structured JSON output** as described.
        """
    )
    
    formatted_prompt = sensitive_data_prompt.format(traffic_data=escaped_traffic_data)
    return formatted_prompt

def load_traffic_data(directory_path: str):
    """
    Load traffic logs from the specified directory.
    
    :param directory_path: Path to the directory containing traffic log files.
    :return: A list of loaded traffic data as strings.
    """
    loader = DirectoryLoader(directory_path, glob="**/*.txt", loader_cls=TextLoader)
    docs = loader.load()
    
    traffic_logs = []
    for doc in docs:
        content = doc.page_content.strip()
        # Check if the content is JSON
        try:
            traffic_json = json.loads(content)
            traffic_logs.append(json.dumps(traffic_json, indent=2))
        except json.JSONDecodeError:
            # If not JSON, store as raw text
            traffic_logs.append(content)
    
    return traffic_logs

# Example usage
directory_path = r"E:\\wearable-capture-traffic\\wearable-standalone\\todolist.scheduleplanner.dailyplanner.todo.reminders"
traffic_data_list = load_traffic_data(directory_path)
for traffic_data in traffic_data_list:
    print("===========================================================")
    print("traffic_data: ", traffic_data)
    formatted_prompt = detect_sensitive_data(traffic_data)
    print("formatted_prompt: ", formatted_prompt)
#     break
# Out:
# ===========================================================
# traffic_data:  {
#   "logRequest": [
#     {
#       "requestTimeMs": 1739052287279,
#       "requestUptimeMs": 113765973,
#       "clientInfo": {
#         "clientType": "ANDROID_FIREBASE",
#         "androidClientInfo": {
#           "sdkVersion": 31,
#           "model": "SM-M515F",
#           "hardware": "qcom",
#           "device": "m51",
#           "product": "m51nsxx",
#           "osBuild": "SP1A.210812.016",
#           "manufacturer": "samsung",
#           "fingerprint": "samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys",
#           "locale": "en",
#           "country": "US",
#           "mccMnc": "45201",
#           "applicationBuild": "1000253"
#         }
#       },
#       "logSourceName": "GDT_CLIENT_METRICS",
#       "logEvent": [
#         {
#           "eventTimeMs": 1739052287277,
#           "eventUptimeMs": 113765971,
#           "sourceExtension": "Cg4IoorgvM4yEK2K4LzOMhoLCgkIgMADEICAgAUiNHRvZG9saXN0LnNjaGVkdWxlcGxhbm5lci5kYWlseXBsYW5uZXIudG9kby5yZW1pbmRlcnM=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         }
#       ],
#       "qosTier": "DEFAULT"
#     },
#     {
#       "requestTimeMs": 1739052287279,
#       "requestUptimeMs": 113765973,
#       "clientInfo": {
#         "clientType": "ANDROID_FIREBASE",
#         "androidClientInfo": {
#           "sdkVersion": 31,
#           "model": "SM-M515F",
#           "hardware": "qcom",
#           "device": "m51",
#           "product": "m51nsxx",
#           "osBuild": "SP1A.210812.016",
#           "manufacturer": "samsung",
#           "fingerprint": "samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys",
#           "locale": "en",
#           "country": "US",
#           "mccMnc": "45201",
#           "applicationBuild": "1000253"
#         }
#       },
#       "logSourceName": "FIREBASE_APPQUALITY_SESSION",
#       "logEvent": [
#         {
#           "eventTimeMs": 1739052255364,
#           "eventUptimeMs": 113734059,
#           "sourceExtensionJsonProto3": "{\"eventType\":1,\"sessionData\":{\"sessionId\":\"8554fe5ea5c34670a29671a8a45f052c\",\"firstSessionId\":\"8554fe5ea5c34670a29671a8a45f052c\",\"sessionIndex\":0,\"eventTimestampUs\":1739052255350000,\"dataCollectionStatus\":{\"performance\":1,\"crashlytics\":2,\"sessionSamplingRate\":1.0},\"firebaseInstallationId\":\"eZPXrzViQjKRpfs0-jvOxB\",\"firebaseAuthenticationToken\":\"eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJhcHBJZCI6IjE6NTExMjQxOTA0MTg0OmFuZHJvaWQ6NDVlNDViYmQ4Y2RkOGI0YzFlMDZjZCIsImV4cCI6MTczOTY1NzA1NSwiZmlkIjoiZVpQWHJ6VmlRaktScGZzMC1qdk94QiIsInByb2plY3ROdW1iZXIiOjUxMTI0MTkwNDE4NH0.AB2LPV8wRAIgQVX-Opgn4CIlpp1GzfjaD8zoyk0w_g56ngyUw1EF74ACIFOY6xE7A625XriuXkuSjQti8UUAJmOZ4yS3VNmfxprV\"},\"applicationInfo\":{\"appId\":\"1:511241904184:android:45e45bbd8cdd8b4c1e06cd\",\"deviceModel\":\"SM-M515F\",\"sessionSdkVersion\":\"2.0.5\",\"osVersion\":\"12\",\"logEnvironment\":3,\"androidAppInfo\":{\"packageName\":\"todolist.scheduleplanner.dailyplanner.todo.reminders\",\"versionName\":\"1.02.69.1218\",\"appBuildVersion\":\"1000253\",\"deviceManufacturer\":\"samsung\",\"currentProcessDetails\":{\"processName\":\"todolist.scheduleplanner.dailyplanner.todo.reminders\",\"pid\":17715,\"importance\":100,\"defaultProcess\":true},\"appProcessDetails\":[{\"processName\":\"todolist.scheduleplanner.dailyplanner.todo.reminders\",\"pid\":17715,\"importance\":100,\"defaultProcess\":true}]}}}",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         }
#       ],
#       "qosTier": "DEFAULT"
#     }
#   ]
# }
# formatted_prompt:
#         You are a cybersecurity expert specializing in **privacy and data security**.
#         Your task is to analyze the outgoing network traffic of an Android application
#         and identify any **sensitive information** that could pose privacy risks.
#
#         ### **Given Traffic Data:**
#         ```
#         {{
#   \"logRequest\": [
#     {{
#       \"requestTimeMs\": 1739052287279,
#       \"requestUptimeMs\": 113765973,
#       \"clientInfo\": {{
#         \"clientType\": \"ANDROID_FIREBASE\",
#         \"androidClientInfo\": {{
#           \"sdkVersion\": 31,
#           \"model\": \"SM-M515F\",
#           \"hardware\": \"qcom\",
#           \"device\": \"m51\",
#           \"product\": \"m51nsxx\",
#           \"osBuild\": \"SP1A.210812.016\",
#           \"manufacturer\": \"samsung\",
#           \"fingerprint\": \"samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys\",
#           \"locale\": \"en\",
#           \"country\": \"US\",
#           \"mccMnc\": \"45201\",
#           \"applicationBuild\": \"1000253\"
#         }}
#       }},
#       \"logSourceName\": \"GDT_CLIENT_METRICS\",
#       \"logEvent\": [
#         {{
#           \"eventTimeMs\": 1739052287277,
#           \"eventUptimeMs\": 113765971,
#           \"sourceExtension\": \"Cg4IoorgvM4yEK2K4LzOMhoLCgkIgMADEICAgAUiNHRvZG9saXN0LnNjaGVkdWxlcGxhbm5lci5kYWlseXBsYW5uZXIudG9kby5yZW1pbmRlcnM=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }}
#       ],
#       \"qosTier\": \"DEFAULT\"
#     }},
#     {{
#       \"requestTimeMs\": 1739052287279,
#       \"requestUptimeMs\": 113765973,
#       \"clientInfo\": {{
#         \"clientType\": \"ANDROID_FIREBASE\",
#         \"androidClientInfo\": {{
#           \"sdkVersion\": 31,
#           \"model\": \"SM-M515F\",
#           \"hardware\": \"qcom\",
#           \"device\": \"m51\",
#           \"product\": \"m51nsxx\",
#           \"osBuild\": \"SP1A.210812.016\",
#           \"manufacturer\": \"samsung\",
#           \"fingerprint\": \"samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys\",
#           \"locale\": \"en\",
#           \"country\": \"US\",
#           \"mccMnc\": \"45201\",
#           \"applicationBuild\": \"1000253\"
#         }}
#       }},
#       \"logSourceName\": \"FIREBASE_APPQUALITY_SESSION\",
#       \"logEvent\": [
#         {{
#           \"eventTimeMs\": 1739052255364,
#           \"eventUptimeMs\": 113734059,
#           \"sourceExtensionJsonProto3\": \"{{\\"eventType\\":1,\\"sessionData\\":{{\\"sessionId\\":\\"8554fe5ea5c34670a29671a8a45f052c\\",\\"firstSessionId\\":\\"8554fe5ea5c34670a29671a8a45f052c\\",\\"sessionIndex\\":0,\\"eventTimestampUs\\":1739052255350000,\\"dataCollectionStatus\\":{{\\"performance\\":1,\\"crashlytics\\":2,\\"sessionSamplingRate\\":1.0}},\\"firebaseInstallationId\\":\\"eZPXrzViQjKRpfs0-jvOxB\\",\\"firebaseAuthenticationToken\\":\\"eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJhcHBJZCI6IjE6NTExMjQxOTA0MTg0OmFuZHJvaWQ6NDVlNDViYmQ4Y2RkOGI0YzFlMDZjZCIsImV4cCI6MTczOTY1NzA1NSwiZmlkIjoiZVpQWHJ6VmlRaktScGZzMC1qdk94QiIsInByb2plY3ROdW1iZXIiOjUxMTI0MTkwNDE4NH0.AB2LPV8wRAIgQVX-Opgn4CIlpp1GzfjaD8zoyk0w_g56ngyUw1EF74ACIFOY6xE7A625XriuXkuSjQti8UUAJmOZ4yS3VNmfxprV\\"}},\\"applicationInfo\\":{{\\"appId\\":\\"1:511241904184:android:45e45bbd8cdd8b4c1e06cd\\",\\"deviceModel\\":\\"SM-M515F\\",\\"sessionSdkVersion\\":\\"2.0.5\\",\\"osVersion\\":\\"12\\",\\"logEnvironment\\":3,\\"androidAppInfo\\":{{\\"packageName\\":\\"todolist.scheduleplanner.dailyplanner.todo.reminders\\",\\"versionName\\":\\"1.02.69.1218\\",\\"appBuildVersion\\":\\"1000253\\",\\"deviceManufacturer\\":\\"samsung\\",\\"currentProcessDetails\\":{{\\"processName\\":\\"todolist.scheduleplanner.dailyplanner.todo.reminders\\",\\"pid\\":17715,\\"importance\\":100,\\"defaultProcess\\":true}},\\"appProcessDetails\\":[{{\\"processName\\":\\"todolist.scheduleplanner.dailyplanner.todo.reminders\\",\\"pid\\":17715,\\"importance\\":100,\\"defaultProcess\\":true}}]}}}}}}\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }}
#       ],
#       \"qosTier\": \"DEFAULT\"
#     }}
#   ]
# }}
#         ```
#
#         ### **Your Task:**
#         1. Identify any **sensitive data** being transmitted, including but not limited to:
#            - **Personal Identifiable Information (PII)**: Email, phone number, IP address, user credentials.
#            - **Device Information**: Model, OS version, manufacturer, fingerprint, MCC/MNC.
#            - **Authentication Data**: Firebase authentication tokens, API keys, session IDs.
#            - **Tracking & Advertising Data**: Firebase installation ID, advertising ID, package name.
#            - **Location & Network Data**: Country, locale, timezone, network connection type.
#            - **Any other potentially sensitive data** that could lead to privacy risks.
#
#         2. Evaluate the potential **privacy risks** associated with each piece of sensitive data.
#
#         3. Provide **recommendations** on how to mitigate privacy concerns, such as encryption, anonymization, or restricting unnecessary data transmission.
#
#         ---
#
#         ### **Expected JSON Output Format:**
#         ```json
#         {
#             "sensitive_data_detected": [
#                 {
#                     "type": "Device ID",
#                     "value": "...",
#                     "risk": "This can be used to track users across applications."
#                 },
#                 {
#                     "type": "Firebase Authentication Token",
#                     "value": "...",
#                     "risk": "May allow unauthorized access if leaked."
#                 }
#             ],
#             "recommendations": "The app should encrypt this data before transmission or avoid sending it if unnecessary."
#         }
#         ```
#
#         Please analyze the given traffic data and return a **structured JSON output** as described.
#
# ===========================================================
# traffic_data:  {
#   "logRequest": [
#     {
#       "requestTimeMs": 1739052286485,
#       "requestUptimeMs": 113765179,
#       "clientInfo": {
#         "clientType": "ANDROID_FIREBASE",
#         "androidClientInfo": {
#           "sdkVersion": 31,
#           "model": "SM-M515F",
#           "hardware": "qcom",
#           "device": "m51",
#           "product": "m51nsxx",
#           "osBuild": "SP1A.210812.016",
#           "manufacturer": "samsung",
#           "fingerprint": "samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys",
#           "locale": "en",
#           "country": "US",
#           "mccMnc": "45201",
#           "applicationBuild": "1000253"
#         }
#       },
#       "logSourceName": "GDT_CLIENT_METRICS",
#       "logEvent": [
#         {
#           "eventTimeMs": 1739052286481,
#           "eventUptimeMs": 113765175,
#           "sourceExtension": "Cg4I3onevM4yEJCE4LzOMhoLCgkIgOAEEICAgAUiNHRvZG9saXN0LnNjaGVkdWxlcGxhbm5lci5kYWlseXBsYW5uZXIudG9kby5yZW1pbmRlcnM=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         }
#       ],
#       "qosTier": "DEFAULT"
#     },
#     {
#       "requestTimeMs": 1739052286486,
#       "requestUptimeMs": 113765180,
#       "clientInfo": {
#         "clientType": "ANDROID_FIREBASE",
#         "androidClientInfo": {
#           "sdkVersion": 31,
#           "model": "SM-M515F",
#           "hardware": "qcom",
#           "device": "m51",
#           "product": "m51nsxx",
#           "osBuild": "SP1A.210812.016",
#           "manufacturer": "samsung",
#           "fingerprint": "samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys",
#           "locale": "en",
#           "country": "US",
#           "mccMnc": "45201",
#           "applicationBuild": "1000253"
#         }
#       },
#       "logSourceName": "PLAY_BILLING_LIBRARY",
#       "logEvent": [
#         {
#           "eventTimeMs": 1739052255066,
#           "eventUptimeMs": 113733760,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgIIBQ==",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052255137,
#           "eventUptimeMs": 113733831,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052255138,
#           "eventUptimeMs": 113733832,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052260790,
#           "eventUptimeMs": 113739484,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052260791,
#           "eventUptimeMs": 113739485,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052260922,
#           "eventUptimeMs": 113739616,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052260924,
#           "eventUptimeMs": 113739618,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052261122,
#           "eventUptimeMs": 113739816,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052261126,
#           "eventUptimeMs": 113739820,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052261143,
#           "eventUptimeMs": 113739837,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052261144,
#           "eventUptimeMs": 113739838,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052262909,
#           "eventUptimeMs": 113741604,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052265599,
#           "eventUptimeMs": 113744293,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052268510,
#           "eventUptimeMs": 113747204,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzEgoIARIGCAESACAW",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052268536,
#           "eventUptimeMs": 113747230,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052268537,
#           "eventUptimeMs": 113747231,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269023,
#           "eventUptimeMs": 113747717,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269023,
#           "eventUptimeMs": 113747717,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269282,
#           "eventUptimeMs": 113747976,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269284,
#           "eventUptimeMs": 113747978,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269285,
#           "eventUptimeMs": 113747979,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         },
#         {
#           "eventTimeMs": 1739052269286,
#           "eventUptimeMs": 113747980,
#           "sourceExtension": "Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=",
#           "timezoneOffsetSeconds": 3600,
#           "networkConnectionInfo": {
#             "networkType": "WIFI"
#           }
#         }
#       ],
#       "qosTier": "DEFAULT"
#     }
#   ]
# }
# formatted_prompt:
#         You are a cybersecurity expert specializing in **privacy and data security**.
#         Your task is to analyze the outgoing network traffic of an Android application
#         and identify any **sensitive information** that could pose privacy risks.
#
#         ### **Given Traffic Data:**
#         ```
#         {{
#   \"logRequest\": [
#     {{
#       \"requestTimeMs\": 1739052286485,
#       \"requestUptimeMs\": 113765179,
#       \"clientInfo\": {{
#         \"clientType\": \"ANDROID_FIREBASE\",
#         \"androidClientInfo\": {{
#           \"sdkVersion\": 31,
#           \"model\": \"SM-M515F\",
#           \"hardware\": \"qcom\",
#           \"device\": \"m51\",
#           \"product\": \"m51nsxx\",
#           \"osBuild\": \"SP1A.210812.016\",
#           \"manufacturer\": \"samsung\",
#           \"fingerprint\": \"samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys\",
#           \"locale\": \"en\",
#           \"country\": \"US\",
#           \"mccMnc\": \"45201\",
#           \"applicationBuild\": \"1000253\"
#         }}
#       }},
#       \"logSourceName\": \"GDT_CLIENT_METRICS\",
#       \"logEvent\": [
#         {{
#           \"eventTimeMs\": 1739052286481,
#           \"eventUptimeMs\": 113765175,
#           \"sourceExtension\": \"Cg4I3onevM4yEJCE4LzOMhoLCgkIgOAEEICAgAUiNHRvZG9saXN0LnNjaGVkdWxlcGxhbm5lci5kYWlseXBsYW5uZXIudG9kby5yZW1pbmRlcnM=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }}
#       ],
#       \"qosTier\": \"DEFAULT\"
#     }},
#     {{
#       \"requestTimeMs\": 1739052286486,
#       \"requestUptimeMs\": 113765180,
#       \"clientInfo\": {{
#         \"clientType\": \"ANDROID_FIREBASE\",
#         \"androidClientInfo\": {{
#           \"sdkVersion\": 31,
#           \"model\": \"SM-M515F\",
#           \"hardware\": \"qcom\",
#           \"device\": \"m51\",
#           \"product\": \"m51nsxx\",
#           \"osBuild\": \"SP1A.210812.016\",
#           \"manufacturer\": \"samsung\",
#           \"fingerprint\": \"samsung/m51nsxx/m51:12/SP1A.210812.016/M515FXXS4DWA3:user/release-keys\",
#           \"locale\": \"en\",
#           \"country\": \"US\",
#           \"mccMnc\": \"45201\",
#           \"applicationBuild\": \"1000253\"
#         }}
#       }},
#       \"logSourceName\": \"PLAY_BILLING_LIBRARY\",
#       \"logEvent\": [
#         {{
#           \"eventTimeMs\": 1739052255066,
#           \"eventUptimeMs\": 113733760,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgIIBQ==\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052255137,
#           \"eventUptimeMs\": 113733831,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052255138,
#           \"eventUptimeMs\": 113733832,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052260790,
#           \"eventUptimeMs\": 113739484,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052260791,
#           \"eventUptimeMs\": 113739485,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052260922,
#           \"eventUptimeMs\": 113739616,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052260924,
#           \"eventUptimeMs\": 113739618,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052261122,
#           \"eventUptimeMs\": 113739816,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052261126,
#           \"eventUptimeMs\": 113739820,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052261143,
#           \"eventUptimeMs\": 113739837,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052261144,
#           \"eventUptimeMs\": 113739838,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052262909,
#           \"eventUptimeMs\": 113741604,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052265599,
#           \"eventUptimeMs\": 113744293,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052268510,
#           \"eventUptimeMs\": 113747204,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzEgoIARIGCAESACAW\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052268536,
#           \"eventUptimeMs\": 113747230,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052268537,
#           \"eventUptimeMs\": 113747231,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269023,
#           \"eventUptimeMs\": 113747717,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269023,
#           \"eventUptimeMs\": 113747717,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269282,
#           \"eventUptimeMs\": 113747976,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269284,
#           \"eventUptimeMs\": 113747978,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269285,
#           \"eventUptimeMs\": 113747979,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }},
#         {{
#           \"eventTimeMs\": 1739052269286,
#           \"eventUptimeMs\": 113747980,
#           \"sourceExtension\": \"Cj0KBTYuMC4xEjR0b2RvbGlzdC5zY2hlZHVsZXBsYW5uZXIuZGFpbHlwbGFubmVyLnRvZG8ucmVtaW5kZXJzGgYIBBICCAk=\",
#           \"timezoneOffsetSeconds\": 3600,
#           \"networkConnectionInfo\": {{
#             \"networkType\": \"WIFI\"
#           }}
#         }}
#       ],
#       \"qosTier\": \"DEFAULT\"
#     }}
#   ]
# }}
#         ```
#
#         ### **Your Task:**
#         1. Identify any **sensitive data** being transmitted, including but not limited to:
#            - **Personal Identifiable Information (PII)**: Email, phone number, IP address, user credentials.
#            - **Device Information**: Model, OS version, manufacturer, fingerprint, MCC/MNC.
#            - **Authentication Data**: Firebase authentication tokens, API keys, session IDs.
#            - **Tracking & Advertising Data**: Firebase installation ID, advertising ID, package name.
#            - **Location & Network Data**: Country, locale, timezone, network connection type.
#            - **Any other potentially sensitive data** that could lead to privacy risks.
#
#         2. Evaluate the potential **privacy risks** associated with each piece of sensitive data.
#
#         3. Provide **recommendations** on how to mitigate privacy concerns, such as encryption, anonymization, or restricting unnecessary data transmission.
#
#         ---
#
#         ### **Expected JSON Output Format:**
#         ```json
#         {
#             "sensitive_data_detected": [
#                 {
#                     "type": "Device ID",
#                     "value": "...",
#                     "risk": "This can be used to track users across applications."
#                 },
#                 {
#                     "type": "Firebase Authentication Token",
#                     "value": "...",
#                     "risk": "May allow unauthorized access if leaked."
#                 }
#             ],
#             "recommendations": "The app should encrypt this data before transmission or avoid sending it if unnecessary."
#         }
#         ```
#
#         Please analyze the given traffic data and return a **structured JSON output** as described.
#
# ===========================================================
# traffic_data:  bsamsungjSM-M515F19.35.36Android12en-USVN`0@@45201w(@<?Europe/RomeT   @  	   F'
#
#
#
# QTI;SM7150samsung
# 8x*:
# (2.,a"/:Myp6_wGn54j2hLicJ
#
# msCssDmsA_ATEaPgHYDiHzo5WMWT2zSkVM9jKZ6UOLlIY1WMzPEo7iOdV1R94BnfhR42BHydTXrtu05YTxemPQT6Dzow-x4rpIEoMD2ePKSVgELujY0L2xItIgJZK2ynw5A5KIk5xvodZLICE8fBH1YdiX622065UV3IIgmdlH5-D3CpweTedNMF-1uOabM9AVHfF13XsUHR-FN4ZlyWb1tgaXH8uCNMYJVnCtHu-gZQjLLNUEcQErA3PrQj_GZsqfDcG3N1fyqOZznehgEk19maf6YuPkPxR-INzxIBdwc34Yzhad7pe-myxvmJWpJ4sx2H0Z4VfFJk2tVUVi4oMUCQThINugykEKvVgP4PccxYtFerv9Q7KJoKnEsaiUnb1yzUbkBCTYK-SKruBEL5dMfediUjVPNgXaBRfJSTcDjp2XxdzPNHG670Yr6biCZebB4jXydXFeTpw_MmM-9Q4NQ0ANvPU3PvKgiYA4h_RehX3G6EP88CUjOrxwhth6AP4MXulFgDA851W2xmsMZwD96fHNMohGdyNlT3myShiT8E84A8HhHIZVVsFX7ua3pfiIQsGsz25mGlgTqK0pnpNHF-xCOS9w7gI3ehQ5v07lIAQ:$e4d794f3-d284-4314-8333-40e34d4adf80@HL?BUCQ0jSGgYMLmRMeTE6UaPPXgr!
# Myp6_wGn54j2hLicP"
# formatted_prompt:
#         You are a cybersecurity expert specializing in **privacy and data security**.
#         Your task is to analyze the outgoing network traffic of an Android application
#         and identify any **sensitive information** that could pose privacy risks.
#
#         ### **Given Traffic Data:**
#         ```
#         bsamsungjSM-M515F19.35.36Android12en-USVN`0@@45201w(@<?Europe/RomeT   @  	   F'
#
#
#
# QTI;SM7150samsung
# 8x*:
# (2.,a\"/:Myp6_wGn54j2hLicJ
#
# msCssDmsA_ATEaPgHYDiHzo5WMWT2zSkVM9jKZ6UOLlIY1WMzPEo7iOdV1R94BnfhR42BHydTXrtu05YTxemPQT6Dzow-x4rpIEoMD2ePKSVgELujY0L2xItIgJZK2ynw5A5KIk5xvodZLICE8fBH1YdiX622065UV3IIgmdlH5-D3CpweTedNMF-1uOabM9AVHfF13XsUHR-FN4ZlyWb1tgaXH8uCNMYJVnCtHu-gZQjLLNUEcQErA3PrQj_GZsqfDcG3N1fyqOZznehgEk19maf6YuPkPxR-INzxIBdwc34Yzhad7pe-myxvmJWpJ4sx2H0Z4VfFJk2tVUVi4oMUCQThINugykEKvVgP4PccxYtFerv9Q7KJoKnEsaiUnb1yzUbkBCTYK-SKruBEL5dMfediUjVPNgXaBRfJSTcDjp2XxdzPNHG670Yr6biCZebB4jXydXFeTpw_MmM-9Q4NQ0ANvPU3PvKgiYA4h_RehX3G6EP88CUjOrxwhth6AP4MXulFgDA851W2xmsMZwD96fHNMohGdyNlT3myShiT8E84A8HhHIZVVsFX7ua3pfiIQsGsz25mGlgTqK0pnpNHF-xCOS9w7gI3ehQ5v07lIAQ:$e4d794f3-d284-4314-8333-40e34d4adf80@HL?BUCQ0jSGgYMLmRMeTE6UaPPXgr!
# Myp6_wGn54j2hLicP\"
#         ```
#
#         ### **Your Task:**
#         1. Identify any **sensitive data** being transmitted, including but not limited to:
#            - **Personal Identifiable Information (PII)**: Email, phone number, IP address, user credentials.
#            - **Device Information**: Model, OS version, manufacturer, fingerprint, MCC/MNC.
#            - **Authentication Data**: Firebase authentication tokens, API keys, session IDs.
#            - **Tracking & Advertising Data**: Firebase installation ID, advertising ID, package name.
#            - **Location & Network Data**: Country, locale, timezone, network connection type.
#            - **Any other potentially sensitive data** that could lead to privacy risks.
#
#         2. Evaluate the potential **privacy risks** associated with each piece of sensitive data.
#
#         3. Provide **recommendations** on how to mitigate privacy concerns, such as encryption, anonymization, or restricting unnecessary data transmission.
#
#         ---
#
#         ### **Expected JSON Output Format:**
#         ```json
#         {
#             "sensitive_data_detected": [
#                 {
#                     "type": "Device ID",
#                     "value": "...",
#                     "risk": "This can be used to track users across applications."
#                 },
#                 {
#                     "type": "Firebase Authentication Token",
#                     "value": "...",
#                     "risk": "May allow unauthorized access if leaked."
#                 }
#             ],
#             "recommendations": "The app should encrypt this data before transmission or avoid sending it if unnecessary."
#         }
#         ```
#
#         Please analyze the given traffic data and return a **structured JSON output** as described.
