# %%
import os

# %%
def get_directories(path: str):
    """
    Get all directory names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of directory names.
    """
    try:
        return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def change_file_extension(directory: str, extension: str):
    """
    Change the extension of all files in a directory to the specified extension.
    
    - If a file has no extension, it adds the target extension.
    - If a file has a different extension, it replaces it with the target extension.
    - If a file already has the target extension, it remains unchanged.

    :param directory: Path to the directory containing files.
    :param extension: New file extension (without the dot, e.g., 'txt').
    """
    # Ensure the extension starts with a dot
    if not extension.startswith("."):
        extension = "." + extension

    # Iterate through files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)

        # Ensure it's a file
        if os.path.isfile(file_path):
            name, ext = os.path.splitext(filename)  # Split name and extension

            # If the file has no extension OR has a different extension, rename it
            if ext == "":  # No extension
                new_file_path = os.path.join(directory, filename + extension)
                os.rename(file_path, new_file_path)
                print(f"Renamed: {filename} -> {filename + extension}")

            elif ext.lower() != extension.lower():  # Different extension
                new_file_path = os.path.join(directory, name + extension)
                os.rename(file_path, new_file_path)
                print(f"Renamed: {filename} -> {name + extension}")

# %%
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"
root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-app"

# %%
array_traffic_directory = get_directories(root_traffic_directory_path)
print(array_traffic_directory)
# Out:
# ['adarshurs.android.vlcmobileremote', 'app.EnForma.fitcoapp.net', 'app.entrenamientogenetico.android.fitcoapp.net', 'app.f4square.fitness', 'app.fit.meet', 'app.growwithjo.diet.fitness', 'app.krowdfit', 'app.LomasGym.fitcoapp.net', 'app.mfit.personal', 'app.midfit.train.own', 'app.mlfitness.diet.workout', 'app.MOVE.fitcoapp.net', 'app.weightfit.android', 'appnativo.navysportcenter.fitcoapp.net', 'at.radioplayer.android', 'biz.mobidev.mdplayer', 'blacknote.amazfitmaster', 'br.com.fitastic.appaluno', 'br.com.mufitness.station.aluno', 'br.com.personalfitapp', 'br.com.tecnofit.mobileapp', 'br.com.w12.bluefit', 'br.com.w12.heyfit', 'br.com.w12.redfit', 'br.com.w12.skyfitapp', 'calorie.pedo.fitbit', 'club.nfit', 'club.skllzz.fitness', 'clubwise.com.fitsense', 'cn.fitdays.fitdays', 'co.macrofit.macroFit', 'coach.zing.fitness', 'com.abhijitvalluri.android.fitnotifications', 'com.abyx.fit.connect', 'com.acmeaom.android.myradar', 'com.acquasys.contrack', 'com.actofitSmartScale', 'com.adi.remote.phone', 'com.aheqab.salahwear', 'com.aircanada', 'com.airofit_app', 'com.alex.crockfit', 'com.alphapod.fitsifu.jordanyeoh', 'com.amdroidalarmclock.amdroid', 'com.anytimefitness.anytimeworkouts', 'com.anytimefitness.app', 'com.anytimefitness.userapp', 'com.apep.fitapp', 'com.app.cy.GsFiten', 'com.app.ufit365.forza.gym', 'com.app.ufit365.gimnasio.zeus', 'com.app.ufit365.world.fitness', 'com.appfour.wearvideos', 'com.appyfurious.getfit', 'com.arisdot.gymfit', 'com.arketa.jamiegfitness', 'com.artkitch.alexfitness', 'com.atlaswearables.ionic', 'com.attspaceventures.fitfit_client', 'com.aukey.fit.pro', 'com.avena.avenafit', 'com.bandlab.bandlab', 'com.basemsalloum.goodfitness.goodfitness', 'com.basicfit.trainingApp', 'com.bbfit', 'com.beatxp.dafit', 'com.bejaofit.app', 'com.benda.fitpro', 'com.bendingspoons.thirtydayfitness', 'com.best.fit', 'com.bhphoto', 'com.bickster.fitbitbandfinder', 'com.biostatusfit.www', 'com.bitafit.client', 'com.biztech.magemobadmin', 'com.blinkfitness.app', 'com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer', 'com.bodyfxfitness', 'com.bottegasol.com.migym.fitnessconnection', 'com.bpfit.bloodpressure.health', 'com.brooklynfitzone.app', 'com.btfit', 'com.caliberfitness.app', 'com.canyon.fit', 'com.cavosmart.wofit', 'com.ccswe.SmokingLog', 'com.chloeting.fitness', 'com.cignahealthbenefits.mobileapp', 'com.cisco.im', 'com.cisco.webex.meetings', 'com.citysportsfitness.android', 'com.cizotech.fit2flaunt', 'com.clearskyapps.fitnessfamily.Run5K', 'com.clearskyapps.fitnessfamily.RunC210K', 'com.cloudgym.hiperfit', 'com.cm.wearintervaltimer', 'com.codebusters.onefit', 'com.cofox.kahunas.ProyectoPapaFit', 'com.cognifit.app', 'com.concapps.benfit', 'com.connect_computer.shesfit', 'com.cpsolutions.contacts', 'com.crossfit.games.android', 'com.crrepa.band.altfit', 'com.crrepa.band.dafit', 'com.crrepa.band.havefit', 'com.cs.booty.fit.buttocks.workout', 'com.czw.freefit', 'com.dailyyoga.fitness.workout', 'com.daniel.apps.wpe', 'com.darebee.fittaplight', 'com.defacto.fit', 'com.dimlix.phrase', 'com.directed.android.smartstart', 'com.directed.android.viper', 'com.dolcegustofree.activity', 'com.dotfit.dotfitweb', 'com.droibit.findwear', 'com.dusiassistant', 'com.earthjumper.myhomefit', 'com.edjing.edjingdjturntable', 'com.eightfit.app', 'com.emilyskyefit.app', 'com.eokoe.smartfitcoach', 'com.equinoxfitness.equinox', 'com.ericfabreu.wearflashcards', 'com.estela', 'com.evlofitness', 'com.evolutionwellness.app.celebrityfitness', 'com.evolutionwellness.app.fitnessfirst', 'com.eztech.fitness', 'com.fbi.fittest', 'com.Female.Fitness.cardio.wellness', 'com.fitapp', 'com.fitapp.timerwodapp', 'com.fitatu.tracker', 'com.fitbit.FitbitMobile', 'com.fitbod.fitbod', 'com.fitelo.android', 'com.fiteniummobile', 'com.fitifyapps.bwcardio', 'com.fitifyapps.bwstretching', 'com.fitifyapps.kettlebell', 'com.fitifyworkouts.bodyweight.workoutapp', 'com.fitiv.fitivapplication', 'com.fitlab.spartan', 'com.fitlapapp', 'com.fitlog.fitlog', 'com.fitmama', 'com. ...

# %%
for i in range(len(array_traffic_directory)):
    print("----------------- Loop-"+str(i)+" -----------------")
    package_name = array_traffic_directory[i]
    print("package_name: ",package_name)
    directory_path = root_traffic_directory_path+"\\"+package_name
    print("directory_path: ",directory_path)
    change_file_extension(directory_path, "txt")
#     break
# Out:
# ----------------- Loop-0 -----------------
# package_name:  adarshurs.android.vlcmobileremote
# directory_path:  E:\wearable-capture-traffic\wearable-app\adarshurs.android.vlcmobileremote
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-1 -----------------
# package_name:  app.EnForma.fitcoapp.net
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.EnForma.fitcoapp.net
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-2 -----------------
# package_name:  app.entrenamientogenetico.android.fitcoapp.net
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.entrenamientogenetico.android.fitcoapp.net
# ----------------- Loop-3 -----------------
# package_name:  app.f4square.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.f4square.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-4 -----------------
# package_name:  app.fit.meet
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-5 -----------------
# package_name:  app.growwithjo.diet.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-6 -----------------
# package_name:  app.krowdfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.krowdfit
# ----------------- Loop-7 -----------------
# package_name:  app.LomasGym.fitcoapp.net
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-8 -----------------
# package_name:  app.mfit.personal
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.mfit.personal
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-9 -----------------
# package_name:  app.midfit.train.own
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.midfit.train.own
# ----------------- Loop-10 -----------------
# package_name:  app.mlfitness.diet.workout
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.mlfitness.diet.workout
# ----------------- Loop-11 -----------------
# package_name:  app.MOVE.fitcoapp.net
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.MOVE.fitcoapp.net
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-12 -----------------
# package_name:  app.weightfit.android
# directory_path:  E:\wearable-capture-traffic\wearable-app\app.weightfit.android
# ----------------- Loop-13 -----------------
# package_name:  appnativo.navysportcenter.fitcoapp.net
# directory_path:  E:\wearable-capture-traffic\wearable-app\appnativo.navysportcenter.fitcoapp.net
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-14 -----------------
# package_name:  at.radioplayer.android
# directory_path:  E:\wearable-capture-traffic\wearable-app\at.radioplayer.android
# ----------------- Loop-15 -----------------
# package_name:  biz.mobidev.mdplayer
# directory_path:  E:\wearable-capture-traffic\wearable-app\biz.mobidev.mdplayer
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-16 -----------------
# package_name:  blacknote.amazfitmaster
# directory_path:  E:\wearable-capture-traffic\wearable-app\blacknote.amazfitmaster
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-17 -----------------
# package_name:  br.com.fitastic.appaluno
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.fitastic.appaluno
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-18 -----------------
# package_name:  br.com.mufitness.station.aluno
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.mufitness.station.aluno
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-19 -----------------
# package_name:  br.com.personalfitapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.personalfitapp
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-20 -----------------
# package_name:  br.com.tecnofit.mobileapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.tecnofit.mobileapp
# ----------------- Loop-21 -----------------
# package_name:  br.com.w12.bluefit
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.bluefit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-22 -----------------
# package_name:  br.com.w12.heyfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-23 -----------------
# package_name:  br.com.w12.redfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-24 -----------------
# package_name:  br.com.w12.skyfitapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.skyfitapp
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-25 -----------------
# package_name:  calorie.pedo.fitbit
# directory_path:  E:\wearable-capture-traffic\wearable-app\calorie.pedo.fitbit
# ----------------- Loop-26 -----------------
# package_name:  club.nfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\club.nfit
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-27 -----------------
# package_name:  club.skllzz.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\club.skllzz.fitness
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-28 -----------------
# package_name:  clubwise.com.fitsense
# directory_path:  E:\wearable-capture-traffic\wearable-app\clubwise.com.fitsense
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-29 -----------------
# package_name:  cn.fitdays.fitdays
# directory_path:  E:\wearable-capture-traffic\wearable-app\cn.fitdays.fitdays
# ----------------- Loop-30 -----------------
# package_name:  co.macrofit.macroFit
# directory_path:  E:\wearable-capture-traffic\wearable-app\co.macrofit.macroFit
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-31 -----------------
# package_name:  coach.zing.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\coach.zing.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-32 -----------------
# package_name:  com.abhijitvalluri.android.fitnotifications
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.abhijitvalluri.android.fitnotifications
# ----------------- Loop-33 -----------------
# package_name:  com.abyx.fit.connect
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.abyx.fit.connect
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-34 -----------------
# package_name:  com.acmeaom.android.myradar
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.acmeaom.android.myradar
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-35 -----------------
# package_name:  com.acquasys.contrack
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.acquasys.contrack
# ----------------- Loop-36 -----------------
# package_name:  com.actofitSmartScale
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-37 -----------------
# package_name:  com.adi.remote.phone
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.adi.remote.phone
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-38 -----------------
# package_name:  com.aheqab.salahwear
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.aheqab.salahwear
# ----------------- Loop-39 -----------------
# package_name:  com.aircanada
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.aircanada
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-40 -----------------
# package_name:  com.airofit_app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.airofit_app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-41 -----------------
# package_name:  com.alex.crockfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.alex.crockfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-42 -----------------
# package_name:  com.alphapod.fitsifu.jordanyeoh
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.alphapod.fitsifu.jordanyeoh
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-43 -----------------
# package_name:  com.amdroidalarmclock.amdroid
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.amdroidalarmclock.amdroid
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-44 -----------------
# package_name:  com.anytimefitness.anytimeworkouts
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.anytimeworkouts
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-45 -----------------
# package_name:  com.anytimefitness.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.app
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-46 -----------------
# package_name:  com.anytimefitness.userapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_24 -> message_24.txt
# Renamed: message_25 -> message_25.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-47 -----------------
# package_name:  com.apep.fitapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.apep.fitapp
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-48 -----------------
# package_name:  com.app.cy.GsFiten
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.app.cy.GsFiten
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-49 -----------------
# package_name:  com.app.ufit365.forza.gym
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.forza.gym
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-50 -----------------
# package_name:  com.app.ufit365.gimnasio.zeus
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.gimnasio.zeus
# ----------------- Loop-51 -----------------
# package_name:  com.app.ufit365.world.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.world.fitness
# ----------------- Loop-52 -----------------
# package_name:  com.appfour.wearvideos
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.appfour.wearvideos
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-53 -----------------
# package_name:  com.appyfurious.getfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.appyfurious.getfit
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-54 -----------------
# package_name:  com.arisdot.gymfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.arisdot.gymfit
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-55 -----------------
# package_name:  com.arketa.jamiegfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-56 -----------------
# package_name:  com.artkitch.alexfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.artkitch.alexfitness
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-57 -----------------
# package_name:  com.atlaswearables.ionic
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.atlaswearables.ionic
# ----------------- Loop-58 -----------------
# package_name:  com.attspaceventures.fitfit_client
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.attspaceventures.fitfit_client
# ----------------- Loop-59 -----------------
# package_name:  com.aukey.fit.pro
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.aukey.fit.pro
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-60 -----------------
# package_name:  com.avena.avenafit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.avena.avenafit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# ----------------- Loop-61 -----------------
# package_name:  com.bandlab.bandlab
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bandlab.bandlab
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-62 -----------------
# package_name:  com.basemsalloum.goodfitness.goodfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-63 -----------------
# package_name:  com.basicfit.trainingApp
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.basicfit.trainingApp
# Renamed: message_0 -> message_0.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-64 -----------------
# package_name:  com.bbfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bbfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-65 -----------------
# package_name:  com.beatxp.dafit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.beatxp.dafit
# ----------------- Loop-66 -----------------
# package_name:  com.bejaofit.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bejaofit.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-67 -----------------
# package_name:  com.benda.fitpro
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.benda.fitpro
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-68 -----------------
# package_name:  com.bendingspoons.thirtydayfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bendingspoons.thirtydayfitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-69 -----------------
# package_name:  com.best.fit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.best.fit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-70 -----------------
# package_name:  com.bhphoto
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bhphoto
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# ----------------- Loop-71 -----------------
# package_name:  com.bickster.fitbitbandfinder
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_8 -> message_8.txt
# ----------------- Loop-72 -----------------
# package_name:  com.biostatusfit.www
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.biostatusfit.www
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-73 -----------------
# package_name:  com.bitafit.client
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bitafit.client
# ----------------- Loop-74 -----------------
# package_name:  com.biztech.magemobadmin
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.biztech.magemobadmin
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-75 -----------------
# package_name:  com.blinkfitness.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.blinkfitness.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-76 -----------------
# package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-77 -----------------
# package_name:  com.bodyfxfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bodyfxfitness
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-78 -----------------
# package_name:  com.bottegasol.com.migym.fitnessconnection
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bottegasol.com.migym.fitnessconnection
# Renamed: message_0 -> message_0.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-79 -----------------
# package_name:  com.bpfit.bloodpressure.health
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_8 -> message_8.txt
# ----------------- Loop-80 -----------------
# package_name:  com.brooklynfitzone.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_25 -> message_25.txt
# Renamed: message_26 -> message_26.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# ----------------- Loop-81 -----------------
# package_name:  com.btfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.btfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-82 -----------------
# package_name:  com.caliberfitness.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.caliberfitness.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-83 -----------------
# package_name:  com.canyon.fit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.canyon.fit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-84 -----------------
# package_name:  com.cavosmart.wofit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cavosmart.wofit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_24 -> message_24.txt
# Renamed: message_25 -> message_25.txt
# Renamed: message_26 -> message_26.txt
# Renamed: message_27 -> message_27.txt
# Renamed: message_28 -> message_28.txt
# Renamed: message_29 -> message_29.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_30 -> message_30.txt
# Renamed: message_31 -> message_31.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-85 -----------------
# package_name:  com.ccswe.SmokingLog
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.ccswe.SmokingLog
# ----------------- Loop-86 -----------------
# package_name:  com.chloeting.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-87 -----------------
# package_name:  com.cignahealthbenefits.mobileapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-88 -----------------
# package_name:  com.cisco.im
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cisco.im
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-89 -----------------
# package_name:  com.cisco.webex.meetings
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cisco.webex.meetings
# Renamed: message_0 -> message_0.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-90 -----------------
# package_name:  com.citysportsfitness.android
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.citysportsfitness.android
# ----------------- Loop-91 -----------------
# package_name:  com.cizotech.fit2flaunt
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cizotech.fit2flaunt
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-92 -----------------
# package_name:  com.clearskyapps.fitnessfamily.Run5K
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.Run5K
# ----------------- Loop-93 -----------------
# package_name:  com.clearskyapps.fitnessfamily.RunC210K
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.RunC210K
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-94 -----------------
# package_name:  com.cloudgym.hiperfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cloudgym.hiperfit
# ----------------- Loop-95 -----------------
# package_name:  com.cm.wearintervaltimer
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cm.wearintervaltimer
# ----------------- Loop-96 -----------------
# package_name:  com.codebusters.onefit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.codebusters.onefit
# ----------------- Loop-97 -----------------
# package_name:  com.cofox.kahunas.ProyectoPapaFit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cofox.kahunas.ProyectoPapaFit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-98 -----------------
# package_name:  com.cognifit.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cognifit.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-99 -----------------
# package_name:  com.concapps.benfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.concapps.benfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-100 -----------------
# package_name:  com.connect_computer.shesfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.connect_computer.shesfit
# ----------------- Loop-101 -----------------
# package_name:  com.cpsolutions.contacts
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cpsolutions.contacts
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-102 -----------------
# package_name:  com.crossfit.games.android
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.crossfit.games.android
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-103 -----------------
# package_name:  com.crrepa.band.altfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.altfit
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-104 -----------------
# package_name:  com.crrepa.band.dafit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.dafit
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-105 -----------------
# package_name:  com.crrepa.band.havefit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.havefit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-106 -----------------
# package_name:  com.cs.booty.fit.buttocks.workout
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.cs.booty.fit.buttocks.workout
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-107 -----------------
# package_name:  com.czw.freefit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.czw.freefit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-108 -----------------
# package_name:  com.dailyyoga.fitness.workout
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.dailyyoga.fitness.workout
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-109 -----------------
# package_name:  com.daniel.apps.wpe
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.daniel.apps.wpe
# ----------------- Loop-110 -----------------
# package_name:  com.darebee.fittaplight
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.darebee.fittaplight
# ----------------- Loop-111 -----------------
# package_name:  com.defacto.fit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.defacto.fit
# ----------------- Loop-112 -----------------
# package_name:  com.dimlix.phrase
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.dimlix.phrase
# ----------------- Loop-113 -----------------
# package_name:  com.directed.android.smartstart
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.directed.android.smartstart
# ----------------- Loop-114 -----------------
# package_name:  com.directed.android.viper
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.directed.android.viper
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-115 -----------------
# package_name:  com.dolcegustofree.activity
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-116 -----------------
# package_name:  com.dotfit.dotfitweb
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.dotfit.dotfitweb
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-117 -----------------
# package_name:  com.droibit.findwear
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.droibit.findwear
# ----------------- Loop-118 -----------------
# package_name:  com.dusiassistant
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.dusiassistant
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-119 -----------------
# package_name:  com.earthjumper.myhomefit
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.earthjumper.myhomefit
# Renamed: message_5 -> message_5.txt
# ----------------- Loop-120 -----------------
# package_name:  com.edjing.edjingdjturntable
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.edjing.edjingdjturntable
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-121 -----------------
# package_name:  com.eightfit.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.eightfit.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-122 -----------------
# package_name:  com.emilyskyefit.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.emilyskyefit.app
# ----------------- Loop-123 -----------------
# package_name:  com.eokoe.smartfitcoach
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.eokoe.smartfitcoach
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-124 -----------------
# package_name:  com.equinoxfitness.equinox
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.equinoxfitness.equinox
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_24 -> message_24.txt
# Renamed: message_25 -> message_25.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-125 -----------------
# package_name:  com.ericfabreu.wearflashcards
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.ericfabreu.wearflashcards
# ----------------- Loop-126 -----------------
# package_name:  com.estela
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.estela
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-127 -----------------
# package_name:  com.evlofitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.evlofitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-128 -----------------
# package_name:  com.evolutionwellness.app.celebrityfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.celebrityfitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ...
# ----------------- Loop-598 -----------------
# package_name:  ott.beatboxingfitnessworkouts
# directory_path:  E:\wearable-capture-traffic\wearable-app\ott.beatboxingfitnessworkouts
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-599 -----------------
# package_name:  ott.transformyoufitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\ott.transformyoufitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-600 -----------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# directory_path:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# Renamed: message_18 -> message_18.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-601 -----------------
# package_name:  pl.efitness.mobile
# directory_path:  E:\wearable-capture-traffic\wearable-app\pl.efitness.mobile
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-602 -----------------
# package_name:  pl.fit.world
# directory_path:  E:\wearable-capture-traffic\wearable-app\pl.fit.world
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-603 -----------------
# package_name:  pl.tweeba.mobile.learning.english
# directory_path:  E:\wearable-capture-traffic\wearable-app\pl.tweeba.mobile.learning.english
# Renamed: message_0 -> message_0.txt
# ----------------- Loop-604 -----------------
# package_name:  rebel.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\rebel.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-605 -----------------
# package_name:  revox.voxnet
# directory_path:  E:\wearable-capture-traffic\wearable-app\revox.voxnet
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-606 -----------------
# package_name:  ro.fitgym
# directory_path:  E:\wearable-capture-traffic\wearable-app\ro.fitgym
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-607 -----------------
# package_name:  rs.abstract.fitpass
# directory_path:  E:\wearable-capture-traffic\wearable-app\rs.abstract.fitpass
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-608 -----------------
# package_name:  rs.fastfit.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\rs.fastfit.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# ----------------- Loop-609 -----------------
# package_name:  rs.nonstopfitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\rs.nonstopfitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# ----------------- Loop-610 -----------------
# package_name:  ru.disav.befit
# directory_path:  E:\wearable-capture-traffic\wearable-app\ru.disav.befit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-611 -----------------
# package_name:  ru.starline
# directory_path:  E:\wearable-capture-traffic\wearable-app\ru.starline
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-612 -----------------
# package_name:  scope.fitnessfirstmena
# directory_path:  E:\wearable-capture-traffic\wearable-app\scope.fitnessfirstmena
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# ----------------- Loop-613 -----------------
# package_name:  se.matlistan.free
# directory_path:  E:\wearable-capture-traffic\wearable-app\se.matlistan.free
# Renamed: message_1 -> message_1.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-614 -----------------
# package_name:  senior.fitness.exercises.elderly
# directory_path:  E:\wearable-capture-traffic\wearable-app\senior.fitness.exercises.elderly
# Renamed: message_0 -> message_0.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_6 -> message_6.txt
# ----------------- Loop-615 -----------------
# package_name:  softin.my.fast.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\softin.my.fast.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-616 -----------------
# package_name:  starshipproduct.perifitmainapp
# directory_path:  E:\wearable-capture-traffic\wearable-app\starshipproduct.perifitmainapp
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-617 -----------------
# package_name:  steptracker.healthandfitness.walkingtracker.pedometer
# directory_path:  E:\wearable-capture-traffic\wearable-app\steptracker.healthandfitness.walkingtracker.pedometer
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-618 -----------------
# package_name:  sweatybetty.com.fitness.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\sweatybetty.com.fitness.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_20 -> message_20.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-619 -----------------
# package_name:  tarlin.fitness.loseweight.belly.fem
# directory_path:  E:\wearable-capture-traffic\wearable-app\tarlin.fitness.loseweight.belly.fem
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_17 -> message_17.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_23 -> message_23.txt
# Renamed: message_25 -> message_25.txt
# Renamed: message_26 -> message_26.txt
# Renamed: message_27 -> message_27.txt
# Renamed: message_28 -> message_28.txt
# Renamed: message_29 -> message_29.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_30 -> message_30.txt
# Renamed: message_31 -> message_31.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-620 -----------------
# package_name:  tk.deuchnord.phonejuicechecker
# directory_path:  E:\wearable-capture-traffic\wearable-app\tk.deuchnord.phonejuicechecker
# ----------------- Loop-621 -----------------
# package_name:  today.upfit
# directory_path:  E:\wearable-capture-traffic\wearable-app\today.upfit
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-622 -----------------
# package_name:  tr.com.fitwell.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\tr.com.fitwell.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# ----------------- Loop-623 -----------------
# package_name:  uk.co.fitness4less.app
# directory_path:  E:\wearable-capture-traffic\wearable-app\uk.co.fitness4less.app
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# ----------------- Loop-624 -----------------
# package_name:  uk.me.andre.dicionarioportugues
# directory_path:  E:\wearable-capture-traffic\wearable-app\uk.me.andre.dicionarioportugues
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# ----------------- Loop-625 -----------------
# package_name:  verv.health.fitness.workout.weight.loss
# directory_path:  E:\wearable-capture-traffic\wearable-app\verv.health.fitness.workout.weight.loss
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_13 -> message_13.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-626 -----------------
# package_name:  women.workout.female.fitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# Renamed: message_0 -> message_0.txt
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_4 -> message_4.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_8 -> message_8.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-627 -----------------
# package_name:  workoutforwomen.femalefitness.womenworkout.loseweight
# directory_path:  E:\wearable-capture-traffic\wearable-app\workoutforwomen.femalefitness.womenworkout.loseweight
# Renamed: message_1 -> message_1.txt
# Renamed: message_10 -> message_10.txt
# Renamed: message_11 -> message_11.txt
# Renamed: message_12 -> message_12.txt
# Renamed: message_14 -> message_14.txt
# Renamed: message_15 -> message_15.txt
# Renamed: message_16 -> message_16.txt
# Renamed: message_18 -> message_18.txt
# Renamed: message_19 -> message_19.txt
# Renamed: message_2 -> message_2.txt
# Renamed: message_21 -> message_21.txt
# Renamed: message_22 -> message_22.txt
# Renamed: message_3 -> message_3.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
# Renamed: message_7 -> message_7.txt
# Renamed: message_9 -> message_9.txt
# ----------------- Loop-628 -----------------
# package_name:  xyz.micrusa.fitnesscalc
# directory_path:  E:\wearable-capture-traffic\wearable-app\xyz.micrusa.fitnesscalc
# Renamed: message_0 -> message_0.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_7 -> message_7.txt
# ----------------- Loop-629 -----------------
# package_name:  yogaworkouts.dailyyoga.yogafitness
# directory_path:  E:\wearable-capture-traffic\wearable-app\yogaworkouts.dailyyoga.yogafitness
# Renamed: message_2 -> message_2.txt
# Renamed: message_5 -> message_5.txt
# Renamed: message_6 -> message_6.txt
