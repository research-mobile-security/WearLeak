# %%
import os

# %%
# Function
def get_directories(path: str):
    """
    Get all directory names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of directory names.
    """
    try:
        return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def remove_empty_files(path: str) -> int:
    """
    Remove all files with size 0 in the specified directory.
    
    :param path: The root directory path to search.
    :return: Count of files removed.
    """
    removed_count = 0
    try:
        for f in os.listdir(path):
            file_path = os.path.join(path, f)
            if os.path.isfile(file_path) and os.path.getsize(file_path) == 0:
                os.remove(file_path)
                removed_count += 1
        return removed_count
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return 0
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return 0
def get_files(path: str):
    """
    Get all file names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of file names.
    """
    try:
        return [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def contains_non_ascii(file_path: str) -> bool:
    """
    Check if a file contains non-ASCII characters or control characters.

    :param file_path: The path of the file to check.
    :return: True if the file contains non-ASCII characters, otherwise False.
    """
    try:
        with open(file_path, "rb") as file:  # Open in binary mode to catch all non-ASCII characters
            content = file.read()
            return any(byte > 127 or byte < 32 for byte in content if byte not in (9, 10, 13))  # Ignore tab, newline, carriage return
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
        return False
    except PermissionError:
        print(f"Error: Permission denied for file '{file_path}'.")
        return False
    except Exception as e:
        print(f"Error: {e}")
        return True
def replace_non_ascii(file_path: str):
    """
    Read a file and replace all non-ASCII characters with an empty string.
    
    :param file_path: The path of the file to process.
    """
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
            content = file.read()
        cleaned_content = ''.join(char if 32 <= ord(char) <= 126 or char in '\t\n\r' else '' for char in content)
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(cleaned_content)
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except PermissionError:
        print(f"Error: Permission denied for file '{file_path}'.")
    except Exception as e:
        print(f"Error: {e}")

# %%
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"
root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-app"
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"

# %%
array_traffic_directory = get_directories(root_traffic_directory_path)
# print(array_traffic_directory)
print(len(array_traffic_directory))
# Out:
# 630

# %%
for i in range(len(array_traffic_directory)):
    print("--------------------------- Loop-"+str(i)+" ---------------------------")
    package_name = array_traffic_directory[i]
    print("package_name: ",package_name)
    traffic_directory = root_traffic_directory_path+"\\"+package_name
    print("traffic_directory: ",traffic_directory)
    zero_file_size = remove_empty_files(traffic_directory)
    print("zero_file_size: ",zero_file_size)
    array_file = get_files(traffic_directory)
    for j in range(len(array_file)):
        file_name = array_file[j]
        file_path = traffic_directory+"\\"+file_name
        check_result = contains_non_ascii(file_path)
        if(check_result==True):
            print("non_ascii_filename: ",file_name)
            print("non_ascii_filename_path: ",file_path)
            replace_non_ascii(file_path)
#     break
# print(array_filename_check)
# Out:
# --------------------------- Loop-0 ---------------------------
# package_name:  adarshurs.android.vlcmobileremote
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\adarshurs.android.vlcmobileremote
# zero_file_size:  0
# --------------------------- Loop-1 ---------------------------
# package_name:  app.EnForma.fitcoapp.net
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.EnForma.fitcoapp.net
# zero_file_size:  0
# --------------------------- Loop-2 ---------------------------
# package_name:  app.entrenamientogenetico.android.fitcoapp.net
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.entrenamientogenetico.android.fitcoapp.net
# zero_file_size:  0
# --------------------------- Loop-3 ---------------------------
# package_name:  app.f4square.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.f4square.fitness
# zero_file_size:  0
# --------------------------- Loop-4 ---------------------------
# package_name:  app.fit.meet
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# zero_file_size:  0
# --------------------------- Loop-5 ---------------------------
# package_name:  app.growwithjo.diet.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# zero_file_size:  0
# --------------------------- Loop-6 ---------------------------
# package_name:  app.krowdfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.krowdfit
# zero_file_size:  0
# --------------------------- Loop-7 ---------------------------
# package_name:  app.LomasGym.fitcoapp.net
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net
# zero_file_size:  0
# --------------------------- Loop-8 ---------------------------
# package_name:  app.mfit.personal
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.mfit.personal
# zero_file_size:  0
# --------------------------- Loop-9 ---------------------------
# package_name:  app.midfit.train.own
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.midfit.train.own
# zero_file_size:  0
# --------------------------- Loop-10 ---------------------------
# package_name:  app.mlfitness.diet.workout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.mlfitness.diet.workout
# zero_file_size:  0
# --------------------------- Loop-11 ---------------------------
# package_name:  app.MOVE.fitcoapp.net
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.MOVE.fitcoapp.net
# zero_file_size:  0
# --------------------------- Loop-12 ---------------------------
# package_name:  app.weightfit.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\app.weightfit.android
# zero_file_size:  0
# --------------------------- Loop-13 ---------------------------
# package_name:  appnativo.navysportcenter.fitcoapp.net
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\appnativo.navysportcenter.fitcoapp.net
# zero_file_size:  0
# --------------------------- Loop-14 ---------------------------
# package_name:  at.radioplayer.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\at.radioplayer.android
# zero_file_size:  0
# --------------------------- Loop-15 ---------------------------
# package_name:  biz.mobidev.mdplayer
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\biz.mobidev.mdplayer
# zero_file_size:  0
# --------------------------- Loop-16 ---------------------------
# package_name:  blacknote.amazfitmaster
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\blacknote.amazfitmaster
# zero_file_size:  0
# --------------------------- Loop-17 ---------------------------
# package_name:  br.com.fitastic.appaluno
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.fitastic.appaluno
# zero_file_size:  0
# --------------------------- Loop-18 ---------------------------
# package_name:  br.com.mufitness.station.aluno
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.mufitness.station.aluno
# zero_file_size:  0
# --------------------------- Loop-19 ---------------------------
# package_name:  br.com.personalfitapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.personalfitapp
# zero_file_size:  0
# --------------------------- Loop-20 ---------------------------
# package_name:  br.com.tecnofit.mobileapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.tecnofit.mobileapp
# zero_file_size:  0
# --------------------------- Loop-21 ---------------------------
# package_name:  br.com.w12.bluefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.w12.bluefit
# zero_file_size:  0
# --------------------------- Loop-22 ---------------------------
# package_name:  br.com.w12.heyfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit
# zero_file_size:  0
# --------------------------- Loop-23 ---------------------------
# package_name:  br.com.w12.redfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit
# zero_file_size:  0
# --------------------------- Loop-24 ---------------------------
# package_name:  br.com.w12.skyfitapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\br.com.w12.skyfitapp
# zero_file_size:  0
# --------------------------- Loop-25 ---------------------------
# package_name:  calorie.pedo.fitbit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\calorie.pedo.fitbit
# zero_file_size:  0
# --------------------------- Loop-26 ---------------------------
# package_name:  club.nfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\club.nfit
# zero_file_size:  0
# --------------------------- Loop-27 ---------------------------
# package_name:  club.skllzz.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\club.skllzz.fitness
# zero_file_size:  0
# --------------------------- Loop-28 ---------------------------
# package_name:  clubwise.com.fitsense
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\clubwise.com.fitsense
# zero_file_size:  0
# --------------------------- Loop-29 ---------------------------
# package_name:  cn.fitdays.fitdays
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\cn.fitdays.fitdays
# zero_file_size:  0
# --------------------------- Loop-30 ---------------------------
# package_name:  co.macrofit.macroFit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\co.macrofit.macroFit
# zero_file_size:  0
# --------------------------- Loop-31 ---------------------------
# package_name:  coach.zing.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\coach.zing.fitness
# zero_file_size:  0
# --------------------------- Loop-32 ---------------------------
# package_name:  com.abhijitvalluri.android.fitnotifications
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.abhijitvalluri.android.fitnotifications
# zero_file_size:  0
# --------------------------- Loop-33 ---------------------------
# package_name:  com.abyx.fit.connect
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.abyx.fit.connect
# zero_file_size:  0
# --------------------------- Loop-34 ---------------------------
# package_name:  com.acmeaom.android.myradar
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.acmeaom.android.myradar
# zero_file_size:  0
# --------------------------- Loop-35 ---------------------------
# package_name:  com.acquasys.contrack
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.acquasys.contrack
# zero_file_size:  0
# --------------------------- Loop-36 ---------------------------
# package_name:  com.actofitSmartScale
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale
# zero_file_size:  0
# --------------------------- Loop-37 ---------------------------
# package_name:  com.adi.remote.phone
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.adi.remote.phone
# zero_file_size:  0
# --------------------------- Loop-38 ---------------------------
# package_name:  com.aheqab.salahwear
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.aheqab.salahwear
# zero_file_size:  0
# --------------------------- Loop-39 ---------------------------
# package_name:  com.aircanada
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.aircanada
# zero_file_size:  0
# --------------------------- Loop-40 ---------------------------
# package_name:  com.airofit_app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.airofit_app
# zero_file_size:  0
# --------------------------- Loop-41 ---------------------------
# package_name:  com.alex.crockfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.alex.crockfit
# zero_file_size:  0
# --------------------------- Loop-42 ---------------------------
# package_name:  com.alphapod.fitsifu.jordanyeoh
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.alphapod.fitsifu.jordanyeoh
# zero_file_size:  0
# --------------------------- Loop-43 ---------------------------
# package_name:  com.amdroidalarmclock.amdroid
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.amdroidalarmclock.amdroid
# zero_file_size:  0
# --------------------------- Loop-44 ---------------------------
# package_name:  com.anytimefitness.anytimeworkouts
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.anytimeworkouts
# zero_file_size:  0
# --------------------------- Loop-45 ---------------------------
# package_name:  com.anytimefitness.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.app
# zero_file_size:  0
# --------------------------- Loop-46 ---------------------------
# package_name:  com.anytimefitness.userapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# zero_file_size:  0
# --------------------------- Loop-47 ---------------------------
# package_name:  com.apep.fitapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.apep.fitapp
# zero_file_size:  0
# --------------------------- Loop-48 ---------------------------
# package_name:  com.app.cy.GsFiten
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.app.cy.GsFiten
# zero_file_size:  0
# --------------------------- Loop-49 ---------------------------
# package_name:  com.app.ufit365.forza.gym
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.forza.gym
# zero_file_size:  0
# --------------------------- Loop-50 ---------------------------
# package_name:  com.app.ufit365.gimnasio.zeus
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.gimnasio.zeus
# zero_file_size:  0
# --------------------------- Loop-51 ---------------------------
# package_name:  com.app.ufit365.world.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.app.ufit365.world.fitness
# zero_file_size:  0
# --------------------------- Loop-52 ---------------------------
# package_name:  com.appfour.wearvideos
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.appfour.wearvideos
# zero_file_size:  0
# --------------------------- Loop-53 ---------------------------
# package_name:  com.appyfurious.getfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.appyfurious.getfit
# zero_file_size:  0
# --------------------------- Loop-54 ---------------------------
# package_name:  com.arisdot.gymfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.arisdot.gymfit
# zero_file_size:  0
# --------------------------- Loop-55 ---------------------------
# package_name:  com.arketa.jamiegfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness
# zero_file_size:  0
# --------------------------- Loop-56 ---------------------------
# package_name:  com.artkitch.alexfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.artkitch.alexfitness
# zero_file_size:  0
# --------------------------- Loop-57 ---------------------------
# package_name:  com.atlaswearables.ionic
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.atlaswearables.ionic
# zero_file_size:  0
# --------------------------- Loop-58 ---------------------------
# package_name:  com.attspaceventures.fitfit_client
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.attspaceventures.fitfit_client
# zero_file_size:  0
# --------------------------- Loop-59 ---------------------------
# package_name:  com.aukey.fit.pro
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.aukey.fit.pro
# zero_file_size:  0
# --------------------------- Loop-60 ---------------------------
# package_name:  com.avena.avenafit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.avena.avenafit
# zero_file_size:  0
# --------------------------- Loop-61 ---------------------------
# package_name:  com.bandlab.bandlab
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bandlab.bandlab
# zero_file_size:  0
# --------------------------- Loop-62 ---------------------------
# package_name:  com.basemsalloum.goodfitness.goodfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness
# zero_file_size:  0
# --------------------------- Loop-63 ---------------------------
# package_name:  com.basicfit.trainingApp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.basicfit.trainingApp
# zero_file_size:  0
# --------------------------- Loop-64 ---------------------------
# package_name:  com.bbfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bbfit
# zero_file_size:  0
# --------------------------- Loop-65 ---------------------------
# package_name:  com.beatxp.dafit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.beatxp.dafit
# zero_file_size:  0
# --------------------------- Loop-66 ---------------------------
# package_name:  com.bejaofit.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bejaofit.app
# zero_file_size:  0
# --------------------------- Loop-67 ---------------------------
# package_name:  com.benda.fitpro
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.benda.fitpro
# zero_file_size:  0
# --------------------------- Loop-68 ---------------------------
# package_name:  com.bendingspoons.thirtydayfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bendingspoons.thirtydayfitness
# zero_file_size:  0
# --------------------------- Loop-69 ---------------------------
# package_name:  com.best.fit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.best.fit
# zero_file_size:  0
# --------------------------- Loop-70 ---------------------------
# package_name:  com.bhphoto
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bhphoto
# zero_file_size:  0
# --------------------------- Loop-71 ---------------------------
# package_name:  com.bickster.fitbitbandfinder
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# zero_file_size:  0
# --------------------------- Loop-72 ---------------------------
# package_name:  com.biostatusfit.www
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.biostatusfit.www
# zero_file_size:  0
# --------------------------- Loop-73 ---------------------------
# package_name:  com.bitafit.client
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bitafit.client
# zero_file_size:  0
# --------------------------- Loop-74 ---------------------------
# package_name:  com.biztech.magemobadmin
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.biztech.magemobadmin
# zero_file_size:  0
# --------------------------- Loop-75 ---------------------------
# package_name:  com.blinkfitness.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.blinkfitness.app
# zero_file_size:  0
# --------------------------- Loop-76 ---------------------------
# package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# zero_file_size:  0
# --------------------------- Loop-77 ---------------------------
# package_name:  com.bodyfxfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bodyfxfitness
# zero_file_size:  0
# --------------------------- Loop-78 ---------------------------
# package_name:  com.bottegasol.com.migym.fitnessconnection
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bottegasol.com.migym.fitnessconnection
# zero_file_size:  0
# --------------------------- Loop-79 ---------------------------
# package_name:  com.bpfit.bloodpressure.health
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# zero_file_size:  0
# --------------------------- Loop-80 ---------------------------
# package_name:  com.brooklynfitzone.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# zero_file_size:  0
# --------------------------- Loop-81 ---------------------------
# package_name:  com.btfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.btfit
# zero_file_size:  0
# --------------------------- Loop-82 ---------------------------
# package_name:  com.caliberfitness.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.caliberfitness.app
# zero_file_size:  0
# --------------------------- Loop-83 ---------------------------
# package_name:  com.canyon.fit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.canyon.fit
# zero_file_size:  0
# --------------------------- Loop-84 ---------------------------
# package_name:  com.cavosmart.wofit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cavosmart.wofit
# zero_file_size:  0
# --------------------------- Loop-85 ---------------------------
# package_name:  com.ccswe.SmokingLog
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.ccswe.SmokingLog
# zero_file_size:  0
# --------------------------- Loop-86 ---------------------------
# package_name:  com.chloeting.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# zero_file_size:  0
# --------------------------- Loop-87 ---------------------------
# package_name:  com.cignahealthbenefits.mobileapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp
# zero_file_size:  0
# --------------------------- Loop-88 ---------------------------
# package_name:  com.cisco.im
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cisco.im
# zero_file_size:  0
# --------------------------- Loop-89 ---------------------------
# package_name:  com.cisco.webex.meetings
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cisco.webex.meetings
# zero_file_size:  0
# --------------------------- Loop-90 ---------------------------
# package_name:  com.citysportsfitness.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.citysportsfitness.android
# zero_file_size:  0
# --------------------------- Loop-91 ---------------------------
# package_name:  com.cizotech.fit2flaunt
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cizotech.fit2flaunt
# zero_file_size:  0
# --------------------------- Loop-92 ---------------------------
# package_name:  com.clearskyapps.fitnessfamily.Run5K
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.Run5K
# zero_file_size:  0
# --------------------------- Loop-93 ---------------------------
# package_name:  com.clearskyapps.fitnessfamily.RunC210K
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.RunC210K
# zero_file_size:  0
# --------------------------- Loop-94 ---------------------------
# package_name:  com.cloudgym.hiperfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cloudgym.hiperfit
# zero_file_size:  0
# --------------------------- Loop-95 ---------------------------
# package_name:  com.cm.wearintervaltimer
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cm.wearintervaltimer
# zero_file_size:  0
# --------------------------- Loop-96 ---------------------------
# package_name:  com.codebusters.onefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.codebusters.onefit
# zero_file_size:  0
# --------------------------- Loop-97 ---------------------------
# package_name:  com.cofox.kahunas.ProyectoPapaFit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cofox.kahunas.ProyectoPapaFit
# zero_file_size:  0
# --------------------------- Loop-98 ---------------------------
# package_name:  com.cognifit.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cognifit.app
# zero_file_size:  0
# --------------------------- Loop-99 ---------------------------
# package_name:  com.concapps.benfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.concapps.benfit
# zero_file_size:  0
# --------------------------- Loop-100 ---------------------------
# package_name:  com.connect_computer.shesfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.connect_computer.shesfit
# zero_file_size:  0
# --------------------------- Loop-101 ---------------------------
# package_name:  com.cpsolutions.contacts
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cpsolutions.contacts
# zero_file_size:  0
# --------------------------- Loop-102 ---------------------------
# package_name:  com.crossfit.games.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.crossfit.games.android
# zero_file_size:  0
# --------------------------- Loop-103 ---------------------------
# package_name:  com.crrepa.band.altfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.altfit
# zero_file_size:  0
# --------------------------- Loop-104 ---------------------------
# package_name:  com.crrepa.band.dafit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.dafit
# zero_file_size:  0
# --------------------------- Loop-105 ---------------------------
# package_name:  com.crrepa.band.havefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.havefit
# zero_file_size:  0
# --------------------------- Loop-106 ---------------------------
# package_name:  com.cs.booty.fit.buttocks.workout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.cs.booty.fit.buttocks.workout
# zero_file_size:  0
# --------------------------- Loop-107 ---------------------------
# package_name:  com.czw.freefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.czw.freefit
# zero_file_size:  0
# --------------------------- Loop-108 ---------------------------
# package_name:  com.dailyyoga.fitness.workout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.dailyyoga.fitness.workout
# zero_file_size:  0
# --------------------------- Loop-109 ---------------------------
# package_name:  com.daniel.apps.wpe
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.daniel.apps.wpe
# zero_file_size:  0
# --------------------------- Loop-110 ---------------------------
# package_name:  com.darebee.fittaplight
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.darebee.fittaplight
# zero_file_size:  0
# --------------------------- Loop-111 ---------------------------
# package_name:  com.defacto.fit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.defacto.fit
# zero_file_size:  0
# --------------------------- Loop-112 ---------------------------
# package_name:  com.dimlix.phrase
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.dimlix.phrase
# zero_file_size:  0
# --------------------------- Loop-113 ---------------------------
# package_name:  com.directed.android.smartstart
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.directed.android.smartstart
# zero_file_size:  0
# --------------------------- Loop-114 ---------------------------
# package_name:  com.directed.android.viper
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.directed.android.viper
# zero_file_size:  0
# --------------------------- Loop-115 ---------------------------
# package_name:  com.dolcegustofree.activity
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity
# zero_file_size:  0
# --------------------------- Loop-116 ---------------------------
# package_name:  com.dotfit.dotfitweb
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.dotfit.dotfitweb
# zero_file_size:  0
# --------------------------- Loop-117 ---------------------------
# package_name:  com.droibit.findwear
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.droibit.findwear
# zero_file_size:  0
# --------------------------- Loop-118 ---------------------------
# package_name:  com.dusiassistant
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.dusiassistant
# zero_file_size:  0
# --------------------------- Loop-119 ---------------------------
# package_name:  com.earthjumper.myhomefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.earthjumper.myhomefit
# zero_file_size:  0
# --------------------------- Loop-120 ---------------------------
# package_name:  com.edjing.edjingdjturntable
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.edjing.edjingdjturntable
# zero_file_size:  0
# --------------------------- Loop-121 ---------------------------
# package_name:  com.eightfit.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.eightfit.app
# zero_file_size:  0
# --------------------------- Loop-122 ---------------------------
# package_name:  com.emilyskyefit.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.emilyskyefit.app
# zero_file_size:  0
# --------------------------- Loop-123 ---------------------------
# package_name:  com.eokoe.smartfitcoach
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.eokoe.smartfitcoach
# zero_file_size:  0
# --------------------------- Loop-124 ---------------------------
# package_name:  com.equinoxfitness.equinox
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.equinoxfitness.equinox
# zero_file_size:  0
# --------------------------- Loop-125 ---------------------------
# package_name:  com.ericfabreu.wearflashcards
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.ericfabreu.wearflashcards
# zero_file_size:  0
# --------------------------- Loop-126 ---------------------------
# package_name:  com.estela
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.estela
# zero_file_size:  0
# --------------------------- Loop-127 ---------------------------
# package_name:  com.evlofitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.evlofitness
# zero_file_size:  0
# --------------------------- Loop-128 ---------------------------
# package_name:  com.evolutionwellness.app.celebrityfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.celebrityfitness
# zero_file_size:  0
# --------------------------- Loop-129 ---------------------------
# package_name:  com.evolutionwellness.app.fitnessfirst
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.fitnessfirst
# zero_file_size:  0
# --------------------------- Loop-130 ---------------------------
# package_name:  com.eztech.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.eztech.fitness
# zero_file_size:  0
# --------------------------- Loop-131 ---------------------------
# package_name:  com.fbi.fittest
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fbi.fittest
# zero_file_size:  0
# --------------------------- Loop-132 ---------------------------
# package_name:  com.Female.Fitness.cardio.wellness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.Female.Fitness.cardio.wellness
# zero_file_size:  0
# --------------------------- Loop-133 ---------------------------
# package_name:  com.fitapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitapp
# zero_file_size:  0
# --------------------------- Loop-134 ---------------------------
# package_name:  com.fitapp.timerwodapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitapp.timerwodapp
# zero_file_size:  0
# --------------------------- Loop-135 ---------------------------
# package_name:  com.fitatu.tracker
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitatu.tracker
# zero_file_size:  0
# --------------------------- Loop-136 ---------------------------
# package_name:  com.fitbit.FitbitMobile
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitbit.FitbitMobile
# zero_file_size:  0
# --------------------------- Loop-137 ---------------------------
# package_name:  com.fitbod.fitbod
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitbod.fitbod
# zero_file_size:  0
# --------------------------- Loop-138 ---------------------------
# package_name:  com.fitelo.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitelo.android
# zero_file_size:  0
# --------------------------- Loop-139 ---------------------------
# package_name:  com.fiteniummobile
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fiteniummobile
# zero_file_size:  0
# --------------------------- Loop-140 ---------------------------
# package_name:  com.fitifyapps.bwcardio
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwcardio
# zero_file_size:  0
# --------------------------- Loop-141 ---------------------------
# package_name:  com.fitifyapps.bwstretching
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching
# zero_file_size:  0
# --------------------------- Loop-142 ---------------------------
# package_name:  com.fitifyapps.kettlebell
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.kettlebell
# zero_file_size:  0
# --------------------------- Loop-143 ---------------------------
# package_name:  com.fitifyworkouts.bodyweight.workoutapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitifyworkouts.bodyweight.workoutapp
# zero_file_size:  0
# --------------------------- Loop-144 ---------------------------
# package_name:  com.fitiv.fitivapplication
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitiv.fitivapplication
# zero_file_size:  0
# --------------------------- Loop-145 ---------------------------
# package_name:  com.fitlab.spartan
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitlab.spartan
# zero_file_size:  0
# --------------------------- Loop-146 ---------------------------
# package_name:  com.fitlapapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitlapapp
# zero_file_size:  0
# --------------------------- Loop-147 ---------------------------
# package_name:  com.fitlog.fitlog
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitlog.fitlog
# zero_file_size:  0
# --------------------------- Loop-148 ---------------------------
# package_name:  com.fitmama
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitmama
# zero_file_size:  0
# --------------------------- Loop-149 ---------------------------
# package_name:  com.fitmind
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitmind
# zero_file_size:  0
# --------------------------- Loop-150 ---------------------------
# package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus
# zero_file_size:  0
# --------------------------- Loop-151 ---------------------------
# package_name:  com.fitness.homeworkout.fullbodyworkout.gymworkout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness.homeworkout.fullbodyworkout.gymworkout
# zero_file_size:  0
# --------------------------- Loop-152 ---------------------------
# package_name:  com.fitness.mybodymass.bmicalculator
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness.mybodymass.bmicalculator
# zero_file_size:  0
# --------------------------- Loop-153 ---------------------------
# package_name:  com.fitness.stepcounter.pedometer
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness.stepcounter.pedometer
# zero_file_size:  0
# --------------------------- Loop-154 ---------------------------
# package_name:  com.fitness.yoga.pregnancy.gym.exercise
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness.yoga.pregnancy.gym.exercise
# zero_file_size:  0
# --------------------------- Loop-155 ---------------------------
# package_name:  com.fitness22.meditation
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness22.meditation
# zero_file_size:  0
# --------------------------- Loop-156 ---------------------------
# package_name:  com.fitness22.running
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness22.running
# zero_file_size:  0
# --------------------------- Loop-157 ---------------------------
# package_name:  com.fitness22.workout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness22.workout
# zero_file_size:  0
# --------------------------- Loop-158 ---------------------------
# package_name:  com.fitness24seven.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitness24seven.app
# zero_file_size:  0
# --------------------------- Loop-159 ---------------------------
# package_name:  com.fitnessanny
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessanny
# zero_file_size:  0
# --------------------------- Loop-160 ---------------------------
# package_name:  com.FitnessAPPs.superheroWorkouts
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.FitnessAPPs.superheroWorkouts
# zero_file_size:  0
# --------------------------- Loop-161 ---------------------------
# package_name:  com.fitnessapps.yogakidsworkouts
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessapps.yogakidsworkouts
# zero_file_size:  0
# --------------------------- Loop-162 ---------------------------
# package_name:  com.fitnesses.fitticoin
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnesses.fitticoin
# zero_file_size:  0
# --------------------------- Loop-163 ---------------------------
# package_name:  com.fitnesskeeper.runkeeper.pro
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnesskeeper.runkeeper.pro
# zero_file_size:  0
# --------------------------- Loop-164 ---------------------------
# package_name:  com.fitnessmobileapps.elevate35253
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.elevate35253
# zero_file_size:  0
# --------------------------- Loop-165 ---------------------------
# package_name:  com.fitnessmobileapps.evolvegym
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.evolvegym
# zero_file_size:  0
# --------------------------- Loop-166 ---------------------------
# package_name:  com.fitnessmobileapps.f45training
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.f45training
# zero_file_size:  0
# --------------------------- Loop-167 ---------------------------
# package_name:  com.fitnessmobileapps.orangetheoryfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.orangetheoryfitness
# zero_file_size:  0
# --------------------------- Loop-168 ---------------------------
# package_name:  com.fitnessmobileapps.oxygenyogaandfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.oxygenyogaandfitness
# zero_file_size:  0
# --------------------------- Loop-169 ---------------------------
# package_name:  com.fitnessmobileapps.speedfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.speedfit
# zero_file_size:  0
# --------------------------- Loop-170 ---------------------------
# package_name:  com.fitnesspassport.androidapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnesspassport.androidapp
# zero_file_size:  0
# --------------------------- Loop-171 ---------------------------
# package_name:  com.fitnessworkout.bodybuilding
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnessworkout.bodybuilding
# zero_file_size:  0
# --------------------------- Loop-172 ---------------------------
# package_name:  com.fitnow.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnow.app
# zero_file_size:  0
# --------------------------- Loop-173 ---------------------------
# package_name:  com.fitnow.challenges
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnow.challenges
# zero_file_size:  0
# --------------------------- Loop-174 ---------------------------
# package_name:  com.fitnow.loseit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitnow.loseit
# zero_file_size:  0
# --------------------------- Loop-175 ---------------------------
# package_name:  com.fitofitness.breast_workout01
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitofitness.breast_workout01
# zero_file_size:  0
# --------------------------- Loop-176 ---------------------------
# package_name:  com.fitofitness.yoga_all_2022
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitofitness.yoga_all_2022
# zero_file_size:  0
# --------------------------- Loop-177 ---------------------------
# package_name:  com.fiton.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fiton.android
# zero_file_size:  0
# --------------------------- Loop-178 ---------------------------
# package_name:  com.fitonomy.health.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness
# zero_file_size:  0
# --------------------------- Loop-179 ---------------------------
# package_name:  com.fitonomy.muscle.man
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitonomy.muscle.man
# zero_file_size:  0
# --------------------------- Loop-180 ---------------------------
# package_name:  com.fitpass.fitpassapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitpass.fitpassapp
# zero_file_size:  0
# --------------------------- Loop-181 ---------------------------
# package_name:  com.fitphilia.fitway.bodyfactory
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitphilia.fitway.bodyfactory
# zero_file_size:  0
# --------------------------- Loop-182 ---------------------------
# package_name:  com.fitphilia.fitway.lion_fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitphilia.fitway.lion_fitness
# zero_file_size:  0
# --------------------------- Loop-183 ---------------------------
# package_name:  com.fitplanapp.fitplan
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan
# zero_file_size:  0
# --------------------------- Loop-184 ---------------------------
# package_name:  com.fitradio
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitradio
# zero_file_size:  0
# --------------------------- Loop-185 ---------------------------
# package_name:  com.fitshow
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitshow
# zero_file_size:  0
# --------------------------- Loop-186 ---------------------------
# package_name:  com.fittech.fasting.tracker
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fittech.fasting.tracker
# zero_file_size:  0
# --------------------------- Loop-187 ---------------------------
# package_name:  com.FitterFly.Wellness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.FitterFly.Wellness
# zero_file_size:  0
# --------------------------- Loop-188 ---------------------------
# package_name:  com.fitwhey.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitwhey.app
# zero_file_size:  0
# --------------------------- Loop-189 ---------------------------
# package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp
# zero_file_size:  0
# --------------------------- Loop-190 ---------------------------
# package_name:  com.fitze
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitze
# zero_file_size:  0
# --------------------------- Loop-191 ---------------------------
# package_name:  com.fitzeee.fitzeeerun
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.fitzeeerun
# zero_file_size:  0
# --------------------------- Loop-192 ---------------------------
# package_name:  com.fitzeee.menworkout
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.menworkout
# zero_file_size:  0
# --------------------------- Loop-193 ---------------------------
# package_name:  com.fitzeee.pedometerwalking
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.pedometerwalking
# zero_file_size:  0
# --------------------------- Loop-194 ---------------------------
# package_name:  com.fivestars.thirtydayfitnesschallenge.loseweight
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fivestars.thirtydayfitnesschallenge.loseweight
# zero_file_size:  0
# --------------------------- Loop-195 ---------------------------
# package_name:  com.fixfit_fitness.twa
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa
# zero_file_size:  0
# --------------------------- Loop-196 ---------------------------
# package_name:  com.fliptonic.nicefitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fliptonic.nicefitness
# zero_file_size:  0
# --------------------------- Loop-197 ---------------------------
# package_name:  com.forfit.mymediterranean
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.forfit.mymediterranean
# zero_file_size:  0
# --------------------------- Loop-198 ---------------------------
# package_name:  com.fuse.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.fuse.fitness
# zero_file_size:  0
# --------------------------- Loop-199 ---------------------------
# package_name:  com.future.FitYou
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.future.FitYou
# zero_file_size:  0
# --------------------------- Loop-200 ---------------------------
# package_name:  com.gin.shoppinglist
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.gin.shoppinglist
# zero_file_size:  0
# --------------------------- Loop-201 ---------------------------
# package_name:  com.github.jamesgay.fitnotes
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.github.jamesgay.fitnotes
# zero_file_size:  0
# --------------------------- Loop-202 ---------------------------
# package_name:  com.glidetalk.glideapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.glidetalk.glideapp
# zero_file_size:  0
# --------------------------- Loop-203 ---------------------------
# package_name:  com.Glossbird.Fitment
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.Glossbird.Fitment
# zero_file_size:  0
# --------------------------- Loop-204 ---------------------------
# package_name:  com.golden.wasfatbodyfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.golden.wasfatbodyfitness
# zero_file_size:  0
# --------------------------- Loop-205 ---------------------------
# package_name:  com.golf.fitforgolf
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.golf.fitforgolf
# zero_file_size:  0
# --------------------------- Loop-206 ---------------------------
# package_name:  com.goodlifefitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.goodlifefitness
# zero_file_size:  0
# --------------------------- Loop-207 ---------------------------
# package_name:  com.google.android.apps.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.google.android.apps.fitness
# zero_file_size:  0
# --------------------------- Loop-208 ---------------------------
# package_name:  com.google.android.apps.messaging
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.google.android.apps.messaging
# zero_file_size:  0
# --------------------------- Loop-209 ---------------------------
# package_name:  com.gp.android.fitproject.colorwalk
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.gp.android.fitproject.colorwalk
# zero_file_size:  0
# --------------------------- Loop-210 ---------------------------
# package_name:  com.groupnos.openfitapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.groupnos.openfitapp
# zero_file_size:  0
# --------------------------- Loop-211 ---------------------------
# package_name:  com.growfitter.fitkit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.growfitter.fitkit
# zero_file_size:  0
# --------------------------- Loop-212 ---------------------------
# package_name:  com.gymshark.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.gymshark.fitness
# zero_file_size:  0
# --------------------------- Loop-213 ---------------------------
# package_name:  com.gymworkout.fitnessbodybuilding.gymworkoutpro
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.gymworkout.fitnessbodybuilding.gymworkoutpro
# zero_file_size:  0
# --------------------------- Loop-214 ---------------------------
# package_name:  com.hadestech.fitday
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hadestech.fitday
# zero_file_size:  0
# --------------------------- Loop-215 ---------------------------
# package_name:  com.hainofit.health
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hainofit.health
# zero_file_size:  0
# --------------------------- Loop-216 ---------------------------
# package_name:  com.hanbit.fitday
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hanbit.fitday
# zero_file_size:  0
# --------------------------- Loop-217 ---------------------------
# package_name:  com.health.bloodsugar.healthly.fit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.health.bloodsugar.healthly.fit
# zero_file_size:  0
# --------------------------- Loop-218 ---------------------------
# package_name:  com.healthfitnessnordic.gxbooking
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.healthfitnessnordic.gxbooking
# zero_file_size:  0
# --------------------------- Loop-219 ---------------------------
# package_name:  com.highfitnesslive
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.highfitnesslive
# zero_file_size:  0
# --------------------------- Loop-220 ---------------------------
# package_name:  com.hinteen.hitfitpro
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hinteen.hitfitpro
# zero_file_size:  0
# --------------------------- Loop-221 ---------------------------
# package_name:  com.hitec.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hitec.fitness
# zero_file_size:  0
# --------------------------- Loop-222 ---------------------------
# package_name:  com.hl.deepfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hl.deepfit
# zero_file_size:  0
# --------------------------- Loop-223 ---------------------------
# package_name:  com.honbow.fitdock
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock
# zero_file_size:  0
# --------------------------- Loop-224 ---------------------------
# package_name:  com.honbow.letsfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.honbow.letsfit
# zero_file_size:  0
# --------------------------- Loop-225 ---------------------------
# package_name:  com.hootapps.soundrecorder
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.hootapps.soundrecorder
# zero_file_size:  0
# --------------------------- Loop-226 ---------------------------
# package_name:  com.huaweiband9fitnessappadvice.kantundev
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.huaweiband9fitnessappadvice.kantundev
# zero_file_size:  0
# --------------------------- Loop-227 ---------------------------
# package_name:  com.huawo.hawofit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.huawo.hawofit
# zero_file_size:  0
# --------------------------- Loop-228 ---------------------------
# package_name:  com.huawo.ufit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\com.huawo.ufit
# zero_file_size:  0
# --------------------------- Loop-229 ---------------------------
# ...
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ie.zappy.fennec.barbellqueenfitness
# zero_file_size:  0
# --------------------------- Loop-555 ---------------------------
# package_name:  il.co.freefit.freefit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\il.co.freefit.freefit
# zero_file_size:  0
# --------------------------- Loop-556 ---------------------------
# package_name:  il.co.offline.profit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\il.co.offline.profit
# zero_file_size:  0
# --------------------------- Loop-557 ---------------------------
# package_name:  in.codeseed.audify
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\in.codeseed.audify
# zero_file_size:  0
# --------------------------- Loop-558 ---------------------------
# package_name:  in.fitnesspal.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\in.fitnesspal.app
# zero_file_size:  0
# --------------------------- Loop-559 ---------------------------
# package_name:  interactiveshift.com.trailswear
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\interactiveshift.com.trailswear
# zero_file_size:  0
# --------------------------- Loop-560 ---------------------------
# package_name:  io.befitter.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\io.befitter.app
# zero_file_size:  0
# --------------------------- Loop-561 ---------------------------
# package_name:  io.fitness.club
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\io.fitness.club
# zero_file_size:  0
# --------------------------- Loop-562 ---------------------------
# package_name:  it.evolutionfit.evolutionfit.club
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\it.evolutionfit.evolutionfit.club
# zero_file_size:  0
# --------------------------- Loop-563 ---------------------------
# package_name:  it.softwarepalestre.newfitnessclub
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\it.softwarepalestre.newfitnessclub
# zero_file_size:  0
# --------------------------- Loop-564 ---------------------------
# package_name:  it.tripix.buddyfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit
# zero_file_size:  0
# --------------------------- Loop-565 ---------------------------
# package_name:  je.fit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\je.fit
# zero_file_size:  0
# --------------------------- Loop-566 ---------------------------
# package_name:  jp.co.yahoo.android.vassist
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist
# zero_file_size:  0
# --------------------------- Loop-567 ---------------------------
# package_name:  jp.joyfit.joyfitappandroid
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\jp.joyfit.joyfitappandroid
# zero_file_size:  0
# --------------------------- Loop-568 ---------------------------
# package_name:  kr.co.everyfit.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\kr.co.everyfit.fitness
# zero_file_size:  0
# --------------------------- Loop-569 ---------------------------
# package_name:  kr.co.openit.openrider
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\kr.co.openit.openrider
# zero_file_size:  0
# --------------------------- Loop-570 ---------------------------
# package_name:  kr.fitt.fmes
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\kr.fitt.fmes
# zero_file_size:  0
# --------------------------- Loop-571 ---------------------------
# package_name:  kz.maestrosultan.fitjournal
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\kz.maestrosultan.fitjournal
# zero_file_size:  0
# --------------------------- Loop-572 ---------------------------
# package_name:  loseweight.weightloss.workout.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\loseweight.weightloss.workout.fitness
# zero_file_size:  0
# --------------------------- Loop-573 ---------------------------
# package_name:  maxcom.toolbox.altimeter
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\maxcom.toolbox.altimeter
# zero_file_size:  0
# --------------------------- Loop-574 ---------------------------
# package_name:  me.cofit.ironman
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\me.cofit.ironman
# zero_file_size:  0
# --------------------------- Loop-575 ---------------------------
# package_name:  musclemonster.fitness.workout.home.gym.planner
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\musclemonster.fitness.workout.home.gym.planner
# zero_file_size:  0
# --------------------------- Loop-576 ---------------------------
# package_name:  net.ddns.axiiim.wearphonelock
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.ddns.axiiim.wearphonelock
# zero_file_size:  0
# --------------------------- Loop-577 ---------------------------
# package_name:  net.familo.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.familo.android
# zero_file_size:  0
# --------------------------- Loop-578 ---------------------------
# package_name:  net.homeip.thkerkmann.einkaufsliste
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.homeip.thkerkmann.einkaufsliste
# zero_file_size:  0
# --------------------------- Loop-579 ---------------------------
# package_name:  net.kosev.dicing
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.kosev.dicing
# zero_file_size:  0
# --------------------------- Loop-580 ---------------------------
# package_name:  net.kurdsofts.fitnesskar
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.kurdsofts.fitnesskar
# zero_file_size:  0
# --------------------------- Loop-581 ---------------------------
# package_name:  net.peater.fitlovers
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers
# zero_file_size:  0
# --------------------------- Loop-582 ---------------------------
# package_name:  net.sarmady.akhbarak
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.sarmady.akhbarak
# zero_file_size:  0
# --------------------------- Loop-583 ---------------------------
# package_name:  net.workout.lose.weight.fitness.fit.coach
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.workout.lose.weight.fitness.fit.coach
# zero_file_size:  0
# --------------------------- Loop-584 ---------------------------
# package_name:  net.workoutinc.seven_7minutesfitness_forwomen
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen
# zero_file_size:  0
# --------------------------- Loop-585 ---------------------------
# package_name:  nl.birdssoftware.mondaymorning
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nl.birdssoftware.mondaymorning
# zero_file_size:  0
# --------------------------- Loop-586 ---------------------------
# package_name:  nl.dominos.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nl.dominos.android
# zero_file_size:  0
# --------------------------- Loop-587 ---------------------------
# package_name:  nl.fitforfree.serviceapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nl.fitforfree.serviceapp
# zero_file_size:  0
# --------------------------- Loop-588 ---------------------------
# package_name:  nl.nefit.easy.main
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nl.nefit.easy.main
# zero_file_size:  0
# --------------------------- Loop-589 ---------------------------
# package_name:  nz.co.madfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nz.co.madfit
# zero_file_size:  0
# --------------------------- Loop-590 ---------------------------
# package_name:  nz.co.telecom.smartphone.android
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android
# zero_file_size:  0
# --------------------------- Loop-591 ---------------------------
# package_name:  oms.mmc.fortunetelling.gmpay.almanac2
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\oms.mmc.fortunetelling.gmpay.almanac2
# zero_file_size:  0
# --------------------------- Loop-592 ---------------------------
# package_name:  org.eson.getfit3
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.eson.getfit3
# zero_file_size:  0
# --------------------------- Loop-593 ---------------------------
# package_name:  org.fitrunner
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.fitrunner
# zero_file_size:  0
# --------------------------- Loop-594 ---------------------------
# package_name:  org.moffitt.brandedpatientportal.play
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.moffitt.brandedpatientportal.play
# zero_file_size:  0
# --------------------------- Loop-595 ---------------------------
# package_name:  org.obduro.kentekeninfo
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.obduro.kentekeninfo
# zero_file_size:  0
# --------------------------- Loop-596 ---------------------------
# package_name:  org.sombrenuit.dk.redfeed.free
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.sombrenuit.dk.redfeed.free
# zero_file_size:  0
# --------------------------- Loop-597 ---------------------------
# package_name:  org.uguess.android.sysinfo.wear
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\org.uguess.android.sysinfo.wear
# zero_file_size:  0
# --------------------------- Loop-598 ---------------------------
# package_name:  ott.beatboxingfitnessworkouts
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ott.beatboxingfitnessworkouts
# zero_file_size:  0
# --------------------------- Loop-599 ---------------------------
# package_name:  ott.transformyoufitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ott.transformyoufitness
# zero_file_size:  0
# --------------------------- Loop-600 ---------------------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# zero_file_size:  0
# --------------------------- Loop-601 ---------------------------
# package_name:  pl.efitness.mobile
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\pl.efitness.mobile
# zero_file_size:  0
# --------------------------- Loop-602 ---------------------------
# package_name:  pl.fit.world
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\pl.fit.world
# zero_file_size:  0
# --------------------------- Loop-603 ---------------------------
# package_name:  pl.tweeba.mobile.learning.english
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\pl.tweeba.mobile.learning.english
# zero_file_size:  0
# --------------------------- Loop-604 ---------------------------
# package_name:  rebel.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\rebel.fitness
# zero_file_size:  0
# --------------------------- Loop-605 ---------------------------
# package_name:  revox.voxnet
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\revox.voxnet
# zero_file_size:  0
# --------------------------- Loop-606 ---------------------------
# package_name:  ro.fitgym
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ro.fitgym
# zero_file_size:  0
# --------------------------- Loop-607 ---------------------------
# package_name:  rs.abstract.fitpass
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\rs.abstract.fitpass
# zero_file_size:  0
# --------------------------- Loop-608 ---------------------------
# package_name:  rs.fastfit.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\rs.fastfit.app
# zero_file_size:  0
# --------------------------- Loop-609 ---------------------------
# package_name:  rs.nonstopfitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\rs.nonstopfitness
# zero_file_size:  0
# --------------------------- Loop-610 ---------------------------
# package_name:  ru.disav.befit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ru.disav.befit
# zero_file_size:  0
# --------------------------- Loop-611 ---------------------------
# package_name:  ru.starline
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\ru.starline
# zero_file_size:  0
# --------------------------- Loop-612 ---------------------------
# package_name:  scope.fitnessfirstmena
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\scope.fitnessfirstmena
# zero_file_size:  0
# --------------------------- Loop-613 ---------------------------
# package_name:  se.matlistan.free
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\se.matlistan.free
# zero_file_size:  0
# --------------------------- Loop-614 ---------------------------
# package_name:  senior.fitness.exercises.elderly
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\senior.fitness.exercises.elderly
# zero_file_size:  0
# --------------------------- Loop-615 ---------------------------
# package_name:  softin.my.fast.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\softin.my.fast.fitness
# zero_file_size:  0
# --------------------------- Loop-616 ---------------------------
# package_name:  starshipproduct.perifitmainapp
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\starshipproduct.perifitmainapp
# zero_file_size:  0
# --------------------------- Loop-617 ---------------------------
# package_name:  steptracker.healthandfitness.walkingtracker.pedometer
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\steptracker.healthandfitness.walkingtracker.pedometer
# zero_file_size:  0
# --------------------------- Loop-618 ---------------------------
# package_name:  sweatybetty.com.fitness.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\sweatybetty.com.fitness.app
# zero_file_size:  0
# --------------------------- Loop-619 ---------------------------
# package_name:  tarlin.fitness.loseweight.belly.fem
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\tarlin.fitness.loseweight.belly.fem
# zero_file_size:  0
# --------------------------- Loop-620 ---------------------------
# package_name:  tk.deuchnord.phonejuicechecker
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\tk.deuchnord.phonejuicechecker
# zero_file_size:  0
# --------------------------- Loop-621 ---------------------------
# package_name:  today.upfit
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\today.upfit
# zero_file_size:  0
# --------------------------- Loop-622 ---------------------------
# package_name:  tr.com.fitwell.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\tr.com.fitwell.app
# zero_file_size:  0
# --------------------------- Loop-623 ---------------------------
# package_name:  uk.co.fitness4less.app
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\uk.co.fitness4less.app
# zero_file_size:  0
# --------------------------- Loop-624 ---------------------------
# package_name:  uk.me.andre.dicionarioportugues
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\uk.me.andre.dicionarioportugues
# zero_file_size:  0
# --------------------------- Loop-625 ---------------------------
# package_name:  verv.health.fitness.workout.weight.loss
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\verv.health.fitness.workout.weight.loss
# zero_file_size:  0
# --------------------------- Loop-626 ---------------------------
# package_name:  women.workout.female.fitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# zero_file_size:  0
# --------------------------- Loop-627 ---------------------------
# package_name:  workoutforwomen.femalefitness.womenworkout.loseweight
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\workoutforwomen.femalefitness.womenworkout.loseweight
# zero_file_size:  0
# --------------------------- Loop-628 ---------------------------
# package_name:  xyz.micrusa.fitnesscalc
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\xyz.micrusa.fitnesscalc
# zero_file_size:  0
# --------------------------- Loop-629 ---------------------------
# package_name:  yogaworkouts.dailyyoga.yogafitness
# traffic_directory:  E:\wearable-capture-traffic\wearable-app\yogaworkouts.dailyyoga.yogafitness
# zero_file_size:  0
