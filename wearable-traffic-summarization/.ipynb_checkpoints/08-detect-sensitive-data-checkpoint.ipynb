# %%
import os
from pymongo import MongoClient
import json
from dotenv import load_dotenv
# Langchain load data
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import DirectoryLoader
### LLMs - Langchain
import openai
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model
### Summary chain
from langchain.prompts import PromptTemplate, ChatPromptTemplate
from langchain.chains import LLMChain, MapReduceChain, load_summarize_chain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain_community.document_loaders import TextLoader

# %%
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_ids_with_sent_out(collection):
    """
    Retrieves all _id values from MongoDB documents that contain the keyword 'sent-out'.
    
    :param collection: The MongoDB collection.
    :return: A list of _id values.
    """
    try:
        # Query to find documents where any field contains "sent-out"
        query = {"sent-out": {"$exists": True}}
        
        # Fetch matching documents and extract _id values
        ids = [doc["_id"] for doc in collection.find(query, {"_id": 1})]
        
        return ids
    except Exception as e:
        print(f"Error retrieving _id values: {e}")
        return []
def get_data_by_id(collection, id_value):
    try:
        # Try to cast id_value to ObjectId if it is a valid ObjectId
        try:
            id_value = ObjectId(id_value)
        except:
            # If it is not a valid ObjectId, leave it as is (e.g., string _id)
            pass
        
        document = collection.find_one({"_id": id_value})
        return document
    except Exception as e:
        print(f"Error: {e}")
        return None
def generate_sensitive_data_prompt(app_data_sent):
    """
    Generates a formatted prompt to analyze Android app outgoing traffic,
    detecting sensitive data based on Android manifest permissions, PII, and tracking.

    :param app_data_sent: List of dictionaries containing outgoing app data.
    :return: A formatted prompt string.
    """
    sensitive_data_prompt = PromptTemplate(
        input_variables=["app_data_sent"],
        template="""
        You are a cybersecurity expert specializing in **privacy and data protection** for Android applications.
        Your task is to analyze the outgoing network traffic from an Android app and determine whether the data is **sensitive** based on Android security policies and privacy regulations.

        ### **Sensitive Data Classification Rules:**
        1. **Device-Related Data:** Considered sensitive **only if** Android OS provides a **manifest permission** to protect it.
        2. **Personally Identifiable Information (PII):** Always sensitive. This includes:
            - **Email, health data, gender, height, weight, phone number, IP address, location, etc.**
        3. **Tracking & Advertising Data:** Always sensitive, including:
            - **Universally unique identifier (UUID), Firebase Installation ID, Advertising ID, Google Advertising ID (GAID), Identifier for Advertisers (IDFA), tracking tokens, app analytics identifiers.**
        
        ### **Expected JSON Output Structure:**
        ```json
        {{
            "sensitive_data_detected": [
                {{
                    "type": "Location Data",
                    "value": "Latitude: 45.8137757, Longitude: 8.8311485",
                    "android_permission": "ACCESS_FINE_LOCATION"
                }},
                {{
                    "type": "Email",
                    "value": "user@example.com",
                    "android_permission": null
                }},
                {{
                    "type": "Tracking ID",
                    "value": "GA-123456",
                    "android_permission": null
                }}
            ]
        }}
        ```

        - **If No Sensitive Data is Found** or Information that is unclear or cannot be identified as sensitive data, return:
          ```json
          {{
              "sensitive_data_detected": "no sensitive data detected"
          }}
          ```

        ### **Given Data for Analysis:**
        ```json
        {app_data_sent}
        ```

        Please only response as JSON above and don't add any explain.
        """
    )
    
    return sensitive_data_prompt.format(app_data_sent=app_data_sent)
def extract_output_text_as_dict(response):
    """
    Extracts the 'output_text' from the response, cleans it, and converts it into a dictionary.

    :param response: The response dictionary containing 'output_text'.
    :return: A dictionary parsed from the 'output_text', or an empty dict if parsing fails.
    """
    if not response or not hasattr(response, "content"):  # Ensure response is valid
        print("Error: Invalid response object.")
        return {}

    output_text = response.content  # Assuming response.content holds the JSON string

    # Remove code block markers (```json and ```) if present
    if output_text.startswith("```json"):
        output_text = output_text[len("```json"):].strip("`").strip()

    try:
        # Convert the cleaned JSON string into a dictionary
        output_dict = json.loads(output_text)
        return output_dict
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return {}  # Return an empty dictionary instead of None


def append_sensitive_data(data_dict, sent_out_arr):
    """
    Append each dictionary under 'sensitive_data_detected' into sent_out_arr.
    If 'sensitive_data_detected' is a string, append it as a dictionary.

    :param data_dict: Dictionary containing sensitive data under "sensitive_data_detected".
    :param sent_out_arr: List to append the extracted data.
    """
    if not isinstance(data_dict, dict):  # Ensure data_dict is valid
        print("Error: data_dict is None or not a dictionary.")
        return  # Exit function safely

    if "sensitive_data_detected" in data_dict:
        detected_data = data_dict["sensitive_data_detected"]

        if isinstance(detected_data, list):  
            # If it's a list, extend the list with individual dictionaries
            sent_out_arr.extend(detected_data)
        elif isinstance(detected_data, str):  
            # If it's a string, append it as a dictionary
            sent_out_arr.append({"sensitive_data_detected": detected_data})
def write_log(file_path, content):
    """Append content to a log file."""
    with open(file_path, "a", encoding="utf-8") as log_file:
        log_file.write(content + "\n")
def update_mongodb_element(collection, _id, update_keyword, update_value):
    """
    Updates a MongoDB document based on the given _id value.
    
    :param collection: The MongoDB collection.
    :param _id: The unique identifier of the document to update.
    :param update_keyword: The field to update in the document.
    :param update_value: Either a string or a list of dictionaries.
    :return: The result of the update operation.
    """
    # Validate that update_value is either a string or a list of dictionaries
    if not isinstance(update_value, (str, list)):
        raise ValueError("update_value must be either a string or a list of dictionaries")

    # If it's a list, ensure it contains only dictionaries
    if isinstance(update_value, list) and not all(isinstance(item, dict) for item in update_value):
        raise ValueError("update_value as a list must contain only dictionaries")

    # MongoDB Update Query
    update_query = {"$set": {update_keyword: update_value}}

    # Perform update
    result = collection.update_one({"_id": _id}, update_query)

    # Return update result
    return result
def write_to_txt(file_path, content):
    """
    Writes a string to a text file. If the file does not exist, it creates one.

    :param file_path: The path of the text file.
    :param content: The string content to write to the file.
    """
    try:
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(content)
        print(f"Data successfully written to {file_path}")
    except Exception as e:
        print(f"Error writing to file: {e}")

# %%
mongoDB_uri = 'mongodb://192.168.1.14:27017'
mongoDB_database = 'wearable-project' 
mongoDB_collection = 'wearable-app'

log_dir = r"C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_summarization_log"
sensitive_data_path = r"C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app"
os.makedirs(log_dir, exist_ok=True)

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)

# %%
traffic_id_arr = get_ids_with_sent_out(collection)
# print("traffic_id_arr: ", traffic_id_arr)
print(len(traffic_id_arr))
# Out:
# 642

# %%
#. Chat model
# Setup model
# Load environment variables
load_dotenv()

# Retrieve API key
api_key = os.getenv("OPENAI_API_KEY")
# Ensure the API key is correctly set
if not api_key:
    raise ValueError("OPENAI_API_KEY is not set in the environment variables")

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    openai_api_key=api_key  # Ensure you explicitly pass the API key
)

# %%
for i in range(0,len(traffic_id_arr)):
    sensitive_data_arr = []
    print("------------------- Loop-"+str(i)+"-------------------")
    check_package_name = traffic_id_arr[i]
    print("check_package_name: ",check_package_name)
    log_file_path = os.path.join(log_dir, f"log-{check_package_name}.log")
    
    # Write initial log info
    write_log(log_file_path, f"------------------- Loop-{i} -------------------")
    write_log(log_file_path, f"check_package_name: {check_package_name}")    
    app_data = get_data_by_id(collection, check_package_name)
    app_data_sent = app_data["sent-out"]
    formatted_prompt = generate_sensitive_data_prompt(app_data_sent)
    write_log(log_file_path, f"**************** Prompt ****************\n{formatted_prompt}")
    output = llm.invoke(formatted_prompt)
    write_log(log_file_path, f"**************** LLM Origin Response ****************\n{output.content}")
    file_path = sensitive_data_path+"\\"+check_package_name+".txt"
    write_to_txt(file_path, output.content)
#     output_dict = extract_output_text_as_dict(output)
#     write_log(log_file_path, f"++++++++++++++++ LLM Dict Response ++++++++++++++++\n {output_dict}")
#     append_sensitive_data(output_dict,sensitive_data_arr)
#     write_log(log_file_path, f"===================== Final Sensitive Data Array ===================== \n{sensitive_data_arr}")
#     update_result_status = update_mongodb_element(collection, check_package_name, "sensitive-data", sensitive_data_arr)
#     if update_result_status.modified_count > 0:
#         print(f"Successfully updated document with list for _id: {check_package_name}")
#     else:
#         print(f"No document found or updated for _id: {check_package_name} (list update)")
#     break
# Out:
# ------------------- Loop-0-------------------
# check_package_name:  in.codeseed.audify
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\in.codeseed.audify.txt
# ------------------- Loop-1-------------------
# check_package_name:  com.urbandroid.lux
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.urbandroid.lux.txt
# ------------------- Loop-2-------------------
# check_package_name:  maxcom.toolbox.altimeter
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\maxcom.toolbox.altimeter.txt
# ------------------- Loop-3-------------------
# check_package_name:  com.reflive.reflive
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.reflive.reflive.txt
# ------------------- Loop-4-------------------
# check_package_name:  com.tomtop.smart
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.tomtop.smart.txt
# ------------------- Loop-5-------------------
# check_package_name:  com.mauriciotogneri.shoppinglist
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.mauriciotogneri.shoppinglist.txt
# ------------------- Loop-6-------------------
# check_package_name:  com.szyk.myheart
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.szyk.myheart.txt
# ------------------- Loop-7-------------------
# check_package_name:  interactiveshift.com.trailswear
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\interactiveshift.com.trailswear.txt
# ------------------- Loop-8-------------------
# check_package_name:  com.atlaswearables.ionic
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.atlaswearables.ionic.txt
# ------------------- Loop-9-------------------
# check_package_name:  je.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\je.fit.txt
# ------------------- Loop-10-------------------
# check_package_name:  com.acquasys.contrack
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.acquasys.contrack.txt
# ------------------- Loop-11-------------------
# check_package_name:  com.daniel.apps.wpe
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.daniel.apps.wpe.txt
# ------------------- Loop-12-------------------
# check_package_name:  net.ddns.axiiim.wearphonelock
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.ddns.axiiim.wearphonelock.txt
# ------------------- Loop-13-------------------
# check_package_name:  org.uguess.android.sysinfo.wear
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\org.uguess.android.sysinfo.wear.txt
# ------------------- Loop-14-------------------
# check_package_name:  com.ericfabreu.wearflashcards
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ericfabreu.wearflashcards.txt
# ------------------- Loop-15-------------------
# check_package_name:  com.appfour.wearvideos
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.appfour.wearvideos.txt
# ------------------- Loop-16-------------------
# check_package_name:  com.lilc103.buttonbattle
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lilc103.buttonbattle.txt
# ------------------- Loop-17-------------------
# check_package_name:  com.overseasolutions.waterapp.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.overseasolutions.waterapp.app.txt
# ------------------- Loop-18-------------------
# check_package_name:  tk.deuchnord.phonejuicechecker
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\tk.deuchnord.phonejuicechecker.txt
# ------------------- Loop-19-------------------
# check_package_name:  de.softxperience.android.quickprofiles
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\de.softxperience.android.quickprofiles.txt
# ------------------- Loop-20-------------------
# check_package_name:  com.piggeh.flip
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.piggeh.flip.txt
# ------------------- Loop-21-------------------
# check_package_name:  kr.co.openit.openrider
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\kr.co.openit.openrider.txt
# ------------------- Loop-22-------------------
# check_package_name:  com.naing.englishmyanmardictionary
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.naing.englishmyanmardictionary.txt
# ------------------- Loop-23-------------------
# check_package_name:  com.gin.shoppinglist
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.gin.shoppinglist.txt
# ------------------- Loop-24-------------------
# check_package_name:  com.ccswe.SmokingLog
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ccswe.SmokingLog.txt
# ------------------- Loop-25-------------------
# check_package_name:  de.svz
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\de.svz.txt
# ------------------- Loop-26-------------------
# check_package_name:  com.komparato.informer.wear
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.komparato.informer.wear.txt
# ------------------- Loop-27-------------------
# check_package_name:  net.sarmady.akhbarak
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.sarmady.akhbarak.txt
# ------------------- Loop-28-------------------
# check_package_name:  org.sombrenuit.dk.redfeed.free
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\org.sombrenuit.dk.redfeed.free.txt
# ------------------- Loop-29-------------------
# check_package_name:  com.glidetalk.glideapp
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.glidetalk.glideapp.txt
# ------------------- Loop-30-------------------
# check_package_name:  uk.me.andre.dicionarioportugues
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\uk.me.andre.dicionarioportugues.txt
# ------------------- Loop-31-------------------
# check_package_name:  com.link.messages.sms
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.link.messages.sms.txt
# ------------------- Loop-32-------------------
# check_package_name:  com.kiss.keeper
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.kiss.keeper.txt
# ------------------- Loop-33-------------------
# check_package_name:  com.google.android.apps.messaging
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.google.android.apps.messaging.txt
# ------------------- Loop-34-------------------
# check_package_name:  com.shinayser.xwingmanager
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.shinayser.xwingmanager.txt
# ------------------- Loop-35-------------------
# check_package_name:  com.aheqab.salahwear
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.aheqab.salahwear.txt
# ------------------- Loop-36-------------------
# check_package_name:  com.rokontrol.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.rokontrol.android.txt
# ------------------- Loop-37-------------------
# check_package_name:  com.biztech.magemobadmin
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.biztech.magemobadmin.txt
# ------------------- Loop-38-------------------
# check_package_name:  com.skimble.workouts
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.skimble.workouts.txt
# ------------------- Loop-39-------------------
# check_package_name:  pl.tweeba.mobile.learning.english
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\pl.tweeba.mobile.learning.english.txt
# ------------------- Loop-40-------------------
# check_package_name:  org.obduro.kentekeninfo
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\org.obduro.kentekeninfo.txt
# ------------------- Loop-41-------------------
# check_package_name:  ru.starline
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\ru.starline.txt
# ------------------- Loop-42-------------------
# check_package_name:  jp.co.yahoo.android.vassist
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\jp.co.yahoo.android.vassist.txt
# ------------------- Loop-43-------------------
# check_package_name:  com.spotify.music
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.spotify.music.txt
# ------------------- Loop-44-------------------
# check_package_name:  oms.mmc.fortunetelling.gmpay.almanac2
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\oms.mmc.fortunetelling.gmpay.almanac2.txt
# ------------------- Loop-45-------------------
# check_package_name:  com.mictale.gpsessentials
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.mictale.gpsessentials.txt
# ------------------- Loop-46-------------------
# check_package_name:  com.ktmusic.geniemusic
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ktmusic.geniemusic.txt
# ------------------- Loop-47-------------------
# check_package_name:  net.familo.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.familo.android.txt
# ------------------- Loop-48-------------------
# check_package_name:  com.cpsolutions.contacts
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.cpsolutions.contacts.txt
# ------------------- Loop-49-------------------
# check_package_name:  eu.power_switch
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\eu.power_switch.txt
# ------------------- Loop-50-------------------
# check_package_name:  com.hootapps.soundrecorder
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.hootapps.soundrecorder.txt
# ------------------- Loop-51-------------------
# check_package_name:  com.directed.android.viper
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.directed.android.viper.txt
# ------------------- Loop-52-------------------
# check_package_name:  com.adi.remote.phone
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.adi.remote.phone.txt
# ------------------- Loop-53-------------------
# check_package_name:  com.lucky_ponies.dokin
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lucky_ponies.dokin.txt
# ------------------- Loop-54-------------------
# check_package_name:  com.yannik.wear.anki
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.yannik.wear.anki.txt
# ------------------- Loop-55-------------------
# check_package_name:  com.toshremote.view
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.toshremote.view.txt
# ------------------- Loop-56-------------------
# check_package_name:  com.muzzley
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.muzzley.txt
# ------------------- Loop-57-------------------
# check_package_name:  net.homeip.thkerkmann.einkaufsliste
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.homeip.thkerkmann.einkaufsliste.txt
# ------------------- Loop-58-------------------
# check_package_name:  se.matlistan.free
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\se.matlistan.free.txt
# ------------------- Loop-59-------------------
# check_package_name:  nl.birdssoftware.mondaymorning
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\nl.birdssoftware.mondaymorning.txt
# ------------------- Loop-60-------------------
# check_package_name:  com.dusiassistant
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.dusiassistant.txt
# ------------------- Loop-61-------------------
# check_package_name:  com.pimp.calculator
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.pimp.calculator.txt
# ------------------- Loop-62-------------------
# check_package_name:  at.radioplayer.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\at.radioplayer.android.txt
# ------------------- Loop-63-------------------
# check_package_name:  revox.voxnet
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\revox.voxnet.txt
# ------------------- Loop-64-------------------
# check_package_name:  com.nstudio.weatherhere.free
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.nstudio.weatherhere.free.txt
# ------------------- Loop-65-------------------
# check_package_name:  com.dimlix.phrase
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.dimlix.phrase.txt
# ------------------- Loop-66-------------------
# check_package_name:  com.cm.wearintervaltimer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.cm.wearintervaltimer.txt
# ------------------- Loop-67-------------------
# check_package_name:  com.pocketlifestyle.music.tune
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.pocketlifestyle.music.tune.txt
# ------------------- Loop-68-------------------
# check_package_name:  com.dolcegustofree.activity
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.dolcegustofree.activity.txt
# ------------------- Loop-69-------------------
# check_package_name:  com.naukriGulf.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.naukriGulf.app.txt
# ------------------- Loop-70-------------------
# check_package_name:  com.palaspro.listainteligentecompra
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.palaspro.listainteligentecompra.txt
# ------------------- Loop-71-------------------
# check_package_name:  com.estela
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.estela.txt
# ------------------- Loop-72-------------------
# check_package_name:  com.k560.luciddreaminducer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.k560.luciddreaminducer.txt
# ------------------- Loop-73-------------------
# check_package_name:  com.droibit.findwear
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.droibit.findwear.txt
# ------------------- Loop-74-------------------
# check_package_name:  com.amdroidalarmclock.amdroid
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.amdroidalarmclock.amdroid.txt
# ------------------- Loop-75-------------------
# check_package_name:  com.aircanada
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.aircanada.txt
# ------------------- Loop-76-------------------
# check_package_name:  fi.hhtec.coach4pro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fi.hhtec.coach4pro.txt
# ------------------- Loop-77-------------------
# check_package_name:  com.cisco.webex.meetings
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.cisco.webex.meetings.txt
# ------------------- Loop-78-------------------
# check_package_name:  nl.dominos.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\nl.dominos.android.txt
# ------------------- Loop-79-------------------
# check_package_name:  nz.co.telecom.smartphone.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\nz.co.telecom.smartphone.android.txt
# ------------------- Loop-80-------------------
# check_package_name:  com.acmeaom.android.myradar
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.acmeaom.android.myradar.txt
# ------------------- Loop-81-------------------
# check_package_name:  com.rageconsulting.android.lightflowlegacy
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.rageconsulting.android.lightflowlegacy.txt
# ------------------- Loop-82-------------------
# check_package_name:  tr.com.fitwell.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\tr.com.fitwell.app.txt
# ------------------- Loop-83-------------------
# check_package_name:  com.cisco.im
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.cisco.im.txt
# ------------------- Loop-84-------------------
# check_package_name:  com.sasyabook.businesscardapp
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.sasyabook.businesscardapp.txt
# ------------------- Loop-85-------------------
# check_package_name:  com.jquiz.english
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.jquiz.english.txt
# ------------------- Loop-86-------------------
# check_package_name:  com.edjing.edjingdjturntable
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.edjing.edjingdjturntable.txt
# ------------------- Loop-87-------------------
# check_package_name:  biz.mobidev.mdplayer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\biz.mobidev.mdplayer.txt
# ------------------- Loop-88-------------------
# check_package_name:  dev.niamor.wearliveboxremote
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\dev.niamor.wearliveboxremote.txt
# ------------------- Loop-89-------------------
# check_package_name:  net.kosev.dicing
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.kosev.dicing.txt
# ------------------- Loop-90-------------------
# check_package_name:  adarshurs.android.vlcmobileremote
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\adarshurs.android.vlcmobileremote.txt
# ------------------- Loop-91-------------------
# check_package_name:  com.pasha.music977
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.pasha.music977.txt
# ------------------- Loop-92-------------------
# check_package_name:  com.bhphoto
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bhphoto.txt
# ------------------- Loop-93-------------------
# check_package_name:  com.unated
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.unated.txt
# ------------------- Loop-94-------------------
# check_package_name:  com.bandlab.bandlab
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bandlab.bandlab.txt
# ------------------- Loop-95-------------------
# check_package_name:  com.kfaraj.notepad
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.kfaraj.notepad.txt
# ------------------- Loop-96-------------------
# check_package_name:  com.SnowReport.screens
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.SnowReport.screens.txt
# ------------------- Loop-97-------------------
# check_package_name:  com.ubivelox.uvophone
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ubivelox.uvophone.txt
# ------------------- Loop-98-------------------
# check_package_name:  com.directed.android.smartstart
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.directed.android.smartstart.txt
# ------------------- Loop-99-------------------
# check_package_name:  com.lf.lfvtandroid
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lf.lfvtandroid.txt
# ------------------- Loop-100-------------------
# check_package_name:  com.moblino.simplenote
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.moblino.simplenote.txt
# ------------------- Loop-101-------------------
# check_package_name:  com.clearskyapps.fitnessfamily.Run5K
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.clearskyapps.fitnessfamily.Run5K.txt
# ------------------- Loop-102-------------------
# check_package_name:  com.google.android.deskclock
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.google.android.deskclock.txt
# ------------------- Loop-103-------------------
# check_package_name:  com.shazam.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.shazam.android.txt
# ------------------- Loop-104-------------------
# check_package_name:  com.biostatusfit.www
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.biostatusfit.www.txt
# ------------------- Loop-105-------------------
# check_package_name:  nl.nefit.easy.main
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\nl.nefit.easy.main.txt
# ------------------- Loop-106-------------------
# check_package_name:  com.google.android.apps.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.google.android.apps.fitness.txt
# ------------------- Loop-107-------------------
# check_package_name:  de.komoot.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\de.komoot.android.txt
# ------------------- Loop-108-------------------
# check_package_name:  com.gp.android.fitproject.colorwalk
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.gp.android.fitproject.colorwalk.txt
# ------------------- Loop-109-------------------
# check_package_name:  com.fitnesskeeper.runkeeper.pro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitnesskeeper.runkeeper.pro.txt
# ------------------- Loop-110-------------------
# check_package_name:  com.myfitnesspal.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.myfitnesspal.android.txt
# ------------------- Loop-111-------------------
# check_package_name:  com.fitbit.FitbitMobile
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitbit.FitbitMobile.txt
# ------------------- Loop-112-------------------
# check_package_name:  steptracker.healthandfitness.walkingtracker.pedometer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\steptracker.healthandfitness.walkingtracker.pedometer.txt
# ------------------- Loop-113-------------------
# check_package_name:  com.czw.freefit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.czw.freefit.txt
# ------------------- Loop-114-------------------
# check_package_name:  com.nb.mybenefits
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.nb.mybenefits.txt
# ------------------- Loop-115-------------------
# check_package_name:  com.topstep.fitcloudpro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.topstep.fitcloudpro.txt
# ------------------- Loop-116-------------------
# check_package_name:  com.planetfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.planetfitness.txt
# ------------------- Loop-117-------------------
# check_package_name:  com.popularapp.thirtydayfitnesschallenge
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.popularapp.thirtydayfitnesschallenge.txt
# ------------------- Loop-118-------------------
# check_package_name:  com.fitness22.running
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitness22.running.txt
# ------------------- Loop-119-------------------
# check_package_name:  women.workout.female.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\women.workout.female.fitness.txt
# ------------------- Loop-120-------------------
# check_package_name:  com.lafitness.lafitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lafitness.lafitness.txt
# ------------------- Loop-121-------------------
# check_package_name:  com.veryfit2hr.second
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.veryfit2hr.second.txt
# ------------------- Loop-122-------------------
# check_package_name:  loseweight.weightloss.workout.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\loseweight.weightloss.workout.fitness.txt
# ------------------- Loop-123-------------------
# check_package_name:  com.hrd.iam
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.hrd.iam.txt
# ------------------- Loop-124-------------------
# check_package_name:  com.zeopoxa.fitness.cycling.bike
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.zeopoxa.fitness.cycling.bike.txt
# ------------------- Loop-125-------------------
# check_package_name:  com.benda.fitpro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.benda.fitpro.txt
# ------------------- Loop-126-------------------
# check_package_name:  com.github.jamesgay.fitnotes
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.github.jamesgay.fitnotes.txt
# ------------------- Loop-127-------------------
# check_package_name:  com.hrd.motivation
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.hrd.motivation.txt
# ------------------- Loop-128-------------------
# check_package_name:  app.weightfit.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\app.weightfit.android.txt
# ------------------- Loop-129-------------------
# check_package_name:  com.walkfit.weightloss.steptracker.pedometer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.walkfit.weightloss.steptracker.pedometer.txt
# ------------------- Loop-130-------------------
# check_package_name:  com.blinkfitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.blinkfitness.app.txt
# ------------------- Loop-131-------------------
# check_package_name:  com.lafitness.esporta
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lafitness.esporta.txt
# ------------------- Loop-132-------------------
# check_package_name:  com.plaifit.plaifit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.plaifit.plaifit.txt
# ------------------- Loop-133-------------------
# check_package_name:  dance.fit.zumba.weightloss.danceburn
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\dance.fit.zumba.weightloss.danceburn.txt
# ------------------- Loop-134-------------------
# check_package_name:  net.workout.lose.weight.fitness.fit.coach
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.workout.lose.weight.fitness.fit.coach.txt
# ------------------- Loop-135-------------------
# check_package_name:  dance.workout.home.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\dance.workout.home.fitness.txt
# ------------------- Loop-136-------------------
# check_package_name:  com.anytimefitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.anytimefitness.app.txt
# ------------------- Loop-137-------------------
# check_package_name:  com.fitnow.loseit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitnow.loseit.txt
# ------------------- Loop-138-------------------
# check_package_name:  com.eokoe.smartfitcoach
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.eokoe.smartfitcoach.txt
# ------------------- Loop-139-------------------
# check_package_name:  cn.fitdays.fitdays
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\cn.fitdays.fitdays.txt
# ------------------- Loop-140-------------------
# check_package_name:  com.starmax.runmefit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.starmax.runmefit.txt
# ------------------- Loop-141-------------------
# check_package_name:  com.runmifit.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.runmifit.android.txt
# ------------------- Loop-142-------------------
# check_package_name:  com.orangetheoryfitness.orangetheory
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.orangetheoryfitness.orangetheory.txt
# ------------------- Loop-143-------------------
# check_package_name:  digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\digifit.android.virtuagym.pro.greaterjolietymcasuperclub.txt
# ------------------- Loop-144-------------------
# check_package_name:  com.fourtechnologies.mynetdiary.ad
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fourtechnologies.mynetdiary.ad.txt
# ------------------- Loop-145-------------------
# check_package_name:  com.fitonomy.muscle.man
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitonomy.muscle.man.txt
# ------------------- Loop-146-------------------
# check_package_name:  com.fiton.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fiton.android.txt
# ------------------- Loop-147-------------------
# check_package_name:  fitness.home.workout.weight.loss
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fitness.home.workout.weight.loss.txt
# ------------------- Loop-148-------------------
# check_package_name:  com.citysportsfitness.android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.citysportsfitness.android.txt
# ------------------- Loop-149-------------------
# check_package_name:  com.lifetimefitness.interests.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lifetimefitness.interests.fitness.txt
# ------------------- Loop-150-------------------
# check_package_name:  app.growwithjo.diet.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\app.growwithjo.diet.fitness.txt
# ------------------- Loop-151-------------------
# check_package_name:  ee.myfitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\ee.myfitness.app.txt
# ------------------- Loop-152-------------------
# check_package_name:  digifit.android.virtuagym.pro.xsportfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\digifit.android.virtuagym.pro.xsportfitness.txt
# ------------------- Loop-153-------------------
# check_package_name:  com.bickster.fitbitbandfinder
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bickster.fitbitbandfinder.txt
# ------------------- Loop-154-------------------
# check_package_name:  com.netpulse.mobile.muvfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.netpulse.mobile.muvfitness.txt
# ------------------- Loop-155-------------------
# check_package_name:  com.fitifyapps.bwcardio
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitifyapps.bwcardio.txt
# ------------------- Loop-156-------------------
# check_package_name:  coach.zing.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\coach.zing.fitness.txt
# ------------------- Loop-157-------------------
# check_package_name:  com.bottegasol.com.migym.fitnessconnection
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bottegasol.com.migym.fitnessconnection.txt
# ------------------- Loop-158-------------------
# check_package_name:  com.lighthouse1.mobilebenefits.dbi
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lighthouse1.mobilebenefits.dbi.txt
# ------------------- Loop-159-------------------
# check_package_name:  com.netpulse.mobile.chuzefitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.netpulse.mobile.chuzefitness.txt
# ------------------- Loop-160-------------------
# check_package_name:  net.workoutinc.seven_7minutesfitness_forwomen
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\net.workoutinc.seven_7minutesfitness_forwomen.txt
# ------------------- Loop-161-------------------
# check_package_name:  com.eightfit.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.eightfit.app.txt
# ------------------- Loop-162-------------------
# check_package_name:  com.vt.vitafit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.vt.vitafit.txt
# ------------------- Loop-163-------------------
# check_package_name:  fitapp.fittofit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fitapp.fittofit.txt
# ------------------- Loop-164-------------------
# check_package_name:  com.mz.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.mz.fit.txt
# ------------------- Loop-165-------------------
# check_package_name:  com.samsung.android.service.health
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.samsung.android.service.health.txt
# ------------------- Loop-166-------------------
# check_package_name:  com.bendingspoons.thirtydayfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bendingspoons.thirtydayfitness.txt
# ------------------- Loop-167-------------------
# check_package_name:  com.qingniu.feelfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.qingniu.feelfit.txt
# ------------------- Loop-168-------------------
# check_package_name:  com.wakeup.wearfit2
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.wakeup.wearfit2.txt
# ------------------- Loop-169-------------------
# check_package_name:  com.trainerize.youfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.trainerize.youfit.txt
# ------------------- Loop-170-------------------
# check_package_name:  com.equinoxfitness.equinox
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.equinoxfitness.equinox.txt
# ------------------- Loop-171-------------------
# check_package_name:  com.organicapps.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.organicapps.fit.txt
# ------------------- Loop-172-------------------
# check_package_name:  com.nutrition.technologies.Fitia
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.nutrition.technologies.Fitia.txt
# ------------------- Loop-173-------------------
# check_package_name:  fitnesscoach.workoutplanner.weightloss
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fitnesscoach.workoutplanner.weightloss.txt
# ------------------- Loop-174-------------------
# check_package_name:  nz.co.madfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\nz.co.madfit.txt
# ------------------- Loop-175-------------------
# check_package_name:  org.moffitt.brandedpatientportal.play
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\org.moffitt.brandedpatientportal.play.txt
# ------------------- Loop-176-------------------
# check_package_name:  com.netpulse.mobile.eosfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.netpulse.mobile.eosfitness.txt
# ------------------- Loop-177-------------------
# check_package_name:  com.fliptonic.nicefitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fliptonic.nicefitness.txt
# ------------------- Loop-178-------------------
# check_package_name:  com.goodlifefitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.goodlifefitness.txt
# ------------------- Loop-179-------------------
# check_package_name:  com.quantumbit.fitmax
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.quantumbit.fitmax.txt
# ------------------- Loop-180-------------------
# check_package_name:  com.fitbod.fitbod
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitbod.fitbod.txt
# ------------------- Loop-181-------------------
# check_package_name:  com.wahoofitness.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.wahoofitness.fitness.txt
# ------------------- Loop-182-------------------
# check_package_name:  com.noisefit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.noisefit.txt
# ------------------- Loop-183-------------------
# check_package_name:  faceyoga.facefitness.dailyworkouts
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\faceyoga.facefitness.dailyworkouts.txt
# ------------------- Loop-184-------------------
# check_package_name:  com.viatek.fitnation.echelon_android
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.viatek.fitnation.echelon_android.txt
# ------------------- Loop-185-------------------
# check_package_name:  yogaworkouts.dailyyoga.yogafitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\yogaworkouts.dailyyoga.yogafitness.txt
# ------------------- Loop-186-------------------
# check_package_name:  com.myhexfit.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.myhexfit.app.txt
# ------------------- Loop-187-------------------
# check_package_name:  com.movefitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.movefitness.app.txt
# ------------------- Loop-188-------------------
# check_package_name:  com.caliberfitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.caliberfitness.app.txt
# ------------------- Loop-189-------------------
# check_package_name:  com.lesmills.fitnessplus
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lesmills.fitnessplus.txt
# ------------------- Loop-190-------------------
# check_package_name:  com.watch.yfitpro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.watch.yfitpro.txt
# ------------------- Loop-191-------------------
# check_package_name:  com.vasafitness.members
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.vasafitness.members.txt
# ------------------- Loop-192-------------------
# check_package_name:  com.centr.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.centr.app.txt
# ------------------- Loop-193-------------------
# check_package_name:  com.ifit.wolf
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ifit.wolf.txt
# ------------------- Loop-194-------------------
# check_package_name:  com.oplayer.goodmansfitpro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.oplayer.goodmansfitpro.txt
# ------------------- Loop-195-------------------
# check_package_name:  com.zjw.ffit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.zjw.ffit.txt
# ------------------- Loop-196-------------------
# check_package_name:  softin.my.fast.fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\softin.my.fast.fitness.txt
# ------------------- Loop-197-------------------
# check_package_name:  com.studiorouleau.funfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.studiorouleau.funfit.txt
# ------------------- Loop-198-------------------
# check_package_name:  drzio.senior.yoga.fitness.elders.old.workout
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\drzio.senior.yoga.fitness.elders.old.workout.txt
# ------------------- Loop-199-------------------
# check_package_name:  fitness.com.senior
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fitness.com.senior.txt
# ------------------- Loop-200-------------------
# check_package_name:  com.ionicframework.fitcoapp644044
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ionicframework.fitcoapp644044.txt
# ------------------- Loop-201-------------------
# check_package_name:  com.mapmyfitness.android2
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.mapmyfitness.android2.txt
# ------------------- Loop-202-------------------
# check_package_name:  com.skyhealth.fitnessbuddyandroidfree
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.skyhealth.fitnessbuddyandroidfree.txt
# ------------------- Loop-203-------------------
# check_package_name:  se.perigee.android.seven
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\se.perigee.android.seven.txt
# ------------------- Loop-204-------------------
# check_package_name:  com.basemsalloum.goodfitness.goodfitness
# ...
# ------------------- Loop-575-------------------
# check_package_name:  com.fitness.mybodymass.bmicalculator
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitness.mybodymass.bmicalculator.txt
# ------------------- Loop-576-------------------
# check_package_name:  com.transformfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.transformfitness.txt
# ------------------- Loop-577-------------------
# check_package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer.txt
# ------------------- Loop-578-------------------
# check_package_name:  com.fitness24seven.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitness24seven.app.txt
# ------------------- Loop-579-------------------
# check_package_name:  com.reset.reset_fitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.reset.reset_fitness.txt
# ------------------- Loop-580-------------------
# check_package_name:  de.myfitcoach.tim.mfc
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\de.myfitcoach.tim.mfc.txt
# ------------------- Loop-581-------------------
# check_package_name:  femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout.txt
# ------------------- Loop-582-------------------
# check_package_name:  com.canyon.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.canyon.fit.txt
# ------------------- Loop-583-------------------
# check_package_name:  homeworkout.fitness.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\homeworkout.fitness.app.txt
# ------------------- Loop-584-------------------
# check_package_name:  com.beatxp.dafit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.beatxp.dafit.txt
# ------------------- Loop-585-------------------
# check_package_name:  it.evolutionfit.evolutionfit.club
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\it.evolutionfit.evolutionfit.club.txt
# ------------------- Loop-586-------------------
# check_package_name:  com.user.livefitt
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.user.livefitt.txt
# ------------------- Loop-587-------------------
# check_package_name:  com.fitmind
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitmind.txt
# ------------------- Loop-588-------------------
# check_package_name:  eu.dscompass.myfitnesstrainer_app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\eu.dscompass.myfitnesstrainer_app.txt
# ------------------- Loop-589-------------------
# check_package_name:  fitness.fitprosport
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fitness.fitprosport.txt
# ------------------- Loop-590-------------------
# check_package_name:  com.golden.wasfatbodyfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.golden.wasfatbodyfitness.txt
# ------------------- Loop-591-------------------
# check_package_name:  com.yc.gloryfitpro
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.yc.gloryfitpro.txt
# ------------------- Loop-592-------------------
# check_package_name:  com.zjw.xwfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.zjw.xwfit.txt
# ------------------- Loop-593-------------------
# check_package_name:  com.step.walking.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.step.walking.fit.txt
# ------------------- Loop-594-------------------
# check_package_name:  com.Female.Fitness.cardio.wellness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.Female.Fitness.cardio.wellness.txt
# ------------------- Loop-595-------------------
# check_package_name:  com.lianhezhuli.hyfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lianhezhuli.hyfit.txt
# ------------------- Loop-596-------------------
# check_package_name:  com.lighthouse1.mobilebenefits.pfa
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.lighthouse1.mobilebenefits.pfa.txt
# ------------------- Loop-597-------------------
# check_package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitworkout.lossweight.homeworkout.fitnessapp.txt
# ------------------- Loop-598-------------------
# check_package_name:  com.women.work.out.fit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.women.work.out.fit.txt
# ------------------- Loop-599-------------------
# check_package_name:  com.jp.fitness.biceps.exrcise
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.jp.fitness.biceps.exrcise.txt
# ------------------- Loop-600-------------------
# check_package_name:  app.krowdfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\app.krowdfit.txt
# ------------------- Loop-601-------------------
# check_package_name:  com.o2fitt
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.o2fitt.txt
# ------------------- Loop-602-------------------
# check_package_name:  com.golf.fitforgolf
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.golf.fitforgolf.txt
# ------------------- Loop-603-------------------
# check_package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitness.hiit.fat.burning.workout.jian032aplus.txt
# ------------------- Loop-604-------------------
# check_package_name:  com.workout.women.hiit.female.fitness.jian062lite
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.workout.women.hiit.female.fitness.jian062lite.txt
# ------------------- Loop-605-------------------
# check_package_name:  com.millsapp.armyfitnesscalculator
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.millsapp.armyfitnesscalculator.txt
# ------------------- Loop-606-------------------
# check_package_name:  com.emilyskyefit.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.emilyskyefit.app.txt
# ------------------- Loop-607-------------------
# check_package_name:  com.fitlab.spartan
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitlab.spartan.txt
# ------------------- Loop-608-------------------
# check_package_name:  com.appyfurious.getfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.appyfurious.getfit.txt
# ------------------- Loop-609-------------------
# check_package_name:  com.airofit_app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.airofit_app.txt
# ------------------- Loop-610-------------------
# check_package_name:  com.jyfitness.iron_mastery
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.jyfitness.iron_mastery.txt
# ------------------- Loop-611-------------------
# check_package_name:  com.bbfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.bbfit.txt
# ------------------- Loop-612-------------------
# check_package_name:  com.walkonfit.app
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.walkonfit.app.txt
# ------------------- Loop-613-------------------
# check_package_name:  com.undersunfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.undersunfitness.txt
# ------------------- Loop-614-------------------
# check_package_name:  com.cizotech.fit2flaunt
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.cizotech.fit2flaunt.txt
# ------------------- Loop-615-------------------
# check_package_name:  com.mycloudfitness.mycloudfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.mycloudfitness.mycloudfitness.txt
# ------------------- Loop-616-------------------
# check_package_name:  com.evlofitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.evlofitness.txt
# ------------------- Loop-617-------------------
# check_package_name:  com.kannergroup.fitnessculture
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.kannergroup.fitnessculture.txt
# ------------------- Loop-618-------------------
# check_package_name:  com.ifit.palantir
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.ifit.palantir.txt
# ------------------- Loop-619-------------------
# check_package_name:  com.highfitnesslive
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.highfitnesslive.txt
# ------------------- Loop-620-------------------
# check_package_name:  com.fitness22.meditation
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitness22.meditation.txt
# ------------------- Loop-621-------------------
# check_package_name:  kr.fitt.fmes
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\kr.fitt.fmes.txt
# ------------------- Loop-622-------------------
# check_package_name:  com.fitmama
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitmama.txt
# ------------------- Loop-623-------------------
# check_package_name:  com.fixfit_fitness.twa
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fixfit_fitness.twa.txt
# ------------------- Loop-624-------------------
# check_package_name:  com.arketa.jamiegfitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.arketa.jamiegfitness.txt
# ------------------- Loop-625-------------------
# check_package_name:  com.trainerize.grindafitness
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.trainerize.grindafitness.txt
# ------------------- Loop-626-------------------
# check_package_name:  fit.remotecoach.kaylag
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\fit.remotecoach.kaylag.txt
# ------------------- Loop-627-------------------
# check_package_name:  com.pushpress.punchkingfitnesssunset
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.pushpress.punchkingfitnesssunset.txt
# ------------------- Loop-628-------------------
# check_package_name:  com.trainerize.outlawfitcamp
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.trainerize.outlawfitcamp.txt
# ------------------- Loop-629-------------------
# check_package_name:  com.fitofitness.yoga_all_2022
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitofitness.yoga_all_2022.txt
# ------------------- Loop-630-------------------
# check_package_name:  com.groupnos.openfitapp
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.groupnos.openfitapp.txt
# ------------------- Loop-631-------------------
# check_package_name:  com.marianatek.cbfit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.marianatek.cbfit.txt
# ------------------- Loop-632-------------------
# check_package_name:  com.fitnessmobileapps.elevate35253
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fitnessmobileapps.elevate35253.txt
# ------------------- Loop-633-------------------
# check_package_name:  com.trainerize.ufit12
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.trainerize.ufit12.txt
# ------------------- Loop-634-------------------
# check_package_name:  calorie.pedo.fitbit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\calorie.pedo.fitbit.txt
# ------------------- Loop-635-------------------
# check_package_name:  com.crrepa.band.dafit
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.crrepa.band.dafit.txt
# ------------------- Loop-636-------------------
# check_package_name:  com.abhijitvalluri.android.fitnotifications
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.abhijitvalluri.android.fitnotifications.txt
# ------------------- Loop-637-------------------
# check_package_name:  com.samsung.android.app.watchmanager
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.samsung.android.app.watchmanager.txt
# ------------------- Loop-638-------------------
# check_package_name:  com.huaweiband9fitnessappadvice.kantundev
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.huaweiband9fitnessappadvice.kantundev.txt
# ------------------- Loop-639-------------------
# check_package_name:  com.flightradar24free
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.flightradar24free.txt
# ------------------- Loop-640-------------------
# check_package_name:  com.google.android.contacts
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.google.android.contacts.txt
# ------------------- Loop-641-------------------
# check_package_name:  com.fsoydan.howistheweather
# Data successfully written to C:\Users\ASUS\anaconda3\wearable-traffic-summarization\sensitive_data_wearable_app\com.fsoydan.howistheweather.txt
