# %%
import os
from pymongo import MongoClient

# %%
def get_directories(path: str):
    """
    Get all directory names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of directory names.
    """
    try:
        return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def count_files(directory_path: str) -> int:
    """
    Count the number of files in a given directory.

    :param directory_path: The directory path to search.
    :return: The number of files in the directory.
    """
    try:
        return sum(1 for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f)))
    except FileNotFoundError:
        print(f"Error: The directory '{directory_path}' does not exist.")
        return 0
    except PermissionError:
        print(f"Error: Permission denied for directory '{directory_path}'.")
        return 0
    except Exception as e:
        print(f"Error: {e}")
        return 0
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def update_mongo_fields(collection, query_filter, update_fields):
    """
    Update one or more fields in a MongoDB collection.

    Parameters:
    - collection: The MongoDB collection object.
    - query_filter: A dictionary specifying the filter to select documents.
    - update_fields: A dictionary of fields to be updated, with keys as field names and values as the new values.

    Example:
    update_mongo_fields(
        collection=your_collection,
        query_filter={'_id': 'in.codeseed.audify'},
        update_fields={'apkfile_name': 'new_name.apk', 'extract_manifest': ['UPDATED', 'MODIFIED']}
    )
    """
    # Print query filter for debugging
    print(f"Query filter: {query_filter}")

    # Prepare the update object with $set to update only the specified fields
    # Check if value is string or list, update accordingly
    update_query = {"$set": {}}

    for field, value in update_fields.items():
        if isinstance(value, list):
            update_query["$set"][field] = value  # If it's a list, set the entire list
        else:
            update_query["$set"][field] = value  # If it's a string, update as a string

    # Perform the update in the collection
    result = collection.update_many(query_filter, update_query)

    # Check if anything was matched or updated
    if result.matched_count == 0:
        print("No documents matched the filter.")
    elif result.modified_count == 0 and result.matched_count > 0:
        print("Documents matched but none were updated (maybe no fields were changed).")
    
    # Print out the result of the update
    print(f"Matched {result.matched_count} document(s), updated {result.modified_count} document(s).")

# %%
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"
root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-app"

# %%
mongoDB_uri = 'mongodb://192.168.1.14:27017'
mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-standalone'
mongoDB_collection = 'wearable-app'

# %%
array_traffic_directory = get_directories(root_traffic_directory_path)
print(array_traffic_directory)
# Out:
# ['app.groupcal.www', 'apps.r.compass', 'ch.publisheria.bring', 'com.albuquerquedesign.adanalog013', 'com.anghami', 'com.audible.application', 'com.c25k', 'com.cardiogram.v1', 'com.centr.app', 'com.codverter.wearflashlight', 'com.contorra.golfpad', 'com.customsolutions.android.alexa', 'com.dungelin.heartrate', 'com.exovoid.weather.app', 'com.fish4fun.mycards', 'com.fitbod.fitbod', 'com.fitiv.fitivapplication', 'com.fiton.android', 'com.flightradar24free', 'com.fourtechnologies.mynetdiary.ad', 'com.fsoydan.howistheweather', 'com.funnmedia.waterminder', 'com.furyapps.scoreswidget', 'com.GD.Minimal', 'com.golfbuddy.smartcaddie', 'com.google.android.apps.maps', 'com.google.android.contacts', 'com.google.android.deskclock', 'com.google.android.keep', 'com.grint.thegrint.pro', 'com.hrd.iam', 'com.hrd.motivation', 'com.imperon.android.gymapp', 'com.ingravity.woo', 'com.jee.calc', 'com.JiaRen.LCDsimple', 'com.juventus.app.android', 'com.krisdb.wearcasts', 'com.lemonsystems.cipadidas', 'com.luxsank.analogclassic', 'com.mobilefootie.wc2010', 'com.mysticmobileapps.gps.area.calculator', 'com.mysticmobileapps.gps.location', 'com.newreading.goodfm', 'com.northcube.sleepcycle', 'com.northpark.drinkwater', 'com.padelem.padelem', 'com.recreative.recreative01', 'com.rideonewheel.onewheel', 'com.shazam.android', 'com.shotzoom.golfshot2', 'com.soundcloud.android', 'com.spotify.music', 'com.todoist', 'com.vpar.android', 'com.watchfacedesigns.Vanish', 'com.watchfacestudio.minimalblack1', 'com.wikiloc.wikilocandroid', 'com.windyty.android', 'de.komoot.android', 'de.michelinside.glucodatahandler', 'grit.storytel.app', 'me.twentyfour.www', 'nl.slisky.stopwatch', 'qubin.de.wearmedia', 'se.perigee.android.seven', 'secureauth.android.token', 'time.flies.nebula', 'todolist.scheduleplanner.dailyplanner.todo.reminders', 'walking.tracker.app.pedometer', 'xyz.klinker.messenger']

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)

# %%
for i in range(len(array_traffic_directory)):
    print("--------------------- Loop-"+str(i)+"---------------------")
    package_name = array_traffic_directory[i]
    print("package_name: ",package_name)
    traffic_directory = root_traffic_directory_path+"\\"+package_name
    print("traffic directory: ",traffic_directory)
    file_number = count_files(traffic_directory)
    print("file_number: ",file_number)
    if(file_number==0):
        update_mongo_fields(
                    collection, 
                    {'_id': str(package_name)}, 
                    {'sent-out': 'no data'}
                )
#     break
# Out:
# --------------------- Loop-0---------------------
# package_name:  app.groupcal.www
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\app.groupcal.www
# file_number:  20
# --------------------- Loop-1---------------------
# package_name:  apps.r.compass
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\apps.r.compass
# file_number:  5
# --------------------- Loop-2---------------------
# package_name:  ch.publisheria.bring
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\ch.publisheria.bring
# file_number:  21
# --------------------- Loop-3---------------------
# package_name:  com.albuquerquedesign.adanalog013
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.albuquerquedesign.adanalog013
# file_number:  1
# --------------------- Loop-4---------------------
# package_name:  com.anghami
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.anghami
# file_number:  8
# --------------------- Loop-5---------------------
# package_name:  com.audible.application
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.audible.application
# file_number:  13
# --------------------- Loop-6---------------------
# package_name:  com.c25k
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.c25k
# file_number:  14
# --------------------- Loop-7---------------------
# package_name:  com.cardiogram.v1
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.cardiogram.v1
# file_number:  36
# --------------------- Loop-8---------------------
# package_name:  com.centr.app
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.centr.app
# file_number:  0
# Query filter: {'_id': 'com.centr.app'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-9---------------------
# package_name:  com.codverter.wearflashlight
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.codverter.wearflashlight
# file_number:  16
# --------------------- Loop-10---------------------
# package_name:  com.contorra.golfpad
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.contorra.golfpad
# file_number:  19
# --------------------- Loop-11---------------------
# package_name:  com.customsolutions.android.alexa
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.customsolutions.android.alexa
# file_number:  21
# --------------------- Loop-12---------------------
# package_name:  com.dungelin.heartrate
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.dungelin.heartrate
# file_number:  15
# --------------------- Loop-13---------------------
# package_name:  com.exovoid.weather.app
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.exovoid.weather.app
# file_number:  1
# --------------------- Loop-14---------------------
# package_name:  com.fish4fun.mycards
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fish4fun.mycards
# file_number:  3
# --------------------- Loop-15---------------------
# package_name:  com.fitbod.fitbod
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fitbod.fitbod
# file_number:  17
# --------------------- Loop-16---------------------
# package_name:  com.fitiv.fitivapplication
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fitiv.fitivapplication
# file_number:  3
# --------------------- Loop-17---------------------
# package_name:  com.fiton.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fiton.android
# file_number:  24
# --------------------- Loop-18---------------------
# package_name:  com.flightradar24free
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.flightradar24free
# file_number:  0
# Query filter: {'_id': 'com.flightradar24free'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-19---------------------
# package_name:  com.fourtechnologies.mynetdiary.ad
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fourtechnologies.mynetdiary.ad
# file_number:  0
# Query filter: {'_id': 'com.fourtechnologies.mynetdiary.ad'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-20---------------------
# package_name:  com.fsoydan.howistheweather
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.fsoydan.howistheweather
# file_number:  0
# Query filter: {'_id': 'com.fsoydan.howistheweather'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-21---------------------
# package_name:  com.funnmedia.waterminder
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.funnmedia.waterminder
# file_number:  1
# --------------------- Loop-22---------------------
# package_name:  com.furyapps.scoreswidget
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.furyapps.scoreswidget
# file_number:  1
# --------------------- Loop-23---------------------
# package_name:  com.GD.Minimal
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.GD.Minimal
# file_number:  9
# --------------------- Loop-24---------------------
# package_name:  com.golfbuddy.smartcaddie
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.golfbuddy.smartcaddie
# file_number:  12
# --------------------- Loop-25---------------------
# package_name:  com.google.android.apps.maps
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.google.android.apps.maps
# file_number:  23
# --------------------- Loop-26---------------------
# package_name:  com.google.android.contacts
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.google.android.contacts
# file_number:  0
# Query filter: {'_id': 'com.google.android.contacts'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-27---------------------
# package_name:  com.google.android.deskclock
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.google.android.deskclock
# file_number:  0
# Query filter: {'_id': 'com.google.android.deskclock'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-28---------------------
# package_name:  com.google.android.keep
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.google.android.keep
# file_number:  44
# --------------------- Loop-29---------------------
# package_name:  com.grint.thegrint.pro
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.grint.thegrint.pro
# file_number:  23
# --------------------- Loop-30---------------------
# package_name:  com.hrd.iam
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.hrd.iam
# file_number:  0
# Query filter: {'_id': 'com.hrd.iam'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-31---------------------
# package_name:  com.hrd.motivation
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.hrd.motivation
# file_number:  0
# Query filter: {'_id': 'com.hrd.motivation'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-32---------------------
# package_name:  com.imperon.android.gymapp
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.imperon.android.gymapp
# file_number:  4
# --------------------- Loop-33---------------------
# package_name:  com.ingravity.woo
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.ingravity.woo
# file_number:  9
# --------------------- Loop-34---------------------
# package_name:  com.jee.calc
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.jee.calc
# file_number:  25
# --------------------- Loop-35---------------------
# package_name:  com.JiaRen.LCDsimple
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.JiaRen.LCDsimple
# file_number:  0
# Query filter: {'_id': 'com.JiaRen.LCDsimple'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-36---------------------
# package_name:  com.juventus.app.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.juventus.app.android
# file_number:  22
# --------------------- Loop-37---------------------
# package_name:  com.krisdb.wearcasts
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.krisdb.wearcasts
# file_number:  1
# --------------------- Loop-38---------------------
# package_name:  com.lemonsystems.cipadidas
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.lemonsystems.cipadidas
# file_number:  2
# --------------------- Loop-39---------------------
# package_name:  com.luxsank.analogclassic
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.luxsank.analogclassic
# file_number:  0
# Query filter: {'_id': 'com.luxsank.analogclassic'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-40---------------------
# package_name:  com.mobilefootie.wc2010
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.mobilefootie.wc2010
# file_number:  0
# Query filter: {'_id': 'com.mobilefootie.wc2010'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-41---------------------
# package_name:  com.mysticmobileapps.gps.area.calculator
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.mysticmobileapps.gps.area.calculator
# file_number:  13
# --------------------- Loop-42---------------------
# package_name:  com.mysticmobileapps.gps.location
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.mysticmobileapps.gps.location
# file_number:  1
# --------------------- Loop-43---------------------
# package_name:  com.newreading.goodfm
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.newreading.goodfm
# file_number:  0
# Query filter: {'_id': 'com.newreading.goodfm'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-44---------------------
# package_name:  com.northcube.sleepcycle
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.northcube.sleepcycle
# file_number:  9
# --------------------- Loop-45---------------------
# package_name:  com.northpark.drinkwater
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.northpark.drinkwater
# file_number:  10
# --------------------- Loop-46---------------------
# package_name:  com.padelem.padelem
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.padelem.padelem
# file_number:  2
# --------------------- Loop-47---------------------
# package_name:  com.recreative.recreative01
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.recreative.recreative01
# file_number:  2
# --------------------- Loop-48---------------------
# package_name:  com.rideonewheel.onewheel
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.rideonewheel.onewheel
# file_number:  19
# --------------------- Loop-49---------------------
# package_name:  com.shazam.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.shazam.android
# file_number:  0
# Query filter: {'_id': 'com.shazam.android'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-50---------------------
# package_name:  com.shotzoom.golfshot2
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.shotzoom.golfshot2
# file_number:  6
# --------------------- Loop-51---------------------
# package_name:  com.soundcloud.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.soundcloud.android
# file_number:  13
# --------------------- Loop-52---------------------
# package_name:  com.spotify.music
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.spotify.music
# file_number:  8
# --------------------- Loop-53---------------------
# package_name:  com.todoist
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.todoist
# file_number:  9
# --------------------- Loop-54---------------------
# package_name:  com.vpar.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.vpar.android
# file_number:  24
# --------------------- Loop-55---------------------
# package_name:  com.watchfacedesigns.Vanish
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.watchfacedesigns.Vanish
# file_number:  0
# Query filter: {'_id': 'com.watchfacedesigns.Vanish'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-56---------------------
# package_name:  com.watchfacestudio.minimalblack1
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.watchfacestudio.minimalblack1
# file_number:  0
# Query filter: {'_id': 'com.watchfacestudio.minimalblack1'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-57---------------------
# package_name:  com.wikiloc.wikilocandroid
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.wikiloc.wikilocandroid
# file_number:  18
# --------------------- Loop-58---------------------
# package_name:  com.windyty.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\com.windyty.android
# file_number:  9
# --------------------- Loop-59---------------------
# package_name:  de.komoot.android
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\de.komoot.android
# file_number:  0
# Query filter: {'_id': 'de.komoot.android'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-60---------------------
# package_name:  de.michelinside.glucodatahandler
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\de.michelinside.glucodatahandler
# file_number:  6
# --------------------- Loop-61---------------------
# package_name:  grit.storytel.app
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\grit.storytel.app
# file_number:  2
# --------------------- Loop-62---------------------
# package_name:  me.twentyfour.www
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\me.twentyfour.www
# file_number:  16
# --------------------- Loop-63---------------------
# package_name:  nl.slisky.stopwatch
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\nl.slisky.stopwatch
# file_number:  4
# --------------------- Loop-64---------------------
# package_name:  qubin.de.wearmedia
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\qubin.de.wearmedia
# file_number:  2
# --------------------- Loop-65---------------------
# package_name:  se.perigee.android.seven
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\se.perigee.android.seven
# file_number:  0
# Query filter: {'_id': 'se.perigee.android.seven'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-66---------------------
# package_name:  secureauth.android.token
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\secureauth.android.token
# file_number:  0
# Query filter: {'_id': 'secureauth.android.token'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-67---------------------
# package_name:  time.flies.nebula
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\time.flies.nebula
# file_number:  0
# Query filter: {'_id': 'time.flies.nebula'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-68---------------------
# package_name:  todolist.scheduleplanner.dailyplanner.todo.reminders
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\todolist.scheduleplanner.dailyplanner.todo.reminders
# file_number:  3
# --------------------- Loop-69---------------------
# package_name:  walking.tracker.app.pedometer
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\walking.tracker.app.pedometer
# file_number:  0
# Query filter: {'_id': 'walking.tracker.app.pedometer'}
# Matched 1 document(s), updated 1 document(s).
# --------------------- Loop-70---------------------
# package_name:  xyz.klinker.messenger
# traffic directory:  E:\wearable-capture-traffic\wearable-standalone\xyz.klinker.messenger
# file_number:  0
# Query filter: {'_id': 'xyz.klinker.messenger'}
# Matched 1 document(s), updated 1 document(s).
