# %%
import os
import shutil
from pymongo import MongoClient

# %%
def get_directories(path: str):
    """
    Get all directory names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of directory names.
    """
    try:
        return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_ids_with_condition(collection,condition):
    """
    Retrieve an array of `_id` values where "sent-out" is "no data".

    :param collection: MongoDB collection object.
    :return: List of `_id` values matching the condition.
    """
#     condition = {"sent-out": "no data"}
    result = collection.find(condition, {"_id": 1})  # Retrieve only the `_id` field
    return [doc["_id"] for doc in result]
def remove_blank_lines(directory):
    """
    Scans all .txt files in the given directory, removes blank lines, 
    and saves the cleaned content back to the file.

    :param directory: The path to the directory containing .txt files.
    """
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)

        # Process only .txt files
        if os.path.isfile(file_path) and filename.endswith(".txt"):
            with open(file_path, "r", encoding="utf-8") as file:
                lines = file.readlines()

            # Remove blank lines
            cleaned_lines = [line for line in lines if line.strip()]

            # Check if there were blank lines
            if len(cleaned_lines) < len(lines):
                print(f"Blank lines found and removed in: {filename}")

                # Write the cleaned content back to the file
                with open(file_path, "w", encoding="utf-8") as file:
                    file.writelines(cleaned_lines)
def move_files_with_phrase(directory, phrase):
    """
    Scans all .txt files in the given directory, and if a file contains the specified phrase,
    moves it to a "delete" subdirectory.

    :param directory: The path to the directory containing .txt files.
    :param phrase: The phrase to search for in the files (default is "youtube").
    """
    delete_dir = os.path.join(directory, "delete")  # Create delete directory path

    # Ensure the delete directory exists
    if not os.path.exists(delete_dir):
        os.makedirs(delete_dir)

    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)

        # Process only .txt files
        if os.path.isfile(file_path) and filename.endswith(".txt"):
            try:
                with open(file_path, "r", encoding="utf-8") as file:
                    content = file.read()

                # Check if the file contains the phrase
                if phrase.lower() in content.lower():  # Case-insensitive search
                    print(f"Moving file: {filename} (contains '{phrase}')")
                    shutil.move(file_path, os.path.join(delete_dir, filename))

            except Exception as e:
                print(f"Error reading file {filename}: {e}")
def remove_empty_files(path: str) -> int:
    """
    Remove all files with size 0 in the specified directory.
    
    :param path: The root directory path to search.
    :return: Count of files removed.
    """
    removed_count = 0
    try:
        for f in os.listdir(path):
            file_path = os.path.join(path, f)
            if os.path.isfile(file_path) and os.path.getsize(file_path) == 0:
                os.remove(file_path)
                removed_count += 1
        return removed_count
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return 0
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return 0

# %%
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"
root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-app"

# %%
mongoDB_uri = 'mongodb://192.168.1.14:27017'
mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-standalone'
mongoDB_collection = 'wearable-app'

# %%
array_traffic_directory = get_directories(root_traffic_directory_path)
print(len(array_traffic_directory))
# Out:
# 630

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
condition = {"sent-out": "no data"}
no_traffic_package_name = get_ids_with_condition(collection,condition)
# print(no_traffic_package_name)
print(len(no_traffic_package_name))
# Out:
# 122

# %%
array_traffic_package_name = list(set(array_traffic_directory) - set(no_traffic_package_name))
print(array_traffic_package_name)
print(len(array_traffic_package_name))
# Out:
# ['jp.joyfit.joyfitappandroid', 'com.apep.fitapp', 'com.fitwhey.app', 'com.zq.fit', 'maxcom.toolbox.altimeter', 'uk.co.fitness4less.app', 'com.instafit.workouts', 'digifit.android.virtuagym.pro.greaterjolietymcasuperclub', 'com.edjing.edjingdjturntable', 'com.artkitch.alexfitness', 'com.onefitstop.bodyfittraining', 'coach.zing.fitness', 'com.golf.fitforgolf', 'com.trainerize.yetifit', 'homeworkoutapp.homeworkout.fitness.workout.loseweight', 'com.skyhealth.fitnessbuddyandroidfree', 'fitapp.fittofit', 'com.fiton.android', 'com.polaroidfit.polaroidfit', 'com.chloeting.fitness', 'com.madarsoft.fitness', 'com.anytimefitness.userapp', 'com.netpulse.mobile.fitzonedelutte', 'com.honbow.letsfit', 'com.anytimefitness.app', 'com.keepfit.loseweight', 'com.samsung.android.shealthmonitor', 'com.zewa.fit.pro', 'com.mycloudfitness.mycloudfitness', 'com.oplayer.goodmansfitpro', 'digifit.android.virtuagym.pro.fisic', 'com.hootapps.soundrecorder', 'eu.fitric.pregnancyworkout', 'com.luni.android.fitnesscoach.app', 'com.szyk.myheart', 'com.viatek.fitnation.echelon_android', 'com.zjw.xwfit', 'com.bandlab.bandlab', 'com.wakeup.wearfit2', 'com.fitworkout.lossweight.homeworkout.fitnessapp', 'com.biztech.magemobadmin', 'com.fitifyapps.bwcardio', 'com.bpfit.bloodpressure.health', 'com.equinoxfitness.equinox', 'com.mobifitness.bettadance342273', 'com.fitness.hiit.fat.burning.workout.jian032aplus', 'com.pocketlifestyle.music.tune', 'com.fitapp.timerwodapp', 'com.mattdoesfitness.morsia', 'home.fitness.challenge', 'app.EnForma.fitcoapp.net', 'com.crrepa.band.havefit', 'com.glidetalk.glideapp', 'com.fuse.fitness', 'com.trainerize.youfit', 'com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer', 'com.qualitrain.fitness', 'com.spotify.music', 'ott.beatboxingfitnessworkouts', 'com.itrack.myfit755570', 'com.movefitness.app', 'com.sasyabook.businesscardapp', 'com.bottegasol.com.migym.fitnessconnection', 'com.bendingspoons.thirtydayfitness', 'com.bickster.fitbitbandfinder', 'com.github.jamesgay.fitnotes', 'fitness.home.workout.weight.loss', 'rs.fastfit.app', 'net.peater.fitlovers', 'rebel.fitness', 'com.qingniu.fitindex', 'faceyoga.facefitness.dailyworkouts', 'com.goodlifefitness', 'com.czw.freefit', 'com.fitzeee.fitzeeerun', 'com.eightfit.app', 'com.runmifit.android', 'com.google.android.apps.fitness', 'com.joshua.hasfit', 'com.lafitness.lafitness', 'com.yc.gloryfitpro', 'com.hwd.flowfit', 'com.walkfit.weightloss.steptracker.pedometer', 'com.riversongfit.epoch', 'club.skllzz.fitness', 'com.xj.inxfit', 'com.mobifitness.nsfit104363', 'dance.workout.home.fitness', 'com.womenfitness.workoutbuddy.mea', 'com.std.fitness.point', 'starshipproduct.perifitmainapp', 'rs.nonstopfitness', 'com.cavosmart.wofit', 'nz.co.telecom.smartphone.android', 'org.moffitt.brandedpatientportal.play', 'workoutforwomen.femalefitness.womenworkout.loseweight', 'digifit.virtuagym.client.android.coaching', 'com.SnowReport.screens', 'com.jquiz.english', 'digifit.android.virtuagym.pro.buzzgymsuperclub', 'com.noisefit.focus', 'com.independence284.badassbodyfitnessx', 'com.eztech.fitness', 'com.myfitnesspal.android', 'com.fitbod.fitbod', 'digifit.android.virtuagym.pro.ymcapeninsulademo', 'com.simplyfit.rowing', 'com.marianatek.cbfit', 'drzio.senior.yoga.fitness.elders.old.workout', 'net.kosev.dicing', 'com.Female.Fitness.cardio.wellness', 'app.fit.meet', 'com.fitnesspassport.androidapp', 'rs.abstract.fitpass', 'digifit.android.virtuagym.pro.bodyassault', 'com.tomtop.smart', 'com.kannergroup.fitnessculture', 'com.fitatu.tracker', 'com.ifit.wolf', 'com.fitness22.workout', 'com.cizotech.fit2flaunt', 'com.fitness22.running', 'com.samsung.android.app.watchmanager', 'com.honbow.fitdock', 'com.fitlab.spartan', 'com.marsathletic.android.macfit.app', 'ru.starline', 'digifit.android.virtuagym.pro.puurpersonaltraining', 'eu.fitric.hourglass', 'homeworkout.fitness.app', 'com.fixfit_fitness.twa', 'com.reset.reset_fitness', 'com.yc.gtfit', 'com.trainerize.outlawfitcamp', 'fit.cult.android', 'com.fitzeee.ped ...
# 520

# %%
for i in range(len(array_traffic_package_name)):
    print("--------------------- Loop-"+str(i)+" ---------------------")
    package_name = array_traffic_package_name[i]
    print("package_name: ",package_name)
    traffic_directory_path = root_traffic_directory_path + "\\" + package_name
    print("traffic_directory_path: ",traffic_directory_path)
    remove_blank_lines(traffic_directory_path)
#     break
# Out:
# --------------------- Loop-0 ---------------------
# package_name:  jp.joyfit.joyfitappandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.joyfit.joyfitappandroid
# --------------------- Loop-1 ---------------------
# package_name:  com.apep.fitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.apep.fitapp
# --------------------- Loop-2 ---------------------
# package_name:  com.fitwhey.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitwhey.app
# --------------------- Loop-3 ---------------------
# package_name:  com.zq.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zq.fit
# --------------------- Loop-4 ---------------------
# package_name:  maxcom.toolbox.altimeter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\maxcom.toolbox.altimeter
# --------------------- Loop-5 ---------------------
# package_name:  uk.co.fitness4less.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\uk.co.fitness4less.app
# --------------------- Loop-6 ---------------------
# package_name:  com.instafit.workouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.instafit.workouts
# --------------------- Loop-7 ---------------------
# package_name:  digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# --------------------- Loop-8 ---------------------
# package_name:  com.edjing.edjingdjturntable
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.edjing.edjingdjturntable
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_20.txt
# Blank lines found and removed in: message_23.txt
# Blank lines found and removed in: message_4.txt
# --------------------- Loop-9 ---------------------
# package_name:  com.artkitch.alexfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.artkitch.alexfitness
# --------------------- Loop-10 ---------------------
# package_name:  com.onefitstop.bodyfittraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.onefitstop.bodyfittraining
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-11 ---------------------
# package_name:  coach.zing.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\coach.zing.fitness
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-12 ---------------------
# package_name:  com.golf.fitforgolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.golf.fitforgolf
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-13 ---------------------
# package_name:  com.trainerize.yetifit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.yetifit
# --------------------- Loop-14 ---------------------
# package_name:  homeworkoutapp.homeworkout.fitness.workout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-15 ---------------------
# package_name:  com.skyhealth.fitnessbuddyandroidfree
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.skyhealth.fitnessbuddyandroidfree
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-16 ---------------------
# package_name:  fitapp.fittofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitapp.fittofit
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-17 ---------------------
# package_name:  com.fiton.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fiton.android
# --------------------- Loop-18 ---------------------
# package_name:  com.polaroidfit.polaroidfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.polaroidfit.polaroidfit
# --------------------- Loop-19 ---------------------
# package_name:  com.chloeting.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-20 ---------------------
# package_name:  com.madarsoft.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.madarsoft.fitness
# Blank lines found and removed in: message_23.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-21 ---------------------
# package_name:  com.anytimefitness.userapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-22 ---------------------
# package_name:  com.netpulse.mobile.fitzonedelutte
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.fitzonedelutte
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# --------------------- Loop-23 ---------------------
# package_name:  com.honbow.letsfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.letsfit
# --------------------- Loop-24 ---------------------
# package_name:  com.anytimefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.app
# --------------------- Loop-25 ---------------------
# package_name:  com.keepfit.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.keepfit.loseweight
# --------------------- Loop-26 ---------------------
# package_name:  com.samsung.android.shealthmonitor
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.shealthmonitor
# --------------------- Loop-27 ---------------------
# package_name:  com.zewa.fit.pro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zewa.fit.pro
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-28 ---------------------
# package_name:  com.mycloudfitness.mycloudfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mycloudfitness.mycloudfitness
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-29 ---------------------
# package_name:  com.oplayer.goodmansfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.oplayer.goodmansfitpro
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-30 ---------------------
# package_name:  digifit.android.virtuagym.pro.fisic
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fisic
# --------------------- Loop-31 ---------------------
# package_name:  com.hootapps.soundrecorder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hootapps.soundrecorder
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-32 ---------------------
# package_name:  eu.fitric.pregnancyworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.pregnancyworkout
# --------------------- Loop-33 ---------------------
# package_name:  com.luni.android.fitnesscoach.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.luni.android.fitnesscoach.app
# --------------------- Loop-34 ---------------------
# package_name:  com.szyk.myheart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.szyk.myheart
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-35 ---------------------
# package_name:  com.viatek.fitnation.echelon_android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-36 ---------------------
# package_name:  com.zjw.xwfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zjw.xwfit
# --------------------- Loop-37 ---------------------
# package_name:  com.bandlab.bandlab
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bandlab.bandlab
# --------------------- Loop-38 ---------------------
# package_name:  com.wakeup.wearfit2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.wakeup.wearfit2
# Blank lines found and removed in: message_24.txt
# Blank lines found and removed in: message_4.txt
# --------------------- Loop-39 ---------------------
# package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_4.txt
# --------------------- Loop-40 ---------------------
# package_name:  com.biztech.magemobadmin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.biztech.magemobadmin
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-41 ---------------------
# package_name:  com.fitifyapps.bwcardio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwcardio
# --------------------- Loop-42 ---------------------
# package_name:  com.bpfit.bloodpressure.health
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-43 ---------------------
# package_name:  com.equinoxfitness.equinox
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.equinoxfitness.equinox
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-44 ---------------------
# package_name:  com.mobifitness.bettadance342273
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.bettadance342273
# --------------------- Loop-45 ---------------------
# package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-46 ---------------------
# package_name:  com.pocketlifestyle.music.tune
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.pocketlifestyle.music.tune
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-47 ---------------------
# package_name:  com.fitapp.timerwodapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitapp.timerwodapp
# --------------------- Loop-48 ---------------------
# package_name:  com.mattdoesfitness.morsia
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mattdoesfitness.morsia
# --------------------- Loop-49 ---------------------
# package_name:  home.fitness.challenge
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\home.fitness.challenge
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-50 ---------------------
# package_name:  app.EnForma.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.EnForma.fitcoapp.net
# --------------------- Loop-51 ---------------------
# package_name:  com.crrepa.band.havefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.havefit
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-52 ---------------------
# package_name:  com.glidetalk.glideapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.glidetalk.glideapp
# --------------------- Loop-53 ---------------------
# package_name:  com.fuse.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fuse.fitness
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-54 ---------------------
# package_name:  com.trainerize.youfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.youfit
# --------------------- Loop-55 ---------------------
# package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# --------------------- Loop-56 ---------------------
# package_name:  com.qualitrain.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qualitrain.fitness
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-57 ---------------------
# package_name:  com.spotify.music
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.spotify.music
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-58 ---------------------
# package_name:  ott.beatboxingfitnessworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ott.beatboxingfitnessworkouts
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-59 ---------------------
# package_name:  com.itrack.myfit755570
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.itrack.myfit755570
# --------------------- Loop-60 ---------------------
# package_name:  com.movefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.movefitness.app
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-61 ---------------------
# package_name:  com.sasyabook.businesscardapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.sasyabook.businesscardapp
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-62 ---------------------
# package_name:  com.bottegasol.com.migym.fitnessconnection
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bottegasol.com.migym.fitnessconnection
# Blank lines found and removed in: message_20.txt
# --------------------- Loop-63 ---------------------
# package_name:  com.bendingspoons.thirtydayfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bendingspoons.thirtydayfitness
# --------------------- Loop-64 ---------------------
# package_name:  com.bickster.fitbitbandfinder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-65 ---------------------
# package_name:  com.github.jamesgay.fitnotes
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.github.jamesgay.fitnotes
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-66 ---------------------
# package_name:  fitness.home.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.home.workout.weight.loss
# --------------------- Loop-67 ---------------------
# package_name:  rs.fastfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.fastfit.app
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-68 ---------------------
# package_name:  net.peater.fitlovers
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-69 ---------------------
# package_name:  rebel.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rebel.fitness
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-70 ---------------------
# package_name:  com.qingniu.fitindex
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.fitindex
# --------------------- Loop-71 ---------------------
# package_name:  faceyoga.facefitness.dailyworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\faceyoga.facefitness.dailyworkouts
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-72 ---------------------
# package_name:  com.goodlifefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.goodlifefitness
# Blank lines found and removed in: message_15.txt
# --------------------- Loop-73 ---------------------
# package_name:  com.czw.freefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.czw.freefit
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-74 ---------------------
# package_name:  com.fitzeee.fitzeeerun
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.fitzeeerun
# --------------------- Loop-75 ---------------------
# package_name:  com.eightfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eightfit.app
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-76 ---------------------
# package_name:  com.runmifit.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.runmifit.android
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_19.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_20.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-77 ---------------------
# package_name:  com.google.android.apps.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.google.android.apps.fitness
# --------------------- Loop-78 ---------------------
# package_name:  com.joshua.hasfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.joshua.hasfit
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-79 ---------------------
# package_name:  com.lafitness.lafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lafitness.lafitness
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-80 ---------------------
# package_name:  com.yc.gloryfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gloryfitpro
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_19.txt
# Blank lines found and removed in: message_20.txt
# Blank lines found and removed in: message_21.txt
# Blank lines found and removed in: message_23.txt
# Blank lines found and removed in: message_24.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-81 ---------------------
# package_name:  com.hwd.flowfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hwd.flowfit
# --------------------- Loop-82 ---------------------
# package_name:  com.walkfit.weightloss.steptracker.pedometer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkfit.weightloss.steptracker.pedometer
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_12.txt
# --------------------- Loop-83 ---------------------
# package_name:  com.riversongfit.epoch
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.riversongfit.epoch
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-84 ---------------------
# package_name:  club.skllzz.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\club.skllzz.fitness
# --------------------- Loop-85 ---------------------
# package_name:  com.xj.inxfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.xj.inxfit
# --------------------- Loop-86 ---------------------
# package_name:  com.mobifitness.nsfit104363
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.nsfit104363
# --------------------- Loop-87 ---------------------
# package_name:  dance.workout.home.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\dance.workout.home.fitness
# Blank lines found and removed in: message_13.txt
# --------------------- Loop-88 ---------------------
# package_name:  com.womenfitness.workoutbuddy.mea
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.womenfitness.workoutbuddy.mea
# --------------------- Loop-89 ---------------------
# package_name:  com.std.fitness.point
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.std.fitness.point
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-90 ---------------------
# package_name:  starshipproduct.perifitmainapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\starshipproduct.perifitmainapp
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_16.txt
# --------------------- Loop-91 ---------------------
# package_name:  rs.nonstopfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.nonstopfitness
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-92 ---------------------
# package_name:  com.cavosmart.wofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cavosmart.wofit
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_27.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-93 ---------------------
# package_name:  nz.co.telecom.smartphone.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_22.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-94 ---------------------
# package_name:  org.moffitt.brandedpatientportal.play
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.moffitt.brandedpatientportal.play
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-95 ---------------------
# package_name:  workoutforwomen.femalefitness.womenworkout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\workoutforwomen.femalefitness.womenworkout.loseweight
# Blank lines found and removed in: message_22.txt
# --------------------- Loop-96 ---------------------
# package_name:  digifit.virtuagym.client.android.coaching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android.coaching
# --------------------- Loop-97 ---------------------
# package_name:  com.SnowReport.screens
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.SnowReport.screens
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-98 ---------------------
# package_name:  com.jquiz.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jquiz.english
# --------------------- Loop-99 ---------------------
# package_name:  digifit.android.virtuagym.pro.buzzgymsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.buzzgymsuperclub
# --------------------- Loop-100 ---------------------
# package_name:  com.noisefit.focus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit.focus
# --------------------- Loop-101 ---------------------
# package_name:  com.independence284.badassbodyfitnessx
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.independence284.badassbodyfitnessx
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-102 ---------------------
# package_name:  com.eztech.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eztech.fitness
# --------------------- Loop-103 ---------------------
# package_name:  com.myfitnesspal.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesspal.android
# --------------------- Loop-104 ---------------------
# package_name:  com.fitbod.fitbod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitbod.fitbod
# --------------------- Loop-105 ---------------------
# package_name:  digifit.android.virtuagym.pro.ymcapeninsulademo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.ymcapeninsulademo
# --------------------- Loop-106 ---------------------
# package_name:  com.simplyfit.rowing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.simplyfit.rowing
# --------------------- Loop-107 ---------------------
# package_name:  com.marianatek.cbfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marianatek.cbfit
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-108 ---------------------
# package_name:  drzio.senior.yoga.fitness.elders.old.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout
# --------------------- Loop-109 ---------------------
# package_name:  net.kosev.dicing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.kosev.dicing
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_14.txt
# --------------------- Loop-110 ---------------------
# package_name:  com.Female.Fitness.cardio.wellness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.Female.Fitness.cardio.wellness
# --------------------- Loop-111 ---------------------
# package_name:  app.fit.meet
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# --------------------- Loop-112 ---------------------
# package_name:  com.fitnesspassport.androidapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesspassport.androidapp
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-113 ---------------------
# package_name:  rs.abstract.fitpass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.abstract.fitpass
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-114 ---------------------
# package_name:  digifit.android.virtuagym.pro.bodyassault
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.bodyassault
# --------------------- Loop-115 ---------------------
# package_name:  com.tomtop.smart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.tomtop.smart
# --------------------- Loop-116 ---------------------
# package_name:  com.kannergroup.fitnessculture
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kannergroup.fitnessculture
# --------------------- Loop-117 ---------------------
# package_name:  com.fitatu.tracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitatu.tracker
# --------------------- Loop-118 ---------------------
# package_name:  com.ifit.wolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ifit.wolf
# --------------------- Loop-119 ---------------------
# package_name:  com.fitness22.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.workout
# --------------------- Loop-120 ---------------------
# package_name:  com.cizotech.fit2flaunt
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cizotech.fit2flaunt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-121 ---------------------
# package_name:  com.fitness22.running
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.running
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-122 ---------------------
# package_name:  com.samsung.android.app.watchmanager
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.app.watchmanager
# --------------------- Loop-123 ---------------------
# package_name:  com.honbow.fitdock
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-124 ---------------------
# package_name:  com.fitlab.spartan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlab.spartan
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-125 ---------------------
# package_name:  com.marsathletic.android.macfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marsathletic.android.macfit.app
# --------------------- Loop-126 ---------------------
# package_name:  ru.starline
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ru.starline
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-127 ---------------------
# package_name:  digifit.android.virtuagym.pro.puurpersonaltraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.puurpersonaltraining
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-128 ---------------------
# package_name:  eu.fitric.hourglass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.hourglass
# --------------------- Loop-129 ---------------------
# package_name:  homeworkout.fitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkout.fitness.app
# --------------------- Loop-130 ---------------------
# package_name:  com.fixfit_fitness.twa
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-131 ---------------------
# package_name:  com.reset.reset_fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.reset.reset_fitness
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-132 ---------------------
# package_name:  com.yc.gtfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gtfit
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_21.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-133 ---------------------
# package_name:  com.trainerize.outlawfitcamp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.outlawfitcamp
# --------------------- Loop-134 ---------------------
# package_name:  fit.cult.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.cult.android
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-135 ---------------------
# package_name:  com.fitzeee.pedometerwalking
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.pedometerwalking
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-136 ---------------------
# package_name:  biz.mobidev.mdplayer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\biz.mobidev.mdplayer
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-137 ---------------------
# package_name:  com.netpulse.mobile.clubfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.clubfit
# --------------------- Loop-138 ---------------------
# package_name:  com.kompanion.fitness.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kompanion.fitness.android
# --------------------- Loop-139 ---------------------
# package_name:  foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# --------------------- Loop-140 ---------------------
# package_name:  pl.tweeba.mobile.learning.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.tweeba.mobile.learning.english
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-141 ---------------------
# package_name:  com.mictale.gpsessentials
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mictale.gpsessentials
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-142 ---------------------
# package_name:  com.trainerize.witfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.witfit
# --------------------- Loop-143 ---------------------
# package_name:  com.bhphoto
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bhphoto
# --------------------- Loop-144 ---------------------
# package_name:  com.toshremote.view
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.toshremote.view
# Blank lines found and removed in: message_0.txt
# --------------------- Loop-145 ---------------------
# package_name:  com.basicfit.trainingApp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basicfit.trainingApp
# --------------------- Loop-146 ---------------------
# package_name:  com.adi.remote.phone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.adi.remote.phone
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-147 ---------------------
# package_name:  com.caliberfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.caliberfitness.app
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-148 ---------------------
# package_name:  com.lifetrons.lifetrons.app.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lifetrons.lifetrons.app.fitness
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-149 ---------------------
# package_name:  tarlin.fitness.loseweight.belly.fem
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\tarlin.fitness.loseweight.belly.fem
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-150 ---------------------
# package_name:  com.fitifyapps.bwstretching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching
# --------------------- Loop-151 ---------------------
# package_name:  nz.co.madfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.madfit
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_20.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-152 ---------------------
# package_name:  com.appyfurious.getfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.appyfurious.getfit
# --------------------- Loop-153 ---------------------
# package_name:  com.walking.fun.rewards.fitness.fitzu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walking.fun.rewards.fitness.fitzu
# --------------------- Loop-154 ---------------------
# package_name:  digifit.android.virtuagym.pro.leisureunitedsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.leisureunitedsuperclub
# --------------------- Loop-155 ---------------------
# package_name:  app.growwithjo.diet.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# --------------------- Loop-156 ---------------------
# package_name:  digifit.android.virtuagym.pro.neobod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.neobod
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_13.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-157 ---------------------
# package_name:  com.aircanada
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.aircanada
# --------------------- Loop-158 ---------------------
# package_name:  digifit.virtuagym.client.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-159 ---------------------
# package_name:  com.smartwidgetlabs.fitbitandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.smartwidgetlabs.fitbitandroid
# --------------------- Loop-160 ---------------------
# package_name:  com.trainerize.grindafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.grindafitness
# --------------------- Loop-161 ---------------------
# package_name:  it.tripix.buddyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-162 ---------------------
# package_name:  com.evolutionwellness.app.celebrityfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.celebrityfitness
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-163 ---------------------
# package_name:  com.nstudio.weatherhere.free
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.nstudio.weatherhere.free
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-164 ---------------------
# package_name:  com.netpulse.mobile.stevenashfitnessworldsportsclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.stevenashfitnessworldsportsclub
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-165 ---------------------
# package_name:  interactiveshift.com.trailswear
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\interactiveshift.com.trailswear
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-166 ---------------------
# package_name:  yogaworkouts.dailyyoga.yogafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\yogaworkouts.dailyyoga.yogafitness
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-167 ---------------------
# package_name:  com.topstep.fitcloudpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.topstep.fitcloudpro
# --------------------- Loop-168 ---------------------
# package_name:  com.fitelo.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitelo.android
# --------------------- Loop-169 ---------------------
# package_name:  com.monkeyfitpass.monkyappv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.monkeyfitpass.monkyappv
# ...
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-466 ---------------------
# package_name:  com.benda.fitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.benda.fitpro
# --------------------- Loop-467 ---------------------
# package_name:  digifit.android.virtuagym.pro.sparksport22
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.sparksport22
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-468 ---------------------
# package_name:  com.ubivelox.uvophone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ubivelox.uvophone
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-469 ---------------------
# package_name:  com.mapmyfitness.android2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mapmyfitness.android2
# --------------------- Loop-470 ---------------------
# package_name:  com.fitradio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitradio
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-471 ---------------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# --------------------- Loop-472 ---------------------
# package_name:  com.blinkfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.blinkfitness.app
# --------------------- Loop-473 ---------------------
# package_name:  com.netpulse.mobile.morefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-474 ---------------------
# package_name:  com.walkonfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkonfit.app
# --------------------- Loop-475 ---------------------
# package_name:  com.fitplanapp.fitplan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-476 ---------------------
# package_name:  com.mauriciotogneri.shoppinglist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mauriciotogneri.shoppinglist
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-477 ---------------------
# package_name:  com.taskoob.fitHer.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.taskoob.fitHer.android
# --------------------- Loop-478 ---------------------
# package_name:  com.WahooFitness.SYSTM
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.WahooFitness.SYSTM
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-479 ---------------------
# package_name:  com.fitnessmobileapps.f45training
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.f45training
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-480 ---------------------
# package_name:  com.worldgymfitness.homeworkoutnoequipments
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.worldgymfitness.homeworkoutnoequipments
# --------------------- Loop-481 ---------------------
# package_name:  com.unated
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.unated
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-482 ---------------------
# package_name:  com.noisefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-483 ---------------------
# package_name:  com.canyon.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.canyon.fit
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-484 ---------------------
# package_name:  com.directed.android.viper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.directed.android.viper
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# --------------------- Loop-485 ---------------------
# package_name:  br.com.w12.skyfitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.skyfitapp
# --------------------- Loop-486 ---------------------
# package_name:  com.netpulse.mobile.uniquefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.uniquefit
# --------------------- Loop-487 ---------------------
# package_name:  today.upfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\today.upfit
# --------------------- Loop-488 ---------------------
# package_name:  digifit.android.virtuagym.pro.clubnorthwest
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.clubnorthwest
# --------------------- Loop-489 ---------------------
# package_name:  digifit.android.virtuagym.pro.celtix
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix
# --------------------- Loop-490 ---------------------
# package_name:  com.netpulse.mobile.healthfitnesscenter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.healthfitnesscenter
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-491 ---------------------
# package_name:  org.obduro.kentekeninfo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.obduro.kentekeninfo
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-492 ---------------------
# package_name:  verv.health.fitness.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\verv.health.fitness.workout.weight.loss
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-493 ---------------------
# package_name:  com.ramonmorcillo.fitbot01
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ramonmorcillo.fitbot01
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-494 ---------------------
# package_name:  fitness.com.senior
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.com.senior
# --------------------- Loop-495 ---------------------
# package_name:  pl.efitness.mobile
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.efitness.mobile
# --------------------- Loop-496 ---------------------
# package_name:  com.fitnessmobileapps.speedfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.speedfit
# --------------------- Loop-497 ---------------------
# package_name:  com.jawline.exercises.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jawline.exercises.fitness
# --------------------- Loop-498 ---------------------
# package_name:  digifit.android.virtuagym.pro.healthyvitabybv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.healthyvitabybv
# --------------------- Loop-499 ---------------------
# package_name:  com.vfit.vfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vfit.vfit
# --------------------- Loop-500 ---------------------
# package_name:  com.lianhezhuli.hyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lianhezhuli.hyfit
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_19.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-501 ---------------------
# package_name:  com.fitnessanny
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessanny
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_5.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-502 ---------------------
# package_name:  ie.zappy.fennec.barbellqueenfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ie.zappy.fennec.barbellqueenfitness
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_6.txt
# Blank lines found and removed in: message_7.txt
# Blank lines found and removed in: message_8.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-503 ---------------------
# package_name:  de.myfitcoach.tim.mfc
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\de.myfitcoach.tim.mfc
# --------------------- Loop-504 ---------------------
# package_name:  com.fitnesses.fitticoin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesses.fitticoin
# --------------------- Loop-505 ---------------------
# package_name:  femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# --------------------- Loop-506 ---------------------
# package_name:  women.workout.female.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# --------------------- Loop-507 ---------------------
# package_name:  com.brooklynfitzone.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_6.txt
# --------------------- Loop-508 ---------------------
# package_name:  com.johnsonfitness.fitdisplay2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.johnsonfitness.fitdisplay2
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# --------------------- Loop-509 ---------------------
# package_name:  com.mc.amazfit1
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mc.amazfit1
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# --------------------- Loop-510 ---------------------
# package_name:  nl.dominos.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nl.dominos.android
# --------------------- Loop-511 ---------------------
# package_name:  org.eson.getfit3
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.eson.getfit3
# Blank lines found and removed in: message_2.txt
# --------------------- Loop-512 ---------------------
# package_name:  com.netpulse.mobile.eosfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.eosfitness
# --------------------- Loop-513 ---------------------
# package_name:  digifit.android.virtuagym.pro.strongfitnesswinfield
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.strongfitnesswinfield
# --------------------- Loop-514 ---------------------
# package_name:  com.innovatise.newvisionfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.newvisionfitness
# --------------------- Loop-515 ---------------------
# package_name:  kz.maestrosultan.fitjournal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kz.maestrosultan.fitjournal
# Blank lines found and removed in: message_1.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_14.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_16.txt
# Blank lines found and removed in: message_17.txt
# Blank lines found and removed in: message_18.txt
# Blank lines found and removed in: message_19.txt
# Blank lines found and removed in: message_20.txt
# Blank lines found and removed in: message_21.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_4.txt
# Blank lines found and removed in: message_8.txt
# --------------------- Loop-516 ---------------------
# package_name:  com.bejaofit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bejaofit.app
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_1.txt
# --------------------- Loop-517 ---------------------
# package_name:  fit.withu.flutter.withu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.withu.flutter.withu
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_7.txt
# --------------------- Loop-518 ---------------------
# package_name:  com.shapehq.fitnessworld
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shapehq.fitnessworld
# Blank lines found and removed in: message_10.txt
# Blank lines found and removed in: message_3.txt
# Blank lines found and removed in: message_9.txt
# --------------------- Loop-519 ---------------------
# package_name:  com.orangetheoryfitness.orangetheory
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory
# Blank lines found and removed in: message_0.txt
# Blank lines found and removed in: message_11.txt
# Blank lines found and removed in: message_12.txt
# Blank lines found and removed in: message_15.txt
# Blank lines found and removed in: message_2.txt
# Blank lines found and removed in: message_7.txt

# %%
for j in range(len(array_traffic_package_name)):
    print("--------------------- Loop-"+str(j)+" ---------------------")
    package_name = array_traffic_package_name[j]
    print("package_name: ",package_name)
    traffic_directory_path = root_traffic_directory_path + "\\" + package_name
    print("traffic_directory_path: ",traffic_directory_path)
    move_files_with_phrase(traffic_directory_path, "youtube")
# Out:
# --------------------- Loop-0 ---------------------
# package_name:  jp.joyfit.joyfitappandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.joyfit.joyfitappandroid
# --------------------- Loop-1 ---------------------
# package_name:  com.apep.fitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.apep.fitapp
# --------------------- Loop-2 ---------------------
# package_name:  com.fitwhey.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitwhey.app
# --------------------- Loop-3 ---------------------
# package_name:  com.zq.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zq.fit
# --------------------- Loop-4 ---------------------
# package_name:  maxcom.toolbox.altimeter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\maxcom.toolbox.altimeter
# --------------------- Loop-5 ---------------------
# package_name:  uk.co.fitness4less.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\uk.co.fitness4less.app
# --------------------- Loop-6 ---------------------
# package_name:  com.instafit.workouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.instafit.workouts
# --------------------- Loop-7 ---------------------
# package_name:  digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# --------------------- Loop-8 ---------------------
# package_name:  com.edjing.edjingdjturntable
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.edjing.edjingdjturntable
# --------------------- Loop-9 ---------------------
# package_name:  com.artkitch.alexfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.artkitch.alexfitness
# --------------------- Loop-10 ---------------------
# package_name:  com.onefitstop.bodyfittraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.onefitstop.bodyfittraining
# --------------------- Loop-11 ---------------------
# package_name:  coach.zing.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\coach.zing.fitness
# Moving file: message_2.txt (contains 'youtube')
# --------------------- Loop-12 ---------------------
# package_name:  com.golf.fitforgolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.golf.fitforgolf
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-13 ---------------------
# package_name:  com.trainerize.yetifit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.yetifit
# --------------------- Loop-14 ---------------------
# package_name:  homeworkoutapp.homeworkout.fitness.workout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight
# --------------------- Loop-15 ---------------------
# package_name:  com.skyhealth.fitnessbuddyandroidfree
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.skyhealth.fitnessbuddyandroidfree
# --------------------- Loop-16 ---------------------
# package_name:  fitapp.fittofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitapp.fittofit
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# --------------------- Loop-17 ---------------------
# package_name:  com.fiton.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fiton.android
# --------------------- Loop-18 ---------------------
# package_name:  com.polaroidfit.polaroidfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.polaroidfit.polaroidfit
# --------------------- Loop-19 ---------------------
# package_name:  com.chloeting.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-20 ---------------------
# package_name:  com.madarsoft.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.madarsoft.fitness
# --------------------- Loop-21 ---------------------
# package_name:  com.anytimefitness.userapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# --------------------- Loop-22 ---------------------
# package_name:  com.netpulse.mobile.fitzonedelutte
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.fitzonedelutte
# --------------------- Loop-23 ---------------------
# package_name:  com.honbow.letsfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.letsfit
# --------------------- Loop-24 ---------------------
# package_name:  com.anytimefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.app
# --------------------- Loop-25 ---------------------
# package_name:  com.keepfit.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.keepfit.loseweight
# --------------------- Loop-26 ---------------------
# package_name:  com.samsung.android.shealthmonitor
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.shealthmonitor
# --------------------- Loop-27 ---------------------
# package_name:  com.zewa.fit.pro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zewa.fit.pro
# --------------------- Loop-28 ---------------------
# package_name:  com.mycloudfitness.mycloudfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mycloudfitness.mycloudfitness
# Moving file: message_2.txt (contains 'youtube')
# --------------------- Loop-29 ---------------------
# package_name:  com.oplayer.goodmansfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.oplayer.goodmansfitpro
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-30 ---------------------
# package_name:  digifit.android.virtuagym.pro.fisic
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fisic
# --------------------- Loop-31 ---------------------
# package_name:  com.hootapps.soundrecorder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hootapps.soundrecorder
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-32 ---------------------
# package_name:  eu.fitric.pregnancyworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.pregnancyworkout
# Moving file: message_6.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-33 ---------------------
# package_name:  com.luni.android.fitnesscoach.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.luni.android.fitnesscoach.app
# --------------------- Loop-34 ---------------------
# package_name:  com.szyk.myheart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.szyk.myheart
# --------------------- Loop-35 ---------------------
# package_name:  com.viatek.fitnation.echelon_android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android
# --------------------- Loop-36 ---------------------
# package_name:  com.zjw.xwfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zjw.xwfit
# --------------------- Loop-37 ---------------------
# package_name:  com.bandlab.bandlab
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bandlab.bandlab
# --------------------- Loop-38 ---------------------
# package_name:  com.wakeup.wearfit2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.wakeup.wearfit2
# --------------------- Loop-39 ---------------------
# package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp
# Moving file: message_14.txt (contains 'youtube')
# Moving file: message_17.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-40 ---------------------
# package_name:  com.biztech.magemobadmin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.biztech.magemobadmin
# --------------------- Loop-41 ---------------------
# package_name:  com.fitifyapps.bwcardio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwcardio
# --------------------- Loop-42 ---------------------
# package_name:  com.bpfit.bloodpressure.health
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-43 ---------------------
# package_name:  com.equinoxfitness.equinox
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.equinoxfitness.equinox
# --------------------- Loop-44 ---------------------
# package_name:  com.mobifitness.bettadance342273
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.bettadance342273
# --------------------- Loop-45 ---------------------
# package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# --------------------- Loop-46 ---------------------
# package_name:  com.pocketlifestyle.music.tune
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.pocketlifestyle.music.tune
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-47 ---------------------
# package_name:  com.fitapp.timerwodapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitapp.timerwodapp
# --------------------- Loop-48 ---------------------
# package_name:  com.mattdoesfitness.morsia
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mattdoesfitness.morsia
# --------------------- Loop-49 ---------------------
# package_name:  home.fitness.challenge
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\home.fitness.challenge
# --------------------- Loop-50 ---------------------
# package_name:  app.EnForma.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.EnForma.fitcoapp.net
# --------------------- Loop-51 ---------------------
# package_name:  com.crrepa.band.havefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.havefit
# --------------------- Loop-52 ---------------------
# package_name:  com.glidetalk.glideapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.glidetalk.glideapp
# --------------------- Loop-53 ---------------------
# package_name:  com.fuse.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fuse.fitness
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-54 ---------------------
# package_name:  com.trainerize.youfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.youfit
# --------------------- Loop-55 ---------------------
# package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# --------------------- Loop-56 ---------------------
# package_name:  com.qualitrain.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qualitrain.fitness
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-57 ---------------------
# package_name:  com.spotify.music
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.spotify.music
# --------------------- Loop-58 ---------------------
# package_name:  ott.beatboxingfitnessworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ott.beatboxingfitnessworkouts
# --------------------- Loop-59 ---------------------
# package_name:  com.itrack.myfit755570
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.itrack.myfit755570
# --------------------- Loop-60 ---------------------
# package_name:  com.movefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.movefitness.app
# --------------------- Loop-61 ---------------------
# package_name:  com.sasyabook.businesscardapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.sasyabook.businesscardapp
# --------------------- Loop-62 ---------------------
# package_name:  com.bottegasol.com.migym.fitnessconnection
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bottegasol.com.migym.fitnessconnection
# --------------------- Loop-63 ---------------------
# package_name:  com.bendingspoons.thirtydayfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bendingspoons.thirtydayfitness
# --------------------- Loop-64 ---------------------
# package_name:  com.bickster.fitbitbandfinder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# --------------------- Loop-65 ---------------------
# package_name:  com.github.jamesgay.fitnotes
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.github.jamesgay.fitnotes
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-66 ---------------------
# package_name:  fitness.home.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.home.workout.weight.loss
# --------------------- Loop-67 ---------------------
# package_name:  rs.fastfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.fastfit.app
# --------------------- Loop-68 ---------------------
# package_name:  net.peater.fitlovers
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers
# --------------------- Loop-69 ---------------------
# package_name:  rebel.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rebel.fitness
# --------------------- Loop-70 ---------------------
# package_name:  com.qingniu.fitindex
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.fitindex
# --------------------- Loop-71 ---------------------
# package_name:  faceyoga.facefitness.dailyworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\faceyoga.facefitness.dailyworkouts
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# Moving file: message_7.txt (contains 'youtube')
# --------------------- Loop-72 ---------------------
# package_name:  com.goodlifefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.goodlifefitness
# Moving file: message_15.txt (contains 'youtube')
# --------------------- Loop-73 ---------------------
# package_name:  com.czw.freefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.czw.freefit
# --------------------- Loop-74 ---------------------
# package_name:  com.fitzeee.fitzeeerun
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.fitzeeerun
# --------------------- Loop-75 ---------------------
# package_name:  com.eightfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eightfit.app
# --------------------- Loop-76 ---------------------
# package_name:  com.runmifit.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.runmifit.android
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_13.txt (contains 'youtube')
# Moving file: message_16.txt (contains 'youtube')
# Moving file: message_17.txt (contains 'youtube')
# Moving file: message_18.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_20.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# --------------------- Loop-77 ---------------------
# package_name:  com.google.android.apps.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.google.android.apps.fitness
# --------------------- Loop-78 ---------------------
# package_name:  com.joshua.hasfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.joshua.hasfit
# --------------------- Loop-79 ---------------------
# package_name:  com.lafitness.lafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lafitness.lafitness
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-80 ---------------------
# package_name:  com.yc.gloryfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gloryfitpro
# Moving file: message_23.txt (contains 'youtube')
# --------------------- Loop-81 ---------------------
# package_name:  com.hwd.flowfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hwd.flowfit
# --------------------- Loop-82 ---------------------
# package_name:  com.walkfit.weightloss.steptracker.pedometer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkfit.weightloss.steptracker.pedometer
# --------------------- Loop-83 ---------------------
# package_name:  com.riversongfit.epoch
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.riversongfit.epoch
# --------------------- Loop-84 ---------------------
# package_name:  club.skllzz.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\club.skllzz.fitness
# --------------------- Loop-85 ---------------------
# package_name:  com.xj.inxfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.xj.inxfit
# --------------------- Loop-86 ---------------------
# package_name:  com.mobifitness.nsfit104363
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.nsfit104363
# --------------------- Loop-87 ---------------------
# package_name:  dance.workout.home.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\dance.workout.home.fitness
# Moving file: message_13.txt (contains 'youtube')
# --------------------- Loop-88 ---------------------
# package_name:  com.womenfitness.workoutbuddy.mea
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.womenfitness.workoutbuddy.mea
# --------------------- Loop-89 ---------------------
# package_name:  com.std.fitness.point
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.std.fitness.point
# --------------------- Loop-90 ---------------------
# package_name:  starshipproduct.perifitmainapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\starshipproduct.perifitmainapp
# --------------------- Loop-91 ---------------------
# package_name:  rs.nonstopfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.nonstopfitness
# --------------------- Loop-92 ---------------------
# package_name:  com.cavosmart.wofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cavosmart.wofit
# Moving file: message_12.txt (contains 'youtube')
# Moving file: message_27.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-93 ---------------------
# package_name:  nz.co.telecom.smartphone.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android
# --------------------- Loop-94 ---------------------
# package_name:  org.moffitt.brandedpatientportal.play
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.moffitt.brandedpatientportal.play
# --------------------- Loop-95 ---------------------
# package_name:  workoutforwomen.femalefitness.womenworkout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\workoutforwomen.femalefitness.womenworkout.loseweight
# Moving file: message_11.txt (contains 'youtube')
# --------------------- Loop-96 ---------------------
# package_name:  digifit.virtuagym.client.android.coaching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android.coaching
# --------------------- Loop-97 ---------------------
# package_name:  com.SnowReport.screens
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.SnowReport.screens
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# --------------------- Loop-98 ---------------------
# package_name:  com.jquiz.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jquiz.english
# --------------------- Loop-99 ---------------------
# package_name:  digifit.android.virtuagym.pro.buzzgymsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.buzzgymsuperclub
# --------------------- Loop-100 ---------------------
# package_name:  com.noisefit.focus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit.focus
# --------------------- Loop-101 ---------------------
# package_name:  com.independence284.badassbodyfitnessx
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.independence284.badassbodyfitnessx
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# --------------------- Loop-102 ---------------------
# package_name:  com.eztech.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eztech.fitness
# --------------------- Loop-103 ---------------------
# package_name:  com.myfitnesspal.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesspal.android
# --------------------- Loop-104 ---------------------
# package_name:  com.fitbod.fitbod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitbod.fitbod
# --------------------- Loop-105 ---------------------
# package_name:  digifit.android.virtuagym.pro.ymcapeninsulademo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.ymcapeninsulademo
# --------------------- Loop-106 ---------------------
# package_name:  com.simplyfit.rowing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.simplyfit.rowing
# --------------------- Loop-107 ---------------------
# package_name:  com.marianatek.cbfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marianatek.cbfit
# Moving file: message_7.txt (contains 'youtube')
# --------------------- Loop-108 ---------------------
# package_name:  drzio.senior.yoga.fitness.elders.old.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout
# --------------------- Loop-109 ---------------------
# package_name:  net.kosev.dicing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.kosev.dicing
# --------------------- Loop-110 ---------------------
# package_name:  com.Female.Fitness.cardio.wellness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.Female.Fitness.cardio.wellness
# --------------------- Loop-111 ---------------------
# package_name:  app.fit.meet
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# --------------------- Loop-112 ---------------------
# package_name:  com.fitnesspassport.androidapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesspassport.androidapp
# Moving file: message_12.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_7.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-113 ---------------------
# package_name:  rs.abstract.fitpass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.abstract.fitpass
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-114 ---------------------
# package_name:  digifit.android.virtuagym.pro.bodyassault
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.bodyassault
# --------------------- Loop-115 ---------------------
# package_name:  com.tomtop.smart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.tomtop.smart
# --------------------- Loop-116 ---------------------
# package_name:  com.kannergroup.fitnessculture
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kannergroup.fitnessculture
# --------------------- Loop-117 ---------------------
# package_name:  com.fitatu.tracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitatu.tracker
# --------------------- Loop-118 ---------------------
# package_name:  com.ifit.wolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ifit.wolf
# --------------------- Loop-119 ---------------------
# package_name:  com.fitness22.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.workout
# --------------------- Loop-120 ---------------------
# package_name:  com.cizotech.fit2flaunt
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cizotech.fit2flaunt
# Moving file: message_15.txt (contains 'youtube')
# --------------------- Loop-121 ---------------------
# package_name:  com.fitness22.running
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.running
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# --------------------- Loop-122 ---------------------
# package_name:  com.samsung.android.app.watchmanager
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.app.watchmanager
# --------------------- Loop-123 ---------------------
# package_name:  com.honbow.fitdock
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock
# Moving file: message_11.txt (contains 'youtube')
# Moving file: message_16.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# --------------------- Loop-124 ---------------------
# package_name:  com.fitlab.spartan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlab.spartan
# --------------------- Loop-125 ---------------------
# package_name:  com.marsathletic.android.macfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marsathletic.android.macfit.app
# --------------------- Loop-126 ---------------------
# package_name:  ru.starline
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ru.starline
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_7.txt (contains 'youtube')
# --------------------- Loop-127 ---------------------
# package_name:  digifit.android.virtuagym.pro.puurpersonaltraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.puurpersonaltraining
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# --------------------- Loop-128 ---------------------
# package_name:  eu.fitric.hourglass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.hourglass
# Moving file: message_3.txt (contains 'youtube')
# --------------------- Loop-129 ---------------------
# package_name:  homeworkout.fitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkout.fitness.app
# --------------------- Loop-130 ---------------------
# package_name:  com.fixfit_fitness.twa
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-131 ---------------------
# package_name:  com.reset.reset_fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.reset.reset_fitness
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-132 ---------------------
# package_name:  com.yc.gtfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gtfit
# --------------------- Loop-133 ---------------------
# package_name:  com.trainerize.outlawfitcamp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.outlawfitcamp
# --------------------- Loop-134 ---------------------
# package_name:  fit.cult.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.cult.android
# --------------------- Loop-135 ---------------------
# package_name:  com.fitzeee.pedometerwalking
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.pedometerwalking
# --------------------- Loop-136 ---------------------
# package_name:  biz.mobidev.mdplayer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\biz.mobidev.mdplayer
# --------------------- Loop-137 ---------------------
# package_name:  com.netpulse.mobile.clubfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.clubfit
# --------------------- Loop-138 ---------------------
# package_name:  com.kompanion.fitness.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kompanion.fitness.android
# --------------------- Loop-139 ---------------------
# package_name:  foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# --------------------- Loop-140 ---------------------
# package_name:  pl.tweeba.mobile.learning.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.tweeba.mobile.learning.english
# --------------------- Loop-141 ---------------------
# package_name:  com.mictale.gpsessentials
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mictale.gpsessentials
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-142 ---------------------
# package_name:  com.trainerize.witfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.witfit
# --------------------- Loop-143 ---------------------
# package_name:  com.bhphoto
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bhphoto
# --------------------- Loop-144 ---------------------
# package_name:  com.toshremote.view
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.toshremote.view
# --------------------- Loop-145 ---------------------
# package_name:  com.basicfit.trainingApp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basicfit.trainingApp
# --------------------- Loop-146 ---------------------
# package_name:  com.adi.remote.phone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.adi.remote.phone
# --------------------- Loop-147 ---------------------
# package_name:  com.caliberfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.caliberfitness.app
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_11.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# --------------------- Loop-148 ---------------------
# package_name:  com.lifetrons.lifetrons.app.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lifetrons.lifetrons.app.fitness
# --------------------- Loop-149 ---------------------
# package_name:  tarlin.fitness.loseweight.belly.fem
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\tarlin.fitness.loseweight.belly.fem
# --------------------- Loop-150 ---------------------
# package_name:  com.fitifyapps.bwstretching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching
# --------------------- Loop-151 ---------------------
# package_name:  nz.co.madfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.madfit
# Moving file: message_12.txt (contains 'youtube')
# Moving file: message_13.txt (contains 'youtube')
# Moving file: message_20.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-152 ---------------------
# package_name:  com.appyfurious.getfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.appyfurious.getfit
# --------------------- Loop-153 ---------------------
# package_name:  com.walking.fun.rewards.fitness.fitzu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walking.fun.rewards.fitness.fitzu
# --------------------- Loop-154 ---------------------
# package_name:  digifit.android.virtuagym.pro.leisureunitedsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.leisureunitedsuperclub
# --------------------- Loop-155 ---------------------
# package_name:  app.growwithjo.diet.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# --------------------- Loop-156 ---------------------
# package_name:  digifit.android.virtuagym.pro.neobod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.neobod
# --------------------- Loop-157 ---------------------
# package_name:  com.aircanada
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.aircanada
# --------------------- Loop-158 ---------------------
# package_name:  digifit.virtuagym.client.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android
# --------------------- Loop-159 ---------------------
# package_name:  com.smartwidgetlabs.fitbitandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.smartwidgetlabs.fitbitandroid
# --------------------- Loop-160 ---------------------
# package_name:  com.trainerize.grindafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.grindafitness
# --------------------- Loop-161 ---------------------
# package_name:  it.tripix.buddyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_10.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# --------------------- Loop-162 ---------------------
# package_name:  com.evolutionwellness.app.celebrityfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.celebrityfitness
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-163 ---------------------
# package_name:  com.nstudio.weatherhere.free
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.nstudio.weatherhere.free
# --------------------- Loop-164 ---------------------
# package_name:  com.netpulse.mobile.stevenashfitnessworldsportsclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.stevenashfitnessworldsportsclub
# --------------------- Loop-165 ---------------------
# package_name:  interactiveshift.com.trailswear
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\interactiveshift.com.trailswear
# --------------------- Loop-166 ---------------------
# package_name:  yogaworkouts.dailyyoga.yogafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\yogaworkouts.dailyyoga.yogafitness
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-167 ---------------------
# package_name:  com.topstep.fitcloudpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.topstep.fitcloudpro
# --------------------- Loop-168 ---------------------
# package_name:  com.fitelo.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitelo.android
# --------------------- Loop-169 ---------------------
# package_name:  com.monkeyfitpass.monkyappv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.monkeyfitpass.monkyappv
# --------------------- Loop-170 ---------------------
# package_name:  com.watch.yfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.watch.yfitpro
# --------------------- Loop-171 ---------------------
# package_name:  se.matlistan.free
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\se.matlistan.free
# --------------------- Loop-172 ---------------------
# package_name:  com.best.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.best.fit
# --------------------- Loop-173 ---------------------
# package_name:  com.jyfitness.iron_mastery
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jyfitness.iron_mastery
# --------------------- Loop-174 ---------------------
# package_name:  br.com.fitastic.appaluno
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.fitastic.appaluno
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-175 ---------------------
# package_name:  com.airofit_app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.airofit_app
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-176 ---------------------
# package_name:  com.perfectgym.perfectgymgo2.fitness247latinamerica
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.fitness247latinamerica
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-177 ---------------------
# package_name:  kr.fitt.fmes
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kr.fitt.fmes
# Moving file: message_11.txt (contains 'youtube')
# Moving file: message_16.txt (contains 'youtube')
# Moving file: message_26.txt (contains 'youtube')
# Moving file: message_27.txt (contains 'youtube')
# Moving file: message_28.txt (contains 'youtube')
# Moving file: message_31.txt (contains 'youtube')
# --------------------- Loop-178 ---------------------
# package_name:  fat.burnning.plank.fitness.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight
# --------------------- Loop-179 ---------------------
# package_name:  fitness.ddx.ddx_fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.ddx.ddx_fitness
# --------------------- Loop-180 ---------------------
# package_name:  br.com.w12.bluefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.bluefit
# --------------------- Loop-181 ---------------------
# package_name:  com.basemsalloum.goodfitness.goodfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness
# --------------------- Loop-182 ---------------------
# package_name:  com.huawo.ufit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.huawo.ufit
# --------------------- Loop-183 ---------------------
# package_name:  kr.co.everyfit.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kr.co.everyfit.fitness
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_10.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-184 ---------------------
# package_name:  com.ktmusic.geniemusic
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ktmusic.geniemusic
# --------------------- Loop-185 ---------------------
# package_name:  tr.com.fitwell.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\tr.com.fitwell.app
# --------------------- Loop-186 ---------------------
# package_name:  jp.co.yahoo.android.vassist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist
# --------------------- Loop-187 ---------------------
# package_name:  com.fittech.fasting.tracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fittech.fasting.tracker
# --------------------- Loop-188 ---------------------
# package_name:  com.fitnow.loseit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnow.loseit
# --------------------- Loop-189 ---------------------
# package_name:  com.fitnessmobileapps.elevate35253
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.elevate35253
# --------------------- Loop-190 ---------------------
# package_name:  com.rageconsulting.android.lightflowlegacy
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy
# --------------------- Loop-191 ---------------------
# package_name:  com.concapps.benfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.concapps.benfit
# --------------------- Loop-192 ---------------------
# package_name:  br.com.w12.heyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit
# --------------------- Loop-193 ---------------------
# package_name:  appnativo.navysportcenter.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\appnativo.navysportcenter.fitcoapp.net
# --------------------- Loop-194 ---------------------
# package_name:  com.innovatise.fitnesstimeleejam
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_25.txt (contains 'youtube')
# --------------------- Loop-195 ---------------------
# package_name:  digifit.android.virtuagym.pro.everlast
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.everlast
# --------------------- Loop-196 ---------------------
# package_name:  fitnesscoach.workoutplanner.weightloss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitnesscoach.workoutplanner.weightloss
# Moving file: message_0.txt (contains 'youtube')
# --------------------- Loop-197 ---------------------
# package_name:  com.qingniu.feelfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.feelfit
# --------------------- Loop-198 ---------------------
# package_name:  digifit.android.virtuagym.pro.yababethfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.yababethfit
# --------------------- Loop-199 ---------------------
# package_name:  com.fitnessmobileapps.orangetheoryfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.orangetheoryfitness
# --------------------- Loop-200 ---------------------
# package_name:  softin.my.fast.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\softin.my.fast.fitness
# --------------------- Loop-201 ---------------------
# package_name:  com.proyecto.fit.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.fit.tgcustom
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# Moving file: message_7.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-202 ---------------------
# package_name:  com.rootberz.thirtydayfitchallenges
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.rootberz.thirtydayfitchallenges
# --------------------- Loop-203 ---------------------
# package_name:  com.kiss.keeper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kiss.keeper
# --------------------- Loop-204 ---------------------
# package_name:  com.proyecto.beonefitnesssport.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom
# --------------------- Loop-205 ---------------------
# package_name:  com.vgfit.shefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit
# --------------------- Loop-206 ---------------------
# package_name:  com.yesfitclient
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yesfitclient
# --------------------- Loop-207 ---------------------
# package_name:  com.dolcegustofree.activity
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity
# --------------------- Loop-208 ---------------------
# package_name:  com.kilogroup.fitter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter
# --------------------- Loop-209 ---------------------
# package_name:  com.fitzeee.menworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.menworkout
# --------------------- Loop-210 ---------------------
# package_name:  com.fitness.mybodymass.bmicalculator
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.mybodymass.bmicalculator
# --------------------- Loop-211 ---------------------
# package_name:  com.forfit.mymediterranean
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.forfit.mymediterranean
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-212 ---------------------
# package_name:  com.future.FitYou
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.future.FitYou
# --------------------- Loop-213 ---------------------
# package_name:  com.megasys.profit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.megasys.profit
# --------------------- Loop-214 ---------------------
# package_name:  com.mysports.branded.mcfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mysports.branded.mcfit
# --------------------- Loop-215 ---------------------
# package_name:  com.arisdot.gymfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.arisdot.gymfit
# --------------------- Loop-216 ---------------------
# package_name:  com.trainerize.fitlov
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.fitlov
# --------------------- Loop-217 ---------------------
# package_name:  com.netpulse.mobile.fitnessproject
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.fitnessproject
# --------------------- Loop-218 ---------------------
# package_name:  com.shikudo.fitrpg.google
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google
# --------------------- Loop-219 ---------------------
# package_name:  app.LomasGym.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net
# --------------------- Loop-220 ---------------------
# package_name:  com.plaifit.plaifit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.plaifit.plaifit
# --------------------- Loop-221 ---------------------
# package_name:  com.user.livefitt
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.user.livefitt
# --------------------- Loop-222 ---------------------
# package_name:  com.techbull.fitolympia
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.techbull.fitolympia
# --------------------- Loop-223 ---------------------
# package_name:  com.studiorouleau.funfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.studiorouleau.funfit
# --------------------- Loop-224 ---------------------
# package_name:  com.clearskyapps.fitnessfamily.RunC210K
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.RunC210K
# --------------------- Loop-225 ---------------------
# ...
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-445 ---------------------
# package_name:  com.organicapps.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.organicapps.fit
# --------------------- Loop-446 ---------------------
# package_name:  com.fitness.stepcounter.pedometer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.stepcounter.pedometer
# --------------------- Loop-447 ---------------------
# package_name:  com.samsung.android.wear.shealth
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.wear.shealth
# --------------------- Loop-448 ---------------------
# package_name:  com.vt.vitafit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vt.vitafit
# --------------------- Loop-449 ---------------------
# package_name:  com.vulsen.popfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vulsen.popfit
# Moving file: message_19.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-450 ---------------------
# package_name:  je.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\je.fit
# Moving file: message_28.txt (contains 'youtube')
# Moving file: message_38.txt (contains 'youtube')
# Moving file: message_51.txt (contains 'youtube')
# Moving file: message_57.txt (contains 'youtube')
# --------------------- Loop-451 ---------------------
# package_name:  com.fitze
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitze
# --------------------- Loop-452 ---------------------
# package_name:  com.netpulse.mobile.chuzefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.chuzefitness
# --------------------- Loop-453 ---------------------
# package_name:  com.trainerize.fitness19bergenfield
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.fitness19bergenfield
# --------------------- Loop-454 ---------------------
# package_name:  es.dreamfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\es.dreamfit.app
# --------------------- Loop-455 ---------------------
# package_name:  com.myfitnesscoach
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach
# --------------------- Loop-456 ---------------------
# package_name:  fit.trainiac.android.client
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.trainiac.android.client
# --------------------- Loop-457 ---------------------
# package_name:  fit.remotecoach.fitin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.remotecoach.fitin
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-458 ---------------------
# package_name:  com.lifetimefitness.interests.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lifetimefitness.interests.fitness
# --------------------- Loop-459 ---------------------
# package_name:  com.actofitSmartScale
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale
# --------------------- Loop-460 ---------------------
# package_name:  com.cs.booty.fit.buttocks.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cs.booty.fit.buttocks.workout
# --------------------- Loop-461 ---------------------
# package_name:  com.fitifyapps.kettlebell
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.kettlebell
# --------------------- Loop-462 ---------------------
# package_name:  com.netpulse.mobile.bodyplexfamilyfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.bodyplexfamilyfitness
# --------------------- Loop-463 ---------------------
# package_name:  com.btfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.btfit
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_13.txt (contains 'youtube')
# Moving file: message_14.txt (contains 'youtube')
# Moving file: message_16.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-464 ---------------------
# package_name:  com.mz.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mz.fit
# Moving file: message_13.txt (contains 'youtube')
# Moving file: message_14.txt (contains 'youtube')
# Moving file: message_6.txt (contains 'youtube')
# --------------------- Loop-465 ---------------------
# package_name:  com.fitlapapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlapapp
# --------------------- Loop-466 ---------------------
# package_name:  com.benda.fitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.benda.fitpro
# --------------------- Loop-467 ---------------------
# package_name:  digifit.android.virtuagym.pro.sparksport22
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.sparksport22
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-468 ---------------------
# package_name:  com.ubivelox.uvophone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ubivelox.uvophone
# Moving file: message_5.txt (contains 'youtube')
# --------------------- Loop-469 ---------------------
# package_name:  com.mapmyfitness.android2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mapmyfitness.android2
# --------------------- Loop-470 ---------------------
# package_name:  com.fitradio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitradio
# --------------------- Loop-471 ---------------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# --------------------- Loop-472 ---------------------
# package_name:  com.blinkfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.blinkfitness.app
# --------------------- Loop-473 ---------------------
# package_name:  com.netpulse.mobile.morefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness
# --------------------- Loop-474 ---------------------
# package_name:  com.walkonfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkonfit.app
# --------------------- Loop-475 ---------------------
# package_name:  com.fitplanapp.fitplan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan
# --------------------- Loop-476 ---------------------
# package_name:  com.mauriciotogneri.shoppinglist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mauriciotogneri.shoppinglist
# --------------------- Loop-477 ---------------------
# package_name:  com.taskoob.fitHer.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.taskoob.fitHer.android
# --------------------- Loop-478 ---------------------
# package_name:  com.WahooFitness.SYSTM
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.WahooFitness.SYSTM
# --------------------- Loop-479 ---------------------
# package_name:  com.fitnessmobileapps.f45training
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.f45training
# --------------------- Loop-480 ---------------------
# package_name:  com.worldgymfitness.homeworkoutnoequipments
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.worldgymfitness.homeworkoutnoequipments
# --------------------- Loop-481 ---------------------
# package_name:  com.unated
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.unated
# --------------------- Loop-482 ---------------------
# package_name:  com.noisefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit
# --------------------- Loop-483 ---------------------
# package_name:  com.canyon.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.canyon.fit
# --------------------- Loop-484 ---------------------
# package_name:  com.directed.android.viper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.directed.android.viper
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-485 ---------------------
# package_name:  br.com.w12.skyfitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.skyfitapp
# --------------------- Loop-486 ---------------------
# package_name:  com.netpulse.mobile.uniquefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.uniquefit
# --------------------- Loop-487 ---------------------
# package_name:  today.upfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\today.upfit
# --------------------- Loop-488 ---------------------
# package_name:  digifit.android.virtuagym.pro.clubnorthwest
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.clubnorthwest
# --------------------- Loop-489 ---------------------
# package_name:  digifit.android.virtuagym.pro.celtix
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix
# --------------------- Loop-490 ---------------------
# package_name:  com.netpulse.mobile.healthfitnesscenter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.healthfitnesscenter
# Moving file: message_3.txt (contains 'youtube')
# Moving file: message_5.txt (contains 'youtube')
# Moving file: message_8.txt (contains 'youtube')
# --------------------- Loop-491 ---------------------
# package_name:  org.obduro.kentekeninfo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.obduro.kentekeninfo
# Moving file: message_0.txt (contains 'youtube')
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-492 ---------------------
# package_name:  verv.health.fitness.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\verv.health.fitness.workout.weight.loss
# --------------------- Loop-493 ---------------------
# package_name:  com.ramonmorcillo.fitbot01
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ramonmorcillo.fitbot01
# Moving file: message_1.txt (contains 'youtube')
# --------------------- Loop-494 ---------------------
# package_name:  fitness.com.senior
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.com.senior
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_4.txt (contains 'youtube')
# --------------------- Loop-495 ---------------------
# package_name:  pl.efitness.mobile
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.efitness.mobile
# --------------------- Loop-496 ---------------------
# package_name:  com.fitnessmobileapps.speedfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.speedfit
# --------------------- Loop-497 ---------------------
# package_name:  com.jawline.exercises.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jawline.exercises.fitness
# --------------------- Loop-498 ---------------------
# package_name:  digifit.android.virtuagym.pro.healthyvitabybv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.healthyvitabybv
# --------------------- Loop-499 ---------------------
# package_name:  com.vfit.vfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vfit.vfit
# --------------------- Loop-500 ---------------------
# package_name:  com.lianhezhuli.hyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lianhezhuli.hyfit
# Moving file: message_1.txt (contains 'youtube')
# Moving file: message_15.txt (contains 'youtube')
# --------------------- Loop-501 ---------------------
# package_name:  com.fitnessanny
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessanny
# Moving file: message_7.txt (contains 'youtube')
# --------------------- Loop-502 ---------------------
# package_name:  ie.zappy.fennec.barbellqueenfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ie.zappy.fennec.barbellqueenfitness
# Moving file: message_11.txt (contains 'youtube')
# Moving file: message_2.txt (contains 'youtube')
# Moving file: message_9.txt (contains 'youtube')
# --------------------- Loop-503 ---------------------
# package_name:  de.myfitcoach.tim.mfc
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\de.myfitcoach.tim.mfc
# --------------------- Loop-504 ---------------------
# package_name:  com.fitnesses.fitticoin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesses.fitticoin
# --------------------- Loop-505 ---------------------
# package_name:  femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# --------------------- Loop-506 ---------------------
# package_name:  women.workout.female.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# --------------------- Loop-507 ---------------------
# package_name:  com.brooklynfitzone.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# --------------------- Loop-508 ---------------------
# package_name:  com.johnsonfitness.fitdisplay2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.johnsonfitness.fitdisplay2
# --------------------- Loop-509 ---------------------
# package_name:  com.mc.amazfit1
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mc.amazfit1
# --------------------- Loop-510 ---------------------
# package_name:  nl.dominos.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nl.dominos.android
# --------------------- Loop-511 ---------------------
# package_name:  org.eson.getfit3
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.eson.getfit3
# --------------------- Loop-512 ---------------------
# package_name:  com.netpulse.mobile.eosfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.eosfitness
# --------------------- Loop-513 ---------------------
# package_name:  digifit.android.virtuagym.pro.strongfitnesswinfield
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.strongfitnesswinfield
# --------------------- Loop-514 ---------------------
# package_name:  com.innovatise.newvisionfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.newvisionfitness
# --------------------- Loop-515 ---------------------
# package_name:  kz.maestrosultan.fitjournal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kz.maestrosultan.fitjournal
# Moving file: message_15.txt (contains 'youtube')
# Moving file: message_16.txt (contains 'youtube')
# Moving file: message_20.txt (contains 'youtube')
# Moving file: message_21.txt (contains 'youtube')
# --------------------- Loop-516 ---------------------
# package_name:  com.bejaofit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bejaofit.app
# --------------------- Loop-517 ---------------------
# package_name:  fit.withu.flutter.withu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.withu.flutter.withu
# --------------------- Loop-518 ---------------------
# package_name:  com.shapehq.fitnessworld
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shapehq.fitnessworld
# --------------------- Loop-519 ---------------------
# package_name:  com.orangetheoryfitness.orangetheory
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory

# %%
for z in range(len(array_traffic_package_name)):
    print("--------------------- Loop-"+str(z)+" ---------------------")
    package_name = array_traffic_package_name[z]
    print("package_name: ",package_name)
    traffic_directory_path = root_traffic_directory_path + "\\" + package_name
    print("traffic_directory_path: ",traffic_directory_path)
    zero_file_size = remove_empty_files(traffic_directory_path)
    print("zero_file_size: ",zero_file_size)
# Out:
# --------------------- Loop-0 ---------------------
# package_name:  jp.joyfit.joyfitappandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.joyfit.joyfitappandroid
# zero_file_size:  0
# --------------------- Loop-1 ---------------------
# package_name:  com.apep.fitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.apep.fitapp
# zero_file_size:  0
# --------------------- Loop-2 ---------------------
# package_name:  com.fitwhey.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitwhey.app
# zero_file_size:  0
# --------------------- Loop-3 ---------------------
# package_name:  com.zq.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zq.fit
# zero_file_size:  0
# --------------------- Loop-4 ---------------------
# package_name:  maxcom.toolbox.altimeter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\maxcom.toolbox.altimeter
# zero_file_size:  0
# --------------------- Loop-5 ---------------------
# package_name:  uk.co.fitness4less.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\uk.co.fitness4less.app
# zero_file_size:  0
# --------------------- Loop-6 ---------------------
# package_name:  com.instafit.workouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.instafit.workouts
# zero_file_size:  0
# --------------------- Loop-7 ---------------------
# package_name:  digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.greaterjolietymcasuperclub
# zero_file_size:  0
# --------------------- Loop-8 ---------------------
# package_name:  com.edjing.edjingdjturntable
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.edjing.edjingdjturntable
# zero_file_size:  0
# --------------------- Loop-9 ---------------------
# package_name:  com.artkitch.alexfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.artkitch.alexfitness
# zero_file_size:  0
# --------------------- Loop-10 ---------------------
# package_name:  com.onefitstop.bodyfittraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.onefitstop.bodyfittraining
# zero_file_size:  0
# --------------------- Loop-11 ---------------------
# package_name:  coach.zing.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\coach.zing.fitness
# zero_file_size:  0
# --------------------- Loop-12 ---------------------
# package_name:  com.golf.fitforgolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.golf.fitforgolf
# zero_file_size:  0
# --------------------- Loop-13 ---------------------
# package_name:  com.trainerize.yetifit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.yetifit
# zero_file_size:  0
# --------------------- Loop-14 ---------------------
# package_name:  homeworkoutapp.homeworkout.fitness.workout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight
# zero_file_size:  1
# --------------------- Loop-15 ---------------------
# package_name:  com.skyhealth.fitnessbuddyandroidfree
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.skyhealth.fitnessbuddyandroidfree
# zero_file_size:  1
# --------------------- Loop-16 ---------------------
# package_name:  fitapp.fittofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitapp.fittofit
# zero_file_size:  0
# --------------------- Loop-17 ---------------------
# package_name:  com.fiton.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fiton.android
# zero_file_size:  0
# --------------------- Loop-18 ---------------------
# package_name:  com.polaroidfit.polaroidfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.polaroidfit.polaroidfit
# zero_file_size:  0
# --------------------- Loop-19 ---------------------
# package_name:  com.chloeting.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# zero_file_size:  0
# --------------------- Loop-20 ---------------------
# package_name:  com.madarsoft.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.madarsoft.fitness
# zero_file_size:  0
# --------------------- Loop-21 ---------------------
# package_name:  com.anytimefitness.userapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# zero_file_size:  0
# --------------------- Loop-22 ---------------------
# package_name:  com.netpulse.mobile.fitzonedelutte
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.fitzonedelutte
# zero_file_size:  0
# --------------------- Loop-23 ---------------------
# package_name:  com.honbow.letsfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.letsfit
# zero_file_size:  0
# --------------------- Loop-24 ---------------------
# package_name:  com.anytimefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.app
# zero_file_size:  0
# --------------------- Loop-25 ---------------------
# package_name:  com.keepfit.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.keepfit.loseweight
# zero_file_size:  0
# --------------------- Loop-26 ---------------------
# package_name:  com.samsung.android.shealthmonitor
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.shealthmonitor
# zero_file_size:  0
# --------------------- Loop-27 ---------------------
# package_name:  com.zewa.fit.pro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zewa.fit.pro
# zero_file_size:  1
# --------------------- Loop-28 ---------------------
# package_name:  com.mycloudfitness.mycloudfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mycloudfitness.mycloudfitness
# zero_file_size:  1
# --------------------- Loop-29 ---------------------
# package_name:  com.oplayer.goodmansfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.oplayer.goodmansfitpro
# zero_file_size:  0
# --------------------- Loop-30 ---------------------
# package_name:  digifit.android.virtuagym.pro.fisic
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fisic
# zero_file_size:  0
# --------------------- Loop-31 ---------------------
# package_name:  com.hootapps.soundrecorder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hootapps.soundrecorder
# zero_file_size:  0
# --------------------- Loop-32 ---------------------
# package_name:  eu.fitric.pregnancyworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.pregnancyworkout
# zero_file_size:  0
# --------------------- Loop-33 ---------------------
# package_name:  com.luni.android.fitnesscoach.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.luni.android.fitnesscoach.app
# zero_file_size:  0
# --------------------- Loop-34 ---------------------
# package_name:  com.szyk.myheart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.szyk.myheart
# zero_file_size:  0
# --------------------- Loop-35 ---------------------
# package_name:  com.viatek.fitnation.echelon_android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android
# zero_file_size:  1
# --------------------- Loop-36 ---------------------
# package_name:  com.zjw.xwfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zjw.xwfit
# zero_file_size:  0
# --------------------- Loop-37 ---------------------
# package_name:  com.bandlab.bandlab
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bandlab.bandlab
# zero_file_size:  0
# --------------------- Loop-38 ---------------------
# package_name:  com.wakeup.wearfit2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.wakeup.wearfit2
# zero_file_size:  0
# --------------------- Loop-39 ---------------------
# package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp
# zero_file_size:  1
# --------------------- Loop-40 ---------------------
# package_name:  com.biztech.magemobadmin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.biztech.magemobadmin
# zero_file_size:  0
# --------------------- Loop-41 ---------------------
# package_name:  com.fitifyapps.bwcardio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwcardio
# zero_file_size:  0
# --------------------- Loop-42 ---------------------
# package_name:  com.bpfit.bloodpressure.health
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# zero_file_size:  0
# --------------------- Loop-43 ---------------------
# package_name:  com.equinoxfitness.equinox
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.equinoxfitness.equinox
# zero_file_size:  0
# --------------------- Loop-44 ---------------------
# package_name:  com.mobifitness.bettadance342273
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.bettadance342273
# zero_file_size:  0
# --------------------- Loop-45 ---------------------
# package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus
# zero_file_size:  0
# --------------------- Loop-46 ---------------------
# package_name:  com.pocketlifestyle.music.tune
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.pocketlifestyle.music.tune
# zero_file_size:  0
# --------------------- Loop-47 ---------------------
# package_name:  com.fitapp.timerwodapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitapp.timerwodapp
# zero_file_size:  0
# --------------------- Loop-48 ---------------------
# package_name:  com.mattdoesfitness.morsia
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mattdoesfitness.morsia
# zero_file_size:  0
# --------------------- Loop-49 ---------------------
# package_name:  home.fitness.challenge
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\home.fitness.challenge
# zero_file_size:  0
# --------------------- Loop-50 ---------------------
# package_name:  app.EnForma.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.EnForma.fitcoapp.net
# zero_file_size:  0
# --------------------- Loop-51 ---------------------
# package_name:  com.crrepa.band.havefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.havefit
# zero_file_size:  0
# --------------------- Loop-52 ---------------------
# package_name:  com.glidetalk.glideapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.glidetalk.glideapp
# zero_file_size:  0
# --------------------- Loop-53 ---------------------
# package_name:  com.fuse.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fuse.fitness
# zero_file_size:  0
# --------------------- Loop-54 ---------------------
# package_name:  com.trainerize.youfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.youfit
# zero_file_size:  0
# --------------------- Loop-55 ---------------------
# package_name:  com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.body.fitness.gymworkout.hiit.bodybuilding.mobile.trainer
# zero_file_size:  0
# --------------------- Loop-56 ---------------------
# package_name:  com.qualitrain.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qualitrain.fitness
# zero_file_size:  1
# --------------------- Loop-57 ---------------------
# package_name:  com.spotify.music
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.spotify.music
# zero_file_size:  1
# --------------------- Loop-58 ---------------------
# package_name:  ott.beatboxingfitnessworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ott.beatboxingfitnessworkouts
# zero_file_size:  0
# --------------------- Loop-59 ---------------------
# package_name:  com.itrack.myfit755570
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.itrack.myfit755570
# zero_file_size:  0
# --------------------- Loop-60 ---------------------
# package_name:  com.movefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.movefitness.app
# zero_file_size:  0
# --------------------- Loop-61 ---------------------
# package_name:  com.sasyabook.businesscardapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.sasyabook.businesscardapp
# zero_file_size:  0
# --------------------- Loop-62 ---------------------
# package_name:  com.bottegasol.com.migym.fitnessconnection
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bottegasol.com.migym.fitnessconnection
# zero_file_size:  0
# --------------------- Loop-63 ---------------------
# package_name:  com.bendingspoons.thirtydayfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bendingspoons.thirtydayfitness
# zero_file_size:  0
# --------------------- Loop-64 ---------------------
# package_name:  com.bickster.fitbitbandfinder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# zero_file_size:  1
# --------------------- Loop-65 ---------------------
# package_name:  com.github.jamesgay.fitnotes
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.github.jamesgay.fitnotes
# zero_file_size:  0
# --------------------- Loop-66 ---------------------
# package_name:  fitness.home.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.home.workout.weight.loss
# zero_file_size:  0
# --------------------- Loop-67 ---------------------
# package_name:  rs.fastfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.fastfit.app
# zero_file_size:  0
# --------------------- Loop-68 ---------------------
# package_name:  net.peater.fitlovers
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers
# zero_file_size:  1
# --------------------- Loop-69 ---------------------
# package_name:  rebel.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rebel.fitness
# zero_file_size:  0
# --------------------- Loop-70 ---------------------
# package_name:  com.qingniu.fitindex
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.fitindex
# zero_file_size:  0
# --------------------- Loop-71 ---------------------
# package_name:  faceyoga.facefitness.dailyworkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\faceyoga.facefitness.dailyworkouts
# zero_file_size:  1
# --------------------- Loop-72 ---------------------
# package_name:  com.goodlifefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.goodlifefitness
# zero_file_size:  0
# --------------------- Loop-73 ---------------------
# package_name:  com.czw.freefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.czw.freefit
# zero_file_size:  1
# --------------------- Loop-74 ---------------------
# package_name:  com.fitzeee.fitzeeerun
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.fitzeeerun
# zero_file_size:  0
# --------------------- Loop-75 ---------------------
# package_name:  com.eightfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eightfit.app
# zero_file_size:  0
# --------------------- Loop-76 ---------------------
# package_name:  com.runmifit.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.runmifit.android
# zero_file_size:  1
# --------------------- Loop-77 ---------------------
# package_name:  com.google.android.apps.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.google.android.apps.fitness
# zero_file_size:  0
# --------------------- Loop-78 ---------------------
# package_name:  com.joshua.hasfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.joshua.hasfit
# zero_file_size:  0
# --------------------- Loop-79 ---------------------
# package_name:  com.lafitness.lafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lafitness.lafitness
# zero_file_size:  2
# --------------------- Loop-80 ---------------------
# package_name:  com.yc.gloryfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gloryfitpro
# zero_file_size:  1
# --------------------- Loop-81 ---------------------
# package_name:  com.hwd.flowfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.hwd.flowfit
# zero_file_size:  0
# --------------------- Loop-82 ---------------------
# package_name:  com.walkfit.weightloss.steptracker.pedometer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkfit.weightloss.steptracker.pedometer
# zero_file_size:  0
# --------------------- Loop-83 ---------------------
# package_name:  com.riversongfit.epoch
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.riversongfit.epoch
# zero_file_size:  0
# --------------------- Loop-84 ---------------------
# package_name:  club.skllzz.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\club.skllzz.fitness
# zero_file_size:  0
# --------------------- Loop-85 ---------------------
# package_name:  com.xj.inxfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.xj.inxfit
# zero_file_size:  0
# --------------------- Loop-86 ---------------------
# package_name:  com.mobifitness.nsfit104363
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mobifitness.nsfit104363
# zero_file_size:  0
# --------------------- Loop-87 ---------------------
# package_name:  dance.workout.home.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\dance.workout.home.fitness
# zero_file_size:  0
# --------------------- Loop-88 ---------------------
# package_name:  com.womenfitness.workoutbuddy.mea
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.womenfitness.workoutbuddy.mea
# zero_file_size:  0
# --------------------- Loop-89 ---------------------
# package_name:  com.std.fitness.point
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.std.fitness.point
# zero_file_size:  1
# --------------------- Loop-90 ---------------------
# package_name:  starshipproduct.perifitmainapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\starshipproduct.perifitmainapp
# zero_file_size:  1
# --------------------- Loop-91 ---------------------
# package_name:  rs.nonstopfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.nonstopfitness
# zero_file_size:  0
# --------------------- Loop-92 ---------------------
# package_name:  com.cavosmart.wofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cavosmart.wofit
# zero_file_size:  0
# --------------------- Loop-93 ---------------------
# package_name:  nz.co.telecom.smartphone.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android
# zero_file_size:  0
# --------------------- Loop-94 ---------------------
# package_name:  org.moffitt.brandedpatientportal.play
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.moffitt.brandedpatientportal.play
# zero_file_size:  0
# --------------------- Loop-95 ---------------------
# package_name:  workoutforwomen.femalefitness.womenworkout.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\workoutforwomen.femalefitness.womenworkout.loseweight
# zero_file_size:  1
# --------------------- Loop-96 ---------------------
# package_name:  digifit.virtuagym.client.android.coaching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android.coaching
# zero_file_size:  0
# --------------------- Loop-97 ---------------------
# package_name:  com.SnowReport.screens
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.SnowReport.screens
# zero_file_size:  1
# --------------------- Loop-98 ---------------------
# package_name:  com.jquiz.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jquiz.english
# zero_file_size:  0
# --------------------- Loop-99 ---------------------
# package_name:  digifit.android.virtuagym.pro.buzzgymsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.buzzgymsuperclub
# zero_file_size:  0
# --------------------- Loop-100 ---------------------
# package_name:  com.noisefit.focus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit.focus
# zero_file_size:  0
# --------------------- Loop-101 ---------------------
# package_name:  com.independence284.badassbodyfitnessx
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.independence284.badassbodyfitnessx
# zero_file_size:  0
# --------------------- Loop-102 ---------------------
# package_name:  com.eztech.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eztech.fitness
# zero_file_size:  0
# --------------------- Loop-103 ---------------------
# package_name:  com.myfitnesspal.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesspal.android
# zero_file_size:  0
# --------------------- Loop-104 ---------------------
# package_name:  com.fitbod.fitbod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitbod.fitbod
# zero_file_size:  0
# --------------------- Loop-105 ---------------------
# package_name:  digifit.android.virtuagym.pro.ymcapeninsulademo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.ymcapeninsulademo
# zero_file_size:  0
# --------------------- Loop-106 ---------------------
# package_name:  com.simplyfit.rowing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.simplyfit.rowing
# zero_file_size:  0
# --------------------- Loop-107 ---------------------
# package_name:  com.marianatek.cbfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marianatek.cbfit
# zero_file_size:  1
# --------------------- Loop-108 ---------------------
# package_name:  drzio.senior.yoga.fitness.elders.old.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout
# zero_file_size:  0
# --------------------- Loop-109 ---------------------
# package_name:  net.kosev.dicing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.kosev.dicing
# zero_file_size:  1
# --------------------- Loop-110 ---------------------
# package_name:  com.Female.Fitness.cardio.wellness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.Female.Fitness.cardio.wellness
# zero_file_size:  0
# --------------------- Loop-111 ---------------------
# package_name:  app.fit.meet
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# zero_file_size:  0
# --------------------- Loop-112 ---------------------
# package_name:  com.fitnesspassport.androidapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesspassport.androidapp
# zero_file_size:  0
# --------------------- Loop-113 ---------------------
# package_name:  rs.abstract.fitpass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\rs.abstract.fitpass
# zero_file_size:  0
# --------------------- Loop-114 ---------------------
# package_name:  digifit.android.virtuagym.pro.bodyassault
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.bodyassault
# zero_file_size:  0
# --------------------- Loop-115 ---------------------
# package_name:  com.tomtop.smart
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.tomtop.smart
# zero_file_size:  0
# --------------------- Loop-116 ---------------------
# package_name:  com.kannergroup.fitnessculture
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kannergroup.fitnessculture
# zero_file_size:  0
# --------------------- Loop-117 ---------------------
# package_name:  com.fitatu.tracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitatu.tracker
# zero_file_size:  0
# --------------------- Loop-118 ---------------------
# package_name:  com.ifit.wolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ifit.wolf
# zero_file_size:  0
# --------------------- Loop-119 ---------------------
# package_name:  com.fitness22.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.workout
# zero_file_size:  0
# --------------------- Loop-120 ---------------------
# package_name:  com.cizotech.fit2flaunt
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cizotech.fit2flaunt
# zero_file_size:  1
# --------------------- Loop-121 ---------------------
# package_name:  com.fitness22.running
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.running
# zero_file_size:  0
# --------------------- Loop-122 ---------------------
# package_name:  com.samsung.android.app.watchmanager
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.app.watchmanager
# zero_file_size:  0
# --------------------- Loop-123 ---------------------
# package_name:  com.honbow.fitdock
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock
# zero_file_size:  1
# --------------------- Loop-124 ---------------------
# package_name:  com.fitlab.spartan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlab.spartan
# zero_file_size:  0
# --------------------- Loop-125 ---------------------
# package_name:  com.marsathletic.android.macfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.marsathletic.android.macfit.app
# zero_file_size:  0
# --------------------- Loop-126 ---------------------
# package_name:  ru.starline
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ru.starline
# zero_file_size:  0
# --------------------- Loop-127 ---------------------
# package_name:  digifit.android.virtuagym.pro.puurpersonaltraining
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.puurpersonaltraining
# zero_file_size:  0
# --------------------- Loop-128 ---------------------
# package_name:  eu.fitric.hourglass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\eu.fitric.hourglass
# zero_file_size:  0
# --------------------- Loop-129 ---------------------
# package_name:  homeworkout.fitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\homeworkout.fitness.app
# zero_file_size:  0
# --------------------- Loop-130 ---------------------
# package_name:  com.fixfit_fitness.twa
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa
# zero_file_size:  0
# --------------------- Loop-131 ---------------------
# package_name:  com.reset.reset_fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.reset.reset_fitness
# zero_file_size:  0
# --------------------- Loop-132 ---------------------
# package_name:  com.yc.gtfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gtfit
# zero_file_size:  1
# --------------------- Loop-133 ---------------------
# package_name:  com.trainerize.outlawfitcamp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.outlawfitcamp
# zero_file_size:  0
# --------------------- Loop-134 ---------------------
# package_name:  fit.cult.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.cult.android
# zero_file_size:  0
# --------------------- Loop-135 ---------------------
# package_name:  com.fitzeee.pedometerwalking
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.pedometerwalking
# zero_file_size:  0
# --------------------- Loop-136 ---------------------
# package_name:  biz.mobidev.mdplayer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\biz.mobidev.mdplayer
# zero_file_size:  1
# --------------------- Loop-137 ---------------------
# package_name:  com.netpulse.mobile.clubfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.clubfit
# zero_file_size:  0
# --------------------- Loop-138 ---------------------
# package_name:  com.kompanion.fitness.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kompanion.fitness.android
# zero_file_size:  0
# --------------------- Loop-139 ---------------------
# package_name:  foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\foodtracker.loseweight.caloriecounter.diet.myfitnesspal
# zero_file_size:  0
# --------------------- Loop-140 ---------------------
# package_name:  pl.tweeba.mobile.learning.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.tweeba.mobile.learning.english
# zero_file_size:  0
# --------------------- Loop-141 ---------------------
# package_name:  com.mictale.gpsessentials
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mictale.gpsessentials
# zero_file_size:  0
# --------------------- Loop-142 ---------------------
# package_name:  com.trainerize.witfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.witfit
# zero_file_size:  0
# --------------------- Loop-143 ---------------------
# package_name:  com.bhphoto
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bhphoto
# zero_file_size:  0
# --------------------- Loop-144 ---------------------
# package_name:  com.toshremote.view
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.toshremote.view
# zero_file_size:  0
# --------------------- Loop-145 ---------------------
# package_name:  com.basicfit.trainingApp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basicfit.trainingApp
# zero_file_size:  0
# --------------------- Loop-146 ---------------------
# package_name:  com.adi.remote.phone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.adi.remote.phone
# zero_file_size:  1
# --------------------- Loop-147 ---------------------
# package_name:  com.caliberfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.caliberfitness.app
# zero_file_size:  0
# --------------------- Loop-148 ---------------------
# package_name:  com.lifetrons.lifetrons.app.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lifetrons.lifetrons.app.fitness
# zero_file_size:  1
# --------------------- Loop-149 ---------------------
# package_name:  tarlin.fitness.loseweight.belly.fem
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\tarlin.fitness.loseweight.belly.fem
# zero_file_size:  1
# --------------------- Loop-150 ---------------------
# package_name:  com.fitifyapps.bwstretching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching
# zero_file_size:  0
# --------------------- Loop-151 ---------------------
# package_name:  nz.co.madfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.madfit
# zero_file_size:  1
# --------------------- Loop-152 ---------------------
# package_name:  com.appyfurious.getfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.appyfurious.getfit
# zero_file_size:  0
# --------------------- Loop-153 ---------------------
# package_name:  com.walking.fun.rewards.fitness.fitzu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walking.fun.rewards.fitness.fitzu
# zero_file_size:  0
# --------------------- Loop-154 ---------------------
# package_name:  digifit.android.virtuagym.pro.leisureunitedsuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.leisureunitedsuperclub
# zero_file_size:  0
# --------------------- Loop-155 ---------------------
# package_name:  app.growwithjo.diet.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# zero_file_size:  0
# --------------------- Loop-156 ---------------------
# package_name:  digifit.android.virtuagym.pro.neobod
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.neobod
# zero_file_size:  0
# --------------------- Loop-157 ---------------------
# package_name:  com.aircanada
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.aircanada
# zero_file_size:  0
# --------------------- Loop-158 ---------------------
# package_name:  digifit.virtuagym.client.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.virtuagym.client.android
# zero_file_size:  0
# --------------------- Loop-159 ---------------------
# package_name:  com.smartwidgetlabs.fitbitandroid
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.smartwidgetlabs.fitbitandroid
# zero_file_size:  0
# --------------------- Loop-160 ---------------------
# package_name:  com.trainerize.grindafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.grindafitness
# zero_file_size:  0
# --------------------- Loop-161 ---------------------
# package_name:  it.tripix.buddyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit
# zero_file_size:  0
# --------------------- Loop-162 ---------------------
# package_name:  com.evolutionwellness.app.celebrityfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.celebrityfitness
# zero_file_size:  0
# --------------------- Loop-163 ---------------------
# package_name:  com.nstudio.weatherhere.free
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.nstudio.weatherhere.free
# zero_file_size:  0
# --------------------- Loop-164 ---------------------
# package_name:  com.netpulse.mobile.stevenashfitnessworldsportsclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.stevenashfitnessworldsportsclub
# zero_file_size:  0
# --------------------- Loop-165 ---------------------
# package_name:  interactiveshift.com.trailswear
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\interactiveshift.com.trailswear
# zero_file_size:  0
# --------------------- Loop-166 ---------------------
# package_name:  yogaworkouts.dailyyoga.yogafitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\yogaworkouts.dailyyoga.yogafitness
# zero_file_size:  0
# --------------------- Loop-167 ---------------------
# package_name:  com.topstep.fitcloudpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.topstep.fitcloudpro
# zero_file_size:  0
# --------------------- Loop-168 ---------------------
# package_name:  com.fitelo.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitelo.android
# zero_file_size:  0
# --------------------- Loop-169 ---------------------
# package_name:  com.monkeyfitpass.monkyappv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.monkeyfitpass.monkyappv
# zero_file_size:  0
# --------------------- Loop-170 ---------------------
# package_name:  com.watch.yfitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.watch.yfitpro
# zero_file_size:  0
# --------------------- Loop-171 ---------------------
# package_name:  se.matlistan.free
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\se.matlistan.free
# zero_file_size:  0
# --------------------- Loop-172 ---------------------
# package_name:  com.best.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.best.fit
# zero_file_size:  0
# --------------------- Loop-173 ---------------------
# package_name:  com.jyfitness.iron_mastery
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jyfitness.iron_mastery
# zero_file_size:  0
# --------------------- Loop-174 ---------------------
# package_name:  br.com.fitastic.appaluno
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.fitastic.appaluno
# zero_file_size:  0
# --------------------- Loop-175 ---------------------
# package_name:  com.airofit_app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.airofit_app
# zero_file_size:  0
# --------------------- Loop-176 ---------------------
# package_name:  com.perfectgym.perfectgymgo2.fitness247latinamerica
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.fitness247latinamerica
# zero_file_size:  1
# --------------------- Loop-177 ---------------------
# package_name:  kr.fitt.fmes
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kr.fitt.fmes
# zero_file_size:  2
# --------------------- Loop-178 ---------------------
# package_name:  fat.burnning.plank.fitness.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight
# zero_file_size:  1
# --------------------- Loop-179 ---------------------
# package_name:  fitness.ddx.ddx_fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.ddx.ddx_fitness
# zero_file_size:  0
# --------------------- Loop-180 ---------------------
# package_name:  br.com.w12.bluefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.bluefit
# zero_file_size:  0
# --------------------- Loop-181 ---------------------
# package_name:  com.basemsalloum.goodfitness.goodfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness
# zero_file_size:  0
# --------------------- Loop-182 ---------------------
# package_name:  com.huawo.ufit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.huawo.ufit
# zero_file_size:  0
# --------------------- Loop-183 ---------------------
# package_name:  kr.co.everyfit.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kr.co.everyfit.fitness
# zero_file_size:  0
# --------------------- Loop-184 ---------------------
# package_name:  com.ktmusic.geniemusic
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ktmusic.geniemusic
# zero_file_size:  0
# --------------------- Loop-185 ---------------------
# package_name:  tr.com.fitwell.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\tr.com.fitwell.app
# zero_file_size:  0
# --------------------- Loop-186 ---------------------
# package_name:  jp.co.yahoo.android.vassist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist
# zero_file_size:  0
# --------------------- Loop-187 ---------------------
# package_name:  com.fittech.fasting.tracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fittech.fasting.tracker
# zero_file_size:  0
# --------------------- Loop-188 ---------------------
# package_name:  com.fitnow.loseit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnow.loseit
# zero_file_size:  0
# --------------------- Loop-189 ---------------------
# package_name:  com.fitnessmobileapps.elevate35253
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.elevate35253
# zero_file_size:  0
# --------------------- Loop-190 ---------------------
# package_name:  com.rageconsulting.android.lightflowlegacy
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy
# zero_file_size:  0
# --------------------- Loop-191 ---------------------
# package_name:  com.concapps.benfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.concapps.benfit
# zero_file_size:  0
# --------------------- Loop-192 ---------------------
# package_name:  br.com.w12.heyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit
# zero_file_size:  0
# --------------------- Loop-193 ---------------------
# package_name:  appnativo.navysportcenter.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\appnativo.navysportcenter.fitcoapp.net
# zero_file_size:  0
# --------------------- Loop-194 ---------------------
# package_name:  com.innovatise.fitnesstimeleejam
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam
# zero_file_size:  0
# --------------------- Loop-195 ---------------------
# package_name:  digifit.android.virtuagym.pro.everlast
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.everlast
# zero_file_size:  0
# --------------------- Loop-196 ---------------------
# package_name:  fitnesscoach.workoutplanner.weightloss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitnesscoach.workoutplanner.weightloss
# zero_file_size:  0
# --------------------- Loop-197 ---------------------
# package_name:  com.qingniu.feelfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.feelfit
# zero_file_size:  3
# --------------------- Loop-198 ---------------------
# package_name:  digifit.android.virtuagym.pro.yababethfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.yababethfit
# zero_file_size:  0
# --------------------- Loop-199 ---------------------
# package_name:  com.fitnessmobileapps.orangetheoryfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.orangetheoryfitness
# zero_file_size:  0
# --------------------- Loop-200 ---------------------
# package_name:  softin.my.fast.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\softin.my.fast.fitness
# zero_file_size:  0
# --------------------- Loop-201 ---------------------
# package_name:  com.proyecto.fit.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.fit.tgcustom
# zero_file_size:  0
# --------------------- Loop-202 ---------------------
# package_name:  com.rootberz.thirtydayfitchallenges
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.rootberz.thirtydayfitchallenges
# zero_file_size:  0
# --------------------- Loop-203 ---------------------
# package_name:  com.kiss.keeper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kiss.keeper
# zero_file_size:  1
# --------------------- Loop-204 ---------------------
# package_name:  com.proyecto.beonefitnesssport.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom
# zero_file_size:  0
# --------------------- Loop-205 ---------------------
# package_name:  com.vgfit.shefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit
# zero_file_size:  0
# --------------------- Loop-206 ---------------------
# package_name:  com.yesfitclient
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yesfitclient
# zero_file_size:  0
# --------------------- Loop-207 ---------------------
# package_name:  com.dolcegustofree.activity
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity
# zero_file_size:  1
# --------------------- Loop-208 ---------------------
# package_name:  com.kilogroup.fitter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter
# zero_file_size:  0
# --------------------- Loop-209 ---------------------
# package_name:  com.fitzeee.menworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitzeee.menworkout
# zero_file_size:  0
# --------------------- Loop-210 ---------------------
# package_name:  com.fitness.mybodymass.bmicalculator
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.mybodymass.bmicalculator
# zero_file_size:  0
# --------------------- Loop-211 ---------------------
# package_name:  com.forfit.mymediterranean
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.forfit.mymediterranean
# zero_file_size:  0
# --------------------- Loop-212 ---------------------
# package_name:  com.future.FitYou
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.future.FitYou
# zero_file_size:  0
# --------------------- Loop-213 ---------------------
# package_name:  com.megasys.profit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.megasys.profit
# zero_file_size:  0
# --------------------- Loop-214 ---------------------
# package_name:  com.mysports.branded.mcfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mysports.branded.mcfit
# zero_file_size:  0
# --------------------- Loop-215 ---------------------
# package_name:  com.arisdot.gymfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.arisdot.gymfit
# zero_file_size:  0
# --------------------- Loop-216 ---------------------
# package_name:  com.trainerize.fitlov
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.fitlov
# zero_file_size:  0
# --------------------- Loop-217 ---------------------
# package_name:  com.netpulse.mobile.fitnessproject
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.fitnessproject
# zero_file_size:  0
# --------------------- Loop-218 ---------------------
# package_name:  com.shikudo.fitrpg.google
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google
# zero_file_size:  0
# --------------------- Loop-219 ---------------------
# package_name:  app.LomasGym.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net
# zero_file_size:  0
# --------------------- Loop-220 ---------------------
# package_name:  com.plaifit.plaifit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.plaifit.plaifit
# zero_file_size:  0
# --------------------- Loop-221 ---------------------
# package_name:  com.user.livefitt
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.user.livefitt
# zero_file_size:  1
# --------------------- Loop-222 ---------------------
# package_name:  com.techbull.fitolympia
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.techbull.fitolympia
# zero_file_size:  0
# --------------------- Loop-223 ---------------------
# package_name:  com.studiorouleau.funfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.studiorouleau.funfit
# zero_file_size:  0
# --------------------- Loop-224 ---------------------
# package_name:  com.clearskyapps.fitnessfamily.RunC210K
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.clearskyapps.fitnessfamily.RunC210K
# zero_file_size:  0
# --------------------- Loop-225 ---------------------
# package_name:  com.pushpress.punchkingfitnesssunset
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.pushpress.punchkingfitnesssunset
# zero_file_size:  0
# --------------------- Loop-226 ---------------------
# package_name:  com.huawo.hawofit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.huawo.hawofit
# zero_file_size:  0
# --------------------- Loop-227 ---------------------
# package_name:  de.upmcmobile.fitnessraum
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\de.upmcmobile.fitnessraum
# zero_file_size:  0
# --------------------- Loop-228 ---------------------
# package_name:  blacknote.amazfitmaster
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\blacknote.amazfitmaster
# zero_file_size:  0
# --------------------- Loop-229 ---------------------
# package_name:  com.perfectgym.perfectgymgo2.wellfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness
# zero_file_size:  1
# --------------------- Loop-230 ---------------------
# package_name:  com.cofox.kahunas.ProyectoPapaFit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cofox.kahunas.ProyectoPapaFit
# zero_file_size:  0
# --------------------- Loop-231 ---------------------
# package_name:  com.crrepa.band.altfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.altfit
# zero_file_size:  0
# --------------------- Loop-232 ---------------------
# ...
# --------------------- Loop-442 ---------------------
# package_name:  com.fitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitapp
# zero_file_size:  0
# --------------------- Loop-443 ---------------------
# package_name:  com.steppi.steppifitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.steppi.steppifitness
# zero_file_size:  0
# --------------------- Loop-444 ---------------------
# package_name:  com.Glossbird.Fitment
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.Glossbird.Fitment
# zero_file_size:  0
# --------------------- Loop-445 ---------------------
# package_name:  com.organicapps.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.organicapps.fit
# zero_file_size:  0
# --------------------- Loop-446 ---------------------
# package_name:  com.fitness.stepcounter.pedometer
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.stepcounter.pedometer
# zero_file_size:  1
# --------------------- Loop-447 ---------------------
# package_name:  com.samsung.android.wear.shealth
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.samsung.android.wear.shealth
# zero_file_size:  0
# --------------------- Loop-448 ---------------------
# package_name:  com.vt.vitafit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vt.vitafit
# zero_file_size:  0
# --------------------- Loop-449 ---------------------
# package_name:  com.vulsen.popfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vulsen.popfit
# zero_file_size:  1
# --------------------- Loop-450 ---------------------
# package_name:  je.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\je.fit
# zero_file_size:  2
# --------------------- Loop-451 ---------------------
# package_name:  com.fitze
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitze
# zero_file_size:  0
# --------------------- Loop-452 ---------------------
# package_name:  com.netpulse.mobile.chuzefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.chuzefitness
# zero_file_size:  0
# --------------------- Loop-453 ---------------------
# package_name:  com.trainerize.fitness19bergenfield
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.trainerize.fitness19bergenfield
# zero_file_size:  0
# --------------------- Loop-454 ---------------------
# package_name:  es.dreamfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\es.dreamfit.app
# zero_file_size:  1
# --------------------- Loop-455 ---------------------
# package_name:  com.myfitnesscoach
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach
# zero_file_size:  0
# --------------------- Loop-456 ---------------------
# package_name:  fit.trainiac.android.client
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.trainiac.android.client
# zero_file_size:  0
# --------------------- Loop-457 ---------------------
# package_name:  fit.remotecoach.fitin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.remotecoach.fitin
# zero_file_size:  0
# --------------------- Loop-458 ---------------------
# package_name:  com.lifetimefitness.interests.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lifetimefitness.interests.fitness
# zero_file_size:  0
# --------------------- Loop-459 ---------------------
# package_name:  com.actofitSmartScale
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale
# zero_file_size:  0
# --------------------- Loop-460 ---------------------
# package_name:  com.cs.booty.fit.buttocks.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cs.booty.fit.buttocks.workout
# zero_file_size:  1
# --------------------- Loop-461 ---------------------
# package_name:  com.fitifyapps.kettlebell
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.kettlebell
# zero_file_size:  1
# --------------------- Loop-462 ---------------------
# package_name:  com.netpulse.mobile.bodyplexfamilyfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.bodyplexfamilyfitness
# zero_file_size:  0
# --------------------- Loop-463 ---------------------
# package_name:  com.btfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.btfit
# zero_file_size:  0
# --------------------- Loop-464 ---------------------
# package_name:  com.mz.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mz.fit
# zero_file_size:  1
# --------------------- Loop-465 ---------------------
# package_name:  com.fitlapapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlapapp
# zero_file_size:  0
# --------------------- Loop-466 ---------------------
# package_name:  com.benda.fitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.benda.fitpro
# zero_file_size:  0
# --------------------- Loop-467 ---------------------
# package_name:  digifit.android.virtuagym.pro.sparksport22
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.sparksport22
# zero_file_size:  0
# --------------------- Loop-468 ---------------------
# package_name:  com.ubivelox.uvophone
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ubivelox.uvophone
# zero_file_size:  0
# --------------------- Loop-469 ---------------------
# package_name:  com.mapmyfitness.android2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mapmyfitness.android2
# zero_file_size:  0
# --------------------- Loop-470 ---------------------
# package_name:  com.fitradio
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitradio
# zero_file_size:  0
# --------------------- Loop-471 ---------------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# zero_file_size:  0
# --------------------- Loop-472 ---------------------
# package_name:  com.blinkfitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.blinkfitness.app
# zero_file_size:  0
# --------------------- Loop-473 ---------------------
# package_name:  com.netpulse.mobile.morefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness
# zero_file_size:  2
# --------------------- Loop-474 ---------------------
# package_name:  com.walkonfit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.walkonfit.app
# zero_file_size:  0
# --------------------- Loop-475 ---------------------
# package_name:  com.fitplanapp.fitplan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan
# zero_file_size:  0
# --------------------- Loop-476 ---------------------
# package_name:  com.mauriciotogneri.shoppinglist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mauriciotogneri.shoppinglist
# zero_file_size:  0
# --------------------- Loop-477 ---------------------
# package_name:  com.taskoob.fitHer.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.taskoob.fitHer.android
# zero_file_size:  0
# --------------------- Loop-478 ---------------------
# package_name:  com.WahooFitness.SYSTM
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.WahooFitness.SYSTM
# zero_file_size:  1
# --------------------- Loop-479 ---------------------
# package_name:  com.fitnessmobileapps.f45training
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.f45training
# zero_file_size:  1
# --------------------- Loop-480 ---------------------
# package_name:  com.worldgymfitness.homeworkoutnoequipments
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.worldgymfitness.homeworkoutnoequipments
# zero_file_size:  0
# --------------------- Loop-481 ---------------------
# package_name:  com.unated
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.unated
# zero_file_size:  1
# --------------------- Loop-482 ---------------------
# package_name:  com.noisefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.noisefit
# zero_file_size:  1
# --------------------- Loop-483 ---------------------
# package_name:  com.canyon.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.canyon.fit
# zero_file_size:  1
# --------------------- Loop-484 ---------------------
# package_name:  com.directed.android.viper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.directed.android.viper
# zero_file_size:  1
# --------------------- Loop-485 ---------------------
# package_name:  br.com.w12.skyfitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.skyfitapp
# zero_file_size:  0
# --------------------- Loop-486 ---------------------
# package_name:  com.netpulse.mobile.uniquefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.uniquefit
# zero_file_size:  0
# --------------------- Loop-487 ---------------------
# package_name:  today.upfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\today.upfit
# zero_file_size:  0
# --------------------- Loop-488 ---------------------
# package_name:  digifit.android.virtuagym.pro.clubnorthwest
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.clubnorthwest
# zero_file_size:  0
# --------------------- Loop-489 ---------------------
# package_name:  digifit.android.virtuagym.pro.celtix
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix
# zero_file_size:  0
# --------------------- Loop-490 ---------------------
# package_name:  com.netpulse.mobile.healthfitnesscenter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.healthfitnesscenter
# zero_file_size:  1
# --------------------- Loop-491 ---------------------
# package_name:  org.obduro.kentekeninfo
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.obduro.kentekeninfo
# zero_file_size:  0
# --------------------- Loop-492 ---------------------
# package_name:  verv.health.fitness.workout.weight.loss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\verv.health.fitness.workout.weight.loss
# zero_file_size:  0
# --------------------- Loop-493 ---------------------
# package_name:  com.ramonmorcillo.fitbot01
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ramonmorcillo.fitbot01
# zero_file_size:  0
# --------------------- Loop-494 ---------------------
# package_name:  fitness.com.senior
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.com.senior
# zero_file_size:  0
# --------------------- Loop-495 ---------------------
# package_name:  pl.efitness.mobile
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pl.efitness.mobile
# zero_file_size:  0
# --------------------- Loop-496 ---------------------
# package_name:  com.fitnessmobileapps.speedfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessmobileapps.speedfit
# zero_file_size:  0
# --------------------- Loop-497 ---------------------
# package_name:  com.jawline.exercises.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jawline.exercises.fitness
# zero_file_size:  0
# --------------------- Loop-498 ---------------------
# package_name:  digifit.android.virtuagym.pro.healthyvitabybv
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.healthyvitabybv
# zero_file_size:  0
# --------------------- Loop-499 ---------------------
# package_name:  com.vfit.vfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vfit.vfit
# zero_file_size:  0
# --------------------- Loop-500 ---------------------
# package_name:  com.lianhezhuli.hyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lianhezhuli.hyfit
# zero_file_size:  1
# --------------------- Loop-501 ---------------------
# package_name:  com.fitnessanny
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnessanny
# zero_file_size:  1
# --------------------- Loop-502 ---------------------
# package_name:  ie.zappy.fennec.barbellqueenfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ie.zappy.fennec.barbellqueenfitness
# zero_file_size:  1
# --------------------- Loop-503 ---------------------
# package_name:  de.myfitcoach.tim.mfc
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\de.myfitcoach.tim.mfc
# zero_file_size:  0
# --------------------- Loop-504 ---------------------
# package_name:  com.fitnesses.fitticoin
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitnesses.fitticoin
# zero_file_size:  0
# --------------------- Loop-505 ---------------------
# package_name:  femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# zero_file_size:  0
# --------------------- Loop-506 ---------------------
# package_name:  women.workout.female.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# zero_file_size:  1
# --------------------- Loop-507 ---------------------
# package_name:  com.brooklynfitzone.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# zero_file_size:  0
# --------------------- Loop-508 ---------------------
# package_name:  com.johnsonfitness.fitdisplay2
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.johnsonfitness.fitdisplay2
# zero_file_size:  1
# --------------------- Loop-509 ---------------------
# package_name:  com.mc.amazfit1
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mc.amazfit1
# zero_file_size:  0
# --------------------- Loop-510 ---------------------
# package_name:  nl.dominos.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nl.dominos.android
# zero_file_size:  0
# --------------------- Loop-511 ---------------------
# package_name:  org.eson.getfit3
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\org.eson.getfit3
# zero_file_size:  0
# --------------------- Loop-512 ---------------------
# package_name:  com.netpulse.mobile.eosfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.eosfitness
# zero_file_size:  0
# --------------------- Loop-513 ---------------------
# package_name:  digifit.android.virtuagym.pro.strongfitnesswinfield
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.strongfitnesswinfield
# zero_file_size:  0
# --------------------- Loop-514 ---------------------
# package_name:  com.innovatise.newvisionfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.newvisionfitness
# zero_file_size:  0
# --------------------- Loop-515 ---------------------
# package_name:  kz.maestrosultan.fitjournal
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\kz.maestrosultan.fitjournal
# zero_file_size:  0
# --------------------- Loop-516 ---------------------
# package_name:  com.bejaofit.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bejaofit.app
# zero_file_size:  0
# --------------------- Loop-517 ---------------------
# package_name:  fit.withu.flutter.withu
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fit.withu.flutter.withu
# zero_file_size:  0
# --------------------- Loop-518 ---------------------
# package_name:  com.shapehq.fitnessworld
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shapehq.fitnessworld
# zero_file_size:  0
# --------------------- Loop-519 ---------------------
# package_name:  com.orangetheoryfitness.orangetheory
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory
# zero_file_size:  1
