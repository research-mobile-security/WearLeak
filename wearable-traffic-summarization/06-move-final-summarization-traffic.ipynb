# %%
import os
import shutil
from pymongo import MongoClient

# %%
def get_directories(path: str):
    """
    Get all directory names under the specified path.
    
    :param path: The root directory path to search.
    :return: A list of directory names.
    """
    try:
        return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    except FileNotFoundError:
        print(f"Error: The path '{path}' does not exist.")
        return []
    except PermissionError:
        print(f"Error: Permission denied for path '{path}'.")
        return []
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def get_ids_with_condition(collection,condition):
    """
    Retrieve an array of `_id` values where "sent-out" is "no data".

    :param collection: MongoDB collection object.
    :return: List of `_id` values matching the condition.
    """
#     condition = {"sent-out": "no data"}
    result = collection.find(condition, {"_id": 1})  # Retrieve only the `_id` field
    return [doc["_id"] for doc in result]
def move_txt_files_to_final_traffic(directory_path):
    """
    Moves all .txt files from the given directory to a new directory named 'final-traffic'.
    
    :param directory_path: Path to the directory containing .txt files.
    """
    # Define the target directory
    final_traffic_dir = os.path.join(directory_path, "final-traffic")

    # Create 'final-traffic' directory if it does not exist
    if not os.path.exists(final_traffic_dir):
        os.makedirs(final_traffic_dir)

    # Iterate over all files in the directory
    for file_name in os.listdir(directory_path):
        file_path = os.path.join(directory_path, file_name)

        # Check if it's a .txt file
        if os.path.isfile(file_path) and file_name.endswith(".txt"):
            # Move file to 'final-traffic' directory
            shutil.move(file_path, os.path.join(final_traffic_dir, file_name))
            print(f"Moved: {file_name} -> {final_traffic_dir}")

# %%
# root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-standalone"
root_traffic_directory_path = r"E:\wearable-capture-traffic\wearable-app"

# %%
mongoDB_uri = 'mongodb://192.168.1.14:27017'
mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-standalone'
mongoDB_collection = 'wearable-app'

# %%
array_traffic_directory = get_directories(root_traffic_directory_path)
print(len(array_traffic_directory))
# Out:
# 630

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
condition = {"sent-out": "no data"}
no_traffic_package_name = get_ids_with_condition(collection,condition)
# print(no_traffic_package_name)
print(len(no_traffic_package_name))
# Out:
# 122

# %%
array_traffic_package_name = list(set(array_traffic_directory) - set(no_traffic_package_name))
print(array_traffic_package_name)
print(len(array_traffic_package_name))
# Out:
# ['com.anytimefitness.userapp', 'app.LomasGym.fitcoapp.net', 'com.itrack.xfit', 'com.actofitSmartScale', 'com.viatek.fitnation.echelon_android', 'net.peater.fitlovers', 'scope.fitnessfirstmena', 'com.eztech.fitness', 'com.movefitness.app', 'com.zq.fit', 'com.simplyfitme.weightloss', 'com.naukriGulf.app', 'br.com.w12.heyfit', 'com.bickster.fitbitbandfinder', 'femaleworkout.pro.workouts.home.femalefitnesswomenworkout', 'com.evolutionwellness.app.fitnessfirst', 'com.tony.hifitpro', 'ro.fitgym', 'com.myfitnesscoach', 'com.airofit_app', 'com.abyx.fit.connect', 'com.honbow.fitdock', 'com.fitbit.FitbitMobile', 'fitness.app.women.female.workout', 'com.kilogroup.fitter', 'com.simplyfit.rowing', 'com.fitness.hiit.fat.burning.workout.jian032aplus', 'com.FitnessAPPs.superheroWorkouts', 'com.fitifyapps.bwstretching', 'com.netpulse.mobile.morefitness', 'jp.co.yahoo.android.vassist', 'club.nfit', 'com.spotify.music', 'com.perfectgym.perfectgymgo2.wellfitness', 'com.india.fitpass', 'app.fit.meet', 'com.lesmills.fitnessplus', 'com.dusiassistant', 'fitness.fitprosport', 'com.netpulse.mobile.maxxfitnessclubzz', 'com.golf.fitforgolf', 'com.fitapp', 'pedometer.stepcounter.fitnessapp.stepstracker', 'br.com.mufitness.station.aluno', 'com.eokoe.smartfitcoach', 'digifit.android.virtuagym.pro.platinumgym', 'nl.birdssoftware.mondaymorning', 'com.cignahealthbenefits.mobileapp', 'com.orangetheoryfitness.orangetheory', 'it.tripix.buddyfit', 'com.shikudo.fitrpg.google', 'digifit.android.virtuagym.pro.celtix', 'com.rageconsulting.android.lightflowlegacy', 'com.mga.fitty', 'digifit.android.virtuagym.pro.fitnessparksuperclub', 'com.jquiz.english', 'com.chloeting.fitness', 'com.komparato.informer.wear', 'com.workout.women.hiit.female.fitness.jian062lite', 'de.hansefit.mobileapp', 'com.megasys.profit', 'fat.burnning.plank.fitness.loseweight', 'com.bpfit.bloodpressure.health', 'com.kiss.keeper', 'com.fitplanapp.fitplan', 'com.quantumbit.fitmax', 'com.yc.gtfit', 'net.workoutinc.seven_7minutesfitness_forwomen', 'com.vgfit.shefit', 'com.dolcegustofree.activity', 'com.fixfit_fitness.twa', 'br.com.w12.redfit', 'clubwise.com.fitsense', 'com.arketa.jamiegfitness', 'com.zeopoxa.fitness.cycling.bike', 'women.workout.female.fitness', 'com.mc.amazfit1', 'com.netpulse.mobile.fitnessforten', 'tr.com.fitwell.app', 'com.evlofitness', 'com.jyfitness.iron_mastery', 'com.samsung.android.shealthmonitor', 'com.zhapp.zeblazefit', 'app.EnForma.fitcoapp.net', 'senior.fitness.exercises.elderly', 'com.fitnesspassport.androidapp', 'com.mauriciotogneri.shoppinglist', 'com.riversongfit.epoch', 'com.fitradio', 'com.ifit.wolf', 'org.obduro.kentekeninfo', 'com.fitmind', 'de.upmcmobile.fitnessraum', 'com.growfitter.fitkit', 'com.fitzeee.menworkout', 'com.netpulse.mobile.fitnessproject', 'com.Glossbird.Fitment', 'se.matlistan.free', 'com.pocketlifestyle.music.tune', 'com.netpulse.mobile.tenfitness', 'br.com.personalfitapp', 'com.fitshow', 'br.com.fitastic.appaluno', 'com.luni.android.fitnesscoach.app', 'com.shapehq.fitnessworld', 'ru.disav.befit', 'com.netpulse.mobile.chuzefitness', 'com.mz.fit', 'com.best.fit', 'rs.nonstopfitness', 'de.fitplusint', 'it.evolutionfit.evolutionfit.club', 'com.user.livefitt', 'com.noisefit.focus', 'faceyoga.facefitness.dailyworkouts', 'com.bhphoto', 'pl.tweeba.mobile.learning.english', 'com.fitnessmobileapps.elevate35253', 'com.hootapps.soundrecorder', 'com.samsung.android.wear.shealth', 'com.caliberfitness.app', 'com.fitness.stepcounter.pedometer', 'com.noisefit', 'digifit.android.virtuagym.pro.neobod', 'kr.fitt.fmes', 'fit.ketoindia.ketoindia', 'com.runmifit.android', 'ee.myfitness.app', 'digifit.android.virtuagym.pro.everlast', 'pl.efitness.mobile', 'com.cisco.im', 'net.familo.android', 'com.directed.android.viper', 'com.moblino.simplenote', 'com.zeopoxa.fitness.running', 'com.cognifit.app', 'rs.abstract.fitpass', 'com.transformfitness', 'steptracker.healthandfitness.walkingtracker.pedometer', 'com.appyfurious.getfit', 'com.fitbod.fitbod', 'com.dotfit.dotfitweb', ...
# 520

# %%
for i in range(len(array_traffic_package_name)):
    print("--------------------- Loop-"+str(i)+" ---------------------")
    package_name = array_traffic_package_name[i]
    print("package_name: ",package_name)
    traffic_directory_path = root_traffic_directory_path + "\\" + package_name
    print("traffic_directory_path: ",traffic_directory_path)
    move_txt_files_to_final_traffic(traffic_directory_path)
#     break
# Out:
# --------------------- Loop-0 ---------------------
# package_name:  com.anytimefitness.userapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_17.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_22.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_25.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.anytimefitness.userapp\final-traffic
# --------------------- Loop-1 ---------------------
# package_name:  app.LomasGym.fitcoapp.net
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\app.LomasGym.fitcoapp.net\final-traffic
# --------------------- Loop-2 ---------------------
# package_name:  com.itrack.xfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.itrack.xfit
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.itrack.xfit\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.itrack.xfit\final-traffic
# --------------------- Loop-3 ---------------------
# package_name:  com.actofitSmartScale
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.actofitSmartScale\final-traffic
# --------------------- Loop-4 ---------------------
# package_name:  com.viatek.fitnation.echelon_android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.viatek.fitnation.echelon_android\final-traffic
# --------------------- Loop-5 ---------------------
# package_name:  net.peater.fitlovers
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\net.peater.fitlovers\final-traffic
# --------------------- Loop-6 ---------------------
# package_name:  scope.fitnessfirstmena
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\scope.fitnessfirstmena
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\scope.fitnessfirstmena\final-traffic
# --------------------- Loop-7 ---------------------
# package_name:  com.eztech.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eztech.fitness
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.eztech.fitness\final-traffic
# --------------------- Loop-8 ---------------------
# package_name:  com.movefitness.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.movefitness.app
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.movefitness.app\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.movefitness.app\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.movefitness.app\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.movefitness.app\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.movefitness.app\final-traffic
# --------------------- Loop-9 ---------------------
# package_name:  com.zq.fit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zq.fit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.zq.fit\final-traffic
# --------------------- Loop-10 ---------------------
# package_name:  com.simplyfitme.weightloss
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.simplyfitme.weightloss
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.simplyfitme.weightloss\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.simplyfitme.weightloss\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.simplyfitme.weightloss\final-traffic
# --------------------- Loop-11 ---------------------
# package_name:  com.naukriGulf.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.naukriGulf.app
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.naukriGulf.app\final-traffic
# --------------------- Loop-12 ---------------------
# package_name:  br.com.w12.heyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.heyfit\final-traffic
# --------------------- Loop-13 ---------------------
# package_name:  com.bickster.fitbitbandfinder
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.bickster.fitbitbandfinder\final-traffic
# --------------------- Loop-14 ---------------------
# package_name:  femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\femaleworkout.pro.workouts.home.femalefitnesswomenworkout\final-traffic
# --------------------- Loop-15 ---------------------
# package_name:  com.evolutionwellness.app.fitnessfirst
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.fitnessfirst
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.fitnessfirst\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.fitnessfirst\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.evolutionwellness.app.fitnessfirst\final-traffic
# --------------------- Loop-16 ---------------------
# package_name:  com.tony.hifitpro
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.tony.hifitpro
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.tony.hifitpro\final-traffic
# --------------------- Loop-17 ---------------------
# package_name:  ro.fitgym
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\ro.fitgym
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\ro.fitgym\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\ro.fitgym\final-traffic
# --------------------- Loop-18 ---------------------
# package_name:  com.myfitnesscoach
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesscoach\final-traffic
# --------------------- Loop-19 ---------------------
# package_name:  com.airofit_app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.airofit_app
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.airofit_app\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.airofit_app\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.airofit_app\final-traffic
# --------------------- Loop-20 ---------------------
# package_name:  com.abyx.fit.connect
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.abyx.fit.connect
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.abyx.fit.connect\final-traffic
# --------------------- Loop-21 ---------------------
# package_name:  com.honbow.fitdock
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.honbow.fitdock\final-traffic
# --------------------- Loop-22 ---------------------
# package_name:  com.fitbit.FitbitMobile
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitbit.FitbitMobile
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitbit.FitbitMobile\final-traffic
# --------------------- Loop-23 ---------------------
# package_name:  fitness.app.women.female.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.app.women.female.workout
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\fitness.app.women.female.workout\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\fitness.app.women.female.workout\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\fitness.app.women.female.workout\final-traffic
# --------------------- Loop-24 ---------------------
# package_name:  com.kilogroup.fitter
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.kilogroup.fitter\final-traffic
# --------------------- Loop-25 ---------------------
# package_name:  com.simplyfit.rowing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.simplyfit.rowing
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.simplyfit.rowing\final-traffic
# --------------------- Loop-26 ---------------------
# package_name:  com.fitness.hiit.fat.burning.workout.jian032aplus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness.hiit.fat.burning.workout.jian032aplus\final-traffic
# --------------------- Loop-27 ---------------------
# package_name:  com.FitnessAPPs.superheroWorkouts
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.FitnessAPPs.superheroWorkouts
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.FitnessAPPs.superheroWorkouts\final-traffic
# --------------------- Loop-28 ---------------------
# package_name:  com.fitifyapps.bwstretching
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fitifyapps.bwstretching\final-traffic
# --------------------- Loop-29 ---------------------
# package_name:  com.netpulse.mobile.morefitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.morefitness\final-traffic
# --------------------- Loop-30 ---------------------
# package_name:  jp.co.yahoo.android.vassist
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\jp.co.yahoo.android.vassist\final-traffic
# --------------------- Loop-31 ---------------------
# package_name:  club.nfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\club.nfit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\club.nfit\final-traffic
# --------------------- Loop-32 ---------------------
# package_name:  com.spotify.music
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.spotify.music
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.spotify.music\final-traffic
# --------------------- Loop-33 ---------------------
# package_name:  com.perfectgym.perfectgymgo2.wellfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.perfectgym.perfectgymgo2.wellfitness\final-traffic
# --------------------- Loop-34 ---------------------
# package_name:  com.india.fitpass
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.india.fitpass
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.india.fitpass\final-traffic
# --------------------- Loop-35 ---------------------
# package_name:  app.fit.meet
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.fit.meet
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\app.fit.meet\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\app.fit.meet\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\app.fit.meet\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\app.fit.meet\final-traffic
# --------------------- Loop-36 ---------------------
# package_name:  com.lesmills.fitnessplus
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.lesmills.fitnessplus\final-traffic
# --------------------- Loop-37 ---------------------
# package_name:  com.dusiassistant
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.dusiassistant
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_19.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.dusiassistant\final-traffic
# --------------------- Loop-38 ---------------------
# package_name:  fitness.fitprosport
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fitness.fitprosport
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\fitness.fitprosport\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\fitness.fitprosport\final-traffic
# --------------------- Loop-39 ---------------------
# package_name:  com.netpulse.mobile.maxxfitnessclubzz
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.maxxfitnessclubzz\final-traffic
# --------------------- Loop-40 ---------------------
# package_name:  com.golf.fitforgolf
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.golf.fitforgolf
# --------------------- Loop-41 ---------------------
# package_name:  com.fitapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitapp
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.fitapp\final-traffic
# --------------------- Loop-42 ---------------------
# package_name:  pedometer.stepcounter.fitnessapp.stepstracker
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker\final-traffic
# Moved: message_22.txt -> E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker\final-traffic
# Moved: message_23.txt -> E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\pedometer.stepcounter.fitnessapp.stepstracker\final-traffic
# --------------------- Loop-43 ---------------------
# package_name:  br.com.mufitness.station.aluno
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.mufitness.station.aluno
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\br.com.mufitness.station.aluno\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\br.com.mufitness.station.aluno\final-traffic
# --------------------- Loop-44 ---------------------
# package_name:  com.eokoe.smartfitcoach
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.eokoe.smartfitcoach
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.eokoe.smartfitcoach\final-traffic
# --------------------- Loop-45 ---------------------
# package_name:  digifit.android.virtuagym.pro.platinumgym
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.platinumgym
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.platinumgym\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.platinumgym\final-traffic
# --------------------- Loop-46 ---------------------
# package_name:  nl.birdssoftware.mondaymorning
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nl.birdssoftware.mondaymorning
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\nl.birdssoftware.mondaymorning\final-traffic
# --------------------- Loop-47 ---------------------
# package_name:  com.cignahealthbenefits.mobileapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.cignahealthbenefits.mobileapp\final-traffic
# --------------------- Loop-48 ---------------------
# package_name:  com.orangetheoryfitness.orangetheory
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_17.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.orangetheoryfitness.orangetheory\final-traffic
# --------------------- Loop-49 ---------------------
# package_name:  it.tripix.buddyfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\it.tripix.buddyfit\final-traffic
# --------------------- Loop-50 ---------------------
# package_name:  com.shikudo.fitrpg.google
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_17.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_19.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_20.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.shikudo.fitrpg.google\final-traffic
# --------------------- Loop-51 ---------------------
# package_name:  digifit.android.virtuagym.pro.celtix
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.celtix\final-traffic
# --------------------- Loop-52 ---------------------
# package_name:  com.rageconsulting.android.lightflowlegacy
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.rageconsulting.android.lightflowlegacy\final-traffic
# --------------------- Loop-53 ---------------------
# package_name:  com.mga.fitty
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.mga.fitty
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.mga.fitty\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.mga.fitty\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.mga.fitty\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.mga.fitty\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.mga.fitty\final-traffic
# --------------------- Loop-54 ---------------------
# package_name:  digifit.android.virtuagym.pro.fitnessparksuperclub
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fitnessparksuperclub
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fitnessparksuperclub\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\digifit.android.virtuagym.pro.fitnessparksuperclub\final-traffic
# --------------------- Loop-55 ---------------------
# package_name:  com.jquiz.english
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.jquiz.english
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.jquiz.english\final-traffic
# --------------------- Loop-56 ---------------------
# package_name:  com.chloeting.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.chloeting.fitness\final-traffic
# --------------------- Loop-57 ---------------------
# package_name:  com.komparato.informer.wear
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.komparato.informer.wear
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.komparato.informer.wear\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.komparato.informer.wear\final-traffic
# --------------------- Loop-58 ---------------------
# package_name:  com.workout.women.hiit.female.fitness.jian062lite
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_19.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.women.hiit.female.fitness.jian062lite\final-traffic
# --------------------- Loop-59 ---------------------
# package_name:  de.hansefit.mobileapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\de.hansefit.mobileapp
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\de.hansefit.mobileapp\final-traffic
# --------------------- Loop-60 ---------------------
# package_name:  com.megasys.profit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.megasys.profit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.megasys.profit\final-traffic
# --------------------- Loop-61 ---------------------
# package_name:  fat.burnning.plank.fitness.loseweight
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_17.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_19.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_20.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_21.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\fat.burnning.plank.fitness.loseweight\final-traffic
# --------------------- Loop-62 ---------------------
# package_name:  com.bpfit.bloodpressure.health
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.bpfit.bloodpressure.health\final-traffic
# --------------------- Loop-63 ---------------------
# package_name:  com.kiss.keeper
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.kiss.keeper
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.kiss.keeper\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.kiss.keeper\final-traffic
# --------------------- Loop-64 ---------------------
# package_name:  com.fitplanapp.fitplan
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.fitplanapp.fitplan\final-traffic
# --------------------- Loop-65 ---------------------
# package_name:  com.quantumbit.fitmax
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.quantumbit.fitmax
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.quantumbit.fitmax\final-traffic
# --------------------- Loop-66 ---------------------
# package_name:  com.yc.gtfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yc.gtfit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_19.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_20.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.yc.gtfit\final-traffic
# --------------------- Loop-67 ---------------------
# package_name:  net.workoutinc.seven_7minutesfitness_forwomen
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\net.workoutinc.seven_7minutesfitness_forwomen\final-traffic
# --------------------- Loop-68 ---------------------
# package_name:  com.vgfit.shefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.vgfit.shefit\final-traffic
# --------------------- Loop-69 ---------------------
# package_name:  com.dolcegustofree.activity
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.dolcegustofree.activity\final-traffic
# --------------------- Loop-70 ---------------------
# package_name:  com.fixfit_fitness.twa
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_13.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.fixfit_fitness.twa\final-traffic
# --------------------- Loop-71 ---------------------
# package_name:  br.com.w12.redfit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\br.com.w12.redfit\final-traffic
# --------------------- Loop-72 ---------------------
# package_name:  clubwise.com.fitsense
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\clubwise.com.fitsense
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\clubwise.com.fitsense\final-traffic
# --------------------- Loop-73 ---------------------
# package_name:  com.arketa.jamiegfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.arketa.jamiegfitness\final-traffic
# --------------------- Loop-74 ---------------------
# package_name:  com.zeopoxa.fitness.cycling.bike
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.zeopoxa.fitness.cycling.bike
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.zeopoxa.fitness.cycling.bike\final-traffic
# --------------------- Loop-75 ---------------------
# package_name:  women.workout.female.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\women.workout.female.fitness\final-traffic
# ...
# Moved: message_26.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\homeworkoutapp.homeworkout.fitness.workout.loseweight\final-traffic
# --------------------- Loop-495 ---------------------
# package_name:  com.workout.fitness.exercise.loseweight.gymworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.workout.fitness.exercise.loseweight.gymworkout
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.fitness.exercise.loseweight.gymworkout\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.fitness.exercise.loseweight.gymworkout\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.workout.fitness.exercise.loseweight.gymworkout\final-traffic
# --------------------- Loop-496 ---------------------
# package_name:  com.qingniu.megafit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.qingniu.megafit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.qingniu.megafit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.qingniu.megafit\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.qingniu.megafit\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.qingniu.megafit\final-traffic
# --------------------- Loop-497 ---------------------
# package_name:  com.brooklynfitzone.app
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_23.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_26.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.brooklynfitzone.app\final-traffic
# --------------------- Loop-498 ---------------------
# package_name:  com.fitness22.running
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitness22.running
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.fitness22.running\final-traffic
# --------------------- Loop-499 ---------------------
# package_name:  com.proyecto.beonefitnesssport.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.beonefitnesssport.tgcustom\final-traffic
# --------------------- Loop-500 ---------------------
# package_name:  com.urbandroid.lux
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.urbandroid.lux
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.urbandroid.lux\final-traffic
# --------------------- Loop-501 ---------------------
# package_name:  nz.co.telecom.smartphone.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_15.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_17.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_21.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_24.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_28.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\nz.co.telecom.smartphone.android\final-traffic
# --------------------- Loop-502 ---------------------
# package_name:  com.crrepa.band.dafit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.crrepa.band.dafit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.crrepa.band.dafit\final-traffic
# --------------------- Loop-503 ---------------------
# package_name:  net.kosev.dicing
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\net.kosev.dicing
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\net.kosev.dicing\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\net.kosev.dicing\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\net.kosev.dicing\final-traffic
# --------------------- Loop-504 ---------------------
# package_name:  com.healthfitnessnordic.gxbooking
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.healthfitnessnordic.gxbooking
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.healthfitnessnordic.gxbooking\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.healthfitnessnordic.gxbooking\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.healthfitnessnordic.gxbooking\final-traffic
# --------------------- Loop-505 ---------------------
# package_name:  com.vivefit
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.vivefit
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_10.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.vivefit\final-traffic
# --------------------- Loop-506 ---------------------
# package_name:  com.ramonmorcillo.fitbot01
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ramonmorcillo.fitbot01
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.ramonmorcillo.fitbot01\final-traffic
# --------------------- Loop-507 ---------------------
# package_name:  com.myfitnesspal.android
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.myfitnesspal.android
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.myfitnesspal.android\final-traffic
# --------------------- Loop-508 ---------------------
# package_name:  com.fitlog.fitlog
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitlog.fitlog
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitlog.fitlog\final-traffic
# --------------------- Loop-509 ---------------------
# package_name:  com.netpulse.mobile.bodyplexfamilyfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.bodyplexfamilyfitness
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.bodyplexfamilyfitness\final-traffic
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.netpulse.mobile.bodyplexfamilyfitness\final-traffic
# --------------------- Loop-510 ---------------------
# package_name:  app.growwithjo.diet.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\app.growwithjo.diet.fitness\final-traffic
# --------------------- Loop-511 ---------------------
# package_name:  com.yomaster.workout.fitness.yoga.yogaworkout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.yomaster.workout.fitness.yoga.yogaworkout
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.yomaster.workout.fitness.yoga.yogaworkout\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.yomaster.workout.fitness.yoga.yogaworkout\final-traffic
# --------------------- Loop-512 ---------------------
# package_name:  com.fitworkout.lossweight.homeworkout.fitnessapp
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_12.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.fitworkout.lossweight.homeworkout.fitnessapp\final-traffic
# --------------------- Loop-513 ---------------------
# package_name:  com.proyecto.fitup.tgcustom
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom\final-traffic
# Moved: message_4.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.proyecto.fitup.tgcustom\final-traffic
# --------------------- Loop-514 ---------------------
# package_name:  com.ionicframework.fitcoapp644044
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.ionicframework.fitcoapp644044
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.ionicframework.fitcoapp644044\final-traffic
# --------------------- Loop-515 ---------------------
# package_name:  com.basemsalloum.goodfitness.goodfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness\final-traffic
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.basemsalloum.goodfitness.goodfitness\final-traffic
# --------------------- Loop-516 ---------------------
# package_name:  drzio.senior.yoga.fitness.elders.old.workout
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout
# Moved: message_1.txt -> E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\drzio.senior.yoga.fitness.elders.old.workout\final-traffic
# --------------------- Loop-517 ---------------------
# package_name:  com.bodyfxfitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.bodyfxfitness
# Moved: message_0.txt -> E:\wearable-capture-traffic\wearable-app\com.bodyfxfitness\final-traffic
# --------------------- Loop-518 ---------------------
# package_name:  com.innovatise.fitnesstimeleejam
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam
# Moved: message_11.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_14.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_16.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_18.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_23.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_26.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_7.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_8.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# Moved: message_9.txt -> E:\wearable-capture-traffic\wearable-app\com.innovatise.fitnesstimeleejam\final-traffic
# --------------------- Loop-519 ---------------------
# package_name:  com.fitonomy.health.fitness
# traffic_directory_path:  E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness
# Moved: message_2.txt -> E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness\final-traffic
# Moved: message_3.txt -> E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness\final-traffic
# Moved: message_5.txt -> E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness\final-traffic
# Moved: message_6.txt -> E:\wearable-capture-traffic\wearable-app\com.fitonomy.health.fitness\final-traffic
