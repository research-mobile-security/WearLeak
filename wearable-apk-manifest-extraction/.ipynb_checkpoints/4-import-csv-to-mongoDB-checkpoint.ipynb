# %%
import pandas as pd
from pymongo import MongoClient

# %%
def create_mongo_database(mongo_url, db_name):
    """
    Function to create or get a MongoDB database.
    """
    # Connect to the MongoDB client
    client = MongoClient(mongo_url)

    # Create or access the database
    db = client[db_name]
    return db

def create_mongo_collection(db, collection_name):
    """
    Function to create or get a MongoDB collection.
    """
    # Create collection if not exists
    if collection_name not in db.list_collection_names():
        collection = db.create_collection(collection_name)
        print(f"Collection '{collection_name}' created.")
    else:
        collection = db[collection_name]
        print(f"Collection '{collection_name}' already exists.")
    
    return collection

# def import_csv_to_mongodb(csv_file_path, collection):
#     """
#     Function to import CSV data into a MongoDB collection, with manifest_permission as an array.
#     """
#     # Read CSV into pandas dataframe
#     df = pd.read_csv(csv_file_path)

#     # Convert each row to a dictionary and insert into the MongoDB collection
#     for index, row in df.iterrows():
#         # Split manifest_permission into an array (assuming they are comma-separated in the CSV)
#         if pd.notna(row['manifest_permission']):
#             manifest_permission_array = row['manifest_permission'].split('\n')
#         else:
#             manifest_permission_array = []

#         # Create a document with pkg_name as the unique _id
#         document = {
#             "_id": row['pkg_name'],  # Use pkg_name as the unique _id
#             "apkfile_name": row['apkfile_name'],
#             "apkfile_name_new": row['apkfile_name_new'],
#             "extract_manifest": row['extract_manifest'],
#             "manifest_permission": manifest_permission_array,  # Store as array
#             "app_group": row['app_group'],
#             "app_group_reason": row['app_group_reason']
#         }

#         try:
#             # Insert document into MongoDB (it will skip if _id already exists)
#             collection.insert_one(document)
#             print(f"Inserted document for pkg_name: {row['pkg_name']}")
#         except Exception as e:
#             print(f"Error inserting document for pkg_name: {row['pkg_name']}. Error: {e}")
def import_csv_to_mongodb(csv_file_path, collection):
    """
    Function to import CSV data into a MongoDB collection, with manifest_permission as an array.
    """
    # Read CSV into pandas dataframe
    df = pd.read_csv(csv_file_path)

    # Convert each row to a dictionary and insert into the MongoDB collection
    for index, row in df.iterrows():
        # Check if the document with the same _id (pkg_name) already exists
        if collection.find_one({"_id": row['pkg_name']}):
            print(f"Document with pkg_name '{row['pkg_name']}' already exists. Skipping insertion.")
            continue  # Skip this document and move to the next one

        # Split manifest_permission into an array (assuming they are comma-separated in the CSV)
        if pd.notna(row['manifest_permission']):
            manifest_permission_array = row['manifest_permission'].split('\n')
        else:
            manifest_permission_array = []

        # Create a document with pkg_name as the unique _id
        document = {
            "_id": row['pkg_name'],  # Use pkg_name as the unique _id
            "apkfile_name": row['apkfile_name'],
            "apkfile_name_new": row['apkfile_name_new'],
            "extract_manifest": row['extract_manifest'],
            "manifest_permission": manifest_permission_array,  # Store as array
            "app_group": row['app_group'],
            "app_group_reason": row['app_group_reason']
        }

        try:
            # Insert document into MongoDB
            collection.insert_one(document)
            print(f"Inserted document for pkg_name: {row['pkg_name']}")
        except Exception as e:
            print(f"Error inserting document for pkg_name: {row['pkg_name']}. Error: {e}")

# %%
# MongoDB configuration
mongo_url = "mongodb://localhost:27017"
db_name = "wearable-project"
collection_name = "wearable-app"
# standalone
db_name = "wearable-project"
collection_name = "wearable-standalone"

# CSV file path
# csv_file_path = r"C:\Users\ASUS\anaconda3\wearable-apk-manifest\combine_filtered_cleaned.csv"

csv_file_path = r"C:\\Users\\ASUS\\anaconda3\\wearable-apk-manifest\\apk-wearable-standalone.csv"

# %%
# Create MongoDB database
db = create_mongo_database(mongo_url, db_name)

# Create MongoDB collection
collection = create_mongo_collection(db, collection_name)

# Import CSV data to MongoDB collection
import_csv_to_mongodb(csv_file_path, collection)
# Out:
# Collection 'wearable-app' already exists.
# Document with pkg_name 'in.codeseed.audify' already exists. Skipping insertion.
# Document with pkg_name 'com.urbandroid.lux' already exists. Skipping insertion.
# Document with pkg_name 'maxcom.toolbox.altimeter' already exists. Skipping insertion.
# Document with pkg_name 'com.reflive.reflive' already exists. Skipping insertion.
# Document with pkg_name 'com.tomtop.smart' already exists. Skipping insertion.
# Document with pkg_name 'com.mauriciotogneri.shoppinglist' already exists. Skipping insertion.
# Document with pkg_name 'com.szyk.myheart' already exists. Skipping insertion.
# Document with pkg_name 'interactiveshift.com.trailswear' already exists. Skipping insertion.
# Document with pkg_name 'com.atlaswearables.ionic' already exists. Skipping insertion.
# Document with pkg_name 'je.fit' already exists. Skipping insertion.
# Document with pkg_name 'com.acquasys.contrack' already exists. Skipping insertion.
# Document with pkg_name 'com.daniel.apps.wpe' already exists. Skipping insertion.
# Document with pkg_name 'net.ddns.axiiim.wearphonelock' already exists. Skipping insertion.
# Document with pkg_name 'org.uguess.android.sysinfo.wear' already exists. Skipping insertion.
# Document with pkg_name 'com.ericfabreu.wearflashcards' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.wearvideos' already exists. Skipping insertion.
# Document with pkg_name 'com.lilc103.buttonbattle' already exists. Skipping insertion.
# Document with pkg_name 'com.overseasolutions.waterapp.app' already exists. Skipping insertion.
# Document with pkg_name 'tk.deuchnord.phonejuicechecker' already exists. Skipping insertion.
# Document with pkg_name 'de.softxperience.android.quickprofiles' already exists. Skipping insertion.
# Document with pkg_name 'com.piggeh.flip' already exists. Skipping insertion.
# Document with pkg_name 'kr.co.openit.openrider' already exists. Skipping insertion.
# Document with pkg_name 'com.naing.englishmyanmardictionary' already exists. Skipping insertion.
# Document with pkg_name 'com.gin.shoppinglist' already exists. Skipping insertion.
# Document with pkg_name 'com.ccswe.SmokingLog' already exists. Skipping insertion.
# Document with pkg_name 'de.svz' already exists. Skipping insertion.
# Document with pkg_name 'com.komparato.informer.wear' already exists. Skipping insertion.
# Document with pkg_name 'net.sarmady.akhbarak' already exists. Skipping insertion.
# Document with pkg_name 'org.sombrenuit.dk.redfeed.free' already exists. Skipping insertion.
# Document with pkg_name 'com.glidetalk.glideapp' already exists. Skipping insertion.
# Document with pkg_name 'uk.me.andre.dicionarioportugues' already exists. Skipping insertion.
# Document with pkg_name 'com.link.messages.sms' already exists. Skipping insertion.
# Document with pkg_name 'com.kiss.keeper' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.messaging' already exists. Skipping insertion.
# Document with pkg_name 'com.shinayser.xwingmanager' already exists. Skipping insertion.
# Document with pkg_name 'com.aheqab.salahwear' already exists. Skipping insertion.
# Document with pkg_name 'com.rokontrol.android' already exists. Skipping insertion.
# Document with pkg_name 'net.waynepiekarski.screeninfo' already exists. Skipping insertion.
# Document with pkg_name 'com.biztech.magemobadmin' already exists. Skipping insertion.
# Document with pkg_name 'com.skimble.workouts' already exists. Skipping insertion.
# Document with pkg_name 'pl.tweeba.mobile.learning.english' already exists. Skipping insertion.
# Document with pkg_name 'org.obduro.kentekeninfo' already exists. Skipping insertion.
# Document with pkg_name 'ru.starline' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.yahoo.android.vassist' already exists. Skipping insertion.
# Document with pkg_name 'com.spotify.music' already exists. Skipping insertion.
# Document with pkg_name 'oms.mmc.fortunetelling.gmpay.almanac2' already exists. Skipping insertion.
# Document with pkg_name 'com.mictale.gpsessentials' already exists. Skipping insertion.
# Document with pkg_name 'com.ktmusic.geniemusic' already exists. Skipping insertion.
# Document with pkg_name 'net.familo.android' already exists. Skipping insertion.
# Document with pkg_name 'com.cpsolutions.contacts' already exists. Skipping insertion.
# Document with pkg_name 'eu.power_switch' already exists. Skipping insertion.
# Document with pkg_name 'com.hootapps.soundrecorder' already exists. Skipping insertion.
# Document with pkg_name 'com.directed.android.viper' already exists. Skipping insertion.
# Document with pkg_name 'com.adi.remote.phone' already exists. Skipping insertion.
# Document with pkg_name 'com.lucky_ponies.dokin' already exists. Skipping insertion.
# Document with pkg_name 'com.yannik.wear.anki' already exists. Skipping insertion.
# Document with pkg_name 'com.toshremote.view' already exists. Skipping insertion.
# Document with pkg_name 'com.muzzley' already exists. Skipping insertion.
# Document with pkg_name 'net.homeip.thkerkmann.einkaufsliste' already exists. Skipping insertion.
# Document with pkg_name 'se.matlistan.free' already exists. Skipping insertion.
# Document with pkg_name 'nl.birdssoftware.mondaymorning' already exists. Skipping insertion.
# Document with pkg_name 'com.dusiassistant' already exists. Skipping insertion.
# Document with pkg_name 'com.pimp.calculator' already exists. Skipping insertion.
# Document with pkg_name 'at.radioplayer.android' already exists. Skipping insertion.
# Document with pkg_name 'revox.voxnet' already exists. Skipping insertion.
# Document with pkg_name 'com.nstudio.weatherhere.free' already exists. Skipping insertion.
# Document with pkg_name 'com.dimlix.phrase' already exists. Skipping insertion.
# Document with pkg_name 'com.cm.wearintervaltimer' already exists. Skipping insertion.
# Document with pkg_name 'com.fredmeyer.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.pocketlifestyle.music.tune' already exists. Skipping insertion.
# Document with pkg_name 'com.bakersplus.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.dolcegustofree.activity' already exists. Skipping insertion.
# Document with pkg_name 'com.naukriGulf.app' already exists. Skipping insertion.
# Document with pkg_name 'com.qfc.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.palaspro.listainteligentecompra' already exists. Skipping insertion.
# Document with pkg_name 'com.estela' already exists. Skipping insertion.
# Document with pkg_name 'com.k560.luciddreaminducer' already exists. Skipping insertion.
# Document with pkg_name 'com.droibit.findwear' already exists. Skipping insertion.
# Document with pkg_name 'com.amdroidalarmclock.amdroid' already exists. Skipping insertion.
# Document with pkg_name 'com.mobisystems.editor.office_with_reg' already exists. Skipping insertion.
# Document with pkg_name 'com.frysfood.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.mobisystems.office' already exists. Skipping insertion.
# Document with pkg_name 'com.kingsoopers.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.smithsfoodanddrug.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.aircanada' already exists. Skipping insertion.
# Document with pkg_name 'com.vivint.vivintsky' already exists. Skipping insertion.
# Document with pkg_name 'fi.hhtec.coach4pro' already exists. Skipping insertion.
# Document with pkg_name 'com.cisco.webex.meetings' already exists. Skipping insertion.
# Document with pkg_name 'com.kroger.mobile' already exists. Skipping insertion.
# Document with pkg_name 'nl.dominos.android' already exists. Skipping insertion.
# Document with pkg_name 'nz.co.telecom.smartphone.android' already exists. Skipping insertion.
# Document with pkg_name 'com.acmeaom.android.myradar' already exists. Skipping insertion.
# Document with pkg_name 'com.rageconsulting.android.lightflowlegacy' already exists. Skipping insertion.
# Document with pkg_name 'tr.com.fitwell.app' already exists. Skipping insertion.
# Document with pkg_name 'com.cisco.im' already exists. Skipping insertion.
# Document with pkg_name 'com.sasyabook.businesscardapp' already exists. Skipping insertion.
# Document with pkg_name 'com.jquiz.english' already exists. Skipping insertion.
# Document with pkg_name 'com.edjing.edjingdjturntable' already exists. Skipping insertion.
# Document with pkg_name 'biz.mobidev.mdplayer' already exists. Skipping insertion.
# Document with pkg_name 'dev.niamor.wearliveboxremote' already exists. Skipping insertion.
# Document with pkg_name 'net.kosev.dicing' already exists. Skipping insertion.
# Document with pkg_name 'adarshurs.android.vlcmobileremote' already exists. Skipping insertion.
# Document with pkg_name 'com.pasha.music977' already exists. Skipping insertion.
# Document with pkg_name 'com.bhphoto' already exists. Skipping insertion.
# Document with pkg_name 'com.unated' already exists. Skipping insertion.
# Document with pkg_name 'com.bandlab.bandlab' already exists. Skipping insertion.
# Document with pkg_name 'com.kfaraj.notepad' already exists. Skipping insertion.
# Document with pkg_name 'com.SnowReport.screens' already exists. Skipping insertion.
# Document with pkg_name 'com.ubivelox.uvophone' already exists. Skipping insertion.
# Document with pkg_name 'com.directed.android.smartstart' already exists. Skipping insertion.
# Document with pkg_name 'com.lf.lfvtandroid' already exists. Skipping insertion.
# Document with pkg_name 'com.moblino.simplenote' already exists. Skipping insertion.
# Document with pkg_name 'com.overdrive.mobile.android.mediaconsole' already exists. Skipping insertion.
# Document with pkg_name 'com.exovoid.weather.app.at' already exists. Skipping insertion.
# Document with pkg_name 'com.weightwatchers.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.evoli.wtc_v1' already exists. Skipping insertion.
# Document with pkg_name 'com.doubleTwist.cloudPlayer' already exists. Skipping insertion.
# Document with pkg_name 'com.navitime.local.naviwalk.gl' already exists. Skipping insertion.
# Document with pkg_name 'com.ofirmiron.findmycarandroidwear' already exists. Skipping insertion.
# Document with pkg_name 'lunosoftware.nhlscores' already exists. Skipping insertion.
# Document with pkg_name 'jp.keita.nakamura.timetable' already exists. Skipping insertion.
# Document with pkg_name 'com.semaphore.login' already exists. Skipping insertion.
# Document with pkg_name 'kr.co.smartstudy.pinkfongtv_android_googlemarket' already exists. Skipping insertion.
# Document with pkg_name 'com.clearskyapps.fitnessfamily.Run5K' already exists. Skipping insertion.
# Document with pkg_name 'com.macropinch.kaiju' already exists. Skipping insertion.
# Document with pkg_name 'com.exovoid.weather.app.be' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.excite.translate' already exists. Skipping insertion.
# Document with pkg_name 'com.thetransitapp.droid' already exists. Skipping insertion.
# Document with pkg_name 'com.neurondigital.exercisetimer' already exists. Skipping insertion.
# Document with pkg_name 'no.nordicsemi.android.nrftoolbox' already exists. Skipping insertion.
# Document with pkg_name 'com.navent.realestate.inmuebles24' already exists. Skipping insertion.
# Document with pkg_name 'com.opl.transitnow' already exists. Skipping insertion.
# Document with pkg_name 'com.exovoid.weather.app' already exists. Skipping insertion.
# Document with pkg_name 'com.northpark.drinkwater' already exists. Skipping insertion.
# Document with pkg_name 'com.v1.v1pro' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.cybird.apps.sports.namiinfo' already exists. Skipping insertion.
# Document with pkg_name 'es.popsports.sevenminute' already exists. Skipping insertion.
# Document with pkg_name 'de.billiger.android' already exists. Skipping insertion.
# Document with pkg_name 'com.ouest.france' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.wearmessages' already exists. Skipping insertion.
# Document with pkg_name 'com.infraware.office.link' already exists. Skipping insertion.
# Document with pkg_name 'com.e8tracks' already exists. Skipping insertion.
# Document with pkg_name 'com.anghami' already exists. Skipping insertion.
# Document with pkg_name 'mtel.htc.contest.parking.app' already exists. Skipping insertion.
# Document with pkg_name 'com.navent.realestate.plusvalia' already exists. Skipping insertion.
# Document with pkg_name 'maya.im.imovelweb' already exists. Skipping insertion.
# Document with pkg_name 'de.ip_symcon.www.haussteuerung' already exists. Skipping insertion.
# Document with pkg_name 'com.fobsolutions.ontime' already exists. Skipping insertion.
# Document with pkg_name 'com.tandt.dash' already exists. Skipping insertion.
# Document with pkg_name 'com.skysoft.kkbox.android' already exists. Skipping insertion.
# Document with pkg_name 'com.dungelin.heartrate' already exists. Skipping insertion.
# Document with pkg_name 'com.idmobile.flashlight' already exists. Skipping insertion.
# Document with pkg_name 'com.vagaro' already exists. Skipping insertion.
# Document with pkg_name 'com.microsoft.office.onenote' already exists. Skipping insertion.
# Document with pkg_name 'com.fewlaps.android.whereismyphone' already exists. Skipping insertion.
# Document with pkg_name 'com.algoriddim.djay_free' already exists. Skipping insertion.
# Document with pkg_name 'com.microsoft.translator' already exists. Skipping insertion.
# Document with pkg_name 'com.technogym.tgapp' already exists. Skipping insertion.
# Document with pkg_name 'com.sweettracker.smartparcel' already exists. Skipping insertion.
# Document with pkg_name 'segi.com.magicarwatch' already exists. Skipping insertion.
# Document with pkg_name 'com.instructure.candroid' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearlauncher' already exists. Skipping insertion.
# Document with pkg_name 'com.wetter.in.de' already exists. Skipping insertion.
# Document with pkg_name 'pl.tweeba.mobile.learning.russian' already exists. Skipping insertion.
# Document with pkg_name 'com.spiraledge.swimapp' already exists. Skipping insertion.
# Document with pkg_name 'com.kth.ollehtvguide' already exists. Skipping insertion.
# Document with pkg_name 'nl.omroepbrabant.android' already exists. Skipping insertion.
# Document with pkg_name 'com.geomobile.tmbmobile' already exists. Skipping insertion.
# Document with pkg_name 'org.ymegane.android.approom' already exists. Skipping insertion.
# Document with pkg_name 'toilet.samruston.com.toilet' already exists. Skipping insertion.
# Document with pkg_name 'com.mobispector.bustimes' already exists. Skipping insertion.
# Document with pkg_name 'com.scoutalarm.android' already exists. Skipping insertion.
# Document with pkg_name 'com.tranzmate' already exists. Skipping insertion.
# Document with pkg_name 'com.vkontakte.android' already exists. Skipping insertion.
# Document with pkg_name 'fr.playsoft.lefigarov3' already exists. Skipping insertion.
# Document with pkg_name 'com.locnall.KimGiSa' already exists. Skipping insertion.
# Document with pkg_name 'cz.shawn.antelli' already exists. Skipping insertion.
# Document with pkg_name 'com.vsct.vsc.mobile.horaireetresa.android' already exists. Skipping insertion.
# Document with pkg_name 'org.codechimp.ttw' already exists. Skipping insertion.
# Document with pkg_name 'com.newssynergy.nwahomepage' already exists. Skipping insertion.
# Document with pkg_name 'com.mobileCounterPremium' already exists. Skipping insertion.
# Document with pkg_name 'com.aovill.language.e2l.ejn' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.weartube' already exists. Skipping insertion.
# Document with pkg_name 'com.yu.ivanyu.weargesturecontrol' already exists. Skipping insertion.
# Document with pkg_name 'com.apptivateme.next.sfss' already exists. Skipping insertion.
# Document with pkg_name 'com.hetweer.in.nl' already exists. Skipping insertion.
# Document with pkg_name 'com.stationdm.genesis' already exists. Skipping insertion.
# Document with pkg_name 'com.stt.android' already exists. Skipping insertion.
# Document with pkg_name 'com.plantronics.headsetservice' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.gm' already exists. Skipping insertion.
# Document with pkg_name 'lunosoftware.mlbscores' already exists. Skipping insertion.
# Document with pkg_name 'com.goldstar' already exists. Skipping insertion.
# Document with pkg_name 'com.fivemobile.thescore' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.deskclock' already exists. Skipping insertion.
# Document with pkg_name 'com.navitime.local.navitime' already exists. Skipping insertion.
# Document with pkg_name 'la.droid.qr.priva' already exists. Skipping insertion.
# Document with pkg_name 'pl.tweeba.mobile.learning.german' already exists. Skipping insertion.
# Document with pkg_name 'com.tizianhoesch.basel' already exists. Skipping insertion.
# Document with pkg_name 'com.apptivateme.next.amc' already exists. Skipping insertion.
# Document with pkg_name 'com.justyoyo' already exists. Skipping insertion.
# Document with pkg_name 'com.bambuna.podcastaddict' already exists. Skipping insertion.
# Document with pkg_name 'com.wingusoft.android.mapapp' already exists. Skipping insertion.
# Document with pkg_name 'com.netbiscuits.kicker' already exists. Skipping insertion.
# Document with pkg_name 'com.priceline.android.negotiator' already exists. Skipping insertion.
# Document with pkg_name 'com.ryosoftware.calendareventsnotifier' already exists. Skipping insertion.
# Document with pkg_name 'com.rauscha.apps.timesheet' already exists. Skipping insertion.
# Document with pkg_name 'ie.radioplayer.android' already exists. Skipping insertion.
# Document with pkg_name 'com.mobilexsoft.ezanvakti' already exists. Skipping insertion.
# Document with pkg_name 'com.gombosdev.ampere' already exists. Skipping insertion.
# Document with pkg_name 'com.apptivateme.next.ct' already exists. Skipping insertion.
# Document with pkg_name 'fr.m6.m6replay' already exists. Skipping insertion.
# Document with pkg_name 'com.parkwhiz.driverApp' already exists. Skipping insertion.
# Document with pkg_name 'com.panaremote.view' already exists. Skipping insertion.
# Document with pkg_name 'com.x3.angolotesti' already exists. Skipping insertion.
# Document with pkg_name 'com.bravolang.phrasebook' already exists. Skipping insertion.
# Document with pkg_name 'com.appestry.roku_remote_wear' already exists. Skipping insertion.
# Document with pkg_name 'com.apptivateme.next.hc' already exists. Skipping insertion.
# Document with pkg_name 'com.astroframe.seoulbus' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.lyonvelov.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.marslevelo.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.sevici.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.dublinbikes.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.nantesbicloo.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.valenbici.view' already exists. Skipping insertion.
# Document with pkg_name 'com.uramaks.music.player' already exists. Skipping insertion.
# Document with pkg_name 'org.telegram.messenger' already exists. Skipping insertion.
# Document with pkg_name 'com.moletag.gallery' already exists. Skipping insertion.
# Document with pkg_name 'com.tortato.tunerwear' already exists. Skipping insertion.
# Document with pkg_name 'com.joelapenna.foursquared' already exists. Skipping insertion.
# Document with pkg_name 'com.viber.voip' already exists. Skipping insertion.
# Document with pkg_name 'no.berghansen' already exists. Skipping insertion.
# Document with pkg_name 'net.cloud95.android.cameraremoter' already exists. Skipping insertion.
# Document with pkg_name 'com.phil.tv.view' already exists. Skipping insertion.
# Document with pkg_name 'com.rcreations.ipcamviewer' already exists. Skipping insertion.
# Document with pkg_name 'com.sonyericsson.music' already exists. Skipping insertion.
# Document with pkg_name 'com.journey.app' already exists. Skipping insertion.
# Document with pkg_name 'com.diaohs.calc1' already exists. Skipping insertion.
# Document with pkg_name 'com.sssemil.advancedsettings' already exists. Skipping insertion.
# Document with pkg_name 'com.ridewithgps.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.joaomgcd.autowear' already exists. Skipping insertion.
# Document with pkg_name 'com.levelup.palabre' already exists. Skipping insertion.
# Document with pkg_name 'com.tencent.mm' already exists. Skipping insertion.
# Document with pkg_name 'me.denley.musio' already exists. Skipping insertion.
# Document with pkg_name 'com.paessler.prtgandroid' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.bruxvillo.view' already exists. Skipping insertion.
# Document with pkg_name 'com.michgauz.velotoulouse.view' already exists. Skipping insertion.
# Document with pkg_name 'com.shazam.android' already exists. Skipping insertion.
# Document with pkg_name 'com.apalon.weatherlive.free' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.wearmail' already exists. Skipping insertion.
# Document with pkg_name 'qubin.de.wearmedia' already exists. Skipping insertion.
# Document with pkg_name 'fr.francetv.apps.info' already exists. Skipping insertion.
# Document with pkg_name 'com.sillens.shapeupclub' already exists. Skipping insertion.
# Document with pkg_name 'no.cita' already exists. Skipping insertion.
# Document with pkg_name 'com.codium.hydrocoach' already exists. Skipping insertion.
# Document with pkg_name 'com.stentec.wingps_marine_lite' already exists. Skipping insertion.
# Document with pkg_name 'com.itunestoppodcastplayer.app' already exists. Skipping insertion.
# Document with pkg_name 'fr.snapp.fidme' already exists. Skipping insertion.
# Document with pkg_name 'com.modryandel' already exists. Skipping insertion.
# Document with pkg_name 'com.soniremote.view' already exists. Skipping insertion.
# Document with pkg_name 'com.codegy.wearconnectforios' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.jorudan.nrkj' already exists. Skipping insertion.
# Document with pkg_name 'com.simplywerx.compass3d' already exists. Skipping insertion.
# Document with pkg_name 'de.stefanheintz.smarthome' already exists. Skipping insertion.
# Document with pkg_name 'com.mapmywalk.android2' already exists. Skipping insertion.
# Document with pkg_name 'com.samremote.view' already exists. Skipping insertion.
# Document with pkg_name 'com.mapmyrun.android2' already exists. Skipping insertion.
# Document with pkg_name 'com.amadeus.cmt.client.android' already exists. Skipping insertion.
# Document with pkg_name 'com.lgremote.view' already exists. Skipping insertion.
# Document with pkg_name 'com.zillow.android.zillowmap' already exists. Skipping insertion.
# Document with pkg_name 'com.alywa.oc.transpo' already exists. Skipping insertion.
# Document with pkg_name 'com.Horairesme' already exists. Skipping insertion.
# Document with pkg_name 'de.radioplayer.android' already exists. Skipping insertion.
# Document with pkg_name 'ca.rmen.android.frenchcalendar' already exists. Skipping insertion.
# Document with pkg_name 'com.golfnow.android.teetimes' already exists. Skipping insertion.
# Document with pkg_name 'com.hade.lottowear' already exists. Skipping insertion.
# Document with pkg_name 'br.com.easytaxi' already exists. Skipping insertion.
# Document with pkg_name 'com.balda.speedtrappro' already exists. Skipping insertion.
# Document with pkg_name 'com.icemobile.albertheijn' already exists. Skipping insertion.
# Document with pkg_name 'com.xiaad.android.thermometertrial' already exists. Skipping insertion.
# Document with pkg_name 'com.snapdeal.main' already exists. Skipping insertion.
# Document with pkg_name 'com.daraz.android' already exists. Skipping insertion.
# Document with pkg_name 'com.simplywerx.compass2d' already exists. Skipping insertion.
# Document with pkg_name 'de.dreier.mytargets' already exists. Skipping insertion.
# Document with pkg_name 'com.ppltalkin.findmywatch' already exists. Skipping insertion.
# Document with pkg_name 'com.sony.tvsideview.phone' already exists. Skipping insertion.
# Document with pkg_name 'org.libreoffice.impressremote' already exists. Skipping insertion.
# Document with pkg_name 'org.jraf.android.dcn' already exists. Skipping insertion.
# Document with pkg_name 'me.denley.fileboss' already exists. Skipping insertion.
# Document with pkg_name 'ie.appz.playbackstarter' already exists. Skipping insertion.
# Document with pkg_name 'com.mv2studio.amarok.kontrol.free' already exists. Skipping insertion.
# Document with pkg_name 'com.appgeneration.itunerfree' already exists. Skipping insertion.
# Document with pkg_name 'sk.martinflorek.wear.feelthewear' already exists. Skipping insertion.
# Document with pkg_name 'com.softwyer.contactlookupevents' already exists. Skipping insertion.
# Document with pkg_name 'mobi.beyondpod' already exists. Skipping insertion.
# Document with pkg_name 'com.finalwire.aida64' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearspotifyplayer' already exists. Skipping insertion.
# Document with pkg_name 'com.babywatcher.babywatcher' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.rakuten.golf.gora2' already exists. Skipping insertion.
# Document with pkg_name 'com.lemonde.androidapp' already exists. Skipping insertion.
# Document with pkg_name 'kik.android' already exists. Skipping insertion.
# Document with pkg_name 'com.stationdm.bluelink' already exists. Skipping insertion.
# Document with pkg_name 'com.textmeinc.freetone' already exists. Skipping insertion.
# Document with pkg_name 'com.navitime.local.carnavitime' already exists. Skipping insertion.
# Document with pkg_name 'workout.progression.lite' already exists. Skipping insertion.
# Document with pkg_name 'com.apptivateme.next.la' already exists. Skipping insertion.
# Document with pkg_name 'com.exaktime.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.steppschuh.remotecontrolcollection' already exists. Skipping insertion.
# Document with pkg_name 'jp.united.app.megtro' already exists. Skipping insertion.
# Document with pkg_name 'se.volvo.vcc' already exists. Skipping insertion.
# Document with pkg_name 'com.dominospizza' already exists. Skipping insertion.
# Document with pkg_name 'org.jraf.android.bikey' already exists. Skipping insertion.
# Document with pkg_name 'com.erudite.ecdict' already exists. Skipping insertion.
# Document with pkg_name 'jack.campbell.messive.compass' already exists. Skipping insertion.
# Document with pkg_name 'com.vuxia.wearchargingwidget' already exists. Skipping insertion.
# Document with pkg_name 'com.rockgecko.dips' already exists. Skipping insertion.
# Document with pkg_name 'com.guxiu.dreamdays_l' already exists. Skipping insertion.
# Document with pkg_name 'com.icounttimer.android.free' already exists. Skipping insertion.
# Document with pkg_name 'com.motivebite.smokefree.free' already exists. Skipping insertion.
# Document with pkg_name 'app.manoth.fahsai' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearlevel' already exists. Skipping insertion.
# Document with pkg_name 'br.com.ridsoftware.shoppinglist' already exists. Skipping insertion.
# Document with pkg_name 'freetime.mikekober.net.freetime' already exists. Skipping insertion.
# Document with pkg_name 'au.com.darkside.touchtime' already exists. Skipping insertion.
# Document with pkg_name 'de.juwei.homekey' already exists. Skipping insertion.
# Document with pkg_name 'com.kiss.countit' already exists. Skipping insertion.
# Document with pkg_name 'la.droid.qr' already exists. Skipping insertion.
# Document with pkg_name 'ch.pete.wakeupwell' already exists. Skipping insertion.
# Document with pkg_name 'com.biostatusapp.www' already exists. Skipping insertion.
# Document with pkg_name 'nl.slisky.stopwatch' already exists. Skipping insertion.
# Document with pkg_name 'com.automattic.simplenote' already exists. Skipping insertion.
# Document with pkg_name 'eu.autogps' already exists. Skipping insertion.
# Document with pkg_name 'com.biostatusfit.www' already exists. Skipping insertion.
# Document with pkg_name 'com.customsolutions.android.utl' already exists. Skipping insertion.
# Document with pkg_name 'com.newlinetechnology.wearvibrationapp' already exists. Skipping insertion.
# Document with pkg_name 'com.meedori.dresswatch' already exists. Skipping insertion.
# Document with pkg_name 'com.strv.metrobot' already exists. Skipping insertion.
# Document with pkg_name 'com.chrishatesbeer.bpmtap' already exists. Skipping insertion.
# Document with pkg_name 'com.kadapp.calculatorwear' already exists. Skipping insertion.
# Document with pkg_name 'com.busywww.cameratrigger' already exists. Skipping insertion.
# Document with pkg_name 'fr.julienvermet.watchtide' already exists. Skipping insertion.
# Document with pkg_name 'au.com.dominos.olo.android.app.nz' already exists. Skipping insertion.
# Document with pkg_name 'com.balda.taskernow' already exists. Skipping insertion.
# Document with pkg_name 'com.busywww.dashboardcam' already exists. Skipping insertion.
# Document with pkg_name 'com.kamoland.ytlog_wear' already exists. Skipping insertion.
# Document with pkg_name 'com.pocketwood.myav_sony_trial' already exists. Skipping insertion.
# Document with pkg_name 'com.circlegate.tt.transit.android' already exists. Skipping insertion.
# Document with pkg_name 'com.eugr.wearmetar' already exists. Skipping insertion.
# Document with pkg_name 'com.kmc3lab.metronomew' already exists. Skipping insertion.
# Document with pkg_name 'pandamonium.noaaweather' already exists. Skipping insertion.
# Document with pkg_name 'com.busywww.cameraremote' already exists. Skipping insertion.
# Document with pkg_name 'nl.nefit.easy.main' already exists. Skipping insertion.
# Document with pkg_name 'com.neowiz.android.bugs' already exists. Skipping insertion.
# Document with pkg_name 'com.lennox.keycut' already exists. Skipping insertion.
# Document with pkg_name 'com.pnn.android.sport_gear_tracker' already exists. Skipping insertion.
# Document with pkg_name 'com.zanyatocorp.chargereminder' already exists. Skipping insertion.
# Document with pkg_name 'org.myklos.inote' already exists. Skipping insertion.
# Document with pkg_name 'com.memorymap.mm2' already exists. Skipping insertion.
# Document with pkg_name 'com.contorra.golfpad' already exists. Skipping insertion.
# Document with pkg_name 'com.cheaptickets' already exists. Skipping insertion.
# Document with pkg_name 'com.haz.prayer.wear' already exists. Skipping insertion.
# Document with pkg_name 'jp.mynd.bohea.android' already exists. Skipping insertion.
# Document with pkg_name 'com.jacoh.wearreader' already exists. Skipping insertion.
# Document with pkg_name 'de.lineas.lit.ntv.android' already exists. Skipping insertion.
# Document with pkg_name 'com.orbitz' already exists. Skipping insertion.
# Document with pkg_name 'jp.co.yahoo.android.apps.transit' already exists. Skipping insertion.
# Document with pkg_name 'com.jee.level' already exists. Skipping insertion.
# Document with pkg_name 'in.amazon.mShop.android.shopping' already exists. Skipping insertion.
# Document with pkg_name 'com.clearchannel.iheartradio.controller' already exists. Skipping insertion.
# Document with pkg_name 'com.accuweather.android' already exists. Skipping insertion.
# Document with pkg_name 'org.leetzone.android.yatsewidgetfree' already exists. Skipping insertion.
# Document with pkg_name 'com.motorola.camera' already exists. Skipping insertion.
# Document with pkg_name 'com.ktcs.whowho' already exists. Skipping insertion.
# Document with pkg_name 'com.bravetheskies.ghostracer' already exists. Skipping insertion.
# Document with pkg_name 'com.dubaipolice.app' already exists. Skipping insertion.
# Document with pkg_name 'com.rcreations.ipc_wear_proxy' already exists. Skipping insertion.
# Document with pkg_name 'hr.wear.tipcalculator' already exists. Skipping insertion.
# Document with pkg_name 'com.asus.wellness' already exists. Skipping insertion.
# Document with pkg_name 'fr.julienvermet.legorafi' already exists. Skipping insertion.
# Document with pkg_name 'com.mjlim.hovernote' already exists. Skipping insertion.
# Document with pkg_name 'com.quirky.android.wink.wink' already exists. Skipping insertion.
# Document with pkg_name 'com.justyo' already exists. Skipping insertion.
# Document with pkg_name 'com.amazon.mShop.android.shopping' already exists. Skipping insertion.
# Document with pkg_name 'com.urbandroid.sleep' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.music' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.fitness' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearwatchfaces' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearstopwatch' already exists. Skipping insertion.
# Document with pkg_name 'com.gettaxi.android' already exists. Skipping insertion.
# Document with pkg_name 'com.hcom.android' already exists. Skipping insertion.
# Document with pkg_name 'ru.mail.mailapp' already exists. Skipping insertion.
# Document with pkg_name 'com.vingle.android' already exists. Skipping insertion.
# Document with pkg_name 'com.baseapp.eyeem' already exists. Skipping insertion.
# Document with pkg_name 'de.equinux.tvproapp.tvpro' already exists. Skipping insertion.
# Document with pkg_name 'com.mohammed.remembermyparking' already exists. Skipping insertion.
# Document with pkg_name 'com.aheqab.memoryinfoforwear' already exists. Skipping insertion.
# Document with pkg_name 'au.com.dominos.olo.android.app' already exists. Skipping insertion.
# Document with pkg_name 'me.thomasvt.brightness' already exists. Skipping insertion.
# Document with pkg_name 'org.iplatform.android.phone2' already exists. Skipping insertion.
# Document with pkg_name 'com.contapps.android.merger' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearsleepmode' already exists. Skipping insertion.
# Document with pkg_name 'wearablesoftware.wearsysteminfo' already exists. Skipping insertion.
# Document with pkg_name 'au.com.penguinapps.android.babyfeeding.client.android' already exists. Skipping insertion.
# Document with pkg_name 'com.todoist' already exists. Skipping insertion.
# Document with pkg_name 'nl.jacobras.notes' already exists. Skipping insertion.
# Document with pkg_name 'info.androidx.medicine2calenf' already exists. Skipping insertion.
# Document with pkg_name 'com.RayDarLLC.rShopping' already exists. Skipping insertion.
# Document with pkg_name 'com.textra' already exists. Skipping insertion.
# Document with pkg_name 'se.soderstrom.runbit' already exists. Skipping insertion.
# Document with pkg_name 'me.denley.wearwifimanager' already exists. Skipping insertion.
# Document with pkg_name 'tuxerito.wear.calendar' already exists. Skipping insertion.
# Document with pkg_name 'tuxerito.wear.chronometer' already exists. Skipping insertion.
# Document with pkg_name 'mobi.byss.instaweather.watchface' already exists. Skipping insertion.
# Document with pkg_name 'rocketstartups.wearcoinflipper' already exists. Skipping insertion.
# Document with pkg_name 'de.j4velin.delayedlock2.trial' already exists. Skipping insertion.
# Document with pkg_name 'rocketstartups.weardiceroller' already exists. Skipping insertion.
# Document with pkg_name 'com.miruker.qcontact' already exists. Skipping insertion.
# Document with pkg_name 'com.barkside.ipcam' already exists. Skipping insertion.
# Document with pkg_name 'ch.publisheria.bring' already exists. Skipping insertion.
# Document with pkg_name 'net.waynepiekarski.android.samples.opengl' already exists. Skipping insertion.
# Document with pkg_name 'com.mydiabetes' already exists. Skipping insertion.
# Document with pkg_name 'com.cuberob.weartasker' already exists. Skipping insertion.
# Document with pkg_name 'mohammad.adib.wlock' already exists. Skipping insertion.
# Document with pkg_name 'mobi.infolife.ezweather' already exists. Skipping insertion.
# Document with pkg_name 'com.capitainetrain.android' already exists. Skipping insertion.
# Document with pkg_name 'com.levelup.brightweather' already exists. Skipping insertion.
# Document with pkg_name 'com.anddoes.notifier' already exists. Skipping insertion.
# Document with pkg_name 'org.codechimp.qrwear' already exists. Skipping insertion.
# Document with pkg_name 'hu.rycus.tweetwear' already exists. Skipping insertion.
# Document with pkg_name 'com.rimidalv.dictaphone' already exists. Skipping insertion.
# Document with pkg_name 'com.barkside.music' already exists. Skipping insertion.
# Document with pkg_name 'net.micene.minigroup.workingtime' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.wearbrowser' already exists. Skipping insertion.
# Document with pkg_name 'ie.appz.dartwear' already exists. Skipping insertion.
# Document with pkg_name 'com.notjust4time.coffeetimeforwear' already exists. Skipping insertion.
# Document with pkg_name 'com.strava' already exists. Skipping insertion.
# Document with pkg_name 'com.kochar.volumecontrol' already exists. Skipping insertion.
# Document with pkg_name 'com.citymapper.app.release' already exists. Skipping insertion.
# Document with pkg_name 'com.cafedered.praiasdegalicia' already exists. Skipping insertion.
# Document with pkg_name 'com.banasiak.coinflip' already exists. Skipping insertion.
# Document with pkg_name 'rocketstartups.wearflashlight' already exists. Skipping insertion.
# Document with pkg_name 'com.abzdev.confcalldialerstd' already exists. Skipping insertion.
# Document with pkg_name 'com.trello' already exists. Skipping insertion.
# Document with pkg_name 'de.komoot.android' already exists. Skipping insertion.
# Document with pkg_name 'com.textmeinc.textme' already exists. Skipping insertion.
# Document with pkg_name 'rocketstartups.wearcalculator' already exists. Skipping insertion.
# Document with pkg_name 'com.ninefolders.hd3' already exists. Skipping insertion.
# Document with pkg_name 'com.delta.mobile.android' already exists. Skipping insertion.
# Document with pkg_name 'com.wearablewidgets' already exists. Skipping insertion.
# Document with pkg_name 'com.augmentra.viewranger.android' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.keep' already exists. Skipping insertion.
# Document with pkg_name 'com.businessslacks.ringremote' already exists. Skipping insertion.
# Document with pkg_name 'com.zumper.rentals' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.diamondelegance' already exists. Skipping insertion.
# Document with pkg_name 'com.bosenko.watchface.marinecommander' already exists. Skipping insertion.
# Document with pkg_name 'com.healthyface.android.wearable.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.dogs' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.faceify' already exists. Skipping insertion.
# Document with pkg_name 'huskydev.android.watchface.christmas2' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.carbongears' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.oreo' already exists. Skipping insertion.
# Document with pkg_name 'de.freal.neonface' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.city' already exists. Skipping insertion.
# Document with pkg_name 'com.atektura.analogglowlitewatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.shockrreveal' already exists. Skipping insertion.
# Document with pkg_name 'com.smartartstudios.digitalforcefree.interactive.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.commandwear.android' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.meshreveal' already exists. Skipping insertion.
# Document with pkg_name 'com.goonzmobile.wear.dx1watchface' already exists. Skipping insertion.
# Document with pkg_name 'watch.richface.androidwear.valiant' already exists. Skipping insertion.
# Document with pkg_name 'watch.richface.androidwear.armada2' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.digigears' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.dashinggears' already exists. Skipping insertion.
# Document with pkg_name 'com.smartartstudios.extremefree.interactive.watchface' already exists. Skipping insertion.
# Document with pkg_name 'me.fomand.nautiluswatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.smartartstudios.halloweensfree.interactive.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.smartartstudios.minimusfree.interactive.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.smartartstudios.regal.interactive.wearnew.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.boldgears' already exists. Skipping insertion.
# Document with pkg_name 'watch.richface.androidwear.timegate' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.meshgears' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.electroplasma' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.mechanigears' already exists. Skipping insertion.
# Document with pkg_name 'com.zadocgames.watchfacerysilver' already exists. Skipping insertion.
# Document with pkg_name 'com.sebcano.bewiwatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.carbonfiber' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.facefx' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.woodengears' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.animatedabstract' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.faceie' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.sports' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.classyelegance' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.darkelegance' already exists. Skipping insertion.
# Document with pkg_name 'de.uschonha.roman.watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.watchlife.appdev.watchlife' already exists. Skipping insertion.
# Document with pkg_name 'com.radefffactory.cleanwatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.magictools.pariswatch' already exists. Skipping insertion.
# Document with pkg_name 'monte.morsewatch' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.timeracer' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.hindugod' already exists. Skipping insertion.
# Document with pkg_name 'pifox.watchface.materialclock' already exists. Skipping insertion.
# Document with pkg_name 'org.trypticon.android.love39watchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.darkshockr' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.jesus' already exists. Skipping insertion.
# Document with pkg_name 'huskydev.android.watchface.photo' already exists. Skipping insertion.
# Document with pkg_name 'com.paulserver.spacestarswatchface' already exists. Skipping insertion.
# Document with pkg_name 'watch.richface.androidwear.fury' already exists. Skipping insertion.
# Document with pkg_name 'huskydev.android.watchface.info' already exists. Skipping insertion.
# Document with pkg_name 'com.brohkahn.omegawatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.metallex' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.leathershockr' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.mysticspinner' already exists. Skipping insertion.
# Document with pkg_name 'watch.richface.androidwear.digitalvision' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.brushedwood' already exists. Skipping insertion.
# Document with pkg_name 'jp.ceres_inc.watch.app7' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.art' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.space' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.nature' already exists. Skipping insertion.
# Document with pkg_name 'com.mrs.simpledark_watchface_digital' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.love' already exists. Skipping insertion.
# Document with pkg_name 'com.rimion.programmerswatchface' already exists. Skipping insertion.
# Document with pkg_name 'fun.droid.appwf.nation' already exists. Skipping insertion.
# Document with pkg_name 'com.faltenreich.watchcraft' already exists. Skipping insertion.
# Document with pkg_name 'net.loves8bit.qrclock' already exists. Skipping insertion.
# Document with pkg_name 'com.fruit4droid.cronosurfsoccer' already exists. Skipping insertion.
# Document with pkg_name 'com.whereismytrain.android' already exists. Skipping insertion.
# Document with pkg_name 'com.stylingandroid.something.oclock' already exists. Skipping insertion.
# Document with pkg_name 'com.peppyworks.starkwatchface' already exists. Skipping insertion.
# Document with pkg_name 'jp.ceres_inc.watch.app1' already exists. Skipping insertion.
# Document with pkg_name 'jp.ceres_inc.watch.app5' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.blackmetal2' already exists. Skipping insertion.
# Document with pkg_name 'com.tbirkas.efflux' already exists. Skipping insertion.
# Document with pkg_name 'com.sspai.cuto.android' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.galaxyglow' already exists. Skipping insertion.
# Document with pkg_name 'com.watch.richface.smartdrive' already exists. Skipping insertion.
# Document with pkg_name 'com.fruit4droid.cronosurf' already exists. Skipping insertion.
# Document with pkg_name 'com.kjsk.watchface.watch1000' already exists. Skipping insertion.
# Document with pkg_name 'com.moyinoluwa.yorubawatchfaces' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.simplefuzion' already exists. Skipping insertion.
# Document with pkg_name 'com.watch.richface.guard' already exists. Skipping insertion.
# Document with pkg_name 'huskydev.android.watchface.everydayfree' already exists. Skipping insertion.
# Document with pkg_name 'com.gmail.maxdiland.firstwatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.daringcarbon' already exists. Skipping insertion.
# Document with pkg_name 'pl.brostudio.soccerlite' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.daringgraphite' already exists. Skipping insertion.
# Document with pkg_name 'com.inductiveconcepts.wearable.mandalafaces' already exists. Skipping insertion.
# Document with pkg_name 'fr.yochi376.glowwatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.github.premnirmal.patagonia' already exists. Skipping insertion.
# Document with pkg_name 'com.teragon.koiwf' already exists. Skipping insertion.
# Document with pkg_name 'droidnexustech.mursiwatchface' already exists. Skipping insertion.
# Document with pkg_name 'com.denite.watchface.polishedstyle' already exists. Skipping insertion.
# Document with pkg_name 'com.microsoft.office.outlook' already exists. Skipping insertion.
# Document with pkg_name 'com.watch.richface.power' already exists. Skipping insertion.
# Document with pkg_name 'co.slashware.pixelworldwatch' already exists. Skipping insertion.
# Document with pkg_name 'huskydev.android.watchface.atlas' already exists. Skipping insertion.
# ...
# Document with pkg_name 'com.vagaroba.mmc' already exists. Skipping insertion.
# Document with pkg_name 'kr.fitt.fmes' already exists. Skipping insertion.
# Document with pkg_name 'relationship.questions.couples.therapy' already exists. Skipping insertion.
# Document with pkg_name 'com.sweat.handsome.workout.useful' already exists. Skipping insertion.
# Document with pkg_name 'org.itsasoftware.vibrator' already exists. Skipping insertion.
# Document with pkg_name 'ie.zappy.fennec.gnarlybsbikes' already exists. Skipping insertion.
# Document with pkg_name 'com.lindorawellness' already exists. Skipping insertion.
# Document with pkg_name 'com.my.jump.lab' already exists. Skipping insertion.
# Document with pkg_name 'com.quietpunch.boxingforall' already exists. Skipping insertion.
# Document with pkg_name 'com.sn.santyl' already exists. Skipping insertion.
# Document with pkg_name 'com.fitmama' already exists. Skipping insertion.
# Document with pkg_name 'com.fixfit_fitness.twa' already exists. Skipping insertion.
# Document with pkg_name 'com.arketa.sukhayogaaustin' already exists. Skipping insertion.
# Document with pkg_name 'com.codergram.itrainer' already exists. Skipping insertion.
# Document with pkg_name 'uk.org.stem4.worthwarrior' already exists. Skipping insertion.
# Document with pkg_name 'ie.zappy.fennec.threeform' already exists. Skipping insertion.
# Document with pkg_name 'com.bloodpressure.healthmonitor' already exists. Skipping insertion.
# Document with pkg_name 'com.ribbon.theyogastudioapp' already exists. Skipping insertion.
# Document with pkg_name 'com.studioyou.iamyoga' already exists. Skipping insertion.
# Document with pkg_name 'com.arketa.jamiegfitness' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.valley' already exists. Skipping insertion.
# Document with pkg_name 'com.trainerize.grindafitness' already exists. Skipping insertion.
# Document with pkg_name 'fit.remotecoach.kaylag' already exists. Skipping insertion.
# Document with pkg_name 'com.afalia.gundryhealth' already exists. Skipping insertion.
# Document with pkg_name 'com.monitorbloodpressure.checkbloodpressure' already exists. Skipping insertion.
# Document with pkg_name 'com.thestrainapp.bonsai' already exists. Skipping insertion.
# Document with pkg_name 'com.pushpress.punchkingfitnesssunset' already exists. Skipping insertion.
# Document with pkg_name 'generations.health.club' already exists. Skipping insertion.
# Document with pkg_name 'xwatch.loveandsports' already exists. Skipping insertion.
# Document with pkg_name 'com.arketa.anamcara' already exists. Skipping insertion.
# Document with pkg_name 'com.arketa.sweatystudio' already exists. Skipping insertion.
# Document with pkg_name 'com.kondeneenen.animalwalk' already exists. Skipping insertion.
# Document with pkg_name 'com.mycompany.kindgym' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.rolla' already exists. Skipping insertion.
# Document with pkg_name 'com.trainerize.outlawfitcamp' already exists. Skipping insertion.
# Document with pkg_name 'com.gpstuner.tqapp' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.mtcarmel' already exists. Skipping insertion.
# Document with pkg_name 'com.appwarecloud.weightlossworkout' already exists. Skipping insertion.
# Document with pkg_name 'ro.dentalverse.app' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.avera' already exists. Skipping insertion.
# Document with pkg_name 'com.pole.plus' already exists. Skipping insertion.
# Document with pkg_name 'com.healthdiary.bloodpressure.allfree' already exists. Skipping insertion.
# Document with pkg_name 'mass.treatment.ruqya' already exists. Skipping insertion.
# Document with pkg_name 'com.fitofitness.yoga_all_2022' already exists. Skipping insertion.
# Document with pkg_name 'com.mysalesforce.mycommunity.C00D36000001HooSEAS.A0OT1R000000GmaKWAS' already exists. Skipping insertion.
# Document with pkg_name 'com.Hybroes.Hybroes' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.fivetownswellness' already exists. Skipping insertion.
# Document with pkg_name 'com.linkntech.thibodaux' already exists. Skipping insertion.
# Document with pkg_name 'com.ribbon.studio50' already exists. Skipping insertion.
# Document with pkg_name 'com.groupnos.openfitapp' already exists. Skipping insertion.
# Document with pkg_name 'com.aiwisdom.mentalhealth' already exists. Skipping insertion.
# Document with pkg_name 'com.marianatek.cbfit' already exists. Skipping insertion.
# Document with pkg_name 'com.bharatambulance.user' already exists. Skipping insertion.
# Document with pkg_name 'com.teampenguin.alphaface' already exists. Skipping insertion.
# Document with pkg_name 'com.bluehealth.longevity' already exists. Skipping insertion.
# Document with pkg_name 'com.breakthroughapps.structuralelement' already exists. Skipping insertion.
# Document with pkg_name 'com.aniketkadam.emotionwheel' already exists. Skipping insertion.
# Document with pkg_name 'com.fitnessmobileapps.elevate35253' already exists. Skipping insertion.
# Document with pkg_name 'ie.zappy.fennec.silverfoxjiujitsu' already exists. Skipping insertion.
# Document with pkg_name 'edu.aku.onehealthlive' already exists. Skipping insertion.
# Document with pkg_name 'com.airestudios.asdp' already exists. Skipping insertion.
# Document with pkg_name 'com.trainerize.ufit12' already exists. Skipping insertion.
# Document with pkg_name 'com.sheerme.app' already exists. Skipping insertion.
# Document with pkg_name 'calorie.pedo.fitbit' already exists. Skipping insertion.
# Document with pkg_name 'com.huami.watch.hmwatchmanager' already exists. Skipping insertion.
# Document with pkg_name 'com.crrepa.band.dafit' already exists. Skipping insertion.
# Document with pkg_name 'com.abhijitvalluri.android.fitnotifications' already exists. Skipping insertion.
# Document with pkg_name 'com.samsung.android.app.watchmanager' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.gtu' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.explore' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.golf' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.connectiq' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.gecko' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.messenger' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.marine' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.clipboard' already exists. Skipping insertion.
# Document with pkg_name 'com.delorme.earthmate' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.phonelink' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.apps.virb' already exists. Skipping insertion.
# Document with pkg_name 'com.garmin.android.driveapp.dezl' already exists. Skipping insertion.
# Document with pkg_name 'com.h2sync.android.h2syncapp' already exists. Skipping insertion.
# Document with pkg_name 'md.your' already exists. Skipping insertion.
# Document with pkg_name 'com.oneplus.health.international' already exists. Skipping insertion.
# Document with pkg_name 'com.huawei.colorbands' already exists. Skipping insertion.
# Document with pkg_name 'com.huawei.band6.app812522998789' already exists. Skipping insertion.
# Document with pkg_name 'com.huaweiband7.watchfaces' already exists. Skipping insertion.
# Document with pkg_name 'com.huaweiband7.faces' already exists. Skipping insertion.
# Document with pkg_name 'com.huaweiwatch.band8' already exists. Skipping insertion.
# Document with pkg_name 'com.huaweiband9fitnessappadvice.kantundev' already exists. Skipping insertion.
# Document with pkg_name 'com.minootechapps.huaweiband7watchappguide' already exists. Skipping insertion.
# Document with pkg_name 'com.minootechapps.huaweiband4appguide' already exists. Skipping insertion.
# Document with pkg_name 'com.rosamodza.huaweiband6appadvice' already exists. Skipping insertion.
# Document with pkg_name 'com.starwatchfaces.huawei' already exists. Skipping insertion.
# Document with pkg_name 'com.telvonia.huaweiband9appadvice' already exists. Skipping insertion.
# Document with pkg_name 'asn.ark.miband5' already exists. Skipping insertion.
# Document with pkg_name 'com.rarejava.mibandfinder' already exists. Skipping insertion.
# Document with pkg_name 'asn.ark.miband8' already exists. Skipping insertion.
# Document with pkg_name 'ee.aegrel.gadgetbridge' already exists. Skipping insertion.
# Document with pkg_name 'asn.ark.miband6' already exists. Skipping insertion.
# Document with pkg_name 'paolo4c.mb4.watchfaces' already exists. Skipping insertion.
# Document with pkg_name 'paolo4c.mb6.watchfaces' already exists. Skipping insertion.
# Document with pkg_name 'com.weaponoid.miband6' already exists. Skipping insertion.
# Document with pkg_name 'asn.ark.miband7' already exists. Skipping insertion.
# Document with pkg_name 'com.xiaomi.smarthome' already exists. Skipping insertion.
# Document with pkg_name 'paolo4c.mb7.watchfaces' already exists. Skipping insertion.
# Document with pkg_name 'paolo4c.mb5.watchfaces' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.tachyon' already exists. Skipping insertion.
# Document with pkg_name 'com.facebook.katana' already exists. Skipping insertion.
# Document with pkg_name 'com.instagram.android' already exists. Skipping insertion.
# Document with pkg_name 'com.facebook.orca' already exists. Skipping insertion.
# Document with pkg_name 'com.netflix.mediaclient' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.maps' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.youtube.music' already exists. Skipping insertion.
# Document with pkg_name 'com.mi.health' already exists. Skipping insertion.
# Document with pkg_name 'com.heytap.health.international' already exists. Skipping insertion.
# Document with pkg_name 'com.infinitygames.loopenergy' already exists. Skipping insertion.
# Document with pkg_name 'app.retro.cactusclassic' already exists. Skipping insertion.
# Document with pkg_name 'app.retro.cactusgame' already exists. Skipping insertion.
# Document with pkg_name 'app.retro.carcrash' already exists. Skipping insertion.
# Document with pkg_name 'app.retro.tunnelracer' already exists. Skipping insertion.
# Document with pkg_name 'by.golubov.circle_ping_pong' already exists. Skipping insertion.
# Document with pkg_name 'com.companyname.galaxylogicgame.mobile' already exists. Skipping insertion.
# Document with pkg_name 'com.fastsoft.game2048w' already exists. Skipping insertion.
# Document with pkg_name 'com.foxxymobile.singletapgames' already exists. Skipping insertion.
# Document with pkg_name 'com.infinitygames.connection' already exists. Skipping insertion.
# Document with pkg_name 'com.infinitygames.loophex' already exists. Skipping insertion.
# Document with pkg_name 'com.infinitygames.shapes' already exists. Skipping insertion.
# Document with pkg_name 'com.nosixfive.nemesis' already exists. Skipping insertion.
# Document with pkg_name 'com.tocapp.letoff' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.apps.chromecast.app' already exists. Skipping insertion.
# Document with pkg_name 'com.audible.application' already exists. Skipping insertion.
# Document with pkg_name 'com.soundcloud.android' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.inputmethod.latin' already exists. Skipping insertion.
# Document with pkg_name 'com.coffeebeanventures.easyvoicerecorder' already exists. Skipping insertion.
# Document with pkg_name 'apps.r.calculator' already exists. Skipping insertion.
# Document with pkg_name 'com.appfour.wearstopwatch' already exists. Skipping insertion.
# Document with pkg_name 'com.zoho.notebook' already exists. Skipping insertion.
# Document with pkg_name 'yducky.application.babytime' already exists. Skipping insertion.
# Document with pkg_name 'todolist.scheduleplanner.dailyplanner.todo.reminders' already exists. Skipping insertion.
# Document with pkg_name 'apps.r.compass' already exists. Skipping insertion.
# Document with pkg_name 'co.unstatic.habitify' already exists. Skipping insertion.
# Document with pkg_name 'com.kemasdimas.wristcamera' already exists. Skipping insertion.
# Document with pkg_name 'com.flightradar24free' already exists. Skipping insertion.
# Document with pkg_name 'aplicacion.tiempo' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.contacts' already exists. Skipping insertion.
# Document with pkg_name 'com.windyty.android' already exists. Skipping insertion.
# Document with pkg_name 'com.juventus.app.android' already exists. Skipping insertion.
# Document with pkg_name 'grit.storytel.app' already exists. Skipping insertion.
# Document with pkg_name 'com.customsolutions.android.alexa' already exists. Skipping insertion.
# Document with pkg_name 'com.amazon.dee.alexaonwearos' already exists. Skipping insertion.
# Document with pkg_name 'com.codverter.wearflashlight' already exists. Skipping insertion.
# Document with pkg_name 'com.fsoydan.howistheweather' already exists. Skipping insertion.
# Document with pkg_name 'com.furyapps.scoreswidget' already exists. Skipping insertion.
# Document with pkg_name 'com.jee.calc' already exists. Skipping insertion.
# Document with pkg_name 'com.joyreading.wehear' already exists. Skipping insertion.
# Document with pkg_name 'lunosoftware.nbascores' already exists. Skipping insertion.
# Document with pkg_name 'no.nrk.yr' already exists. Skipping insertion.
# Document with pkg_name 'com.amazon.mp3' already exists. Skipping insertion.
# Document with pkg_name 'com.radio.pocketfm' already exists. Skipping insertion.
# Document with pkg_name 'com.krisdb.wearcasts' already exists. Skipping insertion.
# Document with pkg_name 'com.vlv.aravali' already exists. Skipping insertion.
# Document with pkg_name 'com.wikiloc.wikilocandroid' already exists. Skipping insertion.
# Document with pkg_name 'com.golfbuddy.smartcaddie' already exists. Skipping insertion.
# Document with pkg_name 'com.razeeman.util.simpletimetracker' already exists. Skipping insertion.
# Document with pkg_name 'com.selfcare.diary.mood.tracker.moodpress' already exists. Skipping insertion.
# Document with pkg_name 'com.windkracht8.wearmusicplayer' already exists. Skipping insertion.
# Document with pkg_name 'com.woocommerce.android' already exists. Skipping insertion.
# Document with pkg_name 'de.cprosoft.navship' already exists. Skipping insertion.
# Document with pkg_name 'de.crysxd.octoapp' already exists. Skipping insertion.
# Document with pkg_name 'com.sec.android.app.sbrowser' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.dialer' already exists. Skipping insertion.
# Document with pkg_name 'jp.naver.line.android' already exists. Skipping insertion.
# Document with pkg_name 'com.kakao.talk' already exists. Skipping insertion.
# Document with pkg_name 'com.toursprung.bikemap' already exists. Skipping insertion.
# Document with pkg_name 'com.anydo' already exists. Skipping insertion.
# Document with pkg_name 'com.squarevalley.i8birdies' already exists. Skipping insertion.
# Document with pkg_name 'com.google.android.calendar' already exists. Skipping insertion.
# Document with pkg_name 'calendar.agenda.calendarplanner.agendaplanner' already exists. Skipping insertion.
# Document with pkg_name 'com.burockgames.timeclocker' already exists. Skipping insertion.
# Document with pkg_name 'com.superelement.pomodoro' already exists. Skipping insertion.
# Document with pkg_name 'com.ifttt.ifttt' already exists. Skipping insertion.
# Document with pkg_name 'com.nhn.android.calendar' already exists. Skipping insertion.
# Document with pkg_name 'com.ticktick.task' already exists. Skipping insertion.
# Document with pkg_name 'prox.lab.calclock' already exists. Skipping insertion.
