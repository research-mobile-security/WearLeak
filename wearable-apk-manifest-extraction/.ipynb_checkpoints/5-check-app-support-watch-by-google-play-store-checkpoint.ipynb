# %%
from pymongo import MongoClient
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import os
import time

# %%
def connect_mongodb(uri,db_name, collection_name):
    # Connect to MongoDB 
    client = MongoClient(uri)
    
    # Select the database and collection
    db = client[db_name]
    collection = db[collection_name]
    
    return collection
def query_mongodb(collection, query, fields=None):
    """
    Queries the MongoDB collection and returns specific fields or all fields if no specific ones are provided.
    
    Args:
        collection: The MongoDB collection object.
        query (dict): The query to filter documents.
        fields (list): List of fields to return from the query. If None, all fields are returned.
    
    Returns:
        result: List of documents with the specified fields or all fields.
    """
    # If fields is None, return all fields
    if fields:
        # Return only the specified fields
        projection = {field: 1 for field in fields}
    else:
        # Return all fields
        projection = None
    
    # Perform the query
    result = collection.find(query, projection)
    
    # Convert the cursor to a list and return
    return list(result)
def update_mongo_fields(collection, query_filter, update_fields):
    """
    Update one or more fields in a MongoDB collection.

    Parameters:
    - collection: The MongoDB collection object.
    - query_filter: A dictionary specifying the filter to select documents.
    - update_fields: A dictionary of fields to be updated, with keys as field names and values as the new values.

    Example:
    update_mongo_fields(
        collection=your_collection,
        query_filter={'_id': 'in.codeseed.audify'},
        update_fields={'apkfile_name': 'new_name.apk', 'extract_manifest': 'UPDATED'}
    )
    """
    # Print query filter for debugging
    print(f"Query filter: {query_filter}")

    # Prepare the update object with $set to update only the specified fields
    update_query = {"$set": update_fields}

    # Perform the update in the collection
    result = collection.update_many(query_filter, update_query)

    # Check if anything was matched or updated
    if result.matched_count == 0:
        print("No documents matched the filter.")
    if result.modified_count == 0 and result.matched_count > 0:
        print("Documents matched but none were updated (maybe no fields were changed).")
    
    # Print out the result of the update
    print(f"Matched {result.matched_count} document(s), updated {result.modified_count} document(s).")

def check_value_in_array(value, array):
    if value in array:
        return 1
    else:
        return 0

# %%
mongoDB_uri = 'mongodb://localhost:27017'
mongoDB_database = 'wearable-project' 
# mongoDB_collection = 'wearable-app'
# standalone
mongoDB_collection = 'wearable-standalone'

# %%
# 1. Setup selenium
chromedriver = 'chromedriver.exe'
os.environ["webdriver.chrome.driver"] = chromedriver
chrome_options = Options()
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_argument("--disable-popup-blocking")
chrome_options.add_argument('--ignore-ssl-errors=yes')
chrome_options.add_argument('--ignore-certificate-errors')
chrome_options.add_argument('--allow-running-insecure-content')
chrome_options.add_argument('--no-proxy-server')
# Prevent first-time setup and use a fresh Chrome profile
chrome_options.add_argument("user-data-dir=/tmp/selenium")
chrome_options.add_argument("--no-first-run")
chrome_options.add_argument("--no-default-browser-check")
chrome_options.add_argument("--disable-search-engine-choice-screen")
prefs = {
    'profile.default_content_setting_values.automatic_downloads': 1,
    "download.default_directory": "",
    'profile.default_content_setting_values.popups': 0,
    'profile.default_content_setting_values.notifications': 2,
    "profile.default_content_setting_values.geolocation": 2,
    "profile.default_content_setting_values.media_stream": 2,
    "profile.default_content_setting_values.cookies": 2,
    "profile.default_content_setting_values.javascript": 1,
    "profile.default_content_setting_values.plugins": 1,
    "profile.default_content_setting_values.fullscreen": 2,
    'profile.default_content_setting_values.automatic_downloads': 1,
    'profile.default_content_settings.popups': 0,
    'profile.default_content_setting_values.default_search_engine_id': 1,
    'profile.default_content_setting_values.prompt_for_download': False,
    'profile': {'default_content_setting_values': {'search_suggest_enabled': False}},
    'intl.accept_languages': 'en,en_US',
    'first_run': False,
    'browser.startup.page': 0,
    'browser.startup.homepage': 'about:blank',
}
chrome_options.add_experimental_option("prefs", prefs)

# %%
# Connect to the MongoDB collection
collection = connect_mongodb(mongoDB_uri,mongoDB_database,mongoDB_collection)
# Specify the fields you want to return (e.g., '_id', 'apkfile_name')
fields = ['_id']

# Fetch the specified fields only
result = query_mongodb(collection,None, fields)

# Print the result (this will contain only '_id' and 'apkfile_name')
#print(result)
# 0 - 884
for i in range(len(result)):
    print("-----------------Loop-"+str(i)+"-----------------")
    pkg_name = result[i]['_id']
    print("pkg_name: ",pkg_name)
    web = webdriver.Chrome(options=chrome_options)
    web.maximize_window()
    apk_path = "https://play.google.com/store/apps/details?id="+pkg_name
    print("apk_path",apk_path)
    web.get(apk_path)
    time.sleep(2)
    #
    try:
        error_element = web.find_element(By.ID, "error-section")
        error_text = error_element.text
        if(error_text=="We're sorry, the requested URL was not found on this server."):
            print("APK not found")
            update_mongo_fields(
                    collection, 
                    {'_id': str(pkg_name)}, 
                    {'ggplaystore': 'Not Found'}
                )
            web.close()
            continue
    except NoSuchElementException:
        support_lists=web.find_elements(By.CSS_SELECTOR,"span[class='ypTNYd']")
        print(len(support_lists))
        if len(support_lists)>0:
            support_array = []
            for i in range(len(support_lists)):
                support_name=web.find_elements(By.CSS_SELECTOR,"span[class='ypTNYd']")[i].text
                support_array.append(support_name)
            print("support_array:", support_array)
            if(check_value_in_array('Watch', support_array)==1):
                update_mongo_fields(
                    collection, 
                    {'_id': str(pkg_name)}, 
                    {'ggplaystore': 'Yes'}
                )
            else:
                update_mongo_fields(
                    collection, 
                    {'_id': str(pkg_name)}, 
                    {'ggplaystore': 'No'}
                )
            web.close()
        else:
            update_mongo_fields(
                    collection, 
                    {'_id': str(pkg_name)}, 
                    {'ggplaystore': 'No'}
                )
            web.close()
    #break
# Out:
# -----------------Loop-0-----------------
# pkg_name:  in.codeseed.audify
# apk_path https://play.google.com/store/apps/details?id=in.codeseed.audify
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'in.codeseed.audify'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-1-----------------
# pkg_name:  com.urbandroid.lux
# apk_path https://play.google.com/store/apps/details?id=com.urbandroid.lux
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.urbandroid.lux'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-2-----------------
# pkg_name:  maxcom.toolbox.altimeter
# apk_path https://play.google.com/store/apps/details?id=maxcom.toolbox.altimeter
# 6
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'maxcom.toolbox.altimeter'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-3-----------------
# pkg_name:  com.reflive.reflive
# apk_path https://play.google.com/store/apps/details?id=com.reflive.reflive
# APK not found
# Query filter: {'_id': 'com.reflive.reflive'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-4-----------------
# pkg_name:  com.tomtop.smart
# apk_path https://play.google.com/store/apps/details?id=com.tomtop.smart
# APK not found
# Query filter: {'_id': 'com.tomtop.smart'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-5-----------------
# pkg_name:  com.mauriciotogneri.shoppinglist
# apk_path https://play.google.com/store/apps/details?id=com.mauriciotogneri.shoppinglist
# 0
# Query filter: {'_id': 'com.mauriciotogneri.shoppinglist'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-6-----------------
# pkg_name:  com.szyk.myheart
# apk_path https://play.google.com/store/apps/details?id=com.szyk.myheart
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.szyk.myheart'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-7-----------------
# pkg_name:  interactiveshift.com.trailswear
# apk_path https://play.google.com/store/apps/details?id=interactiveshift.com.trailswear
# APK not found
# Query filter: {'_id': 'interactiveshift.com.trailswear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-8-----------------
# pkg_name:  com.atlaswearables.ionic
# apk_path https://play.google.com/store/apps/details?id=com.atlaswearables.ionic
# APK not found
# Query filter: {'_id': 'com.atlaswearables.ionic'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-9-----------------
# pkg_name:  je.fit
# apk_path https://play.google.com/store/apps/details?id=je.fit
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'je.fit'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-10-----------------
# pkg_name:  com.acquasys.contrack
# apk_path https://play.google.com/store/apps/details?id=com.acquasys.contrack
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.acquasys.contrack'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-11-----------------
# pkg_name:  com.daniel.apps.wpe
# apk_path https://play.google.com/store/apps/details?id=com.daniel.apps.wpe
# APK not found
# Query filter: {'_id': 'com.daniel.apps.wpe'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-12-----------------
# pkg_name:  net.ddns.axiiim.wearphonelock
# apk_path https://play.google.com/store/apps/details?id=net.ddns.axiiim.wearphonelock
# APK not found
# Query filter: {'_id': 'net.ddns.axiiim.wearphonelock'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-13-----------------
# pkg_name:  org.uguess.android.sysinfo.wear
# apk_path https://play.google.com/store/apps/details?id=org.uguess.android.sysinfo.wear
# APK not found
# Query filter: {'_id': 'org.uguess.android.sysinfo.wear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-14-----------------
# pkg_name:  com.ericfabreu.wearflashcards
# apk_path https://play.google.com/store/apps/details?id=com.ericfabreu.wearflashcards
# APK not found
# Query filter: {'_id': 'com.ericfabreu.wearflashcards'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-15-----------------
# pkg_name:  com.appfour.wearvideos
# apk_path https://play.google.com/store/apps/details?id=com.appfour.wearvideos
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.appfour.wearvideos'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-16-----------------
# pkg_name:  com.lilc103.buttonbattle
# apk_path https://play.google.com/store/apps/details?id=com.lilc103.buttonbattle
# 0
# Query filter: {'_id': 'com.lilc103.buttonbattle'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-17-----------------
# pkg_name:  com.overseasolutions.waterapp.app
# apk_path https://play.google.com/store/apps/details?id=com.overseasolutions.waterapp.app
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.overseasolutions.waterapp.app'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-18-----------------
# pkg_name:  tk.deuchnord.phonejuicechecker
# apk_path https://play.google.com/store/apps/details?id=tk.deuchnord.phonejuicechecker
# APK not found
# Query filter: {'_id': 'tk.deuchnord.phonejuicechecker'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-19-----------------
# pkg_name:  de.softxperience.android.quickprofiles
# apk_path https://play.google.com/store/apps/details?id=de.softxperience.android.quickprofiles
# APK not found
# Query filter: {'_id': 'de.softxperience.android.quickprofiles'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-20-----------------
# pkg_name:  com.piggeh.flip
# apk_path https://play.google.com/store/apps/details?id=com.piggeh.flip
# APK not found
# Query filter: {'_id': 'com.piggeh.flip'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-21-----------------
# pkg_name:  kr.co.openit.openrider
# apk_path https://play.google.com/store/apps/details?id=kr.co.openit.openrider
# 0
# Query filter: {'_id': 'kr.co.openit.openrider'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-22-----------------
# pkg_name:  com.naing.englishmyanmardictionary
# apk_path https://play.google.com/store/apps/details?id=com.naing.englishmyanmardictionary
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.naing.englishmyanmardictionary'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-23-----------------
# pkg_name:  com.gin.shoppinglist
# apk_path https://play.google.com/store/apps/details?id=com.gin.shoppinglist
# APK not found
# Query filter: {'_id': 'com.gin.shoppinglist'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-24-----------------
# pkg_name:  com.ccswe.SmokingLog
# apk_path https://play.google.com/store/apps/details?id=com.ccswe.SmokingLog
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.ccswe.SmokingLog'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-25-----------------
# pkg_name:  de.svz
# apk_path https://play.google.com/store/apps/details?id=de.svz
# APK not found
# Query filter: {'_id': 'de.svz'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-26-----------------
# pkg_name:  com.komparato.informer.wear
# apk_path https://play.google.com/store/apps/details?id=com.komparato.informer.wear
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.komparato.informer.wear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-27-----------------
# pkg_name:  net.sarmady.akhbarak
# apk_path https://play.google.com/store/apps/details?id=net.sarmady.akhbarak
# APK not found
# Query filter: {'_id': 'net.sarmady.akhbarak'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-28-----------------
# pkg_name:  org.sombrenuit.dk.redfeed.free
# apk_path https://play.google.com/store/apps/details?id=org.sombrenuit.dk.redfeed.free
# 0
# Query filter: {'_id': 'org.sombrenuit.dk.redfeed.free'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-29-----------------
# pkg_name:  com.glidetalk.glideapp
# apk_path https://play.google.com/store/apps/details?id=com.glidetalk.glideapp
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.glidetalk.glideapp'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-30-----------------
# pkg_name:  uk.me.andre.dicionarioportugues
# apk_path https://play.google.com/store/apps/details?id=uk.me.andre.dicionarioportugues
# 0
# Query filter: {'_id': 'uk.me.andre.dicionarioportugues'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-31-----------------
# pkg_name:  com.link.messages.sms
# apk_path https://play.google.com/store/apps/details?id=com.link.messages.sms
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.link.messages.sms'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-32-----------------
# pkg_name:  com.kiss.keeper
# apk_path https://play.google.com/store/apps/details?id=com.kiss.keeper
# APK not found
# Query filter: {'_id': 'com.kiss.keeper'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-33-----------------
# pkg_name:  com.google.android.apps.messaging
# apk_path https://play.google.com/store/apps/details?id=com.google.android.apps.messaging
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.google.android.apps.messaging'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-34-----------------
# pkg_name:  com.shinayser.xwingmanager
# apk_path https://play.google.com/store/apps/details?id=com.shinayser.xwingmanager
# APK not found
# Query filter: {'_id': 'com.shinayser.xwingmanager'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-35-----------------
# pkg_name:  com.aheqab.salahwear
# apk_path https://play.google.com/store/apps/details?id=com.aheqab.salahwear
# APK not found
# Query filter: {'_id': 'com.aheqab.salahwear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-36-----------------
# pkg_name:  com.rokontrol.android
# apk_path https://play.google.com/store/apps/details?id=com.rokontrol.android
# APK not found
# Query filter: {'_id': 'com.rokontrol.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-37-----------------
# pkg_name:  net.waynepiekarski.screeninfo
# apk_path https://play.google.com/store/apps/details?id=net.waynepiekarski.screeninfo
# 0
# Query filter: {'_id': 'net.waynepiekarski.screeninfo'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-38-----------------
# pkg_name:  com.biztech.magemobadmin
# apk_path https://play.google.com/store/apps/details?id=com.biztech.magemobadmin
# 0
# Query filter: {'_id': 'com.biztech.magemobadmin'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-39-----------------
# pkg_name:  com.skimble.workouts
# apk_path https://play.google.com/store/apps/details?id=com.skimble.workouts
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.skimble.workouts'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-40-----------------
# pkg_name:  pl.tweeba.mobile.learning.english
# apk_path https://play.google.com/store/apps/details?id=pl.tweeba.mobile.learning.english
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'pl.tweeba.mobile.learning.english'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-41-----------------
# pkg_name:  org.obduro.kentekeninfo
# apk_path https://play.google.com/store/apps/details?id=org.obduro.kentekeninfo
# 1
# support_array: ['Tablet']
# Query filter: {'_id': 'org.obduro.kentekeninfo'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-42-----------------
# pkg_name:  ru.starline
# apk_path https://play.google.com/store/apps/details?id=ru.starline
# 0
# Query filter: {'_id': 'ru.starline'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-43-----------------
# pkg_name:  jp.co.yahoo.android.vassist
# apk_path https://play.google.com/store/apps/details?id=jp.co.yahoo.android.vassist
# 0
# Query filter: {'_id': 'jp.co.yahoo.android.vassist'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-44-----------------
# pkg_name:  com.spotify.music
# apk_path https://play.google.com/store/apps/details?id=com.spotify.music
# 12
# support_array: ['Phone', 'Watch', 'TV', 'Car', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.spotify.music'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-45-----------------
# pkg_name:  oms.mmc.fortunetelling.gmpay.almanac2
# apk_path https://play.google.com/store/apps/details?id=oms.mmc.fortunetelling.gmpay.almanac2
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'oms.mmc.fortunetelling.gmpay.almanac2'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-46-----------------
# pkg_name:  com.mictale.gpsessentials
# apk_path https://play.google.com/store/apps/details?id=com.mictale.gpsessentials
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.mictale.gpsessentials'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-47-----------------
# pkg_name:  com.ktmusic.geniemusic
# apk_path https://play.google.com/store/apps/details?id=com.ktmusic.geniemusic
# 0
# Query filter: {'_id': 'com.ktmusic.geniemusic'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-48-----------------
# pkg_name:  net.familo.android
# apk_path https://play.google.com/store/apps/details?id=net.familo.android
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'net.familo.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-49-----------------
# pkg_name:  com.cpsolutions.contacts
# apk_path https://play.google.com/store/apps/details?id=com.cpsolutions.contacts
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.cpsolutions.contacts'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-50-----------------
# pkg_name:  eu.power_switch
# apk_path https://play.google.com/store/apps/details?id=eu.power_switch
# APK not found
# Query filter: {'_id': 'eu.power_switch'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-51-----------------
# pkg_name:  com.hootapps.soundrecorder
# apk_path https://play.google.com/store/apps/details?id=com.hootapps.soundrecorder
# APK not found
# Query filter: {'_id': 'com.hootapps.soundrecorder'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-52-----------------
# pkg_name:  com.directed.android.viper
# apk_path https://play.google.com/store/apps/details?id=com.directed.android.viper
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.directed.android.viper'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-53-----------------
# pkg_name:  com.adi.remote.phone
# apk_path https://play.google.com/store/apps/details?id=com.adi.remote.phone
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.adi.remote.phone'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-54-----------------
# pkg_name:  com.lucky_ponies.dokin
# apk_path https://play.google.com/store/apps/details?id=com.lucky_ponies.dokin
# APK not found
# Query filter: {'_id': 'com.lucky_ponies.dokin'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-55-----------------
# pkg_name:  com.yannik.wear.anki
# apk_path https://play.google.com/store/apps/details?id=com.yannik.wear.anki
# 7
# support_array: ['Watch', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.yannik.wear.anki'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-56-----------------
# pkg_name:  com.toshremote.view
# apk_path https://play.google.com/store/apps/details?id=com.toshremote.view
# APK not found
# Query filter: {'_id': 'com.toshremote.view'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-57-----------------
# pkg_name:  com.muzzley
# apk_path https://play.google.com/store/apps/details?id=com.muzzley
# APK not found
# Query filter: {'_id': 'com.muzzley'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-58-----------------
# pkg_name:  net.homeip.thkerkmann.einkaufsliste
# apk_path https://play.google.com/store/apps/details?id=net.homeip.thkerkmann.einkaufsliste
# APK not found
# Query filter: {'_id': 'net.homeip.thkerkmann.einkaufsliste'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-59-----------------
# pkg_name:  se.matlistan.free
# apk_path https://play.google.com/store/apps/details?id=se.matlistan.free
# 0
# Query filter: {'_id': 'se.matlistan.free'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-60-----------------
# pkg_name:  nl.birdssoftware.mondaymorning
# apk_path https://play.google.com/store/apps/details?id=nl.birdssoftware.mondaymorning
# APK not found
# Query filter: {'_id': 'nl.birdssoftware.mondaymorning'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-61-----------------
# pkg_name:  com.dusiassistant
# apk_path https://play.google.com/store/apps/details?id=com.dusiassistant
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.dusiassistant'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-62-----------------
# pkg_name:  com.pimp.calculator
# apk_path https://play.google.com/store/apps/details?id=com.pimp.calculator
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.pimp.calculator'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-63-----------------
# pkg_name:  at.radioplayer.android
# apk_path https://play.google.com/store/apps/details?id=at.radioplayer.android
# APK not found
# Query filter: {'_id': 'at.radioplayer.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-64-----------------
# pkg_name:  revox.voxnet
# apk_path https://play.google.com/store/apps/details?id=revox.voxnet
# 0
# Query filter: {'_id': 'revox.voxnet'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-65-----------------
# pkg_name:  com.nstudio.weatherhere.free
# apk_path https://play.google.com/store/apps/details?id=com.nstudio.weatherhere.free
# 0
# Query filter: {'_id': 'com.nstudio.weatherhere.free'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-66-----------------
# pkg_name:  com.dimlix.phrase
# apk_path https://play.google.com/store/apps/details?id=com.dimlix.phrase
# 1
# support_array: ['Tablet']
# Query filter: {'_id': 'com.dimlix.phrase'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-67-----------------
# pkg_name:  com.cm.wearintervaltimer
# apk_path https://play.google.com/store/apps/details?id=com.cm.wearintervaltimer
# 0
# Query filter: {'_id': 'com.cm.wearintervaltimer'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-68-----------------
# pkg_name:  com.fredmeyer.mobile
# apk_path https://play.google.com/store/apps/details?id=com.fredmeyer.mobile
# 0
# Query filter: {'_id': 'com.fredmeyer.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-69-----------------
# pkg_name:  com.pocketlifestyle.music.tune
# apk_path https://play.google.com/store/apps/details?id=com.pocketlifestyle.music.tune
# APK not found
# Query filter: {'_id': 'com.pocketlifestyle.music.tune'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-70-----------------
# pkg_name:  com.bakersplus.mobile
# apk_path https://play.google.com/store/apps/details?id=com.bakersplus.mobile
# 0
# Query filter: {'_id': 'com.bakersplus.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-71-----------------
# pkg_name:  com.dolcegustofree.activity
# apk_path https://play.google.com/store/apps/details?id=com.dolcegustofree.activity
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.dolcegustofree.activity'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-72-----------------
# pkg_name:  com.naukriGulf.app
# apk_path https://play.google.com/store/apps/details?id=com.naukriGulf.app
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.naukriGulf.app'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-73-----------------
# pkg_name:  com.qfc.mobile
# apk_path https://play.google.com/store/apps/details?id=com.qfc.mobile
# 0
# Query filter: {'_id': 'com.qfc.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-74-----------------
# pkg_name:  com.palaspro.listainteligentecompra
# apk_path https://play.google.com/store/apps/details?id=com.palaspro.listainteligentecompra
# APK not found
# Query filter: {'_id': 'com.palaspro.listainteligentecompra'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-75-----------------
# pkg_name:  com.estela
# apk_path https://play.google.com/store/apps/details?id=com.estela
# 0
# Query filter: {'_id': 'com.estela'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-76-----------------
# pkg_name:  com.k560.luciddreaminducer
# apk_path https://play.google.com/store/apps/details?id=com.k560.luciddreaminducer
# 0
# Query filter: {'_id': 'com.k560.luciddreaminducer'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-77-----------------
# pkg_name:  com.droibit.findwear
# apk_path https://play.google.com/store/apps/details?id=com.droibit.findwear
# APK not found
# Query filter: {'_id': 'com.droibit.findwear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-78-----------------
# pkg_name:  com.amdroidalarmclock.amdroid
# apk_path https://play.google.com/store/apps/details?id=com.amdroidalarmclock.amdroid
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.amdroidalarmclock.amdroid'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-79-----------------
# pkg_name:  com.mobisystems.editor.office_with_reg
# apk_path https://play.google.com/store/apps/details?id=com.mobisystems.editor.office_with_reg
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.mobisystems.editor.office_with_reg'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-80-----------------
# pkg_name:  com.frysfood.mobile
# apk_path https://play.google.com/store/apps/details?id=com.frysfood.mobile
# 0
# Query filter: {'_id': 'com.frysfood.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-81-----------------
# pkg_name:  com.mobisystems.office
# apk_path https://play.google.com/store/apps/details?id=com.mobisystems.office
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.mobisystems.office'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-82-----------------
# pkg_name:  com.kingsoopers.mobile
# apk_path https://play.google.com/store/apps/details?id=com.kingsoopers.mobile
# 0
# Query filter: {'_id': 'com.kingsoopers.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-83-----------------
# pkg_name:  com.smithsfoodanddrug.mobile
# apk_path https://play.google.com/store/apps/details?id=com.smithsfoodanddrug.mobile
# 0
# Query filter: {'_id': 'com.smithsfoodanddrug.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-84-----------------
# pkg_name:  com.aircanada
# apk_path https://play.google.com/store/apps/details?id=com.aircanada
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.aircanada'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-85-----------------
# pkg_name:  com.vivint.vivintsky
# apk_path https://play.google.com/store/apps/details?id=com.vivint.vivintsky
# 0
# Query filter: {'_id': 'com.vivint.vivintsky'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-86-----------------
# pkg_name:  fi.hhtec.coach4pro
# apk_path https://play.google.com/store/apps/details?id=fi.hhtec.coach4pro
# 0
# Query filter: {'_id': 'fi.hhtec.coach4pro'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-87-----------------
# pkg_name:  com.cisco.webex.meetings
# apk_path https://play.google.com/store/apps/details?id=com.cisco.webex.meetings
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.cisco.webex.meetings'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-88-----------------
# pkg_name:  com.kroger.mobile
# apk_path https://play.google.com/store/apps/details?id=com.kroger.mobile
# 0
# Query filter: {'_id': 'com.kroger.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-89-----------------
# pkg_name:  nl.dominos.android
# apk_path https://play.google.com/store/apps/details?id=nl.dominos.android
# 0
# Query filter: {'_id': 'nl.dominos.android'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-90-----------------
# pkg_name:  nz.co.telecom.smartphone.android
# apk_path https://play.google.com/store/apps/details?id=nz.co.telecom.smartphone.android
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'nz.co.telecom.smartphone.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-91-----------------
# pkg_name:  com.acmeaom.android.myradar
# apk_path https://play.google.com/store/apps/details?id=com.acmeaom.android.myradar
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.acmeaom.android.myradar'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-92-----------------
# pkg_name:  com.rageconsulting.android.lightflowlegacy
# apk_path https://play.google.com/store/apps/details?id=com.rageconsulting.android.lightflowlegacy
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.rageconsulting.android.lightflowlegacy'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-93-----------------
# pkg_name:  tr.com.fitwell.app
# apk_path https://play.google.com/store/apps/details?id=tr.com.fitwell.app
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'tr.com.fitwell.app'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-94-----------------
# pkg_name:  com.cisco.im
# apk_path https://play.google.com/store/apps/details?id=com.cisco.im
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.cisco.im'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-95-----------------
# pkg_name:  com.sasyabook.businesscardapp
# apk_path https://play.google.com/store/apps/details?id=com.sasyabook.businesscardapp
# 0
# Query filter: {'_id': 'com.sasyabook.businesscardapp'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-96-----------------
# pkg_name:  com.jquiz.english
# apk_path https://play.google.com/store/apps/details?id=com.jquiz.english
# APK not found
# Query filter: {'_id': 'com.jquiz.english'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-97-----------------
# pkg_name:  com.edjing.edjingdjturntable
# apk_path https://play.google.com/store/apps/details?id=com.edjing.edjingdjturntable
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.edjing.edjingdjturntable'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-98-----------------
# pkg_name:  biz.mobidev.mdplayer
# apk_path https://play.google.com/store/apps/details?id=biz.mobidev.mdplayer
# APK not found
# Query filter: {'_id': 'biz.mobidev.mdplayer'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-99-----------------
# pkg_name:  dev.niamor.wearliveboxremote
# apk_path https://play.google.com/store/apps/details?id=dev.niamor.wearliveboxremote
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'dev.niamor.wearliveboxremote'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-100-----------------
# pkg_name:  net.kosev.dicing
# apk_path https://play.google.com/store/apps/details?id=net.kosev.dicing
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'net.kosev.dicing'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-101-----------------
# pkg_name:  adarshurs.android.vlcmobileremote
# apk_path https://play.google.com/store/apps/details?id=adarshurs.android.vlcmobileremote
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'adarshurs.android.vlcmobileremote'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-102-----------------
# pkg_name:  com.pasha.music977
# apk_path https://play.google.com/store/apps/details?id=com.pasha.music977
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.pasha.music977'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-103-----------------
# pkg_name:  com.bhphoto
# apk_path https://play.google.com/store/apps/details?id=com.bhphoto
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.bhphoto'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-104-----------------
# pkg_name:  com.unated
# apk_path https://play.google.com/store/apps/details?id=com.unated
# 0
# Query filter: {'_id': 'com.unated'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-105-----------------
# pkg_name:  com.bandlab.bandlab
# apk_path https://play.google.com/store/apps/details?id=com.bandlab.bandlab
# 10
# support_array: ['Phone', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.bandlab.bandlab'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-106-----------------
# pkg_name:  com.kfaraj.notepad
# apk_path https://play.google.com/store/apps/details?id=com.kfaraj.notepad
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.kfaraj.notepad'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-107-----------------
# pkg_name:  com.SnowReport.screens
# apk_path https://play.google.com/store/apps/details?id=com.SnowReport.screens
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.SnowReport.screens'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-108-----------------
# pkg_name:  com.ubivelox.uvophone
# apk_path https://play.google.com/store/apps/details?id=com.ubivelox.uvophone
# 0
# Query filter: {'_id': 'com.ubivelox.uvophone'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-109-----------------
# pkg_name:  com.directed.android.smartstart
# apk_path https://play.google.com/store/apps/details?id=com.directed.android.smartstart
# 8
# support_array: ['Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.directed.android.smartstart'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-110-----------------
# pkg_name:  com.lf.lfvtandroid
# apk_path https://play.google.com/store/apps/details?id=com.lf.lfvtandroid
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.lf.lfvtandroid'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-111-----------------
# pkg_name:  com.moblino.simplenote
# apk_path https://play.google.com/store/apps/details?id=com.moblino.simplenote
# 0
# Query filter: {'_id': 'com.moblino.simplenote'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-112-----------------
# pkg_name:  com.overdrive.mobile.android.mediaconsole
# apk_path https://play.google.com/store/apps/details?id=com.overdrive.mobile.android.mediaconsole
# 0
# Query filter: {'_id': 'com.overdrive.mobile.android.mediaconsole'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-113-----------------
# pkg_name:  com.exovoid.weather.app.at
# apk_path https://play.google.com/store/apps/details?id=com.exovoid.weather.app.at
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.exovoid.weather.app.at'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-114-----------------
# pkg_name:  com.weightwatchers.mobile
# apk_path https://play.google.com/store/apps/details?id=com.weightwatchers.mobile
# 0
# Query filter: {'_id': 'com.weightwatchers.mobile'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-115-----------------
# pkg_name:  com.evoli.wtc_v1
# apk_path https://play.google.com/store/apps/details?id=com.evoli.wtc_v1
# APK not found
# Query filter: {'_id': 'com.evoli.wtc_v1'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-116-----------------
# pkg_name:  com.doubleTwist.cloudPlayer
# apk_path https://play.google.com/store/apps/details?id=com.doubleTwist.cloudPlayer
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.doubleTwist.cloudPlayer'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-117-----------------
# pkg_name:  com.navitime.local.naviwalk.gl
# apk_path https://play.google.com/store/apps/details?id=com.navitime.local.naviwalk.gl
# 0
# Query filter: {'_id': 'com.navitime.local.naviwalk.gl'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-118-----------------
# pkg_name:  com.ofirmiron.findmycarandroidwear
# apk_path https://play.google.com/store/apps/details?id=com.ofirmiron.findmycarandroidwear
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.ofirmiron.findmycarandroidwear'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-119-----------------
# pkg_name:  lunosoftware.nhlscores
# apk_path https://play.google.com/store/apps/details?id=lunosoftware.nhlscores
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'lunosoftware.nhlscores'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-120-----------------
# pkg_name:  jp.keita.nakamura.timetable
# apk_path https://play.google.com/store/apps/details?id=jp.keita.nakamura.timetable
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'jp.keita.nakamura.timetable'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-121-----------------
# pkg_name:  com.semaphore.login
# apk_path https://play.google.com/store/apps/details?id=com.semaphore.login
# 0
# Query filter: {'_id': 'com.semaphore.login'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-122-----------------
# pkg_name:  kr.co.smartstudy.pinkfongtv_android_googlemarket
# apk_path https://play.google.com/store/apps/details?id=kr.co.smartstudy.pinkfongtv_android_googlemarket
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'kr.co.smartstudy.pinkfongtv_android_googlemarket'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-123-----------------
# pkg_name:  com.clearskyapps.fitnessfamily.Run5K
# apk_path https://play.google.com/store/apps/details?id=com.clearskyapps.fitnessfamily.Run5K
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.clearskyapps.fitnessfamily.Run5K'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-124-----------------
# pkg_name:  com.macropinch.kaiju
# apk_path https://play.google.com/store/apps/details?id=com.macropinch.kaiju
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.macropinch.kaiju'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-125-----------------
# pkg_name:  com.exovoid.weather.app.be
# apk_path https://play.google.com/store/apps/details?id=com.exovoid.weather.app.be
# 0
# Query filter: {'_id': 'com.exovoid.weather.app.be'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-126-----------------
# pkg_name:  jp.co.excite.translate
# apk_path https://play.google.com/store/apps/details?id=jp.co.excite.translate
# APK not found
# Query filter: {'_id': 'jp.co.excite.translate'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-127-----------------
# pkg_name:  com.thetransitapp.droid
# apk_path https://play.google.com/store/apps/details?id=com.thetransitapp.droid
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.thetransitapp.droid'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-128-----------------
# pkg_name:  com.neurondigital.exercisetimer
# apk_path https://play.google.com/store/apps/details?id=com.neurondigital.exercisetimer
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.neurondigital.exercisetimer'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-129-----------------
# pkg_name:  no.nordicsemi.android.nrftoolbox
# apk_path https://play.google.com/store/apps/details?id=no.nordicsemi.android.nrftoolbox
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'no.nordicsemi.android.nrftoolbox'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-130-----------------
# pkg_name:  com.navent.realestate.inmuebles24
# apk_path https://play.google.com/store/apps/details?id=com.navent.realestate.inmuebles24
# 0
# Query filter: {'_id': 'com.navent.realestate.inmuebles24'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-131-----------------
# pkg_name:  com.opl.transitnow
# apk_path https://play.google.com/store/apps/details?id=com.opl.transitnow
# 0
# Query filter: {'_id': 'com.opl.transitnow'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-132-----------------
# pkg_name:  com.exovoid.weather.app
# apk_path https://play.google.com/store/apps/details?id=com.exovoid.weather.app
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.exovoid.weather.app'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-133-----------------
# pkg_name:  com.northpark.drinkwater
# apk_path https://play.google.com/store/apps/details?id=com.northpark.drinkwater
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.northpark.drinkwater'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-134-----------------
# pkg_name:  com.v1.v1pro
# apk_path https://play.google.com/store/apps/details?id=com.v1.v1pro
# APK not found
# Query filter: {'_id': 'com.v1.v1pro'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-135-----------------
# pkg_name:  jp.co.cybird.apps.sports.namiinfo
# apk_path https://play.google.com/store/apps/details?id=jp.co.cybird.apps.sports.namiinfo
# APK not found
# Query filter: {'_id': 'jp.co.cybird.apps.sports.namiinfo'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-136-----------------
# pkg_name:  es.popsports.sevenminute
# apk_path https://play.google.com/store/apps/details?id=es.popsports.sevenminute
# APK not found
# Query filter: {'_id': 'es.popsports.sevenminute'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-137-----------------
# pkg_name:  de.billiger.android
# ...
# Query filter: {'_id': 'com.tranzmate'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-173-----------------
# pkg_name:  com.vkontakte.android
# apk_path https://play.google.com/store/apps/details?id=com.vkontakte.android
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.vkontakte.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-174-----------------
# pkg_name:  fr.playsoft.lefigarov3
# apk_path https://play.google.com/store/apps/details?id=fr.playsoft.lefigarov3
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'fr.playsoft.lefigarov3'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-175-----------------
# pkg_name:  com.locnall.KimGiSa
# apk_path https://play.google.com/store/apps/details?id=com.locnall.KimGiSa
# 0
# Query filter: {'_id': 'com.locnall.KimGiSa'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-176-----------------
# pkg_name:  cz.shawn.antelli
# apk_path https://play.google.com/store/apps/details?id=cz.shawn.antelli
# 0
# Query filter: {'_id': 'cz.shawn.antelli'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-177-----------------
# pkg_name:  com.vsct.vsc.mobile.horaireetresa.android
# apk_path https://play.google.com/store/apps/details?id=com.vsct.vsc.mobile.horaireetresa.android
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.vsct.vsc.mobile.horaireetresa.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-178-----------------
# pkg_name:  org.codechimp.ttw
# apk_path https://play.google.com/store/apps/details?id=org.codechimp.ttw
# APK not found
# Query filter: {'_id': 'org.codechimp.ttw'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-179-----------------
# pkg_name:  com.newssynergy.nwahomepage
# apk_path https://play.google.com/store/apps/details?id=com.newssynergy.nwahomepage
# 0
# Query filter: {'_id': 'com.newssynergy.nwahomepage'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-180-----------------
# pkg_name:  com.mobileCounterPremium
# apk_path https://play.google.com/store/apps/details?id=com.mobileCounterPremium
# APK not found
# Query filter: {'_id': 'com.mobileCounterPremium'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-181-----------------
# pkg_name:  com.aovill.language.e2l.ejn
# apk_path https://play.google.com/store/apps/details?id=com.aovill.language.e2l.ejn
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.aovill.language.e2l.ejn'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-182-----------------
# pkg_name:  com.appfour.weartube
# apk_path https://play.google.com/store/apps/details?id=com.appfour.weartube
# APK not found
# Query filter: {'_id': 'com.appfour.weartube'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-183-----------------
# pkg_name:  com.yu.ivanyu.weargesturecontrol
# apk_path https://play.google.com/store/apps/details?id=com.yu.ivanyu.weargesturecontrol
# APK not found
# Query filter: {'_id': 'com.yu.ivanyu.weargesturecontrol'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-184-----------------
# pkg_name:  com.apptivateme.next.sfss
# apk_path https://play.google.com/store/apps/details?id=com.apptivateme.next.sfss
# 7
# support_array: ['Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.apptivateme.next.sfss'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-185-----------------
# pkg_name:  com.hetweer.in.nl
# apk_path https://play.google.com/store/apps/details?id=com.hetweer.in.nl
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.hetweer.in.nl'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-186-----------------
# pkg_name:  com.stationdm.genesis
# apk_path https://play.google.com/store/apps/details?id=com.stationdm.genesis
# 0
# Query filter: {'_id': 'com.stationdm.genesis'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-187-----------------
# pkg_name:  com.stt.android
# apk_path https://play.google.com/store/apps/details?id=com.stt.android
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.stt.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-188-----------------
# pkg_name:  com.plantronics.headsetservice
# apk_path https://play.google.com/store/apps/details?id=com.plantronics.headsetservice
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.plantronics.headsetservice'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-189-----------------
# pkg_name:  com.google.android.gm
# apk_path https://play.google.com/store/apps/details?id=com.google.android.gm
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.google.android.gm'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-190-----------------
# pkg_name:  lunosoftware.mlbscores
# apk_path https://play.google.com/store/apps/details?id=lunosoftware.mlbscores
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'lunosoftware.mlbscores'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-191-----------------
# pkg_name:  com.goldstar
# apk_path https://play.google.com/store/apps/details?id=com.goldstar
# 0
# Query filter: {'_id': 'com.goldstar'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-192-----------------
# pkg_name:  com.fivemobile.thescore
# apk_path https://play.google.com/store/apps/details?id=com.fivemobile.thescore
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.fivemobile.thescore'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-193-----------------
# pkg_name:  com.google.android.deskclock
# apk_path https://play.google.com/store/apps/details?id=com.google.android.deskclock
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.google.android.deskclock'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-194-----------------
# pkg_name:  com.navitime.local.navitime
# apk_path https://play.google.com/store/apps/details?id=com.navitime.local.navitime
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.navitime.local.navitime'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-195-----------------
# pkg_name:  la.droid.qr.priva
# apk_path https://play.google.com/store/apps/details?id=la.droid.qr.priva
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'la.droid.qr.priva'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-196-----------------
# pkg_name:  pl.tweeba.mobile.learning.german
# apk_path https://play.google.com/store/apps/details?id=pl.tweeba.mobile.learning.german
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'pl.tweeba.mobile.learning.german'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-197-----------------
# pkg_name:  com.tizianhoesch.basel
# apk_path https://play.google.com/store/apps/details?id=com.tizianhoesch.basel
# 0
# Query filter: {'_id': 'com.tizianhoesch.basel'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-198-----------------
# pkg_name:  com.apptivateme.next.amc
# apk_path https://play.google.com/store/apps/details?id=com.apptivateme.next.amc
# 7
# support_array: ['Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.apptivateme.next.amc'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-199-----------------
# pkg_name:  com.justyoyo
# apk_path https://play.google.com/store/apps/details?id=com.justyoyo
# 0
# Query filter: {'_id': 'com.justyoyo'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-200-----------------
# pkg_name:  com.bambuna.podcastaddict
# apk_path https://play.google.com/store/apps/details?id=com.bambuna.podcastaddict
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.bambuna.podcastaddict'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-201-----------------
# pkg_name:  com.wingusoft.android.mapapp
# apk_path https://play.google.com/store/apps/details?id=com.wingusoft.android.mapapp
# 0
# Query filter: {'_id': 'com.wingusoft.android.mapapp'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-202-----------------
# pkg_name:  com.netbiscuits.kicker
# apk_path https://play.google.com/store/apps/details?id=com.netbiscuits.kicker
# 10
# support_array: ['Phone', 'Watch', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.netbiscuits.kicker'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-203-----------------
# pkg_name:  com.priceline.android.negotiator
# apk_path https://play.google.com/store/apps/details?id=com.priceline.android.negotiator
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.priceline.android.negotiator'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-204-----------------
# pkg_name:  com.ryosoftware.calendareventsnotifier
# apk_path https://play.google.com/store/apps/details?id=com.ryosoftware.calendareventsnotifier
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.ryosoftware.calendareventsnotifier'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-205-----------------
# pkg_name:  com.rauscha.apps.timesheet
# apk_path https://play.google.com/store/apps/details?id=com.rauscha.apps.timesheet
# 9
# support_array: ['Phone', 'Watch', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.rauscha.apps.timesheet'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-206-----------------
# pkg_name:  ie.radioplayer.android
# apk_path https://play.google.com/store/apps/details?id=ie.radioplayer.android
# APK not found
# Query filter: {'_id': 'ie.radioplayer.android'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-207-----------------
# pkg_name:  com.mobilexsoft.ezanvakti
# apk_path https://play.google.com/store/apps/details?id=com.mobilexsoft.ezanvakti
# 11
# support_array: ['Phone', 'Watch', 'TV', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.mobilexsoft.ezanvakti'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-208-----------------
# pkg_name:  com.gombosdev.ampere
# apk_path https://play.google.com/store/apps/details?id=com.gombosdev.ampere
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.gombosdev.ampere'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-209-----------------
# pkg_name:  com.apptivateme.next.ct
# apk_path https://play.google.com/store/apps/details?id=com.apptivateme.next.ct
# 0
# Query filter: {'_id': 'com.apptivateme.next.ct'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-210-----------------
# pkg_name:  fr.m6.m6replay
# apk_path https://play.google.com/store/apps/details?id=fr.m6.m6replay
# 0
# Query filter: {'_id': 'fr.m6.m6replay'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-211-----------------
# pkg_name:  com.parkwhiz.driverApp
# apk_path https://play.google.com/store/apps/details?id=com.parkwhiz.driverApp
# 0
# Query filter: {'_id': 'com.parkwhiz.driverApp'}
# Matched 1 document(s), updated 1 document(s).
# -----------------Loop-212-----------------
# pkg_name:  com.panaremote.view
# apk_path https://play.google.com/store/apps/details?id=com.panaremote.view
# 8
# support_array: ['Phone', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.panaremote.view'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-213-----------------
# pkg_name:  com.x3.angolotesti
# apk_path https://play.google.com/store/apps/details?id=com.x3.angolotesti
# 9
# support_array: ['Phone', 'TV', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.x3.angolotesti'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-214-----------------
# pkg_name:  com.bravolang.phrasebook
# apk_path https://play.google.com/store/apps/details?id=com.bravolang.phrasebook
# 9
# support_array: ['Phone', 'Chromebook', 'Tablet', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
# Query filter: {'_id': 'com.bravolang.phrasebook'}
# Documents matched but none were updated (maybe no fields were changed).
# Matched 1 document(s), updated 0 document(s).
# -----------------Loop-215-----------------
# pkg_name:  com.appestry.roku_remote_wear
# apk_path https://play.google.com/store/apps/details?id=com.appestry.roku_remote_wear
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_108300\3743495675.py in <module>
#      19     print("apk_path",apk_path)
#      20     web.get(apk_path)
# ---> 21     time.sleep(2)
#      22     #
#      23     try:
#
# KeyboardInterrupt:
